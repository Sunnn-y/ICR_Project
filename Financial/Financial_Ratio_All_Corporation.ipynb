# %% [markdown]
# # 재무비율

# %% [markdown]
# ## 안정성
# - 부채비율 : 부채총계/자본총계*100
# - 차입금의존도 : (단기차입금+유동성장기부채+사채+장기차입금)/자산총계*100
# - 고정장기적합률 : [비유동자산/(비유동부채+자본총계)]*100
# - 자기자본순이익률 : 당기순이익/[(전기 자본총계+자본총계)/2]

# %% [markdown]
# ## 수익성
# - 매출액영업이익률 : 영업이익/매출액
# - 매출액경상이익률 : 법인세비용차감전순이익(손실)/매출액
# - 이자보상배율(배) : 영업이익/금융비용
# - 금융비용부담률 : 매출액/이자비용 => **이자비용은 주석에서 가져와야함(방법 찾아보기)**
# - 순금융비용부담률 : 매출액/(이자비용-이자수익) => **이자비용, 이자수익은 주석에서 가져와야함(방법 찾아보기)**

# %% [markdown]
# ## 성장성
# - 매출액 증가율 : (매출액 - 전기 매출액)/전기 매출액
# - 총자산 증가율 : (자산총계-전기 자산총계)/전기 자산총계
# - 영업이익 증가율 : (영업이익-전기 영업이익)/전기 영업이익
# - 자기자본 증가율 : (자본총계-전기 자본총계)/자본총계

# %% [markdown]
# ## 활동성
# - 매출채권 회전기일(일) : 매출채권*회계기간/매출액
# - 재고자산회전기일(일) : 재고자산*회계기간/매출액
# - 매입채무 회전기일(일) : 매입채무*회계기간/매출액
# - 총자산회전율 : 매출액/자산총계

# %% [markdown]
# ## 현금흐름
# - 부채상환계수(배) : (영업활동으로 인한 현금흐름+금융비용)/(금융비용+단기차입금+유동성장기차입금)
# - 총차입금상환능력비율 : 영업활동으로 인한 현금흐름/(단기차입금+유동성장기차입금+장기차입금)

# %% [markdown]
# # 건설업계 전체 재무비율 계산
# - 크롤링할 기업 목록 <br>
# corp_name = ['DL이앤씨', 'HDC현대산업개발', '한전KPS', 'HJ중공업', '신세계건설', 'KCC건설', '대우건설', '서희건설', '특수건설', '계룡건설산업', '신원종합개발', '서한', '태영건설', '현대건설', 'GS건설', '동부건설', '코오롱글로벌', 'DL건설', '진흥기업', '남광토건', '한신공영', '금호건설', '삼부토건']
# <br>
# corp_code = ['375500', '294870', '051600', '097230', '034300', '021320', '047040', '035890', '026150', '013580', '017000', '011370', '009410', '000720', '006360', '005960', '003070', '001880', '002780', '001260', '004960', '002990', '001470']

# %%
# !pip install opendartreader
# Out:
# Collecting opendartreader
#   Downloading OpenDartReader-0.2.3-py3-none-any.whl (27 kB)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.10/dist-packages (from opendartreader) (1.5.3)
# Requirement already satisfied: requests>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from opendartreader) (2.31.0)
# Collecting requests-file (from opendartreader)
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from opendartreader) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from opendartreader) (4.11.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->opendartreader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->opendartreader) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19.2->opendartreader) (1.23.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->opendartreader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->opendartreader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->opendartreader) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.3.0->opendartreader) (2023.7.22)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->opendartreader) (2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from requests-file->opendartreader) (1.16.0)
# Installing collected packages: requests-file, opendartreader
# Successfully installed opendartreader-0.2.3 requests-file-1.5.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import OpenDartReader
my_api = "e9239b06215e8ff1addd0cc65d1b144a10af6d57"

dart = OpenDartReader(my_api)

# %%
import pandas as pd
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %% [markdown]
# ### 한전 KPS

# %%
corp_name = ['DL이앤씨', 'HDC현대산업개발', '한전KPS', 'HJ중공업', '신세계건설', 'KCC건설', '대우건설', '서희건설', '특수건설', '계룡건설산업', '신원종합개발',
             '서한', '태영건설', '현대건설', 'GS건설', '동부건설', '코오롱글로벌', 'DL건설', '진흥기업', '남광토건', '한신공영', '금호건설', '삼부토건']
corp_code = ['375500', '294870', '051600', '097230', '034300', '021320', '047040', '035890', '026150', '013580', '017000',
             '011370', '009410', '000720', '006360', '005960', '003070', '001880', '002780', '001260', '004960', '002990', '001470']
report_code = ["11013", "11012", "11014", "11011"] # '11013'=1분기보고서, '11012'=반기보고서, '11014'=3분기보고서, '11011'=사업보고서

corp_name_p = corp_name[2]
corp_code_p = corp_code[2]

all = pd.DataFrame()

for year in range(2019, 2023):
  for code in report_code:
    corp = dart.finstate_all(corp_code_p, year, code, fs_div="OFS")
    # corp = corp.drop('account_id', axis=1)
    all = pd.concat([all, corp], ignore_index=True) # 2019년~2022년 별도 재무제표 전문(분기보고서+반기보고서+사업보고서)

all
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import math
Quarter = [] # 분기
cor_year = [] # 연도
ID_list = [] # 기업코드
corp_name_list = [] # 기업명
year_list = [] # 수집 연도
report_code_list = [] # 보고서 종류
Debt_Ratio = [] # 부채비율
Debt_to_Asset_Ratio = [] # 차입금 의존도
Fixed_Asset_Turnover_Ratio = [] # 고정장기적합률
Return_on_Equity = [] # 자기자본순이익률
Operating_Profit_Margin = [] # 매출액영업이익률
Gross_Profit_Margin = [] # 매출액경상이익률
Interest_Coverage_Ratio =[] # 이자보상배율(배)
Sales_Growth_Rate = [] # 매출액증가율
Total_Asset_Growth_Rate = [] # 총자산 증가율
Operating_Profit_Growth_Rate = [] # 영업이익 증가율
Equity_Growth_Rate= [] # 자기자본 증가율
Accounts_Receivable_Turnover = [] # 매출채권회전기일(일)
Inventory_Turnover = [] # 재고자산회전기일(일)
Accounts_Payable_Turnover = [] # 매입채무회전기일(일)
Total_Asset_Turnover_Ratio = [] # 총자산 회전율
Debt_Service_Coverage_Ratio = [] # 부채상환계수
Debt_to_Equity_Ratio = [] # 총차입금 상환능력계수


for year in range(2020, 2023):
  str_year = str(year)
  report_code_list.extend(['1분기보고서' if code == '11013' else '반기보고서' if code == '11012' else '3분기보고서' if code == '11014' else '사업보고서' for code in report_code])
  Quarter.extend(['01' if code == '11013' else '02' if code == '11012' else '03' if code == '11014' else '04' for code in report_code])
  for code in report_code:
    BS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '자산총계' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자산총계
    BS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 부채총계
    BS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자본총계
    BS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '단기차입금' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 단기차입금
    BS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and ('유동성장기차입금' in row['account_nm'] or '유동성장기채무' in row['account_nm']) and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 유동성장기부채
    BS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '사채' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 사채
    BS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '장기차입금' in row['account_nm'] and '유동성' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 장기차입금
    BS8 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동자산' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동자산
    BS9 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동부채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동부채
    BS10 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자산총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자산총계
    BS11 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 부채총계
    BS12 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자본총계
    BS13 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매출채권' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매출채권
    BS14 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매입채무' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매입채무
    BS15 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '재고자산' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 재고자산

    IS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '포괄손익계산서' and '기순' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 당기순이익
    IS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업이익
    IS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '매출액' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 수익(매출액)
    IS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '법인세' in row['account_nm'] and '차감전' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 법인세비용차감전순이익(손실)
    IS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and (row['account_nm'] == '금융비용' or row['account_nm'] == '금융원가') and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 금융비용
    IS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '매출액' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 수익(매출액) # 분기 보고서만 해당
    IS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 영업이익 # 분기 보고서만 해당

    CF1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '현금흐름표' and row['account_nm'] == '영업활동현금흐름' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업활동으로 인한 현금흐름

    # if BS6 == BS7: # '사채 및 장기차입금'으로 계정과목 하나만 쓰는 회사는 합침(어차피 사채는 차입금 의존도에서만 사용해서 하나 0으로 만들어도 상관없음)
    #   BS6 = ['0']
    # if BS4 == BS5:
    #   BS4 = ['0'] # '단기차입금 및 유동성장기부채' 로 병합해서 쓰는 회사는 하나로 합침(어차피 둘이 항상 붙어서 계산해서 상관없음)
    if BS4 == [''] or BS4 == []: ## 한전 KPS는 전기간 차입금 없음
      BS4 = ['0']
    if BS5 == [''] or BS5 == []:
      BS5 = ['0']
    if BS6 == []:
      BS6 = ['0']
    if BS7 == [] or BS7 == ['']:
      BS7 = ['0']
    # if BS15 == [] or BS15 == ['']:
    #   BS15 = ['0']



    print("자산총계:", BS1, "부채총계:", BS2, "자본총계:", BS3, "단기차입금:", BS4, "유동성장기부채:", BS5, "사채:", BS6, "장기차입금:", BS7, "비유동자산:", BS8, "비유동부채:", BS9, "전기말 자산총계:", BS10, "전기말 부채총계:", BS11,
          "전기말 자본총계:", BS12, "매출채권:", BS13, "매입채무:", BS14, "재고자산:", BS15, "당기순이익:", IS1, "영업이익:", IS2, "수익(매출액):", IS3, "법인세비용차감전순이익(손실):", IS4,
          "금융비용:", IS5, "전기 수익(매출액):", IS6, "전기 영업이익:", IS7, "영업활동으로 인한 현금흐름:", CF1)

    if year != 2020:
      if code == "11013":
        accounting_period = 90
      elif code == "11012":
        accounting_period = 181
      elif code == "11014":
        accounting_period = 273
      elif code == "11011":
        accounting_period = 365
    else: # 2020년은 윤년
      if code == "11013":
        accounting_period = 91
      elif code == "11012":
        accounting_period = 182
      elif code == "11014":
        accounting_period = 274
      elif code == "11011":
        accounting_period = 366


    cor_year.extend([f"{corp_code_p}{str_year}"])
    corp_name_list.append(str(corp_name_p))
    year_list.append(str_year)
    Debt_Ratio.extend([int(BS2)/int(BS3)*100 for BS2, BS3 in zip(BS2, BS3)])
    Debt_to_Asset_Ratio.extend([((int(BS4) + int(BS5) + int(BS6) + int(BS7)) / int(BS1) * 100) for BS4, BS5, BS6, BS7, BS1 in zip(BS4, BS5, BS6, BS7, BS1)])
    Fixed_Asset_Turnover_Ratio.extend([int(BS8)/(int(BS9)+int(BS3))*100 for BS8, BS9, BS3 in zip(BS8, BS9, BS3)]),
    Return_on_Equity.extend([int(IS1)/((int(BS12)+int(BS3))/2) for IS1, BS12, BS3 in zip(IS1, BS12, BS3)])
    Operating_Profit_Margin.extend([int(IS2)/int(IS3) for IS2, IS3 in zip(IS2, IS3)])
    Gross_Profit_Margin.extend([int(IS4)/int(IS3) for IS4, IS3 in zip(IS4, IS3)])
    Interest_Coverage_Ratio.extend([int(IS2)/int(IS5) for IS2, IS5 in zip(IS2, IS5)])
    Sales_Growth_Rate.extend([(int(IS3)-int(IS6))/int(IS6) for IS3, IS6 in zip(IS3, IS6)])
    Total_Asset_Growth_Rate.extend([(int(BS1)-int(BS10))/int(BS10) for BS1, BS10 in zip(BS1, BS10)])
    Operating_Profit_Growth_Rate.extend([(int(IS2)-int(IS7))/int(IS7) for IS2, IS7 in zip(IS2, IS7)])
    Equity_Growth_Rate.extend([(int(BS3)-int(BS12))/int(BS12) for BS3, BS12 in zip(BS3, BS12)])
    Accounts_Receivable_Turnover.extend([int(BS13)/int(IS3)*accounting_period for BS13, IS3 in zip(BS13, IS3)])
    Inventory_Turnover.extend([int(BS15)/int(IS3)*accounting_period for BS15, IS3 in zip(BS15, IS3)])
    Accounts_Payable_Turnover.extend([int(BS14)/int(IS3)*accounting_period for BS14, IS3 in zip(BS14, IS3)])
    Total_Asset_Turnover_Ratio.extend([int(IS3)/int(BS1) for IS3, BS1 in zip(IS3, BS1)])
    Debt_Service_Coverage_Ratio.extend([(int(CF1)+int(IS5))/(int(BS4)+int(BS5)+int(IS5)) for CF1, IS5, BS4, BS5 in zip(CF1, IS5, BS4, BS5)])
    Debt_to_Equity_Ratio.extend([math.inf]) # 전 기간동안 차입금이 없으므로 총차입금상환능력비율은 항상 무한대
    # Debt_to_Equity_Ratio.extend([int(CF1)/(int(BS4)+int(BS7)+int(BS5)) for CF1, BS4, BS7, BS5 in zip(CF1, BS4, BS7, BS5)])

ID_list.extend([x+y for x,y in zip(cor_year,Quarter)])

financial_ratio = {
      '아이디':ID_list,
      '기업명':corp_name_list,
      '연도':year_list,
      '보고서 코드':report_code_list,
      '부채비율' : Debt_Ratio,
      '차입금의존도' : Debt_to_Asset_Ratio,
      '고정장기적합률':Fixed_Asset_Turnover_Ratio,
      '자기자본순이익률':Return_on_Equity,
      '매출액영업이익률':Operating_Profit_Margin,
      '매출액경상이익률':Gross_Profit_Margin,
      '이자보상배율(배)':Interest_Coverage_Ratio,
      '매출액 증가율':Sales_Growth_Rate,
      '총자산 증가율':Total_Asset_Growth_Rate,
      '영업이익 증가율':Operating_Profit_Growth_Rate,
      '자기자본 증가율':Equity_Growth_Rate,
      '매출채권 회전기일(일)':Equity_Growth_Rate,
      '재고자산 회전기일(일)':Accounts_Receivable_Turnover,
      '매입채무 회전기일(일)':Accounts_Payable_Turnover,
      '총자산 회전율':Total_Asset_Turnover_Ratio,
      '부채상환계수(배)':Debt_Service_Coverage_Ratio,
      '총차입금상환능력비율':Debt_to_Equity_Ratio
                    }

df = pd.DataFrame(financial_ratio)
df.set_index('아이디', inplace=True)

df
# Out:
# 자산총계: ['1366462025596'] 부채총계: ['355370968941'] 자본총계: ['1011091056655'] 단기차입금: ['0'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['0'] 비유동자산: ['601853248836'] 비유동부채: ['40548320519'] 전기말 자산총계: ['1311553986820'] 전기말 부채총계: ['400124509955'] 전기말 자본총계: ['911429476865'] 매출채권: ['405711716251'] 매입채무: ['148855930959'] 재고자산: ['1893826893'] 당기순이익: ['23085500523'] 영업이익: ['25452751594'] 수익(매출액): ['248918018946'] 법인세비용차감전순이익(손실): ['30308179445'] 금융비용: ['745454772'] 전기 수익(매출액): ['242676637970'] 전기 영업이익: ['18086767613'] 영업활동으로 인한 현금흐름: ['45193024365']
# 자산총계: ['1313395968632'] 부채총계: ['262559361773'] 자본총계: ['1050836606859'] 단기차입금: ['0'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['0'] 비유동자산: ['573039165851'] 비유동부채: ['52673896608'] 전기말 자산총계: ['1257659620077'] 전기말 부채총계: ['317191830671'] 전기말 자본총계: ['940467789406'] 매출채권: ['455026260656'] 매입채무: ['72641561600'] 재고자산: ['1775317874'] 당기순이익: ['41794088325'] 영업이익: ['35150117071'] 수익(매출액): ['327523913121'] 법인세비용차감전순이익(손실): ['54009365630'] 금융비용: ['749754388'] 전기 수익(매출액): ['327842843174'] 전기 영업이익: ['55648427946'] 영업활동으로 인한 현금흐름: ['45513751482']
# 자산총계: ['1354551120406'] 부채총계: ['322468020223'] 자본총계: ['1032083100183'] 단기차입금: ['0'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['0'] 비유동자산: ['595297875145'] 비유동부채: ['137730248082'] 전기말 자산총계: ['1321070645555'] 전기말 부채총계: ['339207989925'] 전기말 자본총계: ['981862655630'] 매출채권: ['467572265850'] 매입채무: ['74434968455'] 재고자산: ['7268155998'] 당기순이익: ['3125423741'] 영업이익: ['46926422186'] 수익(매출액): ['323479230455'] 법인세비용차감전순이익(손실): ['3364159990'] 금융비용: ['655369795'] 전기 수익(매출액): ['296026890536'] 전기 영업이익: ['52586393729'] 영업활동으로 인한 현금흐름: ['69791778132']
# 자산총계: ['1345856502080'] 부채총계: ['296515488793'] 자본총계: ['1049341013287'] 단기차입금: ['0'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['0'] 비유동자산: ['590402562643'] 비유동부채: ['42020018887'] 전기말 자산총계: ['1356983047578'] 전기말 부채총계: ['294756842806'] 전기말 자본총계: ['1062226204772'] 매출채권: ['493132175704'] 매입채무: ['78810254485'] 재고자산: ['23774630902'] 당기순이익: ['85916349175'] 영업이익: ['133341468799'] 수익(매출액): ['1299186315392'] 법인세비용차감전순이익(손실): ['110311590207'] 금융비용: ['4476892655'] 전기 수익(매출액): ['1244613357678'] 전기 영업이익: ['195254049849'] 영업활동으로 인한 현금흐름: ['74158850262']
# 자산총계: ['1384628831166'] 부채총계: ['335697316967'] 자본총계: ['1048931514199'] 단기차입금: ['0'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['0'] 비유동자산: ['614164399627'] 비유동부채: ['47775349528'] 전기말 자산총계: ['1366462025596'] 전기말 부채총계: ['355370968941'] 전기말 자본총계: ['1011091056655'] 매출채권: ['464598050507'] 매입채무: ['118543652888'] 재고자산: ['24082858428'] 당기순이익: ['44313299433'] 영업이익: ['56092245162'] 수익(매출액): ['320774177196'] 법인세비용차감전순이익(손실): ['59509626145'] 금융비용: ['574731422'] 전기 수익(매출액): ['248918018946'] 전기 영업이익: ['25452751594'] 영업활동으로 인한 현금흐름: ['50556767334']
# 자산총계: ['1381296556400'] 부채총계: ['304022433107'] 자본총계: ['1077274123293'] 단기차입금: ['0'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['0'] 비유동자산: ['590195876602'] 비유동부채: ['54820048149'] 전기말 자산총계: ['1313395968632'] 전기말 부채총계: ['262559361773'] 전기말 자본총계: ['1050836606859'] 매출채권: ['469083276713'] 매입채무: ['70754194908'] 재고자산: ['25121847072'] 당기순이익: ['32003674033'] 영업이익: ['36465571264'] 수익(매출액): ['367661188248'] 법인세비용차감전순이익(손실): ['41468200195'] 금융비용: ['730419001'] 전기 수익(매출액): ['327523913121'] 전기 영업이익: ['35150117071'] 영업활동으로 인한 현금흐름: ['106167635422']
# 자산총계: ['1405728084933'] 부채총계: ['294806541319'] 자본총계: ['1110921543614'] 단기차입금: ['0'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['0'] 비유동자산: ['600193259757'] 비유동부채: ['49825610645'] 전기말 자산총계: ['1354551120406'] 전기말 부채총계: ['322468020223'] 전기말 자본총계: ['1032083100183'] 매출채권: ['476711618245'] 매입채무: ['67726151254'] 재고자산: ['24015863185'] 당기순이익: ['25540265281'] 영업이익: ['29784105890'] 수익(매출액): ['309491945817'] 법인세비용차감전순이익(손실): ['32870984894'] 금융비용: ['516754214'] 전기 수익(매출액): ['323479230455'] 전기 영업이익: ['46926422186'] 영업활동으로 인한 현금흐름: ['130794806243']
# 자산총계: ['1420704554677'] 부채총계: ['311607019426'] 자본총계: ['1109097535251'] 단기차입금: ['0'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['0'] 비유동자산: ['626709451082'] 비유동부채: ['46589580926'] 전기말 자산총계: ['1345856502080'] 전기말 부채총계: ['296515488793'] 전기말 자본총계: ['1049341013287'] 매출채권: ['507239480297'] 매입채무: ['80273488259'] 재고자산: ['23925933647'] 당기순이익: ['98132045813'] 영업이익: ['124062281831'] 수익(매출액): ['1375667684487'] 법인세비용차감전순이익(손실): ['134803513930'] 금융비용: ['3676372606'] 전기 수익(매출액): ['1299186315392'] 전기 영업이익: ['133341468799'] 영업활동으로 인한 현금흐름: ['133160131419']
# 자산총계: ['1465747260089'] 부채총계: ['376657046654'] 자본총계: ['1089090213435'] 단기차입금: ['0'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['0'] 비유동자산: ['651950883525'] 비유동부채: ['39144764298'] 전기말 자산총계: ['1384628831166'] 전기말 부채총계: ['335697316967'] 전기말 자본총계: ['1048931514199'] 매출채권: ['445910332230'] 매입채무: ['138005597944'] 재고자산: ['23708733716'] 당기순이익: ['20706647805'] 영업이익: ['22039052636'] 수익(매출액): ['302211679010'] 법인세비용차감전순이익(손실): ['26382109889'] 금융비용: ['479302811'] 전기 수익(매출액): ['320774177196'] 전기 영업이익: ['56092245162'] 영업활동으로 인한 현금흐름: ['71851707832']
# 자산총계: ['1456342669323'] 부채총계: ['329460733361'] 자본총계: ['1126881935962'] 단기차입금: ['0'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['0'] 비유동자산: ['667085736438'] 비유동부채: ['29667284324'] 전기말 자산총계: ['1381296556400'] 전기말 부채총계: ['304022433107'] 전기말 자본총계: ['1077274123293'] 매출채권: ['565191733942'] 매입채무: ['97238885370'] 재고자산: ['23411557483'] 당기순이익: ['23552458164'] 영업이익: ['28434361655'] 수익(매출액): ['385000636557'] 법인세비용차감전순이익(손실): ['31785575046'] 금융비용: ['883446840'] 전기 수익(매출액): ['367661188248'] 전기 영업이익: ['36465571264'] 영업활동으로 인한 현금흐름: ['7286738822']
# 자산총계: ['1488654490141'] 부채총계: ['313946693897'] 자본총계: ['1174707796244'] 단기차입금: ['0'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['0'] 비유동자산: ['668890099014'] 비유동부채: ['19583977439'] 전기말 자산총계: ['1405728084933'] 전기말 부채총계: ['294806541319'] 전기말 자본총계: ['1110921543614'] 매출채권: ['597674739782'] 매입채무: ['88444313049'] 재고자산: ['23703182374'] 당기순이익: ['23759387129'] 영업이익: ['30897198696'] 수익(매출액): ['341078416382'] 법인세비용차감전순이익(손실): ['31735584275'] 금융비용: ['572307120'] 전기 수익(매출액): ['309491945817'] 전기 영업이익: ['29784105890'] 영업활동으로 인한 현금흐름: ['16253296659']
# 자산총계: ['1555452523571'] 부채총계: ['344701529038'] 자본총계: ['1210750994533'] 단기차입금: ['0'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['0'] 비유동자산: ['693747301304'] 비유동부채: ['28204538467'] 전기말 자산총계: ['1420704554677'] 전기말 부채총계: ['311607019426'] 전기말 자본총계: ['1109097535251'] 매출채권: ['599686933538'] 매입채무: ['84925769503'] 재고자산: ['28749107474'] 당기순이익: ['97880999513'] 영업이익: ['129378141917'] 수익(매출액): ['1425913324444'] 법인세비용차감전순이익(손실): ['132127374475'] 금융비용: ['2996077709'] 전기 수익(매출액): ['1375667684487'] 전기 영업이익: ['124062281831'] 영업활동으로 인한 현금흐름: ['81418805017']
#                 기업명    연도  보고서 코드       부채비율  차입금의존도    고정장기적합률  자기자본순이익률  \
# 아이디
# 051600202001  한전KPS  2020  1분기보고서  35.147276     0.0  57.230003  0.024016
# 051600202002  한전KPS  2020   반기보고서  24.985746     0.0  51.928746  0.041977
# 051600202003  한전KPS  2020  3분기보고서  31.244385     0.0  50.888279  0.003104
# 051600202004  한전KPS  2020   사업보고서  28.257305     0.0  54.097823  0.081377
# 051600202101  한전KPS  2021  1분기보고서  32.003740     0.0  56.000780  0.043022
# 051600202102  한전KPS  2021   반기보고서  28.221455     0.0  52.133108  0.030077
# 051600202103  한전KPS  2021  3분기보고서  26.537116     0.0  51.707494  0.023836
# 051600202104  한전KPS  2021   사업보고서  28.095547     0.0  54.228298  0.090929
# 051600202201  한전KPS  2022  1분기보고서  34.584559     0.0  57.785027  0.019370
# 051600202202  한전KPS  2022   반기보고서  29.236491     0.0  57.678975  0.021371
# 051600202203  한전KPS  2022  3분기보고서  26.725514     0.0  56.007260  0.020790
# 051600202204  한전KPS  2022   사업보고서  28.470060     0.0  55.994528  0.084386
#
#               매출액영업이익률  매출액경상이익률  이자보상배율(배)   매출액 증가율   총자산 증가율  영업이익 증가율  \
# 아이디
# 051600202001  0.102254  0.121760  34.143925  0.025719  0.041865  0.407258
# 051600202002  0.107321  0.164902  46.882176 -0.000973  0.044318 -0.368354
# 051600202003  0.145068  0.010400  71.602968  0.092736  0.025343 -0.107632
# 051600202004  0.102635  0.084908  29.784379  0.043847 -0.008199 -0.317087
# 051600202101  0.174865  0.185519  97.597318  0.288674  0.013295  1.203779
# 051600202102  0.099183  0.112789  49.924182  0.122548  0.051698  0.037424
# 051600202103  0.096235  0.106210  57.636890 -0.043240  0.037781 -0.365302
# 051600202104  0.090183  0.097991  33.745840  0.058869  0.055614 -0.069590
# 051600202201  0.072926  0.087297  45.981480 -0.057868  0.058585 -0.607093
# 051600202202  0.073855  0.082560  32.185708  0.047161  0.054330 -0.220241
# 051600202203  0.090587  0.093045  53.987095  0.102059  0.058992  0.037372
# 051600202204  0.090734  0.092662  43.182505  0.036525  0.094846  0.042848
#
#               자기자본 증가율  매출채권 회전기일(일)  재고자산 회전기일(일)  매입채무 회전기일(일)   총자산 회전율  \
# 아이디
# 051600202001  0.109346      0.109346    148.320987     54.419081  0.182162
# 051600202002  0.117355      0.117355    252.851093     40.365798  0.249372
# 051600202003  0.051148      0.051148    396.052633     63.049431  0.238809
# 051600202004 -0.012130     -0.012130    138.922627     22.202014  0.965323
# 051600202101  0.037425      0.037425    130.352839     33.259936  0.231668
# 051600202102  0.025159      0.025159    230.930204     34.832367  0.266171
# 051600202103  0.076388      0.076388    420.502936     59.740615  0.220165
# 051600202104  0.056947      0.056947    134.583673     21.298620  0.968300
# 051600202201  0.038285      0.038285    132.794107     41.098689  0.206183
# 051600202202  0.046049      0.046049    265.713077     45.714829  0.264361
# 051600202203  0.057417      0.057417    478.380326     70.791045  0.229119
# 051600202204  0.091654      0.091654    153.505635     21.738983  0.916719
#
#                부채상환계수(배)  총차입금상환능력비율
# 아이디
# 051600202001   61.624770         inf
# 051600202002   61.704882         inf
# 051600202003  107.492210         inf
# 051600202004   17.564804         inf
# 051600202101   88.965901         inf
# 051600202102  146.351689         inf
# 051600202103  254.108350         inf
# 051600202104   37.220521         inf
# 051600202201  150.908797         inf
# 051600202202    9.248078         inf
# 051600202203   29.399606         inf
# 051600202204   28.175131         inf

# %%
df.to_csv(f'/content/drive/MyDrive/ICR/재무비율/{corp_name_p}_재무비율.csv')

# %% [markdown]
# ### 신세계 건설

# %%
corp_name = ['DL이앤씨', 'HDC현대산업개발', '한전KPS', 'HJ중공업', '신세계건설', 'KCC건설', '대우건설', '서희건설', '특수건설', '계룡건설산업', '신원종합개발',
             '서한', '태영건설', '현대건설', 'GS건설', '동부건설', '코오롱글로벌', 'DL건설', '진흥기업', '남광토건', '한신공영', '금호건설', '삼부토건']
corp_code = ['375500', '294870', '051600', '097230', '034300', '021320', '047040', '035890', '026150', '013580', '017000',
             '011370', '009410', '000720', '006360', '005960', '003070', '001880', '002780', '001260', '004960', '002990', '001470']
report_code = ["11013", "11012", "11014", "11011"] # '11013'=1분기보고서, '11012'=반기보고서, '11014'=3분기보고서, '11011'=사업보고서

corp_name_p = corp_name[4]
corp_code_p = corp_code[4]

all = pd.DataFrame()

for year in range(2019, 2023):
  for code in report_code:
    corp = dart.finstate_all(corp_code_p, year, code, fs_div="OFS")
    # corp = corp.drop('account_id', axis=1)
    all = pd.concat([all, corp], ignore_index=True) # 2019년~2022년 별도 재무제표 전문(분기보고서+반기보고서+사업보고서)

all
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
Quarter = []
cor_year = []
ID_list = []
corp_name_list = []
year_list = []
report_code_list = []
Debt_Ratio = []
Debt_to_Asset_Ratio = []
Fixed_Asset_Turnover_Ratio = []
Return_on_Equity = []
Operating_Profit_Margin = []
Gross_Profit_Margin = []
Interest_Coverage_Ratio =[]
Sales_Growth_Rate = []
Total_Asset_Growth_Rate = []
Operating_Profit_Growth_Rate = []
Equity_Growth_Rate= []
Accounts_Receivable_Turnover = []
Inventory_Turnover = []
Accounts_Payable_Turnover = []
Total_Asset_Turnover_Ratio = []
Debt_Service_Coverage_Ratio = []
Debt_to_Equity_Ratio = []


for year in range(2020, 2023):
  str_year = str(year)
  report_code_list.extend(['1분기보고서' if code == '11013' else '반기보고서' if code == '11012' else '3분기보고서' if code == '11014' else '사업보고서' for code in report_code])
  Quarter.extend(['01' if code == '11013' else '02' if code == '11012' else '03' if code == '11014' else '04' for code in report_code])
  for code in report_code:
    BS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '자산총계' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자산총계
    BS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 부채총계
    BS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자본총계
    BS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '단기차입금' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 단기차입금
    BS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and ('유동성장기차입금' in row['account_nm'] or '유동성장기채무' in row['account_nm']) and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 유동성장기부채
    BS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '사채' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 사채
    BS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '장기차입금' in row['account_nm'] and '유동성' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 장기차입금
    BS8 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동자산' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동자산
    BS9 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동부채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동부채
    BS10 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자산총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자산총계
    BS11 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 부채총계
    BS12 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and (row['account_nm'] == '자본총계' or '기말자본' in row['account_nm']) and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자본총계
    BS13 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매출채권' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매출채권
    BS14 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매입채무' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매입채무
    BS15 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '재고자산' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 재고자산

    IS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '포괄손익계산서' and '기순' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 당기순이익
    IS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업이익
    IS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '매출액' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 수익(매출액)
    IS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '법인세' in row['account_nm'] and '차감전' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 법인세비용차감전순이익(손실)
    IS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and (row['account_nm'] == '금융비용' or row['account_nm'] == '금융원가') and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 금융비용
    IS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '매출액' in row['account_nm'] and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 수익(매출액) # 분기 보고서만 해당
    IS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 영업이익 # 분기 보고서만 해당

    CF1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '현금흐름표' and row['account_nm'] == '영업활동현금흐름' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업활동으로 인한 현금흐름

    # if BS6 == BS7: # '사채 및 장기차입금'으로 계정과목 하나만 쓰는 회사는 합침(어차피 사채는 차입금 의존도에서만 사용해서 하나 0으로 만들어도 상관없음)
    #   BS6 = ['0']
    # if BS4 == BS5:
    #   BS4 = ['0'] # '단기차입금 및 유동성장기부채' 로 병합해서 쓰는 회사는 하나로 합침(어차피 둘이 항상 붙어서 계산해서 상관없음)
    # if BS4 == [''] or BS4 == []:
    #   BS4 = ['0']
    if BS5 == [''] or BS5 == []: # 신세계건설은 장기차입금이 2022년에만 있어서 3년동안 유동성 장기차입금은 없었음
      BS5 = ['0']
    # if BS6 == []:
    #   BS6 = ['0']
    if BS7 == [] or BS7 == ['']:
      BS7 = ['0']
    # if BS15 == [] or BS15 == ['']:
    #   BS15 = ['0']
    if len(BS6) >= 2:
      BS6 = [str(BS6[0])]

    print("자산총계:", BS1, "부채총계:", BS2, "자본총계:", BS3, "단기차입금:", BS4, "유동성장기부채:", BS5, "사채:", BS6, "장기차입금:", BS7, "비유동자산:", BS8, "비유동부채:", BS9, "전기말 자산총계:", BS10, "전기말 부채총계:", BS11,
          "전기말 자본총계:", BS12, "매출채권:", BS13, "매입채무:", BS14, "재고자산:", BS15, "당기순이익:", IS1, "영업이익:", IS2, "수익(매출액):", IS3, "법인세비용차감전순이익(손실):", IS4,
          "금융비용:", IS5, "전기 수익(매출액):", IS6, "전기 영업이익:", IS7, "영업활동으로 인한 현금흐름:", CF1)

    if year != 2020:
      if code == "11013":
        accounting_period = 90
      elif code == "11012":
        accounting_period = 181
      elif code == "11014":
        accounting_period = 273
      elif code == "11011":
        accounting_period = 365
    else: # 2020년은 윤년
      if code == "11013":
        accounting_period = 91
      elif code == "11012":
        accounting_period = 182
      elif code == "11014":
        accounting_period = 274
      elif code == "11011":
        accounting_period = 366


    cor_year.extend([f"{corp_code_p}{str_year}"])
    corp_name_list.append(str(corp_name_p))
    year_list.append(str_year)
    Debt_Ratio.extend([int(BS2)/int(BS3)*100 for BS2, BS3 in zip(BS2, BS3)])
    Debt_to_Asset_Ratio.extend([((int(BS4) + int(BS5) + int(BS6) + int(BS7)) / int(BS1) * 100) for BS4, BS5, BS6, BS7, BS1 in zip(BS4, BS5, BS6, BS7, BS1)])
    Fixed_Asset_Turnover_Ratio.extend([int(BS8)/(int(BS9)+int(BS3))*100 for BS8, BS9, BS3 in zip(BS8, BS9, BS3)]),
    Return_on_Equity.extend([int(IS1)/((int(BS12)+int(BS3))/2) for IS1, BS12, BS3 in zip(IS1, BS12, BS3)])
    Operating_Profit_Margin.extend([int(IS2)/int(IS3) for IS2, IS3 in zip(IS2, IS3)])
    Gross_Profit_Margin.extend([int(IS4)/int(IS3) for IS4, IS3 in zip(IS4, IS3)])
    Interest_Coverage_Ratio.extend([int(IS2)/int(IS5) for IS2, IS5 in zip(IS2, IS5)])
    Sales_Growth_Rate.extend([(int(IS3)-int(IS6))/int(IS6) for IS3, IS6 in zip(IS3, IS6)])
    Total_Asset_Growth_Rate.extend([(int(BS1)-int(BS10))/int(BS10) for BS1, BS10 in zip(BS1, BS10)])
    Operating_Profit_Growth_Rate.extend([(int(IS2)-int(IS7))/int(IS7) for IS2, IS7 in zip(IS2, IS7)])
    Equity_Growth_Rate.extend([(int(BS3)-int(BS12))/int(BS12) for BS3, BS12 in zip(BS3, BS12)])
    Accounts_Receivable_Turnover.extend([int(BS13)/int(IS3)*accounting_period for BS13, IS3 in zip(BS13, IS3)])
    Inventory_Turnover.extend([int(BS15)/int(IS3)*accounting_period for BS15, IS3 in zip(BS15, IS3)])
    Accounts_Payable_Turnover.extend([int(BS14)/int(IS3)*accounting_period for BS14, IS3 in zip(BS14, IS3)])
    Total_Asset_Turnover_Ratio.extend([int(IS3)/int(BS1) for IS3, BS1 in zip(IS3, BS1)])
    Debt_Service_Coverage_Ratio.extend([(int(CF1)+int(IS5))/(int(BS4)+int(BS5)+int(IS5)) for CF1, IS5, BS4, BS5 in zip(CF1, IS5, BS4, BS5)])
    Debt_to_Equity_Ratio.extend([int(CF1)/(int(BS4)+int(BS7)+int(BS5)) for CF1, BS4, BS7, BS5 in zip(CF1, BS4, BS7, BS5)])

ID_list.extend([x+y for x,y in zip(cor_year,Quarter)])

financial_ratio = {
      '아이디':ID_list,
      '기업명':corp_name_list,
      '연도':year_list,
      '보고서 코드':report_code_list,
      '부채비율' : Debt_Ratio,
      '차입금의존도' : Debt_to_Asset_Ratio,
      '고정장기적합률':Fixed_Asset_Turnover_Ratio,
      '자기자본순이익률':Return_on_Equity,
      '매출액영업이익률':Operating_Profit_Margin,
      '매출액경상이익률':Gross_Profit_Margin,
      '이자보상배율(배)':Interest_Coverage_Ratio,
      '매출액 증가율':Sales_Growth_Rate,
      '총자산 증가율':Total_Asset_Growth_Rate,
      '영업이익 증가율':Operating_Profit_Growth_Rate,
      '자기자본 증가율':Equity_Growth_Rate,
      '매출채권 회전기일(일)':Equity_Growth_Rate,
      '재고자산 회전기일(일)':Accounts_Receivable_Turnover,
      '매입채무 회전기일(일)':Accounts_Payable_Turnover,
      '총자산 회전율':Total_Asset_Turnover_Ratio,
      '부채상환계수(배)':Debt_Service_Coverage_Ratio,
      '총차입금상환능력비율':Debt_to_Equity_Ratio
                    }

df = pd.DataFrame(financial_ratio)
df.set_index('아이디', inplace=True)

df
# Out:
# 자산총계: ['759123761895'] 부채총계: ['563466289686'] 자본총계: ['195657472209'] 단기차입금: ['1500000000'] 유동성장기부채: ['0'] 사채: ['1000000000'] 장기차입금: ['0'] 비유동자산: ['404427864833'] 비유동부채: ['49285552640'] 전기말 자산총계: ['747311703980'] 전기말 부채총계: ['552237777767'] 전기말 자본총계: ['195073926213'] 매출채권: ['138387848454'] 매입채무: ['121312542778'] 재고자산: ['61370113091'] 당기순이익: ['1676401265'] 영업이익: ['4843000620'] 수익(매출액): ['227517292839'] 법인세비용차감전순이익(손실): ['1728153876'] 금융비용: ['923776040'] 전기 수익(매출액): ['217768505969'] 전기 영업이익: ['5093202126'] 영업활동으로 인한 현금흐름: ['40745237707']
# 자산총계: ['788973048294'] 부채총계: ['591068620696'] 자본총계: ['197904427598'] 단기차입금: ['1500000000'] 유동성장기부채: ['0'] 사채: ['1000000000'] 장기차입금: ['0'] 비유동자산: ['408284496973'] 비유동부채: ['49591374080'] 전기말 자산총계: ['782319878085'] 전기말 부채총계: ['599574407014'] 전기말 자본총계: ['182745471071'] 매출채권: ['157141939043'] 매입채무: ['141739430484'] 재고자산: ['67289094829'] 당기순이익: ['2646955389'] 영업이익: ['3548879610'] 수익(매출액): ['264740027535'] 법인세비용차감전순이익(손실): ['3329399524'] 금융비용: ['556660588'] 전기 수익(매출액): ['265214608386'] 전기 영업이익: ['-1968345189'] 영업활동으로 인한 현금흐름: ['59116450180']
# 자산총계: ['796496957212'] 부채총계: ['597703761292'] 자본총계: ['198793195920'] 단기차입금: ['1500000000'] 유동성장기부채: ['0'] 사채: ['1000000000'] 장기차입금: ['0'] 비유동자산: ['417378784086'] 비유동부채: ['67406851873'] 전기말 자산총계: ['793574396135'] 전기말 부채총계: ['599996980668'] 전기말 자본총계: ['193577415467'] 매출채권: ['138917273650'] 매입채무: ['99391373588'] 재고자산: ['64308780979'] 당기순이익: ['1288768322'] 영업이익: ['7581819519'] 수익(매출액): ['206426979101'] 법인세비용차감전순이익(손실): ['4515504683'] 금융비용: ['389842929'] 전기 수익(매출액): ['265345873182'] 전기 영업이익: ['14482217486'] 영업활동으로 인한 현금흐름: ['67816028197']
# 자산총계: ['765614223582'] 부채총계: ['563223277347'] 자본총계: ['202390946235'] 단기차입금: ['1500000000'] 유동성장기부채: ['0'] 사채: ['1000000000'] 장기차입금: ['0'] 비유동자산: ['421822899485'] 비유동부채: ['63230463378'] 전기말 자산총계: ['777742155728'] 전기말 부채총계: ['580161084784'] 전기말 자본총계: ['197581070944'] 매출채권: ['165200890257'] 매입채무: ['94596770113'] 재고자산: ['66620352505'] 당기순이익: ['12230772753'] 영업이익: ['20641628975'] 수익(매출액): ['956756075135'] 법인세비용차감전순이익(손실): ['14776013269'] 금융비용: ['2100538910'] 전기 수익(매출액): ['1016153925439'] 전기 영업이익: ['24238315742'] 영업활동으로 인한 현금흐름: ['36253398255']
# 자산총계: ['837563108842'] 부채총계: ['632700818714'] 자본총계: ['204862290128'] 단기차입금: ['1500000000'] 유동성장기부채: ['0'] 사채: ['1000000000'] 장기차입금: ['0'] 비유동자산: ['424234193767'] 비유동부채: ['63124027497'] 전기말 자산총계: ['759123761895'] 전기말 부채총계: ['563466289686'] 전기말 자본총계: ['195657472209'] 매출채권: ['115639347358'] 매입채무: ['131790638600'] 재고자산: ['50488792932'] 당기순이익: ['6071343893'] 영업이익: ['9428623422'] 수익(매출액): ['260327920636'] 법인세비용차감전순이익(손실): ['7666688162'] 금융비용: ['440252445'] 전기 수익(매출액): ['227517292839'] 전기 영업이익: ['4843000620'] 영업활동으로 인한 현금흐름: ['111290078867']
# 자산총계: ['913951201533'] 부채총계: ['696772685844'] 자본총계: ['217178515689'] 단기차입금: ['1500000000'] 유동성장기부채: ['0'] 사채: ['1000000000'] 장기차입금: ['0'] 비유동자산: ['430488106850'] 비유동부채: ['63017693767'] 전기말 자산총계: ['788973048294'] 전기말 부채총계: ['591068620696'] 전기말 자본총계: ['197904427598'] 매출채권: ['211243950553'] 매입채무: ['182330962948'] 재고자산: ['36983541710'] 당기순이익: ['12716225561'] 영업이익: ['15443170774'] 수익(매출액): ['355294244901'] 법인세비용차감전순이익(손실): ['15997383624'] 금융비용: ['261863211'] 전기 수익(매출액): ['264740027535'] 전기 영업이익: ['3548879610'] 영업활동으로 인한 현금흐름: ['121395758121']
# 자산총계: ['802961708757'] 부채총계: ['580200861710'] 자본총계: ['222760847047'] 단기차입금: ['1500000000'] 유동성장기부채: ['0'] 사채: ['1000000000'] 장기차입금: ['0'] 비유동자산: ['429888284890'] 비유동부채: ['65545517181'] 전기말 자산총계: ['796496957212'] 전기말 부채총계: ['597703761292'] 전기말 자본총계: ['198793195920'] 매출채권: ['81076756976'] 매입채무: ['95871129592'] 재고자산: ['34165329345'] 당기순이익: ['5982331358'] 영업이익: ['10976373704'] 수익(매출액): ['286696656477'] 법인세비용차감전순이익(손실): ['7617830121'] 금융비용: ['364481086'] 전기 수익(매출액): ['206426979101'] 전기 영업이익: ['7581819519'] 영업활동으로 인한 현금흐름: ['155110273395']
# 자산총계: ['828998344092'] 부채총계: ['602860755820'] 자본총계: ['226137588272'] 단기차입금: ['1500000000'] 유동성장기부채: ['0'] 사채: ['1000000000'] 장기차입금: ['0'] 비유동자산: ['444475314195'] 비유동부채: ['59828268962'] 전기말 자산총계: ['765614223582'] 전기말 부채총계: ['563223277347'] 전기말 자본총계: ['202390946235'] 매출채권: ['202831372072'] 매입채무: ['120566505107'] 재고자산: ['40276891921'] 당기순이익: ['26155222476'] 영업이익: ['38439659645'] 수익(매출액): ['1256750439597'] 법인세비용차감전순이익(손실): ['32853966508'] 금융비용: ['3466311024'] 전기 수익(매출액): ['956756075135'] 전기 영업이익: ['20641628975'] 영업활동으로 인한 현금흐름: ['76930608740']
# 자산총계: ['781063191939'] 부채총계: ['556395924824'] 자본총계: ['224667267115'] 단기차입금: ['1500000000'] 유동성장기부채: ['0'] 사채: ['1000000000'] 장기차입금: ['0'] 비유동자산: ['462925222994'] 비유동부채: ['60292308307'] 전기말 자산총계: ['837563108842'] 전기말 부채총계: ['632700818714'] 전기말 자본총계: ['204862290128'] 매출채권: ['67777926969'] 매입채무: ['95111714257'] 재고자산: ['37547003380'] 당기순이익: ['2329678843'] 영업이익: ['1486209396'] 수익(매출액): ['253498039594'] 법인세비용차감전순이익(손실): ['2770217579'] 금융비용: ['499502490'] 전기 수익(매출액): ['260327920636'] 전기 영업이익: ['9428623422'] 영업활동으로 인한 현금흐름: ['55843893016']
# 자산총계: ['904981506565'] 부채총계: ['684922312940'] 자본총계: ['220059193625'] 단기차입금: ['1500000000'] 유동성장기부채: ['0'] 사채: ['1000000000'] 장기차입금: ['0'] 비유동자산: ['458860802761'] 비유동부채: ['59523085685'] 전기말 자산총계: ['913951201533'] 전기말 부채총계: ['696772685844'] 전기말 자본총계: ['217178515689'] 매출채권: ['257041203893'] 매입채무: ['192640395023'] 재고자산: ['40722847721'] 당기순이익: ['5896416510'] 영업이익: ['5630211239'] 수익(매출액): ['395953984238'] 법인세비용차감전순이익(손실): ['7265660440'] 금융비용: ['300618417'] 전기 수익(매출액): ['355294244901'] 전기 영업이익: ['15443170774'] 영업활동으로 인한 현금흐름: ['30597259981']
# 자산총계: ['794808507730'] 부채총계: ['571474367090'] 자본총계: ['223334140640'] 단기차입금: ['1500000000'] 유동성장기부채: ['0'] 사채: ['1000000000'] 장기차입금: ['0'] 비유동자산: ['455180482976'] 비유동부채: ['49298962300'] 전기말 자산총계: ['802961708757'] 전기말 부채총계: ['580200861710'] 전기말 자본총계: ['222760847047'] 매출채권: ['133871286154'] 매입채무: ['114554778614'] 재고자산: ['31977007545'] 당기순이익: ['3679947015'] 영업이익: ['6550085088'] 수익(매출액): ['345482814041'] 법인세비용차감전순이익(손실): ['4600248481'] 금융비용: ['472868752'] 전기 수익(매출액): ['286696656477'] 전기 영업이익: ['10976373704'] 영업활동으로 인한 현금흐름: ['32928457447']
# 자산총계: ['1035610953877'] 부채총계: ['751891779268'] 자본총계: ['283719174609'] 단기차입금: ['51500000000'] 유동성장기부채: ['0'] 사채: ['1000000000'] 장기차입금: ['4200000000'] 비유동자산: ['553010079325'] 비유동부채: ['71310791516'] 전기말 자산총계: ['828998344092'] 전기말 부채총계: ['602860755820'] 전기말 자본총계: ['226137588272'] 매출채권: ['316548663571'] 매입채무: ['205111018588'] 재고자산: ['31687209612'] 당기순이익: ['-14219380450'] 영업이익: ['-12042239735'] 수익(매출액): ['1432384948018'] 법인세비용차감전순이익(손실): ['-17714387020'] 금융비용: ['5326181225'] 전기 수익(매출액): ['1256750439597'] 전기 영업이익: ['38439659645'] 영업활동으로 인한 현금흐름: ['-17815307615']
#                 기업명    연도  보고서 코드        부채비율    차입금의존도     고정장기적합률  자기자본순이익률  \
# 아이디
# 034300202001  신세계건설  2020  1분기보고서  287.986083  0.329327  165.110995  0.008581
# 034300202002  신세계건설  2020   반기보고서  298.663667  0.316868  164.966231  0.013908
# 034300202003  신세계건설  2020  3분기보고서  300.666106  0.313874  156.791401  0.006569
# 034300202004  신세계건설  2020   사업보고서  278.284818  0.326535  158.806062  0.061158
# 034300202101  신세계건설  2021  1분기보고서  308.842012  0.298485  158.304423  0.030317
# 034300202102  신세계건설  2021   반기보고서  320.829472  0.273538  153.638091  0.061271
# 034300202103  신세계건설  2021  3분기보고서  260.459084  0.311347  149.108150  0.028382
# 034300202104  신세계건설  2021   사업보고서  266.590247  0.301569  155.429504  0.122070
# 034300202201  신세계건설  2022  1분기보고서  247.653311  0.320077  162.452945  0.010848
# 034300202202  신세계건설  2022   반기보고서  311.244580  0.276249  164.123708  0.026971
# 034300202203  신세계건설  2022  3분기보고서  255.883120  0.314541  166.957159  0.016498
# 034300202204  신세계건설  2022   사업보고서  265.012677  5.475029  155.764339 -0.055778
#
#               매출액영업이익률  매출액경상이익률  이자보상배율(배)   매출액 증가율   총자산 증가율  영업이익 증가율  \
# 아이디
# 034300202001  0.021286  0.007596   5.242613  0.044767  0.015806 -0.049125
# 034300202002  0.013405  0.012576   6.375302 -0.001789  0.008504 -2.802976
# 034300202003  0.036729  0.021875  19.448396 -0.222046  0.003683 -0.476474
# 034300202004  0.021575  0.015444   9.826825 -0.058454 -0.015594 -0.148388
# 034300202101  0.036218  0.029450  21.416402  0.144212  0.103329  0.946856
# 034300202102  0.043466  0.045026  58.974190  0.342050  0.158406  3.351562
# 034300202103  0.038286  0.026571  30.115071  0.388853  0.008116  0.447723
# 034300202104  0.030587  0.026142  11.089501  0.313554  0.082789  0.862240
# 034300202201  0.005863  0.010928   2.975379 -0.026236 -0.067458 -0.842373
# 034300202202  0.014219  0.018350  18.728764  0.114440 -0.009814 -0.635424
# 034300202203  0.018959  0.013315  13.851804  0.205047 -0.010154 -0.403256
# 034300202204 -0.008407 -0.012367  -2.260952  0.139753  0.249232 -1.313276
#
#               자기자본 증가율  매출채권 회전기일(일)  재고자산 회전기일(일)  매입채무 회전기일(일)   총자산 회전율  \
# 아이디
# 034300202001  0.002991      0.002991     55.350932     48.521329  0.299710
# 034300202002  0.082951      0.082951    108.029878     97.441164  0.335550
# 034300202003  0.026944      0.026944    184.391271    131.926730  0.259169
# 034300202004  0.024344      0.024344     63.196386     36.187299  1.249658
# 034300202101  0.047046      0.047046     39.978583     45.562372  0.310816
# 034300202102  0.097391      0.097391    107.615464     92.886121  0.388745
# 034300202103  0.120566      0.120566     77.203393     91.290979  0.357049
# 034300202104  0.117331      0.117331     58.908633     35.016319  1.515987
# 034300202201  0.096675      0.096675     24.063355     33.767734  0.324555
# 034300202202  0.013264      0.013264    117.499658     88.060514  0.437527
# 034300202203  0.002574      0.002574    105.784889     90.521014  0.434674
# 034300202204  0.254631      0.254631     80.662857     52.266342  1.383130
#
#               부채상환계수(배)  총차입금상환능력비율
# 아이디
# 034300202001  17.191776   27.163492
# 034300202002  29.014564   39.410967
# 034300202003  36.090762   45.210685
# 034300202004  10.652277   24.168932
# 034300202101  57.585461   74.193386
# 034300202102  69.050549   80.930505
# 034300202103  83.387681  103.406849
# 034300202104  16.188458   51.287072
# 034300202201  28.178707   37.229262
# 034300202202  17.159593   20.398173
# 034300202203  16.930334   21.952305
# 034300202204  -0.219778   -0.319844

# %%
df.to_csv(f'/content/drive/MyDrive/ICR/재무비율/{corp_name_p}_재무비율.csv')

# %% [markdown]
# ### KCC 건설

# %%
corp_name = ['DL이앤씨', 'HDC현대산업개발', '한전KPS', 'HJ중공업', '신세계건설', 'KCC건설', '대우건설', '서희건설', '특수건설', '계룡건설산업', '신원종합개발', '서한', '태영건설', '현대건설', 'GS건설', '동부건설', '코오롱글로벌', 'DL건설', '진흥기업', '남광토건', '한신공영', '금호건설', '삼부토건']
corp_code = ['375500', '294870', '051600', '097230', '034300', '021320', '047040', '035890', '026150', '013580', '017000', '011370', '009410', '000720', '006360', '005960', '003070', '001880', '002780', '001260', '004960', '002990', '001470']
report_code = ["11013", "11012", "11014", "11011"] # '11013'=1분기보고서, '11012'=반기보고서, '11014'=3분기보고서, '11011'=사업보고서

corp_name_p = corp_name[5]
corp_code_p = corp_code[5]

all = pd.DataFrame()

for year in range(2019, 2023):
  for code in report_code:
    corp = dart.finstate_all(corp_code_p, year, code, fs_div="OFS")
    # corp = corp.drop('account_id', axis=1)
    all = pd.concat([all, corp], ignore_index=True) # 2019년~2022년 별도 재무제표 전문(분기보고서+반기보고서+사업보고서)

all

# %%
Quarter = []
cor_year = []
ID_list = []
corp_name_list = []
year_list = []
report_code_list = []
Debt_Ratio = []
Debt_to_Asset_Ratio = []
Fixed_Asset_Turnover_Ratio = []
Return_on_Equity = []
Operating_Profit_Margin = []
Gross_Profit_Margin = []
Interest_Coverage_Ratio =[]
Sales_Growth_Rate = []
Total_Asset_Growth_Rate = []
Operating_Profit_Growth_Rate = []
Equity_Growth_Rate= []
Accounts_Receivable_Turnover = []
Inventory_Turnover = []
Accounts_Payable_Turnover = []
Total_Asset_Turnover_Ratio = []
Debt_Service_Coverage_Ratio = []
Debt_to_Equity_Ratio = []


for year in range(2020, 2023):
  str_year = str(year)
  report_code_list.extend(['1분기보고서' if code == '11013' else '반기보고서' if code == '11012' else '3분기보고서' if code == '11014' else '사업보고서' for code in report_code])
  Quarter.extend(['01' if code == '11013' else '02' if code == '11012' else '03' if code == '11014' else '04' for code in report_code])
  for code in report_code:
    BS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '자산총계' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자산총계
    BS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 부채총계
    BS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자본총계
    BS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '단기차입금' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 단기차입금
    BS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and ('유동성장기부채' in row['account_nm'] or '유동성장기채무' in row['account_nm']) and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 유동성장기부채
    BS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '사채' in row['account_nm'] and row['account_id'] == 'dart_BondsIssued' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 사채
    BS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '차입금' in row['account_nm'] and '단기차입금' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 장기차입금
    BS8 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동자산' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동자산
    BS9 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동부채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동부채
    BS10 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자산총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자산총계
    BS11 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 부채총계
    BS12 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자본총계
    BS13 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '매출채권' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매출채권
    BS14 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '매입채무'  and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매입채무
    BS15 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '재고자산' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 재고자산

    IS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '포괄손익계산서' and '기순' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 당기순이익
    IS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업이익
    IS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '매출액' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 수익(매출액)
    IS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '법인세' in row['account_nm'] and '차감전' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 법인세비용차감전순이익(손실)
    IS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and (row['account_nm'] == '금융비용' or row['account_nm'] == '금융원가') and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 금융비용
    IS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '매출액' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 수익(매출액) # 분기 보고서만 해당
    IS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '영업이익' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 영업이익 # 분기 보고서만 해당

    CF1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '현금흐름표' and row['account_nm'] == '영업활동현금흐름' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업활동으로 인한 현금흐름

    if BS6 == BS7: # '사채 및 장기차입금'으로 계정과목 하나만 쓰는 회사는 합침(어차피 사채는 차입금 의존도에서만 사용해서 하나 0으로 만들어도 상관없음)
      BS6 = ['0']
    if BS4 == BS5:
      BS4 = ['0'] # '단기차입금 및 유동성장기부채' 로 병합해서 쓰는 회사는 ㅎ나로 합침(어차피 둘이 항상 붙어서 계산해서 상관없음)
    if BS4 == []:
      BS4 = ['0']
    if BS5 == [''] or BS5 == []:
      BS5 = ['0']
    if BS6 == []:
      BS6 = ['0']
    if BS7 == []:
      BS7 = ['0']

    print("자산총계:", BS1, "부채총계:", BS2, "자본총계:", BS3, "단기차입금:", BS4, "유동성장기부채:", BS5, "사채:", BS6, "장기차입금:", BS7, "비유동자산:", BS8, "비유동부채:", BS9, "전기말 자산총계:", BS10, "전기말 부채총계:", BS11,
          "전기말 자본총계:", BS12, "매출채권:", BS13, "매입채무:", BS14, "재고자산:", BS15, "당기순이익:", IS1, "영업이익:", IS2, "수익(매출액):", IS3, "법인세비용차감전순이익(손실):", IS4,
          "금융비용:", IS5, "전기 수익(매출액):", IS6, "전기 영업이익:", IS7, "영업활동으로 인한 현금흐름:", CF1)

    if year != 2020:
      if code == "11013":
        accounting_period = 90
      elif code == "11012":
        accounting_period = 181
      elif code == "11014":
        accounting_period = 273
      elif code == "11011":
        accounting_period = 365
    else: # 2020년은 윤년
      if code == "11013":
        accounting_period = 91
      elif code == "11012":
        accounting_period = 182
      elif code == "11014":
        accounting_period = 274
      elif code == "11011":
        accounting_period = 366


    cor_year.extend([f"{corp_code_p}{str_year}"])
    corp_name_list.append(str(corp_name_p))
    year_list.append(str_year)
    Debt_Ratio.extend([int(BS2)/int(BS3)*100 for BS2, BS3 in zip(BS2, BS3)])
    Debt_to_Asset_Ratio.extend([((int(BS4) + int(BS5) + int(BS6) + int(BS7)) / int(BS1) * 100) for BS4, BS5, BS6, BS7, BS1 in zip(BS4, BS5, BS6, BS7, BS1)])
    Fixed_Asset_Turnover_Ratio.extend([int(BS8)/(int(BS9)+int(BS3))*100 for BS8, BS9, BS3 in zip(BS8, BS9, BS3)]),
    Return_on_Equity.extend([int(IS1)/((int(BS12)+int(BS3))/2) for IS1, BS12, BS3 in zip(IS1, BS12, BS3)])
    Operating_Profit_Margin.extend([int(IS2)/int(IS3) for IS2, IS3 in zip(IS2, IS3)])
    Gross_Profit_Margin.extend([int(IS4)/int(IS3) for IS4, IS3 in zip(IS4, IS3)])
    Interest_Coverage_Ratio.extend([int(IS2)/int(IS5) for IS2, IS5 in zip(IS2, IS5)])
    Sales_Growth_Rate.extend([(int(IS3)-int(IS6))/int(IS6) for IS3, IS6 in zip(IS3, IS6)])
    Total_Asset_Growth_Rate.extend([(int(BS1)-int(BS10))/int(BS10) for BS1, BS10 in zip(BS1, BS10)])
    Operating_Profit_Growth_Rate.extend([(int(IS2)-int(IS7))/int(IS7) for IS2, IS7 in zip(IS2, IS7)])
    Equity_Growth_Rate.extend([(int(BS3)-int(BS12))/int(BS12) for BS3, BS12 in zip(BS3, BS12)])
    Accounts_Receivable_Turnover.extend([int(BS13)/int(IS3)*accounting_period for BS13, IS3 in zip(BS13, IS3)])
    Inventory_Turnover.extend([int(BS15)/int(IS3)*accounting_period for BS15, IS3 in zip(BS15, IS3)])
    Accounts_Payable_Turnover.extend([int(BS14)/int(IS3)*accounting_period for BS14, IS3 in zip(BS14, IS3)])
    Total_Asset_Turnover_Ratio.extend([int(IS3)/int(BS1) for IS3, BS1 in zip(IS3, BS1)])
    Debt_Service_Coverage_Ratio.extend([(int(CF1)+int(IS5))/(int(BS4)+int(BS5)+int(IS5)) for CF1, IS5, BS4, BS5 in zip(CF1, IS5, BS4, BS5)])
    Debt_to_Equity_Ratio.extend([int(CF1)/(int(BS4)+int(BS7)+int(BS5)) for CF1, BS4, BS7, BS5 in zip(CF1, BS4, BS7, BS5)])

ID_list.extend([x+y for x,y in zip(cor_year,Quarter)])

financial_ratio = {
      '아이디':ID_list,
      '기업명':corp_name_list,
      '연도':year_list,
      '보고서 코드':report_code_list,
      '부채비율' : Debt_Ratio,
      '차입금의존도' : Debt_to_Asset_Ratio,
      '고정장기적합률':Fixed_Asset_Turnover_Ratio,
      '자기자본순이익률':Return_on_Equity,
      '매출액영업이익률':Operating_Profit_Margin,
      '매출액경상이익률':Gross_Profit_Margin,
      '이자보상배율(배)':Interest_Coverage_Ratio,
      '매출액 증가율':Sales_Growth_Rate,
      '총자산 증가율':Total_Asset_Growth_Rate,
      '영업이익 증가율':Operating_Profit_Growth_Rate,
      '자기자본 증가율':Equity_Growth_Rate,
      '매출채권 회전기일(일)':Equity_Growth_Rate,
      '재고자산 회전기일(일)':Accounts_Receivable_Turnover,
      '매입채무 회전기일(일)':Accounts_Payable_Turnover,
      '총자산 회전율':Total_Asset_Turnover_Ratio,
      '부채상환계수(배)':Debt_Service_Coverage_Ratio,
      '총차입금상환능력비율':Debt_to_Equity_Ratio
                    }

df = pd.DataFrame(financial_ratio)
df.set_index('아이디', inplace=True)

df
# Out:
# 자산총계: ['1007074496202'] 부채총계: ['617206294102'] 자본총계: ['389868202100'] 단기차입금: ['117200000000'] 유동성장기부채: ['20000000000'] 사채: ['69858010432'] 장기차입금: ['0'] 비유동자산: ['238923266577'] 비유동부채: ['167345178496'] 전기말 자산총계: ['1068886898524'] 전기말 부채총계: ['706156800224'] 전기말 자본총계: ['362730098300'] 매출채권: ['147530206333'] 매입채무: ['131280109171'] 재고자산: ['55207275755'] 당기순이익: ['15830492041'] 영업이익: ['18469011995'] 수익(매출액): ['331562274803'] 법인세비용차감전순이익(손실): ['16765604070'] 금융비용: ['2478341418'] 전기 수익(매출액): ['340709058428'] 전기 영업이익: ['20217582181'] 영업활동으로 인한 현금흐름: ['108743481749']
# 자산총계: ['1034752706533'] 부채총계: ['636292771747'] 자본총계: ['398459934786'] 단기차입금: ['137200000000'] 유동성장기부채: ['0'] 사채: ['49898600377'] 장기차입금: ['0'] 비유동자산: ['234527642642'] 비유동부채: ['151275645994'] 전기말 자산총계: ['1069282832032'] 전기말 부채총계: ['693262122196'] 전기말 자본총계: ['376020709836'] 매출채권: ['173863451308'] 매입채무: ['109432240049'] 재고자산: ['9873984188'] 당기순이익: ['11023651484'] 영업이익: ['14956910310'] 수익(매출액): ['301950177383'] 법인세비용차감전순이익(손실): ['15077313260'] 금융비용: ['2637495944'] 전기 수익(매출액): ['384659931240'] 전기 영업이익: ['15510766952'] 영업활동으로 인한 현금흐름: ['202255521723']
# 자산총계: ['983798713509'] 부채총계: ['582116598189'] 자본총계: ['401682115320'] 단기차입금: ['137200000000'] 유동성장기부채: ['0'] 사채: ['49909747971'] 장기차입금: ['0'] 비유동자산: ['387959902411'] 비유동부채: ['166354560406'] 전기말 자산총계: ['1113873270499'] 전기말 부채총계: ['732801474544'] 전기말 자본총계: ['381071795955'] 매출채권: ['171170399859'] 매입채무: ['92624250110'] 재고자산: ['6942357559'] 당기순이익: ['6527755838'] 영업이익: ['8295842121'] 수익(매출액): ['218712325372'] 법인세비용차감전순이익(손실): ['8812482789'] 금융비용: ['2315518568'] 전기 수익(매출액): ['391716645569'] 전기 영업이익: ['9862727098'] 영업활동으로 인한 현금흐름: ['158093130766']
# 자산총계: ['977535499042'] 부채총계: ['576990405484'] 자본총계: ['400545093558'] 단기차입금: ['151300000000'] 유동성장기부채: ['0'] 사채: ['49921104853'] 장기차입금: ['0'] 비유동자산: ['372956644698'] 비유동부채: ['176104368335'] 전기말 자산총계: ['1039194850951'] 전기말 부채총계: ['661659129871'] 전기말 자본총계: ['377535721080'] 매출채권: ['133747578433'] 매입채무: ['105680057467'] 재고자산: ['8316583716'] 당기순이익: ['37641374138'] 영업이익: ['54302650524'] 수익(매출액): ['1101612749583'] 법인세비용차감전순이익(손실): ['45620741074'] 금융비용: ['9391539552'] 전기 수익(매출액): ['1642515959742'] 전기 영업이익: ['58800589918'] 영업활동으로 인한 현금흐름: ['211088664134']
# 자산총계: ['1010284238305'] 부채총계: ['600522472737'] 자본총계: ['409761765568'] 단기차입금: ['146300000000'] 유동성장기부채: ['0'] 사채: ['49932360816'] 장기차입금: ['0'] 비유동자산: ['377589954430'] 비유동부채: ['178280271687'] 전기말 자산총계: ['1007074496202'] 전기말 부채총계: ['617206294102'] 전기말 자본총계: ['389868202100'] 매출채권: ['118216285978'] 매입채무: ['114577322527'] 재고자산: ['11029502177'] 당기순이익: ['14463411020'] 영업이익: ['14306039287'] 수익(매출액): ['246983337542'] 법인세비용차감전순이익(손실): ['15591986261'] 금융비용: ['1945821773'] 전기 수익(매출액): ['331562274803'] 전기 영업이익: ['18469011995'] 영업활동으로 인한 현금흐름: ['47580700341']
# 자산총계: ['1126745757814'] 부채총계: ['695862302168'] 자본총계: ['430883455646'] 단기차입금: ['132700000000'] 유동성장기부채: ['0'] 사채: ['99797570098'] 장기차입금: ['0'] 비유동자산: ['380523827812'] 비유동부채: ['225088105525'] 전기말 자산총계: ['1034752706533'] 전기말 부채총계: ['636292771747'] 전기말 자본총계: ['398459934786'] 매출채권: ['178975359908'] 매입채무: ['137382162895'] 재고자산: ['16120573087'] 당기순이익: ['21121693155'] 영업이익: ['21351017767'] 수익(매출액): ['317777673239'] 법인세비용차감전순이익(손실): ['28717187173'] 금융비용: ['2107984407'] 전기 수익(매출액): ['301950177383'] 전기 영업이익: ['14956910310'] 영업활동으로 인한 현금흐름: ['52444236008']
# 자산총계: ['1073346697972'] 부채총계: ['635793084467'] 자본총계: ['437553613505'] 단기차입금: ['132700000000'] 유동성장기부채: ['0'] 사채: ['49866508533'] 장기차입금: ['0'] 비유동자산: ['370247718665'] 비유동부채: ['171111975804'] 전기말 자산총계: ['983798713509'] 전기말 부채총계: ['582116598189'] 전기말 자본총계: ['401682115320'] 매출채권: ['182426829399'] 매입채무: ['142112136563'] 재고자산: ['17361186169'] 당기순이익: ['6670127298'] 영업이익: ['1475254553'] 수익(매출액): ['341734970141'] 법인세비용차감전순이익(손실): ['9000844938'] 금융비용: ['1888695904'] 전기 수익(매출액): ['218712325372'] 전기 영업이익: ['8295842121'] 영업활동으로 인한 현금흐름: ['-29370420396']
# 자산총계: ['1089774227600'] 부채총계: ['647274466274'] 자본총계: ['442499761326'] 단기차입금: ['89300000000'] 유동성장기부채: ['0'] 사채: ['49879106835'] 장기차입금: ['0'] 비유동자산: ['373866798061'] 비유동부채: ['156154564957'] 전기말 자산총계: ['977535499042'] 전기말 부채총계: ['576990405484'] 전기말 자본총계: ['400545093558'] 매출채권: ['181321699397'] 매입채무: ['172320411570'] 재고자산: ['22678565039'] 당기순이익: ['47190335111'] 영업이익: ['31880777428'] 수익(매출액): ['1363965385622'] 법인세비용차감전순이익(손실): ['57113856690'] 금융비용: ['7856159866'] 전기 수익(매출액): ['1101612749583'] 전기 영업이익: ['54302650524'] 영업활동으로 인한 현금흐름: ['-110505848405']
# 자산총계: ['1108014009926'] 부채총계: ['664051518253'] 자본총계: ['443962491673'] 단기차입금: ['85800000000'] 유동성장기부채: ['0'] 사채: ['49891706801'] 장기차입금: ['0'] 비유동자산: ['368762278557'] 비유동부채: ['158524590727'] 전기말 자산총계: ['1010284238305'] 전기말 부채총계: ['600522472737'] 전기말 자본총계: ['409761765568'] 매출채권: ['216036031454'] 매입채무: ['190518261107'] 재고자산: ['21862875176'] 당기순이익: ['5193233528'] 영업이익: ['8342128335'] 수익(매출액): ['428621353240'] 법인세비용차감전순이익(손실): ['10320147469'] 금융비용: ['2522946033'] 전기 수익(매출액): ['246983337542'] 전기 영업이익: ['14306039287'] 영업활동으로 인한 현금흐름: ['15728119588']
# 자산총계: ['1122998176515'] 부채총계: ['677987530598'] 자본총계: ['445010645917'] 단기차입금: ['83600000000'] 유동성장기부채: ['0'] 사채: ['49904508577'] 장기차입금: ['0'] 비유동자산: ['364046823823'] 비유동부채: ['153750034159'] 전기말 자산총계: ['1126745757814'] 전기말 부채총계: ['695862302168'] 전기말 자본총계: ['430883455646'] 매출채권: ['163462593984'] 매입채무: ['202289526478'] 재고자산: ['29159439858'] 당기순이익: ['1048172494'] 영업이익: ['-4977816966'] 수익(매출액): ['439190349690'] 법인세비용차감전순이익(손실): ['1258771236'] 금융비용: ['1986998035'] 전기 수익(매출액): ['317777673239'] 전기 영업이익: ['21351017767'] 영업활동으로 인한 현금흐름: ['7275159819']
# 자산총계: ['1141356333053'] 부채총계: ['702319041245'] 자본총계: ['439037291808'] 단기차입금: ['149600000000'] 유동성장기부채: ['0'] 사채: ['49917392483'] 장기차입금: ['11600000000'] 비유동자산: ['394822127012'] 비유동부채: ['168151141814'] 전기말 자산총계: ['1073346697972'] 전기말 부채총계: ['635793084467'] 전기말 자본총계: ['437553613505'] 매출채권: ['214416377093'] 매입채무: ['203342395717'] 재고자산: ['25337854017'] 당기순이익: ['-5973246944'] 영업이익: ['-7882946567'] 수익(매출액): ['494538781628'] 법인세비용차감전순이익(손실): ['-7664844434'] 금융비용: ['2397492178'] 전기 수익(매출액): ['341734970141'] 전기 영업이익: ['1475254553'] 영업활동으로 인한 현금흐름: ['-26074651709']
# 자산총계: ['1198128493039'] 부채총계: ['747474269742'] 자본총계: ['450654223297'] 단기차입금: ['195300000000'] 유동성장기부채: ['0'] 사채: ['49930319713'] 장기차입금: ['11600000000'] 비유동자산: ['411720155543'] 비유동부채: ['160146081764'] 전기말 자산총계: ['1089774227600'] 전기말 부채총계: ['647274466274'] 전기말 자본총계: ['442499761326'] 매출채권: ['314643536203'] 매입채무: ['218131002048'] 재고자산: ['22671007659'] 당기순이익: ['4438156398'] 영업이익: ['-1091838620'] 수익(매출액): ['1893077679119'] 법인세비용차감전순이익(손실): ['13571221968'] 금융비용: ['10019650706'] 전기 수익(매출액): ['1363965385622'] 전기 영업이익: ['31880777428'] 영업활동으로 인한 현금흐름: ['-78227059691']
#                 기업명    연도  보고서 코드        부채비율     차입금의존도    고정장기적합률  자기자본순이익률  \
# 아이디
# 021320202001  KCC건설  2020  1분기보고서  158.311524  20.560347  42.878236  0.042069
# 021320202002  KCC건설  2020   반기보고서  159.688018  18.081480  42.661900  0.028467
# 021320202003  KCC건설  2020  3분기보고서  144.919720  19.019109  68.298390  0.016679
# 021320202004  KCC건설  2020   사업보고서  144.051298  20.584532  64.676492  0.096754
# 021320202101  KCC건설  2021  1분기보고서  146.554052  19.423480  64.211388  0.036175
# 021320202102  KCC건설  2021   반기보고서  161.496640  20.634430  58.009196  0.050936
# 021320202103  KCC건설  2021  3분기보고서  145.306327  17.009090  60.829415  0.015896
# 021320202104  KCC건설  2021   사업보고서  146.276794  12.771371  62.451198  0.111952
# 021320202201  KCC건설  2022  1분기보고서  149.573788  12.246389  61.206670  0.012166
# 021320202202  KCC건설  2022   반기보고서  152.353104  11.888221  60.800055  0.002393
# 021320202203  KCC건설  2022  3분기보고서  159.967970  18.497062  65.024646 -0.013628
# 021320202204  KCC건설  2022   사업보고서  165.864255  21.435958  67.406672  0.009938
#
#               매출액영업이익률  매출액경상이익률  이자보상배율(배)   매출액 증가율   총자산 증가율  영업이익 증가율  \
# 아이디
# 021320202001  0.055703  0.050565   7.452166 -0.026846 -0.057829 -0.086488
# 021320202002  0.049534  0.049933   5.670875 -0.215020 -0.032293 -0.035708
# 021320202003  0.037930  0.040293   3.582715 -0.441657 -0.116777 -0.158869
# 021320202004  0.049294  0.041413   5.782082 -0.329314 -0.059334 -0.076495
# 021320202101  0.057923  0.063130   7.352184 -0.255092  0.003187 -0.225403
# 021320202102  0.067189  0.090369  10.128641  0.052418  0.088903  0.427502
# 021320202103  0.004317  0.026339   0.781097  0.562486  0.091023 -0.822169
# 021320202104  0.023374  0.041873   4.058061  0.238153  0.114818 -0.412906
# 021320202201  0.019463  0.024078   3.306503  0.735426  0.096735 -0.416881
# 021320202202 -0.011334  0.002866  -2.505195  0.382068 -0.003326 -1.233142
# 021320202203 -0.015940 -0.015499  -3.287997  0.447141  0.063362 -6.343448
# 021320202204 -0.000577  0.007169  -0.108970  0.387922  0.099428 -1.034248
#
#               자기자본 증가율  매출채권 회전기일(일)  재고자산 회전기일(일)  매입채무 회전기일(일)   총자산 회전율  \
# 아이디
# 021320202001  0.074816      0.074816     40.490881     36.030908  0.329233
# 021320202002  0.059676      0.059676    104.795925     65.960113  0.291809
# 021320202003  0.054085      0.054085    214.440085    116.038474  0.222314
# 021320202004  0.060946      0.060946     44.436317     35.111160  1.126929
# 021320202101  0.051026      0.051026     43.077666     41.751639  0.244469
# 021320202102  0.081372      0.081372    101.940894     78.250216  0.282031
# 021320202103  0.089303      0.089303    145.734352    113.528368  0.318383
# 021320202104  0.104744      0.104744     48.522067     46.113304  1.251604
# 021320202201  0.083465      0.083465     45.362282     40.004175  0.386837
# 021320202202  0.032787      0.032787     67.366529     83.367962  0.391087
# 021320202203  0.003391      0.003391    118.364167    112.251003  0.433290
# 021320202204  0.018428      0.018428     60.665704     42.057342  1.580029
#
#               부채상환계수(배)  총차입금상환능력비율
# 아이디
# 021320202001   0.796271    0.792591
# 021320202002   1.465222    1.474166
# 021320202003   1.149755    1.152282
# 021320202004   1.372071    1.395166
# 021320202101   0.334084    0.325227
# 021320202102   0.404666    0.395209
# 021320202103  -0.204190   -0.221329
# 021320202104  -1.056543   -1.237468
# 021320202201   0.206640    0.183311
# 021320202202   0.108219    0.087023
# 021320202203  -0.155773   -0.161753
# 021320202204  -0.332201   -0.378091

# %%
df.to_csv(f'/content/drive/MyDrive/ICR/재무비율/{corp_name_p}_재무비율.csv')

# %% [markdown]
# ### 대우 건설

# %%
corp_name = ['DL이앤씨', 'HDC현대산업개발', '한전KPS', 'HJ중공업', '신세계건설', 'KCC건설', '대우건설', '서희건설', '특수건설', '계룡건설산업', '신원종합개발', '서한', '태영건설', '현대건설', 'GS건설', '동부건설', '코오롱글로벌', 'DL건설', '진흥기업', '남광토건', '한신공영', '금호건설', '삼부토건']
corp_code = ['375500', '294870', '051600', '097230', '034300', '021320', '047040', '035890', '026150', '013580', '017000', '011370', '009410', '000720', '006360', '005960', '003070', '001880', '002780', '001260', '004960', '002990', '001470']
report_code = ["11013", "11012", "11014", "11011"] # '11013'=1분기보고서, '11012'=반기보고서, '11014'=3분기보고서, '11011'=사업보고서

corp_name_p = corp_name[6]
corp_code_p = corp_code[6]

all = pd.DataFrame()

for year in range(2019, 2023):
  for code in report_code:
    corp = dart.finstate_all(corp_code_p, year, code, fs_div="OFS")
    # corp = corp.drop('account_id', axis=1)
    all = pd.concat([all, corp], ignore_index=True) # 2019년~2022년 별도 재무제표 전문(분기보고서+반기보고서+사업보고서)

all
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# 주석에 있는 단기차입금, 유동성장기부채, 회사채, 장기차입금은 수기로 가져와야 함
short_term_loan = ['938096000000', '668614000000', '699794000000', '291779000000', '363325000000', '148406000000', '118584000000', '223320000000', '334339000000', '327497000000', '322433000000', '445803000000']
liquidity_enhancing_long_term_debt = ['921531000000', '996428000000', '1005070000000', '892731000000', '508606000000', '290725000000', '268847000000', '237863000000', '388006000000', '262255000000', '328233000000', '509005000000']
corporate_bond = ['100000000000', '0', '200000000000', '261667000000', '373073000000', '522997000000', '465260000000', '465785000000', '327434000000', '329907000000', '299044000000', '223900000000']
long_term_loan = ['557905000000', '569810000000', '636114000000', '391977000000', '372044000000', '516247000000', '526142000000', '438122000000', '461641000000', '456899000000', '562067000000', '773903000000']
year_i = ['2020','2020','2020','2020','2021','2021','2021','2021','2022','2022','2022','2022']
report_code_i = ["11013", "11012", "11014", "11011","11013", "11012", "11014", "11011","11013", "11012", "11014", "11011"]

debt = {
    'year':year_i,
    'report_code':report_code_i,
    '단기차입금': short_term_loan,
    '유동성장기부채': liquidity_enhancing_long_term_debt,
    '사채': corporate_bond,
    '장기차입금': long_term_loan}

debt_df = pd.DataFrame(debt)
debt_df
# Out:
#     year report_code         단기차입금        유동성장기부채            사채         장기차입금
# 0   2020       11013  938096000000   921531000000  100000000000  557905000000
# 1   2020       11012  668614000000   996428000000             0  569810000000
# 2   2020       11014  699794000000  1005070000000  200000000000  636114000000
# 3   2020       11011  291779000000   892731000000  261667000000  391977000000
# 4   2021       11013  363325000000   508606000000  373073000000  372044000000
# 5   2021       11012  148406000000   290725000000  522997000000  516247000000
# 6   2021       11014  118584000000   268847000000  465260000000  526142000000
# 7   2021       11011  223320000000   237863000000  465785000000  438122000000
# 8   2022       11013  334339000000   388006000000  327434000000  461641000000
# 9   2022       11012  327497000000   262255000000  329907000000  456899000000
# 10  2022       11014  322433000000   328233000000  299044000000  562067000000
# 11  2022       11011  445803000000   509005000000  223900000000  773903000000

# %%
Quarter = []
cor_year = []
ID_list = []
corp_name_list = []
year_list = []
report_code_list = []
Debt_Ratio = []
Debt_to_Asset_Ratio = []
Fixed_Asset_Turnover_Ratio = []
Return_on_Equity = []
Operating_Profit_Margin = []
Gross_Profit_Margin = []
Interest_Coverage_Ratio =[]
Sales_Growth_Rate = []
Total_Asset_Growth_Rate = []
Operating_Profit_Growth_Rate = []
Equity_Growth_Rate= []
Accounts_Receivable_Turnover = []
Inventory_Turnover = []
Accounts_Payable_Turnover = []
Total_Asset_Turnover_Ratio = []
Debt_Service_Coverage_Ratio = []
Debt_to_Equity_Ratio = []


for year in range(2020, 2023):
  str_year = str(year)
  report_code_list.extend(['1분기보고서' if code == '11013' else '반기보고서' if code == '11012' else '3분기보고서' if code == '11014' else '사업보고서' for code in report_code])
  Quarter.extend(['01' if code == '11013' else '02' if code == '11012' else '03' if code == '11014' else '04' for code in report_code])
  for code in report_code:
    BS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '자산총계' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자산총계
    BS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 부채총계
    BS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자본총계
    BS4 = [(row['단기차입금']) for index, row in debt_df.iterrows() if row['year'] == str(year) and row['report_code'] == str(code)]
    BS5 = [(row['유동성장기부채']) for index, row in debt_df.iterrows() if row['year'] == str(year) and row['report_code'] == str(code)]
    BS6 = [(row['사채']) for index, row in debt_df.iterrows() if row['year'] == str(year) and row['report_code'] == str(code)]
    BS7 = [(row['장기차입금']) for index, row in debt_df.iterrows() if row['year'] == str(year) and row['report_code'] == str(code)]
    # BS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '단기차입금' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 단기차입금
    # BS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and ('유동성장기부채' in row['account_nm'] or '유동성장기채무' in row['account_nm']) and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 유동성장기부채
    # BS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '사채' in row['account_nm'] and row['account_id'] == 'dart_BondsIssued' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 사채
    # BS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '차입금' in row['account_nm'] and '단기차입금' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 장기차입금
    BS8 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동자산' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동자산
    BS9 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동부채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동부채
    BS10 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자산총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자산총계
    BS11 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 부채총계
    BS12 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자본총계
    BS13 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '매출채권' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매출채권
    BS14 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '매입채무'  and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매입채무
    BS15 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '재고자산' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 재고자산

    IS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '포괄손익계산서' and '기순' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 당기순이익
    IS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업이익
    IS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '매출액' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 수익(매출액)
    IS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '법인세' in row['account_nm'] and '차감전' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 법인세비용차감전순이익(손실)
    IS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and (row['account_nm'] == '금융비용' or row['account_nm'] == '금융원가') and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 금융비용
    IS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '매출액' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 수익(매출액) # 분기 보고서만 해당
    IS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 영업이익 # 분기 보고서만 해당

    CF1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '현금흐름표' and row['account_nm'] == '영업활동으로 인한 현금흐름' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업활동으로 인한 현금흐름

    # if BS6 == BS7: # '사채 및 장기차입금'으로 계정과목 하나만 쓰는 회사는 합침(어차피 사채는 차입금 의존도에서만 사용해서 하나 0으로 만들어도 상관없음)
    #   BS6 = ['0']
    # if BS4 == BS5:
    #   BS4 = ['0'] # '단기차입금 및 유동성장기부채' 로 병합해서 쓰는 회사는 하나로 합침(어차피 둘이 항상 붙어서 계산해서 상관없음)
    # if BS4 == []:
    #   BS4 = ['0']
    # if BS5 == [''] or BS5 == []:
    #   BS5 = ['0']
    # if BS6 == []:
    #   BS6 = ['0']
    # if BS7 == []:
    #   BS7 = ['0']



    print("자산총계:", BS1, "부채총계:", BS2, "자본총계:", BS3, "단기차입금:", BS4, "유동성장기부채:", BS5, "사채:", BS6, "장기차입금:", BS7, "비유동자산:", BS8, "비유동부채:", BS9, "전기말 자산총계:", BS10, "전기말 부채총계:", BS11,
          "전기말 자본총계:", BS12, "매출채권:", BS13, "매입채무:", BS14, "재고자산:", BS15, "당기순이익:", IS1, "영업이익:", IS2, "수익(매출액):", IS3, "법인세비용차감전순이익(손실):", IS4,
          "금융비용:", IS5, "전기 수익(매출액):", IS6, "전기 영업이익:", IS7, "영업활동으로 인한 현금흐름:", CF1)

    if year != 2020:
      if code == "11013":
        accounting_period = 90
      elif code == "11012":
        accounting_period = 181
      elif code == "11014":
        accounting_period = 273
      elif code == "11011":
        accounting_period = 365
    else: # 2020년은 윤년
      if code == "11013":
        accounting_period = 91
      elif code == "11012":
        accounting_period = 182
      elif code == "11014":
        accounting_period = 274
      elif code == "11011":
        accounting_period = 366


    cor_year.extend([f"{corp_code_p}{str_year}"])
    corp_name_list.append(str(corp_name_p))
    year_list.append(str_year)
    Debt_Ratio.extend([int(BS2)/int(BS3)*100 for BS2, BS3 in zip(BS2, BS3)])
    Debt_to_Asset_Ratio.extend([((int(BS4) + int(BS5) + int(BS6) + int(BS7)) / int(BS1) * 100) for BS4, BS5, BS6, BS7, BS1 in zip(BS4, BS5, BS6, BS7, BS1)])
    Fixed_Asset_Turnover_Ratio.extend([int(BS8)/(int(BS9)+int(BS3))*100 for BS8, BS9, BS3 in zip(BS8, BS9, BS3)]),
    Return_on_Equity.extend([int(IS1)/((int(BS12)+int(BS3))/2) for IS1, BS12, BS3 in zip(IS1, BS12, BS3)])
    Operating_Profit_Margin.extend([int(IS2)/int(IS3) for IS2, IS3 in zip(IS2, IS3)])
    Gross_Profit_Margin.extend([int(IS4)/int(IS3) for IS4, IS3 in zip(IS4, IS3)])
    Interest_Coverage_Ratio.extend([int(IS2)/int(IS5) for IS2, IS5 in zip(IS2, IS5)])
    Sales_Growth_Rate.extend([(int(IS3)-int(IS6))/int(IS6) for IS3, IS6 in zip(IS3, IS6)])
    Total_Asset_Growth_Rate.extend([(int(BS1)-int(BS10))/int(BS10) for BS1, BS10 in zip(BS1, BS10)])
    Operating_Profit_Growth_Rate.extend([(int(IS2)-int(IS7))/int(IS7) for IS2, IS7 in zip(IS2, IS7)])
    Equity_Growth_Rate.extend([(int(BS3)-int(BS12))/int(BS12) for BS3, BS12 in zip(BS3, BS12)])
    Accounts_Receivable_Turnover.extend([int(BS13)/int(IS3)*accounting_period for BS13, IS3 in zip(BS13, IS3)])
    Inventory_Turnover.extend([int(BS15)/int(IS3)*accounting_period for BS15, IS3 in zip(BS15, IS3)])
    Accounts_Payable_Turnover.extend([int(BS14)/int(IS3)*accounting_period for BS14, IS3 in zip(BS14, IS3)])
    Total_Asset_Turnover_Ratio.extend([int(IS3)/int(BS1) for IS3, BS1 in zip(IS3, BS1)])
    Debt_Service_Coverage_Ratio.extend([(int(CF1)+int(IS5))/(int(BS4)+int(BS5)+int(IS5)) for CF1, IS5, BS4, BS5 in zip(CF1, IS5, BS4, BS5)])
    Debt_to_Equity_Ratio.extend([int(CF1)/(int(BS4)+int(BS7)+int(BS5)) for CF1, BS4, BS7, BS5 in zip(CF1, BS4, BS7, BS5)])

ID_list.extend([x+y for x,y in zip(cor_year,Quarter)])

financial_ratio = {
      '아이디':ID_list,
      '기업명':corp_name_list,
      '연도':year_list,
      '보고서 코드':report_code_list,
      '부채비율' : Debt_Ratio,
      '차입금의존도' : Debt_to_Asset_Ratio,
      '고정장기적합률':Fixed_Asset_Turnover_Ratio,
      '자기자본순이익률':Return_on_Equity,
      '매출액영업이익률':Operating_Profit_Margin,
      '매출액경상이익률':Gross_Profit_Margin,
      '이자보상배율(배)':Interest_Coverage_Ratio,
      '매출액 증가율':Sales_Growth_Rate,
      '총자산 증가율':Total_Asset_Growth_Rate,
      '영업이익 증가율':Operating_Profit_Growth_Rate,
      '자기자본 증가율':Equity_Growth_Rate,
      '매출채권 회전기일(일)':Equity_Growth_Rate,
      '재고자산 회전기일(일)':Accounts_Receivable_Turnover,
      '매입채무 회전기일(일)':Accounts_Payable_Turnover,
      '총자산 회전율':Total_Asset_Turnover_Ratio,
      '부채상환계수(배)':Debt_Service_Coverage_Ratio,
      '총차입금상환능력비율':Debt_to_Equity_Ratio
                    }

df = pd.DataFrame(financial_ratio)
df.set_index('아이디', inplace=True)

df
# Out:
# 자산총계: ['9091065099961'] 부채총계: ['6826758903774'] 자본총계: ['2264306196187'] 단기차입금: ['938096000000'] 유동성장기부채: ['921531000000'] 사채: ['100000000000'] 장기차입금: ['557905000000'] 비유동자산: ['3441334029113'] 비유동부채: ['1641536930613'] 전기말 자산총계: ['9148452072767'] 전기말 부채총계: ['6886869630553'] 전기말 자본총계: ['2261582442214'] 매출채권: ['968547688901'] 매입채무: ['295026958441'] 재고자산: ['681897760853'] 당기순이익: ['57958541170'] 영업이익: ['118483764587'] 수익(매출액): ['1931518113653'] 법인세비용차감전순이익(손실): ['72829635072'] 금융비용: ['24217794837'] 전기 수익(매출액): ['1933251297778'] 전기 영업이익: ['86336625575'] 영업활동으로 인한 현금흐름: ['131061482187']
# 자산총계: ['8697913555153'] 부채총계: ['6388560546295'] 자본총계: ['2309353008858'] 단기차입금: ['668614000000'] 유동성장기부채: ['996428000000'] 사채: ['0'] 장기차입금: ['569810000000'] 비유동자산: ['3333762124653'] 비유동부채: ['1571995291820'] 전기말 자산총계: ['9154066383743'] 전기말 부채총계: ['6835881018881'] 전기말 자본총계: ['2318185364862'] 매출채권: ['939576994572'] 매입채무: ['302817501412'] 재고자산: ['940001791777'] 당기순이익: ['54387040703'] 영업이익: ['76183787314'] 수익(매출액): ['1883550047823'] 법인세비용차감전순이익(손실): ['69633138137'] 금융비용: ['25749985474'] 전기 수익(매출액): ['2136256279302'] 전기 영업이익: ['76915657299'] 영업활동으로 인한 현금흐름: ['90518228026']
# 자산총계: ['9090853808632'] 부채총계: ['6732058695715'] 자본총계: ['2358795112917'] 단기차입금: ['699794000000'] 유동성장기부채: ['1005070000000'] 사채: ['200000000000'] 장기차입금: ['636114000000'] 비유동자산: ['3387473925170'] 비유동부채: ['1824878779989'] 전기말 자산총계: ['8694260450701'] 전기말 부채총계: ['6318450669096'] 전기말 자본총계: ['2375809781605'] 매출채권: ['770377815454'] 매입채무: ['274319228473'] 재고자산: ['925400650508'] 당기순이익: ['61274289633'] 영업이익: ['99141726870'] 수익(매출액): ['1843011294759'] 법인세비용차감전순이익(손실): ['68500767742'] 금융비용: ['22557731821'] 전기 수익(매출액): ['1945705540093'] 전기 영업이익: ['86003888567'] 영업활동으로 인한 현금흐름: ['216023499647']
# 자산총계: ['8399269136848'] 부채총계: ['6029114121579'] 자본총계: ['2370155015269'] 단기차입금: ['291779000000'] 유동성장기부채: ['892731000000'] 사채: ['261667000000'] 장기차입금: ['391977000000'] 비유동자산: ['3233536854789'] 비유동부채: ['1471845465566'] 전기말 자산총계: ['8734473025223'] 전기말 부채총계: ['6559695786274'] 전기말 자본총계: ['2174777238949'] 매출채권: ['875445036944'] 매입채무: ['104593891192'] 재고자산: ['1255133701262'] 당기순이익: ['176906546172'] 영업이익: ['377087261041'] 수익(매출액): ['7637255920891'] 법인세비용차감전순이익(손실): ['212016802723'] 금융비용: ['93564396064'] 전기 수익(매출액): ['8091938554367'] 전기 영업이익: ['156152991270'] 영업활동으로 인한 현금흐름: ['268136888568']
# 자산총계: ['8948112939835'] 부채총계: ['6414588428668'] 자본총계: ['2533524511167'] 단기차입금: ['363325000000'] 유동성장기부채: ['508606000000'] 사채: ['373073000000'] 장기차입금: ['372044000000'] 비유동자산: ['3155285316280'] 비유동부채: ['1628056515858'] 전기말 자산총계: ['9091065099961'] 전기말 부채총계: ['6826758903774'] 전기말 자본총계: ['2264306196187'] 매출채권: ['816729572071'] 매입채무: ['268827390274'] 재고자산: ['1501653249967'] 당기순이익: ['154762016328'] 영업이익: ['217871327504'] 수익(매출액): ['1866179349332'] 법인세비용차감전순이익(손실): ['203857452050'] 금융비용: ['16516843315'] 전기 수익(매출액): ['1931518113653'] 전기 영업이익: ['118483764587'] 영업활동으로 인한 현금흐름: ['702765101468']
# 자산총계: ['9249581815791'] 부채총계: ['6640525859573'] 자본총계: ['2609055956218'] 단기차입금: ['148406000000'] 유동성장기부채: ['290725000000'] 사채: ['522997000000'] 장기차입금: ['516247000000'] 비유동자산: ['3199612679940'] 비유동부채: ['1995754590841'] 전기말 자산총계: ['8697913555153'] 전기말 부채총계: ['6388560546295'] 전기말 자본총계: ['2309353008858'] 매출채권: ['833704158866'] 매입채무: ['309620695016'] 재고자산: ['1548063641597'] 당기순이익: ['82963482558'] 영업이익: ['103873344789'] 수익(매출액): ['1975185669051'] 법인세비용차감전순이익(손실): ['105490190989'] 금융비용: ['13964425468'] 전기 수익(매출액): ['1883550047823'] 전기 영업이익: ['76183787314'] 영업활동으로 인한 현금흐름: ['831843963896']
# 자산총계: ['9022540219730'] 부채총계: ['6366023278217'] 자본총계: ['2656516941513'] 단기차입금: ['118584000000'] 유동성장기부채: ['268847000000'] 사채: ['465260000000'] 장기차입금: ['526142000000'] 비유동자산: ['3246914437924'] 비유동부채: ['1947704386146'] 전기말 자산총계: ['9090853808632'] 전기말 부채총계: ['6732058695715'] 전기말 자본총계: ['2358795112917'] 매출채권: ['681105466546'] 매입채무: ['204339723458'] 재고자산: ['1449486747535'] 당기순이익: ['34261178820'] 영업이익: ['69237549017'] 수익(매출액): ['1932489004916'] 법인세비용차감전순이익(손실): ['45302348614'] 금융비용: ['11752040645'] 전기 수익(매출액): ['1843011294759'] 전기 영업이익: ['99141726870'] 영업활동으로 인한 현금흐름: ['858111658428']
# 자산총계: ['9192699186815'] 부채총계: ['6468101092253'] 자본총계: ['2724598094562'] 단기차입금: ['223320000000'] 유동성장기부채: ['237863000000'] 사채: ['465785000000'] 장기차입금: ['438122000000'] 비유동자산: ['3163662604943'] 비유동부채: ['1884486808794'] 전기말 자산총계: ['8399269136848'] 전기말 부채총계: ['6029114121579'] 전기말 자본총계: ['2370155015269'] 매출채권: ['690256173237'] 매입채무: ['237812061993'] 재고자산: ['1218178614728'] 당기순이익: ['356917295443'] 영업이익: ['572905326640'] 수익(매출액): ['8085719645404'] 법인세비용차감전순이익(손실): ['462700234077'] 금융비용: ['53180876439'] 전기 수익(매출액): ['7637255920891'] 전기 영업이익: ['377087261041'] 영업활동으로 인한 현금흐름: ['1479793183132']
# 자산총계: ['9380249156253'] 부채총계: ['6504252257820'] 자본총계: ['2875996898433'] 단기차입금: ['334339000000'] 유동성장기부채: ['388006000000'] 사채: ['327434000000'] 장기차입금: ['461641000000'] 비유동자산: ['3172617477285'] 비유동부채: ['1803701149261'] 전기말 자산총계: ['8948112939835'] 전기말 부채총계: ['6414588428668'] 전기말 자본총계: ['2533524511167'] 매출채권: ['676101541227'] 매입채무: ['218945487259'] 재고자산: ['1687441303151'] 당기순이익: ['148168963505'] 영업이익: ['199650946427'] 수익(매출액): ['2121328484400'] 법인세비용차감전순이익(손실): ['198454756423'] 금융비용: ['11331588849'] 전기 수익(매출액): ['1866179349332'] 전기 영업이익: ['217871327504'] 영업활동으로 인한 현금흐름: ['-68167183197']
# 자산총계: ['9413887630713'] 부채총계: ['6481933972393'] 자본총계: ['2931953658320'] 단기차입금: ['327497000000'] 유동성장기부채: ['262255000000'] 사채: ['329907000000'] 장기차입금: ['456899000000'] 비유동자산: ['3085899053974'] 비유동부채: ['1693336098653'] 전기말 자산총계: ['9249581815791'] 전기말 부채총계: ['6640525859573'] 전기말 자본총계: ['2609055956218'] 매출채권: ['759418144663'] 매입채무: ['276214461669'] 재고자산: ['1638632130676'] 당기순이익: ['43660307100'] 영업이익: ['70344613252'] 수익(매출액): ['2300772932094'] 법인세비용차감전순이익(손실): ['56364851126'] 금융비용: ['13531716871'] 전기 수익(매출액): ['1975185669051'] 전기 영업이익: ['103873344789'] 영업활동으로 인한 현금흐름: ['31250754547']
# 자산총계: ['9716286284362'] 부채총계: ['6633497003238'] 자본총계: ['3082789281124'] 단기차입금: ['322433000000'] 유동성장기부채: ['328233000000'] 사채: ['299044000000'] 장기차입금: ['562067000000'] 비유동자산: ['3172065346806'] 비유동부채: ['1598355712612'] 전기말 자산총계: ['9022540219730'] 전기말 부채총계: ['6366023278217'] 전기말 자본총계: ['2656516941513'] 매출채권: ['854438761908'] 매입채무: ['247833460388'] 재고자산: ['1600234212038'] 당기순이익: ['109768317457'] 영업이익: ['126009443030'] 수익(매출액): ['2305041474982'] 법인세비용차감전순이익(손실): ['147393534913'] 금융비용: ['16076327513'] 전기 수익(매출액): ['1932489004916'] 전기 영업이익: ['69237549017'] 영업활동으로 인한 현금흐름: ['-221140647937']
# 자산총계: ['9668849512525'] 부채총계: ['6674852811814'] 자본총계: ['2993996700711'] 단기차입금: ['445803000000'] 유동성장기부채: ['509005000000'] 사채: ['223900000000'] 장기차입금: ['773903000000'] 비유동자산: ['3026639308956'] 비유동부채: ['1773091797936'] 전기말 자산총계: ['9192699186815'] 전기말 부채총계: ['6468101092253'] 전기말 자본총계: ['2724598094562'] 매출채권: ['1015376441659'] 매입채무: ['328062948402'] 재고자산: ['1546551086448'] 당기순이익: ['254741242738'] 영업이익: ['433402928333'] 수익(매출액): ['9318914840012'] 법인세비용차감전순이익(손실): ['364861644950'] 금융비용: ['71858683014'] 전기 수익(매출액): ['8085719645404'] 전기 영업이익: ['572905326640'] 영업활동으로 인한 현금흐름: ['-532919701620']
#                기업명    연도  보고서 코드        부채비율     차입금의존도    고정장기적합률  자기자본순이익률  \
# 아이디
# 047040202001  대우건설  2020  1분기보고서  301.494511  27.692377  88.107328  0.025612
# 047040202002  대우건설  2020   반기보고서  276.638544  25.694116  85.891857  0.023506
# 047040202003  대우건설  2020  3분기보고서  285.402435  27.950928  80.968881  0.025884
# 047040202004  대우건설  2020   사업보고서  254.376363  21.884690  84.162844  0.077848
# 047040202101  대우건설  2021  1분기보고서  253.188331  18.071386  75.819389  0.064513
# 047040202102  대우건설  2021   반기보고서  254.518338  15.983155  69.484133  0.033736
# 047040202103  대우건설  2021  3분기보고서  239.637970  15.282093  70.520381  0.013663
# 047040202104  대우건설  2021   사업보고서  237.396521  14.849719  68.639712  0.140112
# 047040202201  대우건설  2022  1분기보고서  226.156442  16.112792  67.795346  0.054781
# 047040202202  대우건설  2022   반기보고서  221.079005  14.622630  66.717962  0.015759
# 047040202203  대우건설  2022  3분기보고서  215.178411  15.559206  67.762595  0.038251
# 047040202204  대우건설  2022   사업보고서  222.941221  20.194864  63.490311  0.089092
#
#               매출액영업이익률  매출액경상이익률  이자보상배율(배)   매출액 증가율   총자산 증가율  영업이익 증가율  \
# 아이디
# 047040202001  0.061342  0.037706   4.892426 -0.000897 -0.006273  0.372346
# 047040202002  0.040447  0.036969   2.958595 -0.118294 -0.049831 -0.009515
# 047040202003  0.053793  0.037168   4.395022 -0.052780  0.045616  0.152759
# 047040202004  0.049375  0.027761   4.030243 -0.056190 -0.038377  1.414858
# 047040202101  0.116747  0.109238  13.190858 -0.033828 -0.015724  0.838829
# 047040202102  0.052589  0.053408   7.438426  0.048650  0.063425  0.363457
# 047040202103  0.035828  0.023442   5.891534  0.048550 -0.007515 -0.301631
# 047040202104  0.070854  0.057224  10.772770  0.058721  0.094464  0.519291
# 047040202201  0.094116  0.093552  17.618972  0.136723  0.048294 -0.083629
# 047040202202  0.030574  0.024498   5.198499  0.164839  0.017764 -0.322785
# 047040202203  0.054667  0.063944   7.838198  0.192784  0.076890  0.819958
# 047040202204  0.046508  0.039153   6.031323  0.152515  0.051797 -0.243500
#
#               자기자본 증가율  매출채권 회전기일(일)  재고자산 회전기일(일)  매입채무 회전기일(일)   총자산 회전율  \
# 아이디
# 047040202001  0.001204      0.001204     45.631381     13.899664  0.212463
# 047040202002 -0.003810     -0.003810     90.787613     29.260059  0.216552
# 047040202003 -0.007162     -0.007162    114.531865     40.782967  0.202732
# 047040202004  0.089838      0.089838     41.953928      5.012450  0.909276
# 047040202101  0.118897      0.118897     39.388316     12.964705  0.208556
# 047040202102  0.129778      0.129778     76.398110     28.372698  0.213543
# 047040202103  0.126218      0.126218     96.218810     28.866785  0.214185
# 047040202104  0.149544      0.149544     31.159070     10.735149  0.879581
# 047040202201  0.135176      0.135176     28.684449      9.289035  0.226148
# 047040202202  0.123760      0.123760     59.742829     21.729575  0.244402
# 047040202203  0.160463      0.160463    101.196349     29.352415  0.237235
# 047040202204  0.098876      0.098876     39.769910     12.849455  0.963808
#
#               부채상환계수(배)  총차입금상환능력비율
# 아이디
# 047040202001   0.082427    0.054213
# 047040202002   0.068766    0.040503
# 047040202003   0.138114    0.092279
# 047040202004   0.283005    0.170085
# 047040202101   0.809594    0.564935
# 047040202102   1.866733    0.870696
# 047040202103   2.179110    0.939292
# 047040202104   2.980330    1.645485
# 047040202201  -0.077467   -0.057574
# 047040202202   0.074231    0.029858
# 047040202203  -0.307562   -0.182349
# 047040202204  -0.449085   -0.308276

# %%
df.to_csv(f'/content/drive/MyDrive/ICR/재무비율/{corp_name_p}_재무비율.csv')

# %% [markdown]
# ### 서희 건설

# %%
corp_name = ['DL이앤씨', 'HDC현대산업개발', '한전KPS', 'HJ중공업', '신세계건설', 'KCC건설', '대우건설', '서희건설', '특수건설', '계룡건설산업', '신원종합개발', '서한', '태영건설', '현대건설', 'GS건설', '동부건설', '코오롱글로벌', 'DL건설', '진흥기업', '남광토건', '한신공영', '금호건설', '삼부토건']
corp_code = ['375500', '294870', '051600', '097230', '034300', '021320', '047040', '035890', '026150', '013580', '017000', '011370', '009410', '000720', '006360', '005960', '003070', '001880', '002780', '001260', '004960', '002990', '001470']
report_code = ["11013", "11012", "11014", "11011"] # '11013'=1분기보고서, '11012'=반기보고서, '11014'=3분기보고서, '11011'=사업보고서

corp_name_p = corp_name[7]
corp_code_p = corp_code[7]

all = pd.DataFrame()

for year in range(2019, 2023):
  for code in report_code:
    corp = dart.finstate_all(corp_code_p, year, code, fs_div="OFS")
    # corp = corp.drop('account_id', axis=1)
    all = pd.concat([all, corp], ignore_index=True) # 2019년~2022년 별도 재무제표 전문(분기보고서+반기보고서+사업보고서)

all
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# 주석에 있는 단기차입금, 유동성장기부채, 회사채, 장기차입금은 수기로 가져와야 함
short_term_loan = ['10000000000', '9500000000', '9000000000', '9000000000', '9000000000', '7000000000', '7000000000', '7000000000', '7000000000', '7000000000', '7000000000', '7000000000']
liquidity_enhancing_long_term_debt = ['59333000', '59333000', '59333000', '59333000', '59333000', '59333000', '59333000', '59333000', '59333000', '59333000', '59333000', '59333000']
corporate_bond = ['3900000000', '8900000000', '8900000000', '5000000000', '5000000000', '0', '0', '0', '0', '0', '0', '0']
long_term_loan = ['2926582000', '2926582000', '2926582000', '2926582000', '2867249000', '2867249000', '2867249000', '25867249000', '25807915000', '25807915000', '25807915000', '25807915000']
year_i = ['2020','2020','2020','2020','2021','2021','2021','2021','2022','2022','2022','2022']
report_code_i = ["11013", "11012", "11014", "11011","11013", "11012", "11014", "11011","11013", "11012", "11014", "11011"]

debt = {
    'year':year_i,
    'report_code':report_code_i,
    '단기차입금': short_term_loan,
    '유동성장기부채': liquidity_enhancing_long_term_debt,
    '사채': corporate_bond,
    '장기차입금': long_term_loan}

debt_df = pd.DataFrame(debt)
debt_df
# Out:
#     year report_code        단기차입금   유동성장기부채          사채        장기차입금
# 0   2020       11013  10000000000  59333000  3900000000   2926582000
# 1   2020       11012   9500000000  59333000  8900000000   2926582000
# 2   2020       11014   9000000000  59333000  8900000000   2926582000
# 3   2020       11011   9000000000  59333000  5000000000   2926582000
# 4   2021       11013   9000000000  59333000  5000000000   2867249000
# 5   2021       11012   7000000000  59333000           0   2867249000
# 6   2021       11014   7000000000  59333000           0   2867249000
# 7   2021       11011   7000000000  59333000           0  25867249000
# 8   2022       11013   7000000000  59333000           0  25807915000
# 9   2022       11012   7000000000  59333000           0  25807915000
# 10  2022       11014   7000000000  59333000           0  25807915000
# 11  2022       11011   7000000000  59333000           0  25807915000

# %%
Quarter = []
cor_year = []
ID_list = []
corp_name_list = []
year_list = []
report_code_list = []
Debt_Ratio = []
Debt_to_Asset_Ratio = []
Fixed_Asset_Turnover_Ratio = []
Return_on_Equity = []
Operating_Profit_Margin = []
Gross_Profit_Margin = []
Interest_Coverage_Ratio =[]
Sales_Growth_Rate = []
Total_Asset_Growth_Rate = []
Operating_Profit_Growth_Rate = []
Equity_Growth_Rate= []
Accounts_Receivable_Turnover = []
Inventory_Turnover = []
Accounts_Payable_Turnover = []
Total_Asset_Turnover_Ratio = []
Debt_Service_Coverage_Ratio = []
Debt_to_Equity_Ratio = []


for year in range(2020, 2023):
  str_year = str(year)
  report_code_list.extend(['1분기보고서' if code == '11013' else '반기보고서' if code == '11012' else '3분기보고서' if code == '11014' else '사업보고서' for code in report_code])
  Quarter.extend(['01' if code == '11013' else '02' if code == '11012' else '03' if code == '11014' else '04' for code in report_code])
  for code in report_code:
    BS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '자산총계' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자산총계
    BS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 부채총계
    BS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자본총계
    BS4 = [(row['단기차입금']) for index, row in debt_df.iterrows() if row['year'] == str(year) and row['report_code'] == str(code)]
    BS5 = [(row['유동성장기부채']) for index, row in debt_df.iterrows() if row['year'] == str(year) and row['report_code'] == str(code)]
    BS6 = [(row['사채']) for index, row in debt_df.iterrows() if row['year'] == str(year) and row['report_code'] == str(code)]
    BS7 = [(row['장기차입금']) for index, row in debt_df.iterrows() if row['year'] == str(year) and row['report_code'] == str(code)]
    # BS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '단기차입금' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 단기차입금
    # BS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and ('유동성장기부채' in row['account_nm'] or '유동성장기채무' in row['account_nm']) and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 유동성장기부채
    # BS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '사채' in row['account_nm'] and row['account_id'] == 'dart_BondsIssued' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 사채
    # BS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '차입금' in row['account_nm'] and '단기차입금' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 장기차입금
    BS8 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동자산' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동자산
    BS9 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동부채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동부채
    BS10 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자산총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자산총계
    BS11 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 부채총계
    BS12 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자본총계
    BS13 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매출채권' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매출채권
    BS14 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매입채무' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매입채무
    BS15 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '재고자산' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 재고자산

    IS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '포괄손익계산서' and '기순' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 당기순이익
    IS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업이익
    IS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '수익(매출액)' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 수익(매출액)
    IS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '법인세' in row['account_nm'] and '차감전' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 법인세비용차감전순이익(손실)
    IS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and (row['account_nm'] == '금융비용' or row['account_nm'] == '금융원가') and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 금융비용
    IS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '수익(매출액)' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 수익(매출액) # 분기 보고서만 해당
    IS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '영업이익' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 영업이익 # 분기 보고서만 해당

    CF1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '현금흐름표' and row['account_nm'] == '영업활동현금흐름' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업활동으로 인한 현금흐름

    # if BS6 == BS7: # '사채 및 장기차입금'으로 계정과목 하나만 쓰는 회사는 합침(어차피 사채는 차입금 의존도에서만 사용해서 하나 0으로 만들어도 상관없음)
    #   BS6 = ['0']
    # if BS4 == BS5:
    #   BS4 = ['0'] # '단기차입금 및 유동성장기부채' 로 병합해서 쓰는 회사는 ㅎ나로 합침(어차피 둘이 항상 붙어서 계산해서 상관없음)
    # if BS4 == []:
    #   BS4 = ['0']
    # if BS5 == [''] or BS5 == []:
    #   BS5 = ['0']
    # if BS6 == []:
    #   BS6 = ['0']
    # if BS7 == []:
    #   BS7 = ['0']

    print("자산총계:", BS1, "부채총계:", BS2, "자본총계:", BS3, "단기차입금:", BS4, "유동성장기부채:", BS5, "사채:", BS6, "장기차입금:", BS7, "비유동자산:", BS8, "비유동부채:", BS9, "전기말 자산총계:", BS10, "전기말 부채총계:", BS11,
          "전기말 자본총계:", BS12, "매출채권:", BS13, "매입채무:", BS14, "재고자산:", BS15, "당기순이익:", IS1, "영업이익:", IS2, "수익(매출액):", IS3, "법인세비용차감전순이익(손실):", IS4,
          "금융비용:", IS5, "전기 수익(매출액):", IS6, "전기 영업이익:", IS7, "영업활동으로 인한 현금흐름:", CF1)

    if year != 2020:
      if code == "11013":
        accounting_period = 90
      elif code == "11012":
        accounting_period = 181
      elif code == "11014":
        accounting_period = 273
      elif code == "11011":
        accounting_period = 365
    else: # 2020년은 윤년
      if code == "11013":
        accounting_period = 91
      elif code == "11012":
        accounting_period = 182
      elif code == "11014":
        accounting_period = 274
      elif code == "11011":
        accounting_period = 366


    cor_year.extend([f"{corp_code_p}{str_year}"])
    corp_name_list.append(str(corp_name_p))
    year_list.append(str_year)
    Debt_Ratio.extend([int(BS2)/int(BS3)*100 for BS2, BS3 in zip(BS2, BS3)])
    Debt_to_Asset_Ratio.extend([((int(BS4) + int(BS5) + int(BS6) + int(BS7)) / int(BS1) * 100) for BS4, BS5, BS6, BS7, BS1 in zip(BS4, BS5, BS6, BS7, BS1)])
    Fixed_Asset_Turnover_Ratio.extend([int(BS8)/(int(BS9)+int(BS3))*100 for BS8, BS9, BS3 in zip(BS8, BS9, BS3)]),
    Return_on_Equity.extend([int(IS1)/((int(BS12)+int(BS3))/2) for IS1, BS12, BS3 in zip(IS1, BS12, BS3)])
    Operating_Profit_Margin.extend([int(IS2)/int(IS3) for IS2, IS3 in zip(IS2, IS3)])
    Gross_Profit_Margin.extend([int(IS4)/int(IS3) for IS4, IS3 in zip(IS4, IS3)])
    Interest_Coverage_Ratio.extend([int(IS2)/int(IS5) for IS2, IS5 in zip(IS2, IS5)])
    Sales_Growth_Rate.extend([(int(IS3)-int(IS6))/int(IS6) for IS3, IS6 in zip(IS3, IS6)])
    Total_Asset_Growth_Rate.extend([(int(BS1)-int(BS10))/int(BS10) for BS1, BS10 in zip(BS1, BS10)])
    Operating_Profit_Growth_Rate.extend([(int(IS2)-int(IS7))/int(IS7) for IS2, IS7 in zip(IS2, IS7)])
    Equity_Growth_Rate.extend([(int(BS3)-int(BS12))/int(BS12) for BS3, BS12 in zip(BS3, BS12)])
    Accounts_Receivable_Turnover.extend([int(BS13)/int(IS3)*accounting_period for BS13, IS3 in zip(BS13, IS3)])
    Inventory_Turnover.extend([int(BS15)/int(IS3)*accounting_period for BS15, IS3 in zip(BS15, IS3)])
    Accounts_Payable_Turnover.extend([int(BS14)/int(IS3)*accounting_period for BS14, IS3 in zip(BS14, IS3)])
    Total_Asset_Turnover_Ratio.extend([int(IS3)/int(BS1) for IS3, BS1 in zip(IS3, BS1)])
    Debt_Service_Coverage_Ratio.extend([(int(CF1)+int(IS5))/(int(BS4)+int(BS5)+int(IS5)) for CF1, IS5, BS4, BS5 in zip(CF1, IS5, BS4, BS5)])
    Debt_to_Equity_Ratio.extend([int(CF1)/(int(BS4)+int(BS7)+int(BS5)) for CF1, BS4, BS7, BS5 in zip(CF1, BS4, BS7, BS5)])

ID_list.extend([x+y for x,y in zip(cor_year,Quarter)])

financial_ratio = {
      '아이디':ID_list,
      '기업명':corp_name_list,
      '연도':year_list,
      '보고서 코드':report_code_list,
      '부채비율' : Debt_Ratio,
      '차입금의존도' : Debt_to_Asset_Ratio,
      '고정장기적합률':Fixed_Asset_Turnover_Ratio,
      '자기자본순이익률':Return_on_Equity,
      '매출액영업이익률':Operating_Profit_Margin,
      '매출액경상이익률':Gross_Profit_Margin,
      '이자보상배율(배)':Interest_Coverage_Ratio,
      '매출액 증가율':Sales_Growth_Rate,
      '총자산 증가율':Total_Asset_Growth_Rate,
      '영업이익 증가율':Operating_Profit_Growth_Rate,
      '자기자본 증가율':Equity_Growth_Rate,
      '매출채권 회전기일(일)':Equity_Growth_Rate,
      '재고자산 회전기일(일)':Accounts_Receivable_Turnover,
      '매입채무 회전기일(일)':Accounts_Payable_Turnover,
      '총자산 회전율':Total_Asset_Turnover_Ratio,
      '부채상환계수(배)':Debt_Service_Coverage_Ratio,
      '총차입금상환능력비율':Debt_to_Equity_Ratio
                    }

df = pd.DataFrame(financial_ratio)
df.set_index('아이디', inplace=True)

df
# Out:
# 자산총계: ['921209861093'] 부채총계: ['502172029651'] 자본총계: ['419037831442'] 단기차입금: ['10000000000'] 유동성장기부채: ['59333000'] 사채: ['3900000000'] 장기차입금: ['2926582000'] 비유동자산: ['238886158967'] 비유동부채: ['37961041320'] 전기말 자산총계: ['803100525127'] 전기말 부채총계: ['497445575517'] 전기말 자본총계: ['305654949610'] 매출채권: ['222745839499'] 매입채무: ['237134529122'] 재고자산: ['4826000428'] 당기순이익: ['24209196865'] 영업이익: ['38254185498'] 수익(매출액): ['283501041746'] 법인세비용차감전순이익(손실): ['32905393634'] 금융비용: ['3623474751'] 전기 수익(매출액): ['273863858529'] 전기 영업이익: ['22038332074'] 영업활동으로 인한 현금흐름: ['60670131483']
# 자산총계: ['971707165406'] 부채총계: ['524868252673'] 자본총계: ['446838912733'] 단기차입금: ['9500000000'] 유동성장기부채: ['59333000'] 사채: ['8900000000'] 장기차입금: ['2926582000'] 비유동자산: ['236990136975'] 비유동부채: ['51292559157'] 전기말 자산총계: ['833205251668'] 전기말 부채총계: ['465693640534'] 전기말 자본총계: ['367511611134'] 매출채권: ['218333484951'] 매입채무: ['253411828123'] 재고자산: ['4091504087'] 당기순이익: ['32464557421'] 영업이익: ['45602627559'] 수익(매출액): ['338171050478'] 법인세비용차감전순이익(손실): ['45152490307'] 금융비용: ['826164766'] 전기 수익(매출액): ['347401826152'] 전기 영업이익: ['37609228873'] 영업활동으로 인한 현금흐름: ['125155286286']
# 자산총계: ['1024856173295'] 부채총계: ['543748435940'] 자본총계: ['481107737355'] 단기차입금: ['9000000000'] 유동성장기부채: ['59333000'] 사채: ['8900000000'] 장기차입금: ['2926582000'] 비유동자산: ['256181346859'] 비유동부채: ['55151272878'] 전기말 자산총계: ['816746996867'] 전기말 부채총계: ['442424918642'] 전기말 자본총계: ['374322078225'] 매출채권: ['225629139387'] 매입채무: ['232109605378'] 재고자산: ['2566562606'] 당기순이익: ['35345346911'] 영업이익: ['47392226894'] 수익(매출액): ['306051745057'] 법인세비용차감전순이익(손실): ['47104362426'] 금융비용: ['711186241'] 전기 수익(매출액): ['278413397992'] 전기 영업이익: ['18054309021'] 영업활동으로 인한 현금흐름: ['164111619662']
# 자산총계: ['1046496553904'] 부채총계: ['502070868659'] 자본총계: ['544425685245'] 단기차입금: ['9000000000'] 유동성장기부채: ['59333000'] 사채: ['5000000000'] 장기차입금: ['2926582000'] 비유동자산: ['258917952882'] 비유동부채: ['50657135153'] 전기말 자산총계: ['862840494864'] 전기말 부채총계: ['461418690213'] 전기말 자본총계: ['401421804651'] 매출채권: ['214840634584'] 매입채무: ['241627719143'] 재고자산: ['2592317406'] 당기순이익: ['126548462759'] 영업이익: ['179248427262'] 수익(매출액): ['1258385234169'] 법인세비용차감전순이익(손실): ['172134269475'] 금융비용: ['11795691152'] 전기 수익(매출액): ['1216979058515'] 전기 영업이익: ['115299745478'] 영업활동으로 인한 현금흐름: ['236783463081']
# 자산총계: ['1082377985969'] 부채총계: ['503681198200'] 자본총계: ['578696787769'] 단기차입금: ['9000000000'] 유동성장기부채: ['59333000'] 사채: ['5000000000'] 장기차입금: ['2867249000'] 비유동자산: ['259735241927'] 비유동부채: ['55774579438'] 전기말 자산총계: ['921209861093'] 전기말 부채총계: ['502172029651'] 전기말 자본총계: ['419037831442'] 매출채권: ['123558374902'] 매입채무: ['224044571094'] 재고자산: ['2568247218'] 당기순이익: ['43475590828'] 영업이익: ['50351169995'] 수익(매출액): ['278661548814'] 법인세비용차감전순이익(손실): ['58696464394'] 금융비용: ['3094224390'] 전기 수익(매출액): ['283501041746'] 전기 영업이익: ['38254185498'] 영업활동으로 인한 현금흐름: ['94585116608']
# 자산총계: ['1175893653601'] 부채총계: ['542885923138'] 자본총계: ['633007730463'] 단기차입금: ['7000000000'] 유동성장기부채: ['59333000'] 사채: ['0'] 장기차입금: ['2867249000'] 비유동자산: ['294323315817'] 비유동부채: ['56509404072'] 전기말 자산총계: ['971707165406'] 전기말 부채총계: ['524868252673'] 전기말 자본총계: ['446838912733'] 매출채권: ['111756231636'] 매입채무: ['233002394598'] 재고자산: ['2226213565'] 당기순이익: ['55791313713'] 영업이익: ['60513011824'] 수익(매출액): ['319625441623'] 법인세비용차감전순이익(손실): ['75336209765'] 금융비용: ['-139674312'] 전기 수익(매출액): ['338171050478'] 전기 영업이익: ['45602627559'] 영업활동으로 인한 현금흐름: ['198928347315']
# 자산총계: ['1203953778451'] 부채총계: ['533731929687'] 자본총계: ['670221848764'] 단기차입금: ['7000000000'] 유동성장기부채: ['59333000'] 사채: ['0'] 장기차입금: ['2867249000'] 비유동자산: ['361063558748'] 비유동부채: ['58282666172'] 전기말 자산총계: ['1024856173295'] 전기말 부채총계: ['543748435940'] 전기말 자본총계: ['481107737355'] 매출채권: ['102582152555'] 매입채무: ['248996027748'] 재고자산: ['2481408557'] 당기순이익: ['37238535555'] 영업이익: ['49668079256'] 수익(매출액): ['316607896290'] 법인세비용차감전순이익(손실): ['50226712741'] 금융비용: ['3217569760'] 전기 수익(매출액): ['306051745057'] 전기 영업이익: ['47392226894'] 영업활동으로 인한 현금흐름: ['219808973252']
# 자산총계: ['1338590317343'] 부채총계: ['635872864617'] 자본총계: ['702717452726'] 단기차입금: ['7000000000'] 유동성장기부채: ['59333000'] 사채: ['0'] 장기차입금: ['25867249000'] 비유동자산: ['458122265312'] 비유동부채: ['80474319137'] 전기말 자산총계: ['1046496553904'] 전기말 부채총계: ['502070868659'] 전기말 자본총계: ['544425685245'] 매출채권: ['135252690054'] 매입채무: ['293169782619'] 재고자산: ['2588125415'] 당기순이익: ['169912812562'] 영업이익: ['210637716316'] 수익(매출액): ['1305566780712'] 법인세비용차감전순이익(손실): ['237042219935'] 금융비용: ['6766093394'] 전기 수익(매출액): ['1258385234169'] 전기 영업이익: ['179248427262'] 영업활동으로 인한 현금흐름: ['295220926252']
# 자산총계: ['1333327880389'] 부채총계: ['613460559427'] 자본총계: ['719867320962'] 단기차입금: ['7000000000'] 유동성장기부채: ['59333000'] 사채: ['0'] 장기차입금: ['25807915000'] 비유동자산: ['478439895001'] 비유동부채: ['82207298687'] 전기말 자산총계: ['1082377985969'] 전기말 부채총계: ['503681198200'] 전기말 자본총계: ['578696787769'] 매출채권: ['119339519122'] 매입채무: ['279843239084'] 재고자산: ['2395093405'] 당기순이익: ['27524503502'] 영업이익: ['50849888944'] 수익(매출액): ['329776467314'] 법인세비용차감전순이익(손실): ['36806844681'] 금융비용: ['13297818527'] 전기 수익(매출액): ['278661548814'] 전기 영업이익: ['50351169995'] 영업활동으로 인한 현금흐름: ['20932703431']
# 자산총계: ['1409450702899'] 부채총계: ['660221399791'] 자본총계: ['749229303108'] 단기차입금: ['7000000000'] 유동성장기부채: ['59333000'] 사채: ['0'] 장기차입금: ['25807915000'] 비유동자산: ['525118811368'] 비유동부채: ['89608798888'] 전기말 자산총계: ['1175893653601'] 전기말 부채총계: ['542885923138'] 전기말 자본총계: ['633007730463'] 매출채권: ['157926155412'] 매입채무: ['291547347775'] 재고자산: ['2464937136'] 당기순이익: ['29287493307'] 영업이익: ['62776204055'] 수익(매출액): ['398461790665'] 법인세비용차감전순이익(손실): ['39905137603'] 금융비용: ['20755700898'] 전기 수익(매출액): ['319625441623'] 전기 영업이익: ['60513011824'] 영업활동으로 인한 현금흐름: ['107252167608']
# 자산총계: ['1385324530728'] 부채총계: ['605433641996'] 자본총계: ['779890888732'] 단기차입금: ['7000000000'] 유동성장기부채: ['59333000'] 사채: ['0'] 장기차입금: ['25807915000'] 비유동자산: ['529978374576'] 비유동부채: ['89985380515'] 전기말 자산총계: ['1203953778451'] 전기말 부채총계: ['533731929687'] 전기말 자본총계: ['670221848764'] 매출채권: ['193106548574'] 매입채무: ['263252782061'] 재고자산: ['2477344243'] 당기순이익: ['30307628453'] 영업이익: ['43516426146'] 수익(매출액): ['327777268685'] 법인세비용차감전순이익(손실): ['41284629870'] 금융비용: ['-2661930713'] 전기 수익(매출액): ['316607896290'] 전기 영업이익: ['49668079256'] 영업활동으로 인한 현금흐름: ['48537184456']
# 자산총계: ['1518325666333'] 부채총계: ['727580506369'] 자본총계: ['790745159964'] 단기차입금: ['7000000000'] 유동성장기부채: ['59333000'] 사채: ['0'] 장기차입금: ['25807915000'] 비유동자산: ['521742628076'] 비유동부채: ['90867607200'] 전기말 자산총계: ['1338590317343'] 전기말 부채총계: ['635872864617'] 전기말 자본총계: ['702717452726'] 매출채권: ['268876848106'] 매입채무: ['283096018609'] 재고자산: ['2417920371'] 당기순이익: ['99283902648'] 영업이익: ['203427369940'] 수익(매출액): ['1407700694106'] 법인세비용차감전순이익(손실): ['138428490299'] 금융비용: ['46842414185'] 전기 수익(매출액): ['1305566780712'] 전기 영업이익: ['210637716316'] 영업활동으로 인한 현금흐름: ['167457949950']
#                기업명    연도  보고서 코드        부채비율    차입금의존도    고정장기적합률  자기자본순이익률  \
# 아이디
# 035890202001  서희건설  2020  1분기보고서  119.839306  1.833015  52.272811  0.066812
# 035890202002  서희건설  2020   반기보고서  117.462521  2.200860  47.575821  0.079731
# 035890202003  서희건설  2020  3분기보고서  113.020098  2.037936  47.771943  0.082638
# 035890202004  서희건설  2020   사업보고서   92.220276  1.623122  43.509566  0.267587
# 035890202101  서희건설  2021  1분기보고서   87.037151  1.563833  40.937268  0.087149
# 035890202102  서희건설  2021   반기보고서   85.762922  0.844173  42.685424  0.103332
# 035890202103  서희건설  2021  3분기보고서   79.635113  0.824499  49.562295  0.064688
# 035890202104  서희건설  2021   사업보고서   90.487701  2.459795  58.494264  0.272483
# 035890202201  서희건설  2022  1분기보고서   85.218559  2.465054  59.650297  0.042392
# 035890202202  서희건설  2022   반기보고서   88.120072  2.331919  62.600734  0.042377
# 035890202203  서희건설  2022  3분기보고서   77.630557  2.372531  60.925719  0.041800
# 035890202204  서희건설  2022   사업보고서   92.012009  2.164703  59.180476  0.132958
#
#               매출액영업이익률  매출액경상이익률   이자보상배율(배)   매출액 증가율   총자산 증가율  영업이익 증가율  \
# 아이디
# 035890202001  0.134935  0.116068   10.557321  0.035190  0.147067  0.735802
# 035890202002  0.134851  0.133520   55.197982 -0.026571  0.166228  0.212538
# 035890202003  0.154850  0.153910   66.638279  0.099271  0.254802  1.624981
# 035890202004  0.142443  0.136790   15.196094  0.034024  0.212851  0.554630
# 035890202101  0.180689  0.210637   16.272630 -0.017070  0.174953  0.316226
# 035890202102  0.189325  0.235702 -433.243672 -0.054841  0.210132  0.326963
# 035890202103  0.156876  0.158640   15.436520  0.034491  0.174754  0.048022
# 035890202104  0.161338  0.181563   31.131364  0.037494  0.279116  0.175116
# 035890202201  0.154195  0.111611    3.823927  0.183430  0.231851  0.009905
# 035890202202  0.157546  0.100148    3.024528  0.246652  0.198621  0.037400
# 035890202203  0.132762  0.125953  -16.347693  0.035278  0.150646 -0.123855
# 035890202204  0.144510  0.098337    4.342803  0.078230  0.134272 -0.034231
#
#               자기자본 증가율  매출채권 회전기일(일)  재고자산 회전기일(일)  매입채무 회전기일(일)   총자산 회전율  \
# 아이디
# 035890202001  0.370951      0.370951     71.498402     76.116977  0.307749
# 035890202002  0.215850      0.215850    117.504719    136.383504  0.348017
# 035890202003  0.285277      0.285277    201.999777    207.801566  0.298629
# 035890202004  0.356243      0.356243     62.486169     70.277164  1.202474
# 035890202101  0.381013      0.381013     39.905950     72.360222  0.257453
# 035890202102  0.416635      0.416635     63.286195    131.946422  0.271815
# 035890202103  0.393081      0.393081     88.453030    214.700632  0.262973
# 035890202104  0.290750      0.290750     37.812874     81.962081  0.975330
# 035890202201  0.243946      0.243946     32.569203     76.372616  0.247333
# 035890202202  0.183602      0.183602     71.737453    132.434455  0.282707
# 035890202203  0.163631      0.163631    160.835094    219.258675  0.236607
# 035890202204  0.125268      0.125268     69.716560     73.403421  0.927140
#
#               부채상환계수(배)  총차입금상환능력비율
# 아이디
# 035890202001   4.698861    4.671995
# 035890202002  12.130516   10.023718
# 035890202003  16.869401   13.692039
# 035890202004  11.919389   19.755143
# 035890202101   8.037099    7.930614
# 035890202102  28.728104   20.039964
# 035890202103  21.701727   22.143470
# 035890202104  21.842872    8.966036
# 035890202201   1.681499    0.636886
# 035890202202   4.602111    3.263193
# 035890202203  10.432353    1.476764
# 035890202204   3.975759    5.094979

# %%
df.to_csv(f'/content/drive/MyDrive/ICR/재무비율/{corp_name_p}_재무비율.csv')

# %% [markdown]
# ### 특수건설

# %%
corp_name = ['DL이앤씨', 'HDC현대산업개발', '한전KPS', 'HJ중공업', '신세계건설', 'KCC건설', '대우건설', '서희건설', '특수건설', '계룡건설산업', '신원종합개발', '서한', '태영건설', '현대건설', 'GS건설', '동부건설', '코오롱글로벌', 'DL건설', '진흥기업', '남광토건', '한신공영', '금호건설', '삼부토건']
corp_code = ['375500', '294870', '051600', '097230', '034300', '021320', '047040', '035890', '026150', '013580', '017000', '011370', '009410', '000720', '006360', '005960', '003070', '001880', '002780', '001260', '004960', '002990', '001470']
report_code = ["11013", "11012", "11014", "11011"] # '11013'=1분기보고서, '11012'=반기보고서, '11014'=3분기보고서, '11011'=사업보고서

corp_name_p = corp_name[8]
corp_code_p = corp_code[8]

all = pd.DataFrame()

for year in range(2019, 2023):
  for code in report_code:
    corp = dart.finstate_all(corp_code_p, year, code, fs_div="OFS")
    # corp = corp.drop('account_id', axis=1)
    all = pd.concat([all, corp], ignore_index=True) # 2019년~2022년 별도 재무제표 전문(분기보고서+반기보고서+사업보고서)

all
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
Quarter = []
cor_year = []
ID_list = []
corp_name_list = []
year_list = []
report_code_list = []
Debt_Ratio = []
Debt_to_Asset_Ratio = []
Fixed_Asset_Turnover_Ratio = []
Return_on_Equity = []
Operating_Profit_Margin = []
Gross_Profit_Margin = []
Interest_Coverage_Ratio =[]
Sales_Growth_Rate = []
Total_Asset_Growth_Rate = []
Operating_Profit_Growth_Rate = []
Equity_Growth_Rate= []
Accounts_Receivable_Turnover = []
Inventory_Turnover = []
Accounts_Payable_Turnover = []
Total_Asset_Turnover_Ratio = []
Debt_Service_Coverage_Ratio = []
Debt_to_Equity_Ratio = []


for year in range(2020, 2023):
  str_year = str(year)
  report_code_list.extend(['1분기보고서' if code == '11013' else '반기보고서' if code == '11012' else '3분기보고서' if code == '11014' else '사업보고서' for code in report_code])
  Quarter.extend(['01' if code == '11013' else '02' if code == '11012' else '03' if code == '11014' else '04' for code in report_code])
  for code in report_code:
    BS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '자산총계' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자산총계
    BS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 부채총계
    BS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자본총계
    BS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '단기차입금' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 단기차입금
    BS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and ('유동성장기차입' in row['account_nm'] or '유동성장기채무' in row['account_nm']) and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 유동성장기부채
    BS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '신주인수권부사채' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 사채
    BS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '장기차입금' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 장기차입금
    BS8 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동자산' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동자산
    BS9 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동부채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동부채
    BS10 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자산총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자산총계
    BS11 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 부채총계
    BS12 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자본총계
    BS13 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '매출채권' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매출채권
    BS14 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '매입채무'  and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매입채무
    BS15 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '재고자산' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 재고자산
    BS16 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '전환권조정' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 사채 전환권 조정
    BS17 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '사채할인발행차금' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 사채할인발행차금

    IS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '포괄손익계산서' and '기순' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 당기순이익
    IS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업이익
    IS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '매출액' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 수익(매출액)
    IS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '법인세' in row['account_nm'] and '차감전' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 법인세비용차감전순이익(손실)
    IS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and (row['account_nm'] == '금융비용' or row['account_nm'] == '금융원가') and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 금융비용
    IS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '매출액' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 수익(매출액) # 분기 보고서만 해당
    IS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '영업이익(손실)' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 영업이익 # 분기 보고서만 해당

    CF1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '현금흐름표' and row['account_nm'] == '영업활동현금흐름' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업활동으로 인한 현금흐름

    # if BS6 == BS7: # '사채 및 장기차입금'으로 계정과목 하나만 쓰는 회사는 합침(어차피 사채는 차입금 의존도에서만 사용해서 하나 0으로 만들어도 상관없음)
    #   BS6 = ['0']
    # if BS4 == BS5:
    #   BS4 = ['0'] # '단기차입금 및 유동성장기부채' 로 병합해서 쓰는 회사는 하나로 합침(어차피 둘이 항상 붙어서 계산해서 상관없음)
    # if BS4 == []:
    #   BS4 = ['0']
    # if BS5 == [''] or BS5 == []:
    #   BS5 = ['0']
    if BS6 == [''] or BS6 == []:
      BS6 = ['0']
      BS16 = ['0']
      BS17 = ['0']
    if len(BS6) >= 2:
      BS6 = [str(BS6[0])]
    # if BS7 == []:
    #   BS7 = ['0']

    print("자산총계:", BS1, "부채총계:", BS2, "자본총계:", BS3, "단기차입금:", BS4, "유동성장기부채:", BS5, "사채:", BS6, "장기차입금:", BS7, "비유동자산:", BS8, "비유동부채:", BS9, "전기말 자산총계:", BS10, "전기말 부채총계:", BS11,
          "전기말 자본총계:", BS12, "매출채권:", BS13, "매입채무:", BS14, "재고자산:", BS15, "당기순이익:", IS1, "영업이익:", IS2, "수익(매출액):", IS3, "법인세비용차감전순이익(손실):", IS4,
          "금융비용:", IS5, "전기 수익(매출액):", IS6, "전기 영업이익:", IS7, "영업활동으로 인한 현금흐름:", CF1)

    if year != 2020:
      if code == "11013":
        accounting_period = 90
      elif code == "11012":
        accounting_period = 181
      elif code == "11014":
        accounting_period = 273
      elif code == "11011":
        accounting_period = 365
    else: # 2020년은 윤년
      if code == "11013":
        accounting_period = 91
      elif code == "11012":
        accounting_period = 182
      elif code == "11014":
        accounting_period = 274
      elif code == "11011":
        accounting_period = 366


    cor_year.extend([f"{corp_code_p}{str_year}"])
    corp_name_list.append(str(corp_name_p))
    year_list.append(str_year)
    Debt_Ratio.extend([int(BS2)/int(BS3)*100 for BS2, BS3 in zip(BS2, BS3)])
    Debt_to_Asset_Ratio.extend([((int(BS4) + int(BS5) + int(BS6) - int(BS16) - int(BS17) + int(BS7)) / int(BS1) * 100) for BS4, BS5, BS6, BS7, BS1, BS16, BS17 in zip(BS4, BS5, BS6, BS7, BS1, BS16, BS17)])
    Fixed_Asset_Turnover_Ratio.extend([int(BS8)/(int(BS9)+int(BS3))*100 for BS8, BS9, BS3 in zip(BS8, BS9, BS3)]),
    Return_on_Equity.extend([int(IS1)/((int(BS12)+int(BS3))/2) for IS1, BS12, BS3 in zip(IS1, BS12, BS3)])
    Operating_Profit_Margin.extend([int(IS2)/int(IS3) for IS2, IS3 in zip(IS2, IS3)])
    Gross_Profit_Margin.extend([int(IS4)/int(IS3) for IS4, IS3 in zip(IS4, IS3)])
    Interest_Coverage_Ratio.extend([int(IS2)/int(IS5) for IS2, IS5 in zip(IS2, IS5)])
    Sales_Growth_Rate.extend([(int(IS3)-int(IS6))/int(IS6) for IS3, IS6 in zip(IS3, IS6)])
    Total_Asset_Growth_Rate.extend([(int(BS1)-int(BS10))/int(BS10) for BS1, BS10 in zip(BS1, BS10)])
    Operating_Profit_Growth_Rate.extend([(int(IS2)-int(IS7))/int(IS7) for IS2, IS7 in zip(IS2, IS7)])
    Equity_Growth_Rate.extend([(int(BS3)-int(BS12))/int(BS12) for BS3, BS12 in zip(BS3, BS12)])
    Accounts_Receivable_Turnover.extend([int(BS13)/int(IS3)*accounting_period for BS13, IS3 in zip(BS13, IS3)])
    Inventory_Turnover.extend([int(BS15)/int(IS3)*accounting_period for BS15, IS3 in zip(BS15, IS3)])
    Accounts_Payable_Turnover.extend([int(BS14)/int(IS3)*accounting_period for BS14, IS3 in zip(BS14, IS3)])
    Total_Asset_Turnover_Ratio.extend([int(IS3)/int(BS1) for IS3, BS1 in zip(IS3, BS1)])
    Debt_Service_Coverage_Ratio.extend([(int(CF1)+int(IS5))/(int(BS4)+int(BS5)+int(IS5)) for CF1, IS5, BS4, BS5 in zip(CF1, IS5, BS4, BS5)])
    Debt_to_Equity_Ratio.extend([int(CF1)/(int(BS4)+int(BS7)+int(BS5)) for CF1, BS4, BS7, BS5 in zip(CF1, BS4, BS7, BS5)])

ID_list.extend([x+y for x,y in zip(cor_year,Quarter)])

financial_ratio = {
      '아이디':ID_list,
      '기업명':corp_name_list,
      '연도':year_list,
      '보고서 코드':report_code_list,
      '부채비율' : Debt_Ratio,
      '차입금의존도' : Debt_to_Asset_Ratio,
      '고정장기적합률':Fixed_Asset_Turnover_Ratio,
      '자기자본순이익률':Return_on_Equity,
      '매출액영업이익률':Operating_Profit_Margin,
      '매출액경상이익률':Gross_Profit_Margin,
      '이자보상배율(배)':Interest_Coverage_Ratio,
      '매출액 증가율':Sales_Growth_Rate,
      '총자산 증가율':Total_Asset_Growth_Rate,
      '영업이익 증가율':Operating_Profit_Growth_Rate,
      '자기자본 증가율':Equity_Growth_Rate,
      '매출채권 회전기일(일)':Equity_Growth_Rate,
      '재고자산 회전기일(일)':Accounts_Receivable_Turnover,
      '매입채무 회전기일(일)':Accounts_Payable_Turnover,
      '총자산 회전율':Total_Asset_Turnover_Ratio,
      '부채상환계수(배)':Debt_Service_Coverage_Ratio,
      '총차입금상환능력비율':Debt_to_Equity_Ratio
                    }

df = pd.DataFrame(financial_ratio)
df.set_index('아이디', inplace=True)

df
# Out:
# 자산총계: ['176008446258'] 부채총계: ['87529498497'] 자본총계: ['88478947761'] 단기차입금: ['10988729052'] 유동성장기부채: ['400000000'] 사채: ['4000000000'] 장기차입금: ['11200000000'] 비유동자산: ['68773411886'] 비유동부채: ['24658750198'] 전기말 자산총계: ['159048496372'] 전기말 부채총계: ['73277896017'] 전기말 자본총계: ['85770600355'] 매출채권: ['1592257296'] 매입채무: ['29225103128'] 재고자산: ['9581454401'] 당기순이익: ['2042042051'] 영업이익: ['2149657156'] 수익(매출액): ['52392796080'] 법인세비용차감전순이익(손실): ['2042042051'] 금융비용: ['327239476'] 전기 수익(매출액): ['48358609258'] 전기 영업이익: ['588002960'] 영업활동으로 인한 현금흐름: ['3834365218']
# 자산총계: ['169890279595'] 부채총계: ['79311064667'] 자본총계: ['90579214928'] 단기차입금: ['9734964436'] 유동성장기부채: ['600000000'] 사채: ['2000000000'] 장기차입금: ['11100000000'] 비유동자산: ['69845833531'] 비유동부채: ['25171602795'] 전기말 자산총계: ['158475063970'] 전기말 부채총계: ['71758715217'] 전기말 자본총계: ['86716348753'] 매출채권: ['1110172781'] 매입채무: ['23447078638'] 재고자산: ['9411248500'] 당기순이익: ['227455048'] 영업이익: ['1327451931'] 수익(매출액): ['47405870239'] 법인세비용차감전순이익(손실): ['1090390501'] 금융비용: ['374596923'] 전기 수익(매출액): ['45784741186'] 전기 영업이익: ['1425717764'] 영업활동으로 인한 현금흐름: ['19805577098']
# 자산총계: ['165560350913'] 부채총계: ['76097247718'] 자본총계: ['89463103195'] 단기차입금: ['9477628902'] 유동성장기부채: ['500000000'] 사채: ['2000000000'] 장기차입금: ['11000000000'] 비유동자산: ['70013599744'] 비유동부채: ['24647443697'] 전기말 자산총계: ['157559197239'] 전기말 부채총계: ['71157572309'] 전기말 자본총계: ['86401624930'] 매출채권: ['1111300436'] 매입채무: ['22109140357'] 재고자산: ['9660770221'] 당기순이익: ['-1005517499'] 영업이익: ['-1141864215'] 수익(매출액): ['41247704762'] 법인세비용차감전순이익(손실): ['-1005517499'] 금융비용: ['311892705'] 전기 수익(매출액): ['40190034565'] 전기 영업이익: ['-1228824586'] 영업활동으로 인한 현금흐름: ['6501260268']
# 자산총계: ['173221482717'] 부채총계: ['82394024581'] 자본총계: ['90827458136'] 단기차입금: ['4600519946'] 유동성장기부채: ['5714386305'] 사채: ['2000000000'] 장기차입금: ['12298771690'] 비유동자산: ['70676100363'] 비유동부채: ['23985153820'] 전기말 자산총계: ['169619463963'] 전기말 부채총계: ['83110315863'] 전기말 자본총계: ['86509148100'] 매출채권: ['636634731'] 매입채무: ['22702136913'] 재고자산: ['6575829999'] 당기순이익: ['2401664751'] 영업이익: ['4898652132'] 수익(매출액): ['192599032119'] 법인세비용차감전순이익(손실): ['3486302948'] 금융비용: ['1529676244'] 전기 수익(매출액): ['182821495456'] 전기 영업이익: ['1139177848'] 영업활동으로 인한 현금흐름: ['26410872467']
# 자산총계: ['177811187452'] 부채총계: ['86011797920'] 자본총계: ['91799389532'] 단기차입금: ['5607373038'] 유동성장기부채: ['4665420285'] 사채: ['2000000000'] 장기차입금: ['11833126969'] 비유동자산: ['73658391665'] 비유동부채: ['23664201824'] 전기말 자산총계: ['176008446258'] 전기말 부채총계: ['87529498497'] 전기말 자본총계: ['88478947761'] 매출채권: ['1013027731'] 매입채무: ['28590821961'] 재고자산: ['5700535243'] 당기순이익: ['568072460'] 영업이익: ['782061306'] 수익(매출액): ['58768458188'] 법인세비용차감전순이익(손실): ['568072460'] 금융비용: ['278998993'] 전기 수익(매출액): ['52392796080'] 전기 영업이익: ['2149657156'] 영업활동으로 인한 현금흐름: ['-7825569742']
# 자산총계: ['179643104930'] 부채총계: ['87052736573'] 자본총계: ['92590368357'] 단기차입금: ['3507003885'] 유동성장기부채: ['4580020147'] 사채: ['2000000000'] 장기차입금: ['11330701185'] 비유동자산: ['79204194921'] 비유동부채: ['23732044898'] 전기말 자산총계: ['169890279595'] 전기말 부채총계: ['79311064667'] 전기말 자본총계: ['90579214928'] 매출채권: ['771691131'] 매입채무: ['30629049367'] 재고자산: ['6286177356'] 당기순이익: ['796399787'] 영업이익: ['2884000836'] 수익(매출액): ['63746390117'] 법인세비용차감전순이익(손실): ['971079073'] 금융비용: ['1887776870'] 전기 수익(매출액): ['47405870239'] 전기 영업이익: ['1327451931'] 영업활동으로 인한 현금흐름: ['-509086390']
# 자산총계: ['191788402414'] 부채총계: ['84549808931'] 자본총계: ['107238593483'] 단기차입금: ['3518030966'] 유동성장기부채: ['4536771906'] 사채: ['2000000000'] 장기차입금: ['11253354948'] 비유동자산: ['85945571801'] 비유동부채: ['23672953738'] 전기말 자산총계: ['165560350913'] 전기말 부채총계: ['76097247718'] 전기말 자본총계: ['89463103195'] 매출채권: ['1326893564'] 매입채무: ['30704191524'] 재고자산: ['9092412462'] 당기순이익: ['-534666055'] 영업이익: ['617865586'] 수익(매출액): ['53934710346'] 법인세비용차감전순이익(손실): ['-534666055'] 금융비용: ['246038400'] 전기 수익(매출액): ['41247704762'] 전기 영업이익: ['-1141864215'] 영업활동으로 인한 현금흐름: ['-5839141506']
# 자산총계: ['179358015665'] 부채총계: ['75656172610'] 자본총계: ['103701843055'] 단기차입금: ['2520593109'] 유동성장기부채: ['5126585510'] 사채: ['0'] 장기차입금: ['10665616821'] 비유동자산: ['81120860803'] 비유동부채: ['21925138887'] 전기말 자산총계: ['173221482717'] 전기말 부채총계: ['82394024581'] 전기말 자본총계: ['90827458136'] 매출채권: ['1515054084'] 매입채무: ['26548046359'] 재고자산: ['8431465634'] 당기순이익: ['-6829149052'] 영업이익: ['2415745361'] 수익(매출액): ['229539892157'] 법인세비용차감전순이익(손실): ['-7610617567'] 금융비용: ['2623383845'] 전기 수익(매출액): ['192599032119'] 전기 영업이익: ['4898652132'] 영업활동으로 인한 현금흐름: ['-4154631933']
# 자산총계: ['179878689883'] 부채총계: ['73264179975'] 자본총계: ['106614509908'] 단기차입금: ['2527168422'] 유동성장기부채: ['4702598234'] 사채: ['0'] 장기차입금: ['10497064003'] 비유동자산: ['79643290806'] 비유동부채: ['22195746399'] 전기말 자산총계: ['177811187452'] 전기말 부채총계: ['86011797920'] 전기말 자본총계: ['91799389532'] 매출채권: ['1294377400'] 매입채무: ['23574801993'] 재고자산: ['8701494433'] 당기순이익: ['2402787758'] 영업이익: ['2470349634'] 수익(매출액): ['54256022576'] 법인세비용차감전순이익(손실): ['2402787758'] 금융비용: ['177537586'] 전기 수익(매출액): ['58768458188'] 전기 영업이익: ['782061306'] 영업활동으로 인한 현금흐름: ['-5830003433']
# 자산총계: ['186301374714'] 부채총계: ['80412951185'] 자본총계: ['105888423529'] 단기차입금: ['2539171383'] 유동성장기부채: ['4271513733'] 사채: ['0'] 장기차입금: ['10325271574'] 비유동자산: ['78806430335'] 비유동부채: ['22451487950'] 전기말 자산총계: ['179643104930'] 전기말 부채총계: ['87052736573'] 전기말 자본총계: ['92590368357'] 매출채권: ['1665622400'] 매입채무: ['25679145030'] 재고자산: ['8836366042'] 당기순이익: ['-1118636391'] 영업이익: ['-435910185'] 수익(매출액): ['52307463405'] 법인세비용차감전순이익(손실): ['-603067068'] 금융비용: ['178050633'] 전기 수익(매출액): ['63746390117'] 전기 영업이익: ['2884000836'] 영업활동으로 인한 현금흐름: ['400287327']
# 자산총계: ['189859160681'] 부채총계: ['82265994169'] 자본총계: ['107593166512'] 단기차입금: ['2566199977'] 유동성장기부채: ['10768885260'] 사채: ['0'] 장기차입금: ['10200000000'] 비유동자산: ['80009836987'] 비유동부채: ['22862045483'] 전기말 자산총계: ['191788402414'] 전기말 부채총계: ['84549808931'] 전기말 자본총계: ['107238593483'] 매출채권: ['2473244400'] 매입채무: ['24160507426'] 재고자산: ['9340187291'] 당기순이익: ['368508884'] 영업이익: ['155983452'] 수익(매출액): ['46437661819'] 법인세비용차감전순이익(손실): ['368508884'] 금융비용: ['257151890'] 전기 수익(매출액): ['53934710346'] 전기 영업이익: ['617865586'] 영업활동으로 인한 현금흐름: ['-7095167762']
# 자산총계: ['182913656832'] 부채총계: ['76833861865'] 자본총계: ['106079794967'] 단기차입금: ['9444705026'] 유동성장기부채: ['10678072919'] 사채: ['0'] 장기차입금: ['0'] 비유동자산: ['73987093490'] 비유동부채: ['10090111102'] 전기말 자산총계: ['179358015665'] 전기말 부채총계: ['75656172610'] 전기말 자본총계: ['103701843055'] 매출채권: ['2376168200'] 매입채무: ['19644540896'] 재고자산: ['9032800247'] 당기순이익: ['1745834538'] 영업이익: ['2924351980'] 수익(매출액): ['202379166027'] 법인세비용차감전순이익(손실): ['2801596534'] 금융비용: ['867872682'] 전기 수익(매출액): ['229539892157'] 전기 영업이익: ['2415745361'] 영업활동으로 인한 현금흐름: ['15497892476']
#                기업명    연도  보고서 코드       부채비율     차입금의존도    고정장기적합률  자기자본순이익률  \
# 아이디
# 026150202001  특수건설  2020  1분기보고서  98.926921  14.160956  60.787353  0.023438
# 026150202002  특수건설  2020   반기보고서  87.559894  14.257979  60.341547  0.002566
# 026150202003  특수건설  2020  3분기보고서  85.059924  14.326945  61.355941 -0.011435
# 026150202004  특수건설  2020   사업보고서  90.714885  13.808418  61.557785  0.027086
# 026150202101  특수건설  2021  1분기보고서  93.695392  13.194050  63.793609  0.006302
# 026150202102  특수건설  2021   반기보고서  94.019214  11.591771  68.090227  0.008696
# 026150202103  특수건설  2021  3분기보고서  78.842706  10.828306  65.651635 -0.005436
# 026150202104  특수건설  2021   사업보고서  72.955475  10.210191  64.572801 -0.070212
# 026150202201  특수건설  2022  1분기보고서  68.718770   9.854881  61.829930  0.024220
# 026150202202  특수건설  2022   반기보고서  75.941211   9.197977  61.404461 -0.011272
# 026150202203  특수건설  2022  3분기보고서  76.460241  12.396076  61.331269  0.003431
# 026150202204  특수건설  2022   사업보고서  72.430251  11.001244  63.688692  0.016644
#
#               매출액영업이익률  매출액경상이익률  이자보상배율(배)   매출액 증가율   총자산 증가율  영업이익 증가율  \
# 아이디
# 026150202001  0.041030  0.038976   6.569064  0.083422  0.106634  2.655861
# 026150202002  0.028002  0.023001   3.543681  0.035408  0.072032 -0.068924
# 026150202003 -0.027683 -0.024378  -3.661080  0.026317  0.050782 -0.070767
# 026150202004  0.025434  0.018101   3.202411  0.053481  0.021236  3.300164
# 026150202101  0.013308  0.009666   2.803097  0.121690  0.010242 -0.636193
# 026150202102  0.045242  0.015233   1.527723  0.344694  0.057407  1.172584
# 026150202103  0.011456 -0.009913   2.511257  0.307581  0.158420 -1.541103
# 026150202104  0.010524 -0.033156   0.920851  0.191802  0.035426 -0.506855
# 026150202201  0.045531  0.044286  13.914516 -0.076783  0.011628  2.158767
# 026150202202 -0.008334 -0.011529  -2.448237 -0.179444  0.037064 -1.151148
# 026150202203  0.003359  0.007936   0.606581 -0.139002 -0.010059 -0.747545
# 026150202204  0.014450  0.013843   3.369563 -0.118327  0.019824  0.210538
#
#               자기자본 증가율  매출채권 회전기일(일)  재고자산 회전기일(일)  매입채무 회전기일(일)   총자산 회전율  \
# 아이디
# 026150202001  0.031577      0.031577      2.765560     50.760497  0.297672
# 026150202002  0.044546      0.044546      4.262161     90.017719  0.279038
# 026150202003  0.035433      0.035433      7.382140    146.866462  0.249140
# 026150202004  0.049917      0.049917      1.209810     43.141349  1.111866
# 026150202101  0.037528      0.037528      1.551385     43.784950  0.330510
# 026150202102  0.022203      0.022203      2.191122     86.967402  0.354850
# 026150202103  0.198691      0.198691      6.716305    155.414653  0.281220
# 026150202104  0.141746      0.141746      2.409144     42.215045  1.279786
# 026150202201  0.161386      0.161386      2.147116     39.105929  0.301626
# 026150202202  0.143622      0.143622      5.763569     88.857783  0.280768
# 026150202203  0.003306      0.003306     14.539830    142.035974  0.244590
# 026150202204  0.022931      0.022931      4.285527     35.429820  1.106419
#
#               부채상환계수(배)  총차입금상환능력비율
# 아이디
# 026150202001   0.355208    0.169747
# 026150202002   1.884314    0.923985
# 026150202003   0.662145    0.309914
# 026150202004   2.358931    1.167916
# 026150202101  -0.715193   -0.354003
# 026150202102   0.138217   -0.026218
# 026150202103  -0.673800   -0.302418
# 026150202104  -0.149091   -0.226870
# 026150202201  -0.763094   -0.328880
# 026150202202   0.082753    0.023359
# 026150202203  -0.503082   -0.301472
# 026150202204   0.779669    0.770167

# %%
df.to_csv(f'/content/drive/MyDrive/ICR/재무비율/{corp_name_p}_재무비율.csv')

# %% [markdown]
# ### 계룡건설산업

# %%
corp_name = ['DL이앤씨', 'HDC현대산업개발', '한전KPS', 'HJ중공업', '신세계건설', 'KCC건설', '대우건설', '서희건설', '특수건설', '계룡건설산업', '신원종합개발', '서한', '태영건설', '현대건설', 'GS건설', '동부건설', '코오롱글로벌', 'DL건설', '진흥기업', '남광토건', '한신공영', '금호건설', '삼부토건']
corp_code = ['375500', '294870', '051600', '097230', '034300', '021320', '047040', '035890', '026150', '013580', '017000', '011370', '009410', '000720', '006360', '005960', '003070', '001880', '002780', '001260', '004960', '002990', '001470']
report_code = ["11013", "11012", "11014", "11011"] # '11013'=1분기보고서, '11012'=반기보고서, '11014'=3분기보고서, '11011'=사업보고서

corp_name_p = corp_name[9]
corp_code_p = corp_code[9]

all = pd.DataFrame()

for year in range(2019, 2023):
  for code in report_code:
    corp = dart.finstate_all(corp_code_p, year, code, fs_div="OFS")
    # corp = corp.drop('account_id', axis=1)
    all = pd.concat([all, corp], ignore_index=True) # 2019년~2022년 별도 재무제표 전문(분기보고서+반기보고서+사업보고서)

all
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
Quarter = []
cor_year = []
ID_list = []
corp_name_list = []
year_list = []
report_code_list = []
Debt_Ratio = []
Debt_to_Asset_Ratio = []
Fixed_Asset_Turnover_Ratio = []
Return_on_Equity = []
Operating_Profit_Margin = []
Gross_Profit_Margin = []
Interest_Coverage_Ratio =[]
Sales_Growth_Rate = []
Total_Asset_Growth_Rate = []
Operating_Profit_Growth_Rate = []
Equity_Growth_Rate= []
Accounts_Receivable_Turnover = []
Inventory_Turnover = []
Accounts_Payable_Turnover = []
Total_Asset_Turnover_Ratio = []
Debt_Service_Coverage_Ratio = []
Debt_to_Equity_Ratio = []


for year in range(2020, 2023):
  str_year = str(year)
  report_code_list.extend(['1분기보고서' if code == '11013' else '반기보고서' if code == '11012' else '3분기보고서' if code == '11014' else '사업보고서' for code in report_code])
  Quarter.extend(['01' if code == '11013' else '02' if code == '11012' else '03' if code == '11014' else '04' for code in report_code])
  for code in report_code:
    BS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '자산총계' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자산총계
    BS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 부채총계
    BS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자본총계
    BS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '단기차입금' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 단기차입금
    BS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and ('유동성장기차입' in row['account_nm'] or '유동성장기채무' in row['account_nm']) and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 유동성장기부채
    BS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '사채' in row['account_nm'] and row['account_id'] == 'dart_BondsIssued' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 사채
    BS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '장기차입금' in row['account_nm'] and '유동성' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 장기차입금
    BS8 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동자산' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동자산
    BS9 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동부채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동부채
    BS10 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자산총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자산총계
    BS11 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 부채총계
    BS12 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자본총계
    BS13 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '매출채권' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매출채권
    BS14 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매입채무' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매입채무
    BS15 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '재고자산' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 재고자산

    IS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '포괄손익계산서' and '기순' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 당기순이익
    IS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업이익
    IS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '매출액' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 수익(매출액)
    IS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '법인세' in row['account_nm'] and '차감전' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 법인세비용차감전순이익(손실)
    IS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and (row['account_nm'] == '금융비용' or row['account_nm'] == '금융원가') and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 금융비용
    IS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '매출액' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 수익(매출액) # 분기 보고서만 해당
    IS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '영업이익(손실)' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 영업이익 # 분기 보고서만 해당

    CF1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '현금흐름표' and row['account_nm'] == '영업활동현금흐름' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업활동으로 인한 현금흐름

    # if BS6 == BS7: # '사채 및 장기차입금'으로 계정과목 하나만 쓰는 회사는 합침(어차피 사채는 차입금 의존도에서만 사용해서 하나 0으로 만들어도 상관없음)
    #   BS6 = ['0']
    # if BS4 == BS5:
    #   BS4 = ['0'] # '단기차입금 및 유동성장기부채' 로 병합해서 쓰는 회사는 ㅎ나로 합침(어차피 둘이 항상 붙어서 계산해서 상관없음)
    # if BS4 == []:
    #   BS4 = ['0']
    # if BS5 == [''] or BS5 == []:
    #   BS5 = ['0']
    # if BS6 == []:
    #   BS6 = ['0']
    # if BS7 == []:
    #   BS7 = ['0']

    print("자산총계:", BS1, "부채총계:", BS2, "자본총계:", BS3, "단기차입금:", BS4, "유동성장기부채:", BS5, "사채:", BS6, "장기차입금:", BS7, "비유동자산:", BS8, "비유동부채:", BS9, "전기말 자산총계:", BS10, "전기말 부채총계:", BS11,
          "전기말 자본총계:", BS12, "매출채권:", BS13, "매입채무:", BS14, "재고자산:", BS15, "당기순이익:", IS1, "영업이익:", IS2, "수익(매출액):", IS3, "법인세비용차감전순이익(손실):", IS4,
          "금융비용:", IS5, "전기 수익(매출액):", IS6, "전기 영업이익:", IS7, "영업활동으로 인한 현금흐름:", CF1)

    if year != 2020:
      if code == "11013":
        accounting_period = 90
      elif code == "11012":
        accounting_period = 181
      elif code == "11014":
        accounting_period = 273
      elif code == "11011":
        accounting_period = 365
    else: # 2020년은 윤년
      if code == "11013":
        accounting_period = 91
      elif code == "11012":
        accounting_period = 182
      elif code == "11014":
        accounting_period = 274
      elif code == "11011":
        accounting_period = 366


    cor_year.extend([f"{corp_code_p}{str_year}"])
    corp_name_list.append(str(corp_name_p))
    year_list.append(str_year)
    Debt_Ratio.extend([int(BS2)/int(BS3)*100 for BS2, BS3 in zip(BS2, BS3)])
    Debt_to_Asset_Ratio.extend([((int(BS4) + int(BS5) + int(BS6) + int(BS7)) / int(BS1) * 100) for BS4, BS5, BS6, BS7, BS1 in zip(BS4, BS5, BS6, BS7, BS1)])
    Fixed_Asset_Turnover_Ratio.extend([int(BS8)/(int(BS9)+int(BS3))*100 for BS8, BS9, BS3 in zip(BS8, BS9, BS3)]),
    Return_on_Equity.extend([int(IS1)/((int(BS12)+int(BS3))/2) for IS1, BS12, BS3 in zip(IS1, BS12, BS3)])
    Operating_Profit_Margin.extend([int(IS2)/int(IS3) for IS2, IS3 in zip(IS2, IS3)])
    Gross_Profit_Margin.extend([int(IS4)/int(IS3) for IS4, IS3 in zip(IS4, IS3)])
    Interest_Coverage_Ratio.extend([int(IS2)/int(IS5) for IS2, IS5 in zip(IS2, IS5)])
    Sales_Growth_Rate.extend([(int(IS3)-int(IS6))/int(IS6) for IS3, IS6 in zip(IS3, IS6)])
    Total_Asset_Growth_Rate.extend([(int(BS1)-int(BS10))/int(BS10) for BS1, BS10 in zip(BS1, BS10)])
    Operating_Profit_Growth_Rate.extend([(int(IS2)-int(IS7))/int(IS7) for IS2, IS7 in zip(IS2, IS7)])
    Equity_Growth_Rate.extend([(int(BS3)-int(BS12))/int(BS12) for BS3, BS12 in zip(BS3, BS12)])
    Accounts_Receivable_Turnover.extend([int(BS13)/int(IS3)*accounting_period for BS13, IS3 in zip(BS13, IS3)])
    Inventory_Turnover.extend([int(BS15)/int(IS3)*accounting_period for BS15, IS3 in zip(BS15, IS3)])
    Accounts_Payable_Turnover.extend([int(BS14)/int(IS3)*accounting_period for BS14, IS3 in zip(BS14, IS3)])
    Total_Asset_Turnover_Ratio.extend([int(IS3)/int(BS1) for IS3, BS1 in zip(IS3, BS1)])
    Debt_Service_Coverage_Ratio.extend([(int(CF1)+int(IS5))/(int(BS4)+int(BS5)+int(IS5)) for CF1, IS5, BS4, BS5 in zip(CF1, IS5, BS4, BS5)])
    Debt_to_Equity_Ratio.extend([int(CF1)/(int(BS4)+int(BS7)+int(BS5)) for CF1, BS4, BS7, BS5 in zip(CF1, BS4, BS7, BS5)])

ID_list.extend([x+y for x,y in zip(cor_year,Quarter)])

financial_ratio = {
      '아이디':ID_list,
      '기업명':corp_name_list,
      '연도':year_list,
      '보고서 코드':report_code_list,
      '부채비율' : Debt_Ratio,
      '차입금의존도' : Debt_to_Asset_Ratio,
      '고정장기적합률':Fixed_Asset_Turnover_Ratio,
      '자기자본순이익률':Return_on_Equity,
      '매출액영업이익률':Operating_Profit_Margin,
      '매출액경상이익률':Gross_Profit_Margin,
      '이자보상배율(배)':Interest_Coverage_Ratio,
      '매출액 증가율':Sales_Growth_Rate,
      '총자산 증가율':Total_Asset_Growth_Rate,
      '영업이익 증가율':Operating_Profit_Growth_Rate,
      '자기자본 증가율':Equity_Growth_Rate,
      '매출채권 회전기일(일)':Equity_Growth_Rate,
      '재고자산 회전기일(일)':Accounts_Receivable_Turnover,
      '매입채무 회전기일(일)':Accounts_Payable_Turnover,
      '총자산 회전율':Total_Asset_Turnover_Ratio,
      '부채상환계수(배)':Debt_Service_Coverage_Ratio,
      '총차입금상환능력비율':Debt_to_Equity_Ratio
                    }

df = pd.DataFrame(financial_ratio)
df.set_index('아이디', inplace=True)

df
# Out:
# 자산총계: ['1549944455666'] 부채총계: ['1127492025145'] 자본총계: ['422452430521'] 단기차입금: ['339704650000'] 유동성장기부채: ['63044824380'] 사채: ['10100000000'] 장기차입금: ['98027326419'] 비유동자산: ['604868799916'] 비유동부채: ['230005131747'] 전기말 자산총계: ['1289008874928'] 전기말 부채총계: ['933726344144'] 전기말 자본총계: ['355282530784'] 매출채권: ['125689933683'] 매입채무: ['744291651876', '217126246111'] 재고자산: ['339364686952'] 당기순이익: ['16110341190'] 영업이익: ['24270324240'] 수익(매출액): ['342269861204'] 법인세비용차감전순이익(손실): ['21860558265'] 금융비용: ['2990383717'] 전기 수익(매출액): ['394380556890'] 전기 영업이익: ['21413177155'] 영업활동으로 인한 현금흐름: ['62376110538']
# 자산총계: ['1597792139029'] 부채총계: ['1150556345340'] 자본총계: ['447235793689'] 단기차입금: ['340704650000'] 유동성장기부채: ['63044824380'] 사채: ['21100000000'] 장기차입금: ['84034288255'] 비유동자산: ['616148096537'] 비유동부채: ['228886527574'] 전기말 자산총계: ['1384267440828'] 전기말 부채총계: ['1006027628989'] 전기말 자본총계: ['378239811839'] 매출채권: ['145456009184'] 매입채무: ['790722529920', '227557269879'] 재고자산: ['332362529070'] 당기순이익: ['24131260354'] 영업이익: ['38409995279'] 수익(매출액): ['402099405672'] 법인세비용차감전순이익(손실): ['31008693337'] 금융비용: ['2945337475'] 전기 수익(매출액): ['394387347176'] 전기 영업이익: ['38365544143'] 영업활동으로 인한 현금흐름: ['115783993733']
# 자산총계: ['1534084960803'] 부채총계: ['1055146261324'] 자본총계: ['478938699479'] 단기차입금: ['218554650000'] 유동성장기부채: ['44824380'] 사채: ['26700000000'] 장기차입금: ['207641208477'] 비유동자산: ['610166446266'] 비유동부채: ['354504247745'] 전기말 자산총계: ['1480276712458'] 전기말 부채총계: ['1083382965966'] 전기말 자본총계: ['396893746492'] 매출채권: ['94844240227'] 매입채무: ['560156557128', '206837475410'] 재고자산: ['315211640337'] 당기순이익: ['32144829286'] 영업이익: ['44184588975'] 수익(매출액): ['396893279693'] 법인세비용차감전순이익(손실): ['42182650549'] 금융비용: ['2809936143'] 전기 수익(매출액): ['377525197089'] 전기 영업이익: ['26472935802'] 영업활동으로 인한 현금흐름: ['165774007322']
# 자산총계: ['1539768324466'] 부채총계: ['1023996169302'] 자본총계: ['515772155164'] 단기차입금: ['184850000000'] 유동성장기부채: ['44824380'] 사채: ['41000000000'] 장기차입금: ['194397843552'] 비유동자산: ['615407244663'] 비유동부채: ['344614117706'] 전기말 자산총계: ['1534677299780'] 전기말 부채총계: ['1122506285094'] 전기말 자본총계: ['412171014686'] 매출채권: ['108521913357'] 매입채무: ['512231376721', '224028478174'] 재고자산: ['329713410337'] 당기순이익: ['101814090741'] 영업이익: ['151990194050'] 수익(매출액): ['1571292959736'] 법인세비용차감전순이익(손실): ['129213755395'] 금융비용: ['12486663268'] 전기 수익(매출액): ['1649389656049'] 전기 영업이익: ['116922456688'] 영업활동으로 인한 현금흐름: ['197592752737']
# 자산총계: ['1710458237460'] 부채총계: ['1178150092009'] 자본총계: ['532308145451'] 단기차입금: ['205644000000'] 유동성장기부채: ['44824380'] 사채: ['41000000000'] 장기차입금: ['133738416995'] 비유동자산: ['624009075779'] 비유동부채: ['278993384460'] 전기말 자산총계: ['1549944455666'] 전기말 부채총계: ['1127492025145'] 전기말 자본총계: ['422452430521'] 매출채권: ['138083555344'] 매입채무: ['640188513316', '260026578973'] 재고자산: ['321819137761'] 당기순이익: ['22416223645'] 영업이익: ['30277049500'] 수익(매출액): ['369847924869'] 법인세비용차감전순이익(손실): ['29951680713'] 금융비용: ['3644561851'] 전기 수익(매출액): ['342269861204'] 전기 영업이익: ['24270324240'] 영업활동으로 인한 현금흐름: ['125652263160']
# 자산총계: ['1773598193817'] 부채총계: ['1193462401055'] 자본총계: ['580135792762'] 단기차입금: ['205644000000'] 유동성장기부채: ['25844824380'] 사채: ['89000000000'] 장기차입금: ['78649837612'] 비유동자산: ['624833548675'] 비유동부채: ['264879422588'] 전기말 자산총계: ['1597792139029'] 전기말 부채총계: ['1150556345340'] 전기말 자본총계: ['447235793689'] 매출채권: ['106650602543'] 매입채무: ['661763935055', '277537905426'] 재고자산: ['333788742018'] 당기순이익: ['47816776507'] 영업이익: ['60578882002'] 수익(매출액): ['478035640464'] 법인세비용차감전순이익(손실): ['62968016017'] 금융비용: ['3464739805'] 전기 수익(매출액): ['402099405672'] 전기 영업이익: ['38409995279'] 영업활동으로 인한 현금흐름: ['178076805167']
# 자산총계: ['1665101710873'] 부채총계: ['1063567550408'] 자본총계: ['601534160465'] 단기차입금: ['205644000000'] 유동성장기부채: ['25844824380'] 사채: ['89000000000'] 장기차입금: ['80656195642'] 비유동자산: ['646107050239'] 비유동부채: ['267774051799'] 전기말 자산총계: ['1534084960803'] 전기말 부채총계: ['1055146261324'] 전기말 자본총계: ['478938699479'] 매출채권: ['70101058931'] 매입채무: ['534255188841', '209628933035'] 재고자산: ['332851604046'] 당기순이익: ['22515526440'] 영업이익: ['31477073538'] 수익(매출액): ['396885802126'] 법인세비용차감전순이익(손실): ['29752125822'] 금융비용: ['3443496919'] 전기 수익(매출액): ['396893279693'] 전기 영업이익: ['44184588975'] 영업활동으로 인한 현금흐름: ['76934861279']
# 자산총계: ['1722670382530'] 부채총계: ['1066972417422'] 자본총계: ['655697965108'] 단기차입금: ['207770000000'] 유동성장기부채: ['44824380'] 사채: ['89000000000'] 장기차입금: ['64322682304'] 비유동자산: ['632551346063'] 비유동부채: ['262682969133'] 전기말 자산총계: ['1539768324466'] 전기말 부채총계: ['1023996169302'] 전기말 자본총계: ['515772155164'] 매출채권: ['91030676405'] 매입채무: ['588999551253', '316357049376'] 재고자산: ['341859825741'] 당기순이익: ['149700379317'] 영업이익: ['203621424439'] 수익(매출액): ['1870762288982'] 법인세비용차감전순이익(손실): ['202036409296'] 금융비용: ['14078174592'] 전기 수익(매출액): ['1571292959736'] 전기 영업이익: ['151990194050'] 영업활동으로 인한 현금흐름: ['133322211236']
# 자산총계: ['1822929857176'] 부채총계: ['1154703566059'] 자본총계: ['668226291117'] 단기차입금: ['228564000000'] 유동성장기부채: ['44824380'] 사채: ['89000000000'] 장기차입금: ['52343712840'] 비유동자산: ['641574890547'] 비유동부채: ['251770104241'] 전기말 자산총계: ['1710458237460'] 전기말 부채총계: ['1178150092009'] 전기말 자본총계: ['532308145451'] 매출채권: ['38402505829'] 매입채무: ['665896961136', '291386015080'] 재고자산: ['320316506333'] 당기순이익: ['20251639942'] 영업이익: ['30177451104'] 수익(매출액): ['451256743642'] 법인세비용차감전순이익(손실): ['25926241718'] 금융비용: ['3187138204'] 전기 수익(매출액): ['369847924869'] 전기 영업이익: ['30277049500'] 영업활동으로 인한 현금흐름: ['106163572778']
# 자산총계: ['1911395719599'] 부채총계: ['1235805088321'] 자본총계: ['675590631278'] 단기차입금: ['222888329000'] 유동성장기부채: ['44824380'] 사채: ['109700000000'] 장기차입금: ['49417188137'] 비유동자산: ['667510370146'] 비유동부채: ['271062038159'] 전기말 자산총계: ['1773598193817'] 전기말 부채총계: ['1193462401055'] 전기말 자본총계: ['580135792762'] 매출채권: ['81583876799'] 매입채무: ['762592373440', '380576027092'] 재고자산: ['291892037551'] 당기순이익: ['10242319846'] 영업이익: ['9937540631'] 수익(매출액): ['548599419646'] 법인세비용차감전순이익(손실): ['13504346866'] 금융비용: ['3528584802'] 전기 수익(매출액): ['478035640464'] 전기 영업이익: ['60578882002'] 영업활동으로 인한 현금흐름: ['121108015514']
# 자산총계: ['1841700182852'] 부채총계: ['1157002147630'] 자본총계: ['684698035222'] 단기차입금: ['222888329000'] 유동성장기부채: ['44824380'] 사채: ['99700000000'] 장기차입금: ['28645876982'] 비유동자산: ['679877831158'] 비유동부채: ['246467512518'] 전기말 자산총계: ['1665101710873'] 전기말 부채총계: ['1063567550408'] 전기말 자본총계: ['601534160465'] 매출채권: ['51997240964'] 매입채무: ['693254448783', '327735679550'] 재고자산: ['304678524264'] 당기순이익: ['14170625079'] 영업이익: ['23243964581'] 수익(매출액): ['475076360909'] 법인세비용차감전순이익(손실): ['18310812199'] 금융비용: ['2656184131'] 전기 수익(매출액): ['396885802126'] 전기 영업이익: ['31477073538'] 영업활동으로 인한 현금흐름: ['102124988257']
# 자산총계: ['1800240035446'] 부채총계: ['1098232791923'] 자본총계: ['702007243523'] 단기차입금: ['202094329000'] 유동성장기부채: ['15844824380'] 사채: ['79700000000'] 장기차입금: ['21419977439'] 비유동자산: ['716705857353'] 비유동부채: ['213111160230'] 전기말 자산총계: ['1722670382530'] 전기말 부채총계: ['1066972417422'] 전기말 자본총계: ['655697965108'] 매출채권: ['86625617632'] 매입채무: ['660267411314', '319830413883'] 재고자산: ['395442666371'] 당기순이익: ['58220410707'] 영업이익: ['96367097203'] 수익(매출액): ['2052333741476'] 법인세비용차감전순이익(손실): ['87514928661'] 금융비용: ['12905429810'] 전기 수익(매출액): ['1870762288982'] 전기 영업이익: ['203621424439'] 영업활동으로 인한 현금흐름: ['56289558906']
#                  기업명    연도  보고서 코드        부채비율     차입금의존도    고정장기적합률  \
# 아이디
# 013580202001  계룡건설산업  2020  1분기보고서  266.892067  32.960975  92.706229
# 013580202002  계룡건설산업  2020   반기보고서  257.259451  31.849184  91.129678
# 013580202003  계룡건설산업  2020  3분기보고서  220.309251  29.525137  73.210344
# 013580202004  계룡건설산업  2020   사업보고서  198.536536  27.295838  71.526855
# 013580202101  계룡건설산업  2021  1분기보고서  221.328586  22.241247  76.914569
# 013580202102  계룡건설산업  2021   반기보고서  205.721215  22.504458  73.943467
# 013580202103  계룡건설산업  2021  3분기보고서  176.809169  24.091322  74.324278
# 013580202104  계룡건설산업  2021   사업보고서  162.723155  20.963819  68.876794
# 013580202201  계룡건설산업  2022  1분기보고서  172.801277  20.294392  69.736674
# 013580202202  계룡건설산업  2022   반기보고서  182.922177  19.988030  70.512701
# 013580202203  계룡건설산업  2022  3분기보고서  168.979913  19.073627  73.013637
# 013580202204  계룡건설산업  2022   사업보고서  156.441803  17.723144  78.318374
#
#               자기자본순이익률  매출액영업이익률  매출액경상이익률  이자보상배율(배)   매출액 증가율   총자산 증가율  \
# 아이디
# 013580202001  0.041429  0.070910  0.063869   8.116124 -0.132133  0.202431
# 013580202002  0.058466  0.095524  0.077117  13.040949  0.019555  0.154251
# 013580202003  0.073404  0.111326  0.106282  15.724410  0.051303  0.036350
# 013580202004  0.219440  0.096729  0.082234  12.172203 -0.047349  0.003317
# 013580202101  0.046957  0.081864  0.080984   8.307459  0.080574  0.103561
# 013580202102  0.093086  0.126725  0.131722  17.484396  0.188849  0.110031
# 013580202103  0.041677  0.079310  0.074964   9.141020 -0.000019  0.085404
# 013580202104  0.255577  0.108844  0.107997  14.463624  0.190588  0.118785
# 013580202201  0.033738  0.066874  0.057453   9.468510  0.220114  0.065755
# 013580202202  0.016313  0.018114  0.024616   2.816296  0.147612  0.077694
# 013580202203  0.022034  0.048927  0.038543   8.750886  0.197010  0.106059
# 013580202204  0.085763  0.046955  0.042642   7.467175  0.097057  0.045029
#
#               영업이익 증가율  자기자본 증가율  매출채권 회전기일(일)  재고자산 회전기일(일)  매입채무 회전기일(일)  \
# 아이디
# 013580202001  0.133429  0.189061      0.189061     33.417444    197.886370
# 013580202002  0.001159  0.182413      0.182413     65.836938    357.900306
# 013580202003  0.669048  0.206718      0.206718     65.476850    386.710747
# 013580202004  0.299923  0.251355      0.251355     25.277922    119.313641
# 013580202101  0.247493  0.260043      0.260043     33.601703    155.785560
# 013580202102  0.577165  0.297159      0.297159     40.381422    250.565569
# 013580202103 -0.287601  0.255973      0.255973     48.219384    367.490260
# 013580202104  0.339701  0.271294      0.271294     17.760780    114.918308
# 013580202201 -0.003290  0.255337      0.255337      7.659111    132.808490
# 013580202202 -0.835957  0.164539      0.164539     26.917057    251.602927
# 013580202203 -0.261559  0.138253      0.138253     29.879927    398.374830
# 013580202204 -0.526734  0.070626      0.070626     15.406047    117.426128
#
#                총자산 회전율  부채상환계수(배)  총차입금상환능력비율
# 아이디
# 013580202001  0.220827   0.161104    0.124559
# 013580202002  0.251659   0.291937    0.237367
# 013580202003  0.258717   0.761413    0.388921
# 013580202004  1.020474   1.064332    0.520951
# 013580202101  0.216227   0.617660    0.370189
# 013580202102  0.269529   0.772670    0.574184
# 013580202103  0.238355   0.342134    0.246472
# 013580202104  1.085966   0.664286    0.489908
# 013580202201  0.247545   0.471754    0.377870
# 013580202202  0.287015   0.550365    0.444677
# 013580202203  0.257955   0.464478    0.405936
# 013580202204  1.140033   0.299747    0.235168

# %%
df.to_csv(f'/content/drive/MyDrive/ICR/재무비율/{corp_name_p}_재무비율.csv')

# %% [markdown]
# ### 신원종합개발

# %%
corp_name = ['DL이앤씨', 'HDC현대산업개발', '한전KPS', 'HJ중공업', '신세계건설', 'KCC건설', '대우건설', '서희건설', '특수건설', '계룡건설산업', '신원종합개발', '서한', '태영건설', '현대건설', 'GS건설', '동부건설', '코오롱글로벌', 'DL건설', '진흥기업', '남광토건', '한신공영', '금호건설', '삼부토건']
corp_code = ['375500', '294870', '051600', '097230', '034300', '021320', '047040', '035890', '026150', '013580', '017000', '011370', '009410', '000720', '006360', '005960', '003070', '001880', '002780', '001260', '004960', '002990', '001470']
report_code = ["11013", "11012", "11014", "11011"] # '11013'=1분기보고서, '11012'=반기보고서, '11014'=3분기보고서, '11011'=사업보고서

corp_name_p = corp_name[10]
corp_code_p = corp_code[10]

all = pd.DataFrame()

for year in range(2019, 2023):
  for code in report_code:
    corp = dart.finstate_all(corp_code_p, year, code, fs_div="OFS")
    # corp = corp.drop('account_id', axis=1)
    all = pd.concat([all, corp], ignore_index=True) # 2019년~2022년 별도 재무제표 전문(분기보고서+반기보고서+사업보고서)

all
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
Quarter = []
cor_year = []
ID_list = []
corp_name_list = []
year_list = []
report_code_list = []
Debt_Ratio = []
Debt_to_Asset_Ratio = []
Fixed_Asset_Turnover_Ratio = []
Return_on_Equity = []
Operating_Profit_Margin = []
Gross_Profit_Margin = []
Interest_Coverage_Ratio =[]
Sales_Growth_Rate = []
Total_Asset_Growth_Rate = []
Operating_Profit_Growth_Rate = []
Equity_Growth_Rate= []
Accounts_Receivable_Turnover = []
Inventory_Turnover = []
Accounts_Payable_Turnover = []
Total_Asset_Turnover_Ratio = []
Debt_Service_Coverage_Ratio = []
Debt_to_Equity_Ratio = []


for year in range(2020, 2023):
  str_year = str(year)
  report_code_list.extend(['1분기보고서' if code == '11013' else '반기보고서' if code == '11012' else '3분기보고서' if code == '11014' else '사업보고서' for code in report_code])
  Quarter.extend(['01' if code == '11013' else '02' if code == '11012' else '03' if code == '11014' else '04' for code in report_code])
  for code in report_code:
    BS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '자산총계' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자산총계
    BS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 부채총계
    BS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자본총계
    BS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '단기차입금' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 단기차입금
    BS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and ('유동성장기부채' in row['account_nm'] or '유동성장기채무' in row['account_nm']) and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 유동성장기부채
    BS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '사채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 사채
    BS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '장기차입금' in row['account_nm'] and '유동성' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 장기차입금
    BS8 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동자산' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동자산
    BS9 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동부채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동부채
    BS10 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자산총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자산총계
    BS11 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 부채총계
    BS12 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자본총계
    BS13 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매출채권' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매출채권
    BS14 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매입채무' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매입채무
    BS15 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '재고자산' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 재고자산
    BS16 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '유동성사채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 유동성사채

    IS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '포괄손익계산서' and '당기순이익(손실)' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 당기순이익
    IS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업이익
    IS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '매출액' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 수익(매출액)
    IS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '법인세' in row['account_nm'] and '차감전' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 법인세비용차감전순이익(손실)
    IS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and (row['account_nm'] == '금융비용' or row['account_nm'] == '금융원가') and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 금융비용
    IS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '매출액' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 수익(매출액) # 분기 보고서만 해당
    IS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '영업이익(손실)' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 영업이익 # 분기 보고서만 해당

    CF1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '현금흐름표' and row['account_nm'] == '영업활동현금흐름' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업활동으로 인한 현금흐름

    # if BS6 == BS7: # '사채 및 장기차입금'으로 계정과목 하나만 쓰는 회사는 합침(어차피 사채는 차입금 의존도에서만 사용해서 하나 0으로 만들어도 상관없음)
    #   BS6 = ['0']
    # if BS4 == BS5:
    #   BS4 = ['0'] # '단기차입금 및 유동성장기부채' 로 병합해서 쓰는 회사는 ㅎ나로 합침(어차피 둘이 항상 붙어서 계산해서 상관없음)
    # if BS4 == []:
    #   BS4 = ['0']
    # if BS5 == [''] or BS5 == []:
    #   BS5 = ['0']
    if BS6 == []:
      BS6 = ['0']
    if BS16 == []:
      BS16 = ['0']
    # if BS7 == []:
    #   BS7 = ['0']

    print("자산총계:", BS1, "부채총계:", BS2, "자본총계:", BS3, "단기차입금:", BS4, "유동성장기부채:", BS5, "사채:", BS6, "장기차입금:", BS7, "비유동자산:", BS8, "비유동부채:", BS9, "전기말 자산총계:", BS10, "전기말 부채총계:", BS11,
          "전기말 자본총계:", BS12, "매출채권:", BS13, "매입채무:", BS14, "재고자산:", BS15, "유동성사채:", BS16, "당기순이익:", IS1, "영업이익:", IS2, "수익(매출액):", IS3, "법인세비용차감전순이익(손실):", IS4,
          "금융비용:", IS5, "전기 수익(매출액):", IS6, "전기 영업이익:", IS7, "영업활동으로 인한 현금흐름:", CF1)

    if year != 2020:
      if code == "11013":
        accounting_period = 90
      elif code == "11012":
        accounting_period = 181
      elif code == "11014":
        accounting_period = 273
      elif code == "11011":
        accounting_period = 365
    else: # 2020년은 윤년
      if code == "11013":
        accounting_period = 91
      elif code == "11012":
        accounting_period = 182
      elif code == "11014":
        accounting_period = 274
      elif code == "11011":
        accounting_period = 366


    cor_year.extend([f"{corp_code_p}{str_year}"])
    corp_name_list.append(str(corp_name_p))
    year_list.append(str_year)
    Debt_Ratio.extend([int(BS2)/int(BS3)*100 for BS2, BS3 in zip(BS2, BS3)])
    Debt_to_Asset_Ratio.extend([((int(BS4) + int(BS5) + int(BS6) + int(BS7) + int(BS16)) / int(BS1) * 100) for BS4, BS5, BS6, BS7, BS1, BS16 in zip(BS4, BS5, BS6, BS7, BS1, BS16)])
    Fixed_Asset_Turnover_Ratio.extend([int(BS8)/(int(BS9)+int(BS3))*100 for BS8, BS9, BS3 in zip(BS8, BS9, BS3)]),
    Return_on_Equity.extend([int(IS1)/((int(BS12)+int(BS3))/2) for IS1, BS12, BS3 in zip(IS1, BS12, BS3)])
    Operating_Profit_Margin.extend([int(IS2)/int(IS3) for IS2, IS3 in zip(IS2, IS3)])
    Gross_Profit_Margin.extend([int(IS4)/int(IS3) for IS4, IS3 in zip(IS4, IS3)])
    Interest_Coverage_Ratio.extend([int(IS2)/int(IS5) for IS2, IS5 in zip(IS2, IS5)])
    Sales_Growth_Rate.extend([(int(IS3)-int(IS6))/int(IS6) for IS3, IS6 in zip(IS3, IS6)])
    Total_Asset_Growth_Rate.extend([(int(BS1)-int(BS10))/int(BS10) for BS1, BS10 in zip(BS1, BS10)])
    Operating_Profit_Growth_Rate.extend([(int(IS2)-int(IS7))/int(IS7) for IS2, IS7 in zip(IS2, IS7)])
    Equity_Growth_Rate.extend([(int(BS3)-int(BS12))/int(BS12) for BS3, BS12 in zip(BS3, BS12)])
    Accounts_Receivable_Turnover.extend([int(BS13)/int(IS3)*accounting_period for BS13, IS3 in zip(BS13, IS3)])
    Inventory_Turnover.extend([int(BS15)/int(IS3)*accounting_period for BS15, IS3 in zip(BS15, IS3)])
    Accounts_Payable_Turnover.extend([int(BS14)/int(IS3)*accounting_period for BS14, IS3 in zip(BS14, IS3)])
    Total_Asset_Turnover_Ratio.extend([int(IS3)/int(BS1) for IS3, BS1 in zip(IS3, BS1)])
    Debt_Service_Coverage_Ratio.extend([(int(CF1)+int(IS5))/(int(BS4)+int(BS5)+int(IS5)) for CF1, IS5, BS4, BS5 in zip(CF1, IS5, BS4, BS5)])
    Debt_to_Equity_Ratio.extend([int(CF1)/(int(BS4)+int(BS7)+int(BS5)) for CF1, BS4, BS7, BS5 in zip(CF1, BS4, BS7, BS5)])

ID_list.extend([x+y for x,y in zip(cor_year,Quarter)])

financial_ratio = {
      '아이디':ID_list,
      '기업명':corp_name_list,
      '연도':year_list,
      '보고서 코드':report_code_list,
      '부채비율' : Debt_Ratio,
      '차입금의존도' : Debt_to_Asset_Ratio,
      '고정장기적합률':Fixed_Asset_Turnover_Ratio,
      '자기자본순이익률':Return_on_Equity,
      '매출액영업이익률':Operating_Profit_Margin,
      '매출액경상이익률':Gross_Profit_Margin,
      '이자보상배율(배)':Interest_Coverage_Ratio,
      '매출액 증가율':Sales_Growth_Rate,
      '총자산 증가율':Total_Asset_Growth_Rate,
      '영업이익 증가율':Operating_Profit_Growth_Rate,
      '자기자본 증가율':Equity_Growth_Rate,
      '매출채권 회전기일(일)':Equity_Growth_Rate,
      '재고자산 회전기일(일)':Accounts_Receivable_Turnover,
      '매입채무 회전기일(일)':Accounts_Payable_Turnover,
      '총자산 회전율':Total_Asset_Turnover_Ratio,
      '부채상환계수(배)':Debt_Service_Coverage_Ratio,
      '총차입금상환능력비율':Debt_to_Equity_Ratio
                    }

df = pd.DataFrame(financial_ratio)
df.set_index('아이디', inplace=True)

df
# Out:
# 자산총계: ['171859849649'] 부채총계: ['82026878441'] 자본총계: ['89832971208'] 단기차입금: ['7783025000'] 유동성장기부채: ['2167009664'] 사채: ['9366360754'] 장기차입금: ['3916609535'] 비유동자산: ['43392892552'] 비유동부채: ['31609274446'] 전기말 자산총계: ['192773199523'] 전기말 부채총계: ['115018806725'] 전기말 자본총계: ['77754392798'] 매출채권: ['83605290063'] 매입채무: ['18601796088'] 재고자산: ['25740215494'] 유동성사채: ['5000000000'] 당기순이익: ['632505168'] 영업이익: ['1368917900'] 수익(매출액): ['27110687923'] 법인세비용차감전순이익(손실): ['1027402411'] 금융비용: ['953456943'] 전기 수익(매출액): ['50544473063'] 전기 영업이익: ['1527299945'] 영업활동으로 인한 현금흐름: ['2510777914']
# 자산총계: ['175638634185'] 부채총계: ['84066393202'] 자본총계: ['91572240983'] 단기차입금: ['7724025000'] 유동성장기부채: ['715009664'] 사채: ['7400000000'] 장기차입금: ['3241290655'] 비유동자산: ['39473454438'] 비유동부채: ['29849175199'] 전기말 자산총계: ['188511086443'] 전기말 부채총계: ['105610306815'] 전기말 자본총계: ['82900779628'] 매출채권: ['90747484004'] 매입채무: ['19182825479'] 재고자산: ['22932589535'] 유동성사채: ['6973398902'] 당기순이익: ['1747735035'] 영업이익: ['1317663812'] 수익(매출액): ['31277731152'] 법인세비용차감전순이익(손실): ['1975240758'] 금융비용: ['-831173156'] 전기 수익(매출액): ['66512765540'] 전기 영업이익: ['3743667616'] 영업활동으로 인한 현금흐름: ['9249721825']
# 자산총계: ['172535899696'] 부채총계: ['82703722455'] 자본총계: ['89832177241'] 단기차입금: ['2869000000'] 유동성장기부채: ['715009664'] 사채: ['6700000000'] 장기차입금: ['2747811611'] 비유동자산: ['39406802311'] 비유동부채: ['29443559127'] 전기말 자산총계: ['193761435071'] 전기말 부채총계: ['106138297941'] 전기말 자본총계: ['87623137130'] 매출채권: ['88675183190'] 매입채무: ['18990047435'] 재고자산: ['23814699632'] 유동성사채: ['6980922855'] 당기순이익: ['-1745737778'] 영업이익: ['-1322295516'] 수익(매출액): ['33441977893'] 법인세비용차감전순이익(손실): ['-1678789120'] 금융비용: ['530972771'] 전기 수익(매출액): ['60248167042'] 전기 영업이익: ['5262386450'] 영업활동으로 인한 현금흐름: ['-6753230253']
# 자산총계: ['173860624854'] 부채총계: ['98997193935'] 자본총계: ['74863430919'] 단기차입금: ['2810000000'] 유동성장기부채: ['719259726'] 사채: ['0'] 장기차입금: ['13526940306'] 비유동자산: ['39951586084'] 비유동부채: ['43243164743'] 전기말 자산총계: ['186237504364'] 전기말 부채총계: ['97026649950'] 전기말 자본총계: ['89210854414'] 매출채권: ['84687178542'] 매입채무: ['21386758175'] 재고자산: ['23814699632'] 유동성사채: ['11288562501'] 당기순이익: ['-14314964341'] 영업이익: ['3126194151'] 수익(매출액): ['123807109583'] 법인세비용차감전순이익(손실): ['-14542142271'] 금융비용: ['5227088882'] 전기 수익(매출액): ['251690727575'] 전기 영업이익: ['8975032210'] 영업활동으로 인한 현금흐름: ['-10675298760']
# 자산총계: ['172457671330'] 부채총계: ['93559796873'] 자본총계: ['78897874457'] 단기차입금: ['10267795097'] 유동성장기부채: ['55009664'] 사채: ['0'] 장기차입금: ['11147210044'] 비유동자산: ['44925217926'] 비유동부채: ['40988442077'] 전기말 자산총계: ['171859849649'] 전기말 부채총계: ['82026878441'] 전기말 자본총계: ['89832971208'] 매출채권: ['73937161001'] 매입채무: ['16771864734'] 재고자산: ['28919616108'] 유동성사채: ['6295769240'] 당기순이익: ['722731591'] 영업이익: ['904735464'] 수익(매출액): ['22254957989'] 법인세비용차감전순이익(손실): ['933655713'] 금융비용: ['666944579'] 전기 수익(매출액): ['27110687923'] 전기 영업이익: ['1368917900'] 영업활동으로 인한 현금흐름: ['7824443454']
# 자산총계: ['163435440388'] 부채총계: ['80659004648'] 자본총계: ['82776435740'] 단기차입금: ['8449999969'] 유동성장기부채: ['55009664'] 사채: ['1450110760'] 장기차입금: ['12892510044'] 비유동자산: ['43438574531'] 비유동부채: ['42725141401'] 전기말 자산총계: ['175638634185'] 전기말 부채총계: ['84066393202'] 전기말 자본총계: ['91572240983'] 매출채권: ['68789130367'] 매입채무: ['15550076074'] 재고자산: ['31145467458'] 유동성사채: ['0'] 당기순이익: ['-648701698'] 영업이익: ['1144645107'] 수익(매출액): ['30090084101'] 법인세비용차감전순이익(손실): ['-599507646'] 금융비용: ['1649322332'] 전기 수익(매출액): ['31277731152'] 전기 영업이익: ['1317663812'] 영업활동으로 인한 현금흐름: ['5325692166']
# 자산총계: ['158342274765'] 부채총계: ['72661597562'] 자본총계: ['85680677203'] 단기차입금: ['8449999969'] 유동성장기부채: ['6956549893'] 사채: ['1454684092'] 장기차입금: ['3981269815'] 비유동자산: ['44379871200'] 비유동부채: ['33934789246'] 전기말 자산총계: ['172535899696'] 전기말 부채총계: ['82703722455'] 전기말 자본총계: ['89832177241'] 매출채권: ['61388044559'] 매입채무: ['18314162370'] 재고자산: ['28273829336'] 유동성사채: ['0'] 당기순이익: ['262607312'] 영업이익: ['-1183031237'] 수익(매출액): ['37627405456'] 법인세비용차감전순이익(손실): ['143861958'] 금융비용: ['-74416951'] 전기 수익(매출액): ['33441977893'] 전기 영업이익: ['-1322295516'] 영업활동으로 인한 현금흐름: ['11315694192']
# 자산총계: ['199471368754'] 부채총계: ['110479364650'] 자본총계: ['88992004104'] 단기차입금: ['25449999969'] 유동성장기부채: ['4880299954'] 사채: ['1461223814'] 장기차입금: ['18211628452'] 비유동자산: ['41295731085'] 비유동부채: ['48620093726'] 전기말 자산총계: ['173860624854'] 전기말 부채총계: ['98997193935'] 전기말 자본총계: ['74863430919'] 매출채권: ['71400193418'] 매입채무: ['24625569369'] 재고자산: ['50060163676'] 유동성사채: ['0'] 당기순이익: ['3690554665'] 영업이익: ['5119302038'] 수익(매출액): ['139060809283'] 법인세비용차감전순이익(손실): ['4294939615'] 금융비용: ['2657686523'] 전기 수익(매출액): ['123807109583'] 전기 영업이익: ['3126194151'] 영업활동으로 인한 현금흐름: ['-11341741281']
# 자산총계: ['189244246288'] 부채총계: ['99879612366'] 자본총계: ['89364633922'] 단기차입금: ['22410000000'] 유동성장기부채: ['3223649893'] 사채: ['1467799243'] 장기차입금: ['18211877310'] 비유동자산: ['42482321714'] 비유동부채: ['48657428868'] 전기말 자산총계: ['172457671330'] 전기말 부채총계: ['93559796873'] 전기말 자본총계: ['78897874457'] 매출채권: ['72555213514'] 매입채무: ['19969198991'] 재고자산: ['50374933459'] 유동성사채: ['0'] 당기순이익: ['342860284'] 영업이익: ['175157806'] 수익(매출액): ['32452873452'] 법인세비용차감전순이익(손실): ['571694397'] 금융비용: ['613729755'] 전기 수익(매출액): ['22254957989'] 전기 영업이익: ['904735464'] 영업활동으로 인한 현금흐름: ['-5380347802']
# 자산총계: ['192858209191'] 부채총계: ['99296919957'] 자본총계: ['93561289234'] 단기차입금: ['4480000000'] 유동성장기부채: ['5925649893'] 사채: ['0'] 장기차입금: ['14253371510'] 비유동자산: ['53588903769'] 비유동부채: ['49415037928'] 전기말 자산총계: ['163435440388'] 전기말 부채총계: ['80659004648'] 전기말 자본총계: ['82776435740'] 매출채권: ['74751623149'] 매입채무: ['31409819149'] 재고자산: ['50138917612'] 유동성사채: ['1474613536'] 당기순이익: ['4014305650'] 영업이익: ['282128763'] 수익(매출액): ['41426668134'] 법인세비용차감전순이익(손실): ['5150499185'] 금융비용: ['1002878785'] 전기 수익(매출액): ['30090084101'] 전기 영업이익: ['1144645107'] 영업활동으로 인한 현금흐름: ['138717459']
# 자산총계: ['205155055450'] 부채총계: ['104148805614'] 자본총계: ['101006249836'] 단기차입금: ['19880000000'] 유동성장기부채: ['4255009664'] 사채: ['0'] 장기차입금: ['17218716310'] 비유동자산: ['58318453193'] 비유동부채: ['46616826140'] 전기말 자산총계: ['158342274765'] 전기말 부채총계: ['72661597562'] 전기말 자본총계: ['85680677203'] 매출채권: ['85489320796'] 매입채무: ['26164113901'] 재고자산: ['50015203220'] 유동성사채: ['1481466800'] 당기순이익: ['5974129014'] 영업이익: ['2737532546'] 수익(매출액): ['46222103728'] 법인세비용차감전순이익(손실): ['9361713082'] 금융비용: ['1101544840'] 전기 수익(매출액): ['37627405456'] 전기 영업이익: ['-1183031237'] 영업활동으로 인한 현금흐름: ['-14935773033']
# 자산총계: ['227136915216'] 부채총계: ['133300677121'] 자본총계: ['93836238095'] 단기차입금: ['19880000000'] 유동성장기부채: ['9063009726'] 사채: ['0'] 장기차입금: ['9102053383'] 비유동자산: ['57180420650'] 비유동부채: ['31500618726'] 전기말 자산총계: ['199471368754'] 전기말 부채총계: ['110479364650'] 전기말 자본총계: ['88992004104'] 매출채권: ['94057522617'] 매입채무: ['44176933177'] 재고자산: ['50510055587'] 유동성사채: ['1488427882'] 당기순이익: ['4440252586'] 영업이익: ['2032585973'] 수익(매출액): ['188210171518'] 법인세비용차감전순이익(손실): ['9124637217'] 금융비용: ['6356371962'] 전기 수익(매출액): ['139060809283'] 전기 영업이익: ['5119302038'] 영업활동으로 인한 현금흐름: ['12039838160']
#                  기업명    연도  보고서 코드        부채비율     차입금의존도    고정장기적합률  \
# 아이디
# 017000202001  신원종합개발  2020  1분기보고서   91.310437  16.427924  35.731300
# 017000202002  신원종합개발  2020   반기보고서   91.803359  14.833709  32.509466
# 017000202003  신원종합개발  2020  3분기보고서   92.064698  11.599177  33.038406
# 017000202004  신원종합개발  2020   사업보고서  132.237052  16.303152  33.826719
# 017000202101  신원종합개발  2021  1분기보고서  118.583419  16.100057  37.473182
# 017000202102  신원종합개발  2021   반기보고서   97.441988  13.979606  34.611975
# 017000202103  신원종합개발  2021  3분기보고서   84.805116  13.162943  37.102118
# 017000202104  신원종합개발  2021   사업보고서  124.145271  25.067834  30.008794
# 017000202201  신원종합개발  2022  1분기보고서  111.766376  23.944361  30.779370
# 017000202202  신원종합개발  2022   반기보고서  106.130346  13.550699  37.480963
# 017000202203  신원종합개발  2022  3분기보고서  103.111249  20.879423  39.504971
# 017000202204  신원종합개발  2022   사업보고서  142.056715  17.405137  45.621393
#
#               자기자본순이익률  매출액영업이익률  매출액경상이익률  이자보상배율(배)   매출액 증가율   총자산 증가율  \
# 아이디
# 017000202001  0.007548  0.050494  0.037897   1.435742 -0.463627 -0.108487
# 017000202002  0.020034  0.042128  0.063152  -1.585306 -0.529748 -0.068285
# 017000202003 -0.019675 -0.039540 -0.050200  -2.490326 -0.444930 -0.109545
# 017000202004 -0.174494  0.025251 -0.117458   0.598076 -0.508098 -0.066458
# 017000202101  0.008567  0.040653  0.041953   1.356538 -0.179108  0.003479
# 017000202102 -0.007441  0.038041 -0.019924   0.694009 -0.037971 -0.069479
# 017000202103  0.002992 -0.031441  0.003823  15.897336  0.125155 -0.082265
# 017000202104  0.045046  0.036813  0.030885   1.926225  0.123205  0.147306
# 017000202201  0.004075  0.005397  0.017616   0.285399  0.458231  0.097337
# 017000202202  0.045530  0.006810  0.124328   0.281319  0.376755  0.180027
# 017000202203  0.064002  0.059226  0.202538   2.485176  0.228416  0.295643
# 017000202204  0.048573  0.010800  0.048481   0.319771  0.353438  0.138694
#
#               영업이익 증가율  자기자본 증가율  매출채권 회전기일(일)  재고자산 회전기일(일)  매입채무 회전기일(일)  \
# 아이디
# 017000202001 -0.103701  0.155343      0.155343    280.630334     62.438971
# 017000202002 -0.648029  0.104600      0.104600    528.044762    111.621723
# 017000202003 -1.251273  0.025211      0.025211    726.541961    155.591066
# 017000202004 -0.651679 -0.160826     -0.160826    250.353210     63.223780
# 017000202101 -0.339087 -0.121727     -0.121727    299.005035     67.826137
# 017000202102 -0.131307 -0.096053     -0.096053    413.785238     93.537916
# 017000202103 -0.105320 -0.046214     -0.046214    445.391755    132.875660
# 017000202104  0.637551  0.188725      0.188725    187.407730     64.635988
# 017000202201 -0.806399  0.132662      0.132662    201.213899     55.379623
# 017000202202 -0.753523  0.130289      0.130289    326.602269    137.234722
# 017000202203 -3.313999  0.178868      0.178868    504.922595    154.532194
# 017000202204 -0.602956  0.054434      0.054434    182.407760     85.673269
#
#                총자산 회전율  부채상환계수(배)  총차입금상환능력비율
# 아이디
# 017000202001  0.157749   0.317718    0.181066
# 017000202002  0.178080   1.106559    0.791906
# 017000202003  0.193826  -1.512098   -1.066554
# 017000202004  0.712106  -0.622201   -0.625890
# 017000202101  0.129046   0.772664    0.364436
# 017000202102  0.184110   0.686900    0.248893
# 017000202103  0.237633   0.733184    0.583650
# 017000202104  0.697147  -0.263249   -0.233648
# 017000202201  0.171487  -0.181604   -0.122711
# 017000202202  0.214804   0.100065    0.005625
# 017000202203  0.225303  -0.548182   -0.361171
# 017000202204  0.828620   0.521148    0.316463

# %%
df.to_csv(f'/content/drive/MyDrive/ICR/재무비율/{corp_name_p}_재무비율.csv')

# %% [markdown]
# ### 서한

# %%
corp_name = ['DL이앤씨', 'HDC현대산업개발', '한전KPS', 'HJ중공업', '신세계건설', 'KCC건설', '대우건설', '서희건설', '특수건설', '계룡건설산업', '신원종합개발', '서한', '태영건설', '현대건설', 'GS건설', '동부건설', '코오롱글로벌', 'DL건설', '진흥기업', '남광토건', '한신공영', '금호건설', '삼부토건']
corp_code = ['375500', '294870', '051600', '097230', '034300', '021320', '047040', '035890', '026150', '013580', '017000', '011370', '009410', '000720', '006360', '005960', '003070', '001880', '002780', '001260', '004960', '002990', '001470']
report_code = ["11013", "11012", "11014", "11011"] # '11013'=1분기보고서, '11012'=반기보고서, '11014'=3분기보고서, '11011'=사업보고서

corp_name_p = corp_name[11]
corp_code_p = corp_code[11]

all = pd.DataFrame()

for year in range(2019, 2023):
  for code in report_code:
    corp = dart.finstate_all(corp_code_p, year, code, fs_div="OFS")
    # corp = corp.drop('account_id', axis=1)
    all = pd.concat([all, corp], ignore_index=True) # 2019년~2022년 별도 재무제표 전문(분기보고서+반기보고서+사업보고서)

all
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
Quarter = []
cor_year = []
ID_list = []
corp_name_list = []
year_list = []
report_code_list = []
Debt_Ratio = []
Debt_to_Asset_Ratio = []
Fixed_Asset_Turnover_Ratio = []
Return_on_Equity = []
Operating_Profit_Margin = []
Gross_Profit_Margin = []
Interest_Coverage_Ratio =[]
Sales_Growth_Rate = []
Total_Asset_Growth_Rate = []
Operating_Profit_Growth_Rate = []
Equity_Growth_Rate= []
Accounts_Receivable_Turnover = []
Inventory_Turnover = []
Accounts_Payable_Turnover = []
Total_Asset_Turnover_Ratio = []
Debt_Service_Coverage_Ratio = []
Debt_to_Equity_Ratio = []


for year in range(2020, 2023):
  str_year = str(year)
  report_code_list.extend(['1분기보고서' if code == '11013' else '반기보고서' if code == '11012' else '3분기보고서' if code == '11014' else '사업보고서' for code in report_code])
  Quarter.extend(['01' if code == '11013' else '02' if code == '11012' else '03' if code == '11014' else '04' for code in report_code])
  for code in report_code:
    BS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '자산총계' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자산총계
    BS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 부채총계
    BS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자본총계
    BS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '단기차입금' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 단기차입금
    BS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and ('유동성장기차입금' in row['account_nm'] or '유동성장기채무' in row['account_nm']) and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 유동성장기부채
    # BS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '사채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 사채 # 서한 기업은 장기차입금 안에 사채 포함되어 있어서 따로 안 뽑음
    BS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '장기차입금' in row['account_nm'] and '유동성' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 장기차입금
    BS8 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동자산' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동자산
    BS9 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동부채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동부채
    BS10 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자산총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자산총계
    BS11 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 부채총계
    BS12 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자본총계
    BS13 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매출채권' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매출채권
    BS14 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매입채무' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매입채무
    BS15 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '재고자산' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 재고자산

    IS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '포괄손익계산서' and '기순이익' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 당기순이익
    IS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업이익
    IS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '매출액' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 수익(매출액)
    IS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '법인세' in row['account_nm'] and '차감전' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 법인세비용차감전순이익(손실)
    IS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and (row['account_nm'] == '금융비용' or row['account_nm'] == '금융원가') and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 금융비용
    IS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '매출액' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 수익(매출액) # 분기 보고서만 해당
    IS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 영업이익 # 분기 보고서만 해당

    CF1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '현금흐름표' and row['account_nm'] == '영업활동현금흐름' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업활동으로 인한 현금흐름

    # if BS6 == BS7: # '사채 및 장기차입금'으로 계정과목 하나만 쓰는 회사는 합침(어차피 사채는 차입금 의존도에서만 사용해서 하나 0으로 만들어도 상관없음)
    #   BS6 = ['0']
    # if BS4 == BS5:
    #   BS4 = ['0'] # '단기차입금 및 유동성장기부채' 로 병합해서 쓰는 회사는 ㅎ나로 합침(어차피 둘이 항상 붙어서 계산해서 상관없음)
    if BS4 == []:
      BS4 = ['0']
    # if BS5 == [''] or BS5 == []:
    #   BS5 = ['0']
    # if BS6 == []:
    #   BS6 = ['0']
    # if BS16 == []:
    #   BS16 = ['0']
    # if BS7 == []:
    #   BS7 = ['0']

    print("자산총계:", BS1, "부채총계:", BS2, "자본총계:", BS3, "단기차입금:", BS4, "유동성장기부채:", BS5, "장기차입금:", BS7, "비유동자산:", BS8, "비유동부채:", BS9, "전기말 자산총계:", BS10, "전기말 부채총계:", BS11,
          "전기말 자본총계:", BS12, "매출채권:", BS13, "매입채무:", BS14, "재고자산:", BS15, "당기순이익:", IS1, "영업이익:", IS2, "수익(매출액):", IS3, "법인세비용차감전순이익(손실):", IS4,
          "금융비용:", IS5, "전기 수익(매출액):", IS6, "전기 영업이익:", IS7, "영업활동으로 인한 현금흐름:", CF1)

    if year != 2020:
      if code == "11013":
        accounting_period = 90
      elif code == "11012":
        accounting_period = 181
      elif code == "11014":
        accounting_period = 273
      elif code == "11011":
        accounting_period = 365
    else: # 2020년은 윤년
      if code == "11013":
        accounting_period = 91
      elif code == "11012":
        accounting_period = 182
      elif code == "11014":
        accounting_period = 274
      elif code == "11011":
        accounting_period = 366


    cor_year.extend([f"{corp_code_p}{str_year}"])
    corp_name_list.append(str(corp_name_p))
    year_list.append(str_year)
    Debt_Ratio.extend([int(BS2)/int(BS3)*100 for BS2, BS3 in zip(BS2, BS3)])
    Debt_to_Asset_Ratio.extend([((int(BS4) + int(BS5) + int(BS7)) / int(BS1) * 100) for BS4, BS5, BS7, BS1 in zip(BS4, BS5, BS7, BS1)])
    Fixed_Asset_Turnover_Ratio.extend([int(BS8)/(int(BS9)+int(BS3))*100 for BS8, BS9, BS3 in zip(BS8, BS9, BS3)]),
    Return_on_Equity.extend([int(IS1)/((int(BS12)+int(BS3))/2) for IS1, BS12, BS3 in zip(IS1, BS12, BS3)])
    Operating_Profit_Margin.extend([int(IS2)/int(IS3) for IS2, IS3 in zip(IS2, IS3)])
    Gross_Profit_Margin.extend([int(IS4)/int(IS3) for IS4, IS3 in zip(IS4, IS3)])
    Interest_Coverage_Ratio.extend([int(IS2)/int(IS5) for IS2, IS5 in zip(IS2, IS5)])
    Sales_Growth_Rate.extend([(int(IS3)-int(IS6))/int(IS6) for IS3, IS6 in zip(IS3, IS6)])
    Total_Asset_Growth_Rate.extend([(int(BS1)-int(BS10))/int(BS10) for BS1, BS10 in zip(BS1, BS10)])
    Operating_Profit_Growth_Rate.extend([(int(IS2)-int(IS7))/int(IS7) for IS2, IS7 in zip(IS2, IS7)])
    Equity_Growth_Rate.extend([(int(BS3)-int(BS12))/int(BS12) for BS3, BS12 in zip(BS3, BS12)])
    Accounts_Receivable_Turnover.extend([int(BS13)/int(IS3)*accounting_period for BS13, IS3 in zip(BS13, IS3)])
    Inventory_Turnover.extend([int(BS15)/int(IS3)*accounting_period for BS15, IS3 in zip(BS15, IS3)])
    Accounts_Payable_Turnover.extend([int(BS14)/int(IS3)*accounting_period for BS14, IS3 in zip(BS14, IS3)])
    Total_Asset_Turnover_Ratio.extend([int(IS3)/int(BS1) for IS3, BS1 in zip(IS3, BS1)])
    Debt_Service_Coverage_Ratio.extend([(int(CF1)+int(IS5))/(int(BS4)+int(BS5)+int(IS5)) for CF1, IS5, BS4, BS5 in zip(CF1, IS5, BS4, BS5)])
    Debt_to_Equity_Ratio.extend([int(CF1)/(int(BS4)+int(BS7)+int(BS5)) for CF1, BS4, BS7, BS5 in zip(CF1, BS4, BS7, BS5)])

ID_list.extend([x+y for x,y in zip(cor_year,Quarter)])

financial_ratio = {
      '아이디':ID_list,
      '기업명':corp_name_list,
      '연도':year_list,
      '보고서 코드':report_code_list,
      '부채비율' : Debt_Ratio,
      '차입금의존도' : Debt_to_Asset_Ratio,
      '고정장기적합률':Fixed_Asset_Turnover_Ratio,
      '자기자본순이익률':Return_on_Equity,
      '매출액영업이익률':Operating_Profit_Margin,
      '매출액경상이익률':Gross_Profit_Margin,
      '이자보상배율(배)':Interest_Coverage_Ratio,
      '매출액 증가율':Sales_Growth_Rate,
      '총자산 증가율':Total_Asset_Growth_Rate,
      '영업이익 증가율':Operating_Profit_Growth_Rate,
      '자기자본 증가율':Equity_Growth_Rate,
      '매출채권 회전기일(일)':Equity_Growth_Rate,
      '재고자산 회전기일(일)':Accounts_Receivable_Turnover,
      '매입채무 회전기일(일)':Accounts_Payable_Turnover,
      '총자산 회전율':Total_Asset_Turnover_Ratio,
      '부채상환계수(배)':Debt_Service_Coverage_Ratio,
      '총차입금상환능력비율':Debt_to_Equity_Ratio
                    }

df = pd.DataFrame(financial_ratio)
df.set_index('아이디', inplace=True)

df
# Out:
# 자산총계: ['468591603341'] 부채총계: ['165217063744'] 자본총계: ['303374539597'] 단기차입금: ['2327000000'] 유동성장기부채: ['3333320000'] 장기차입금: ['33300056345'] 비유동자산: ['89331350449'] 비유동부채: ['51710781261'] 전기말 자산총계: ['502577739673'] 전기말 부채총계: ['203752979536'] 전기말 자본총계: ['298824760137'] 매출채권: ['43568757638'] 매입채무: ['58454982991'] 재고자산: ['109063112235'] 당기순이익: ['5064905672'] 영업이익: ['7302211753'] 수익(매출액): ['95434499036'] 법인세비용차감전순이익(손실): ['6021547094'] 금융비용: ['751554981'] 전기 수익(매출액): ['132985145886'] 전기 영업이익: ['4321037251'] 영업활동으로 인한 현금흐름: ['-285274084']
# 자산총계: ['486038729182'] 부채총계: ['182103073372'] 자본총계: ['303935655810'] 단기차입금: ['12027000000'] 유동성장기부채: ['21640639484'] 장기차입금: ['14999980000'] 비유동자산: ['89417562990'] 비유동부채: ['41716346451'] 전기말 자산총계: ['538339095925'] 전기말 부채총계: ['230825640003'] 전기말 자본총계: ['307513455922'] 매출채권: ['50931851084'] 매입채무: ['48109069188'] 재고자산: ['97204454550'] 당기순이익: ['367269062'] 영업이익: ['1336317035'] 수익(매출액): ['131120884631'] 법인세비용차감전순이익(손실): ['561971743'] 금융비용: ['335795542'] 전기 수익(매출액): ['159007357497'] 전기 영업이익: ['15422468630'] 영업활동으로 인한 현금흐름: ['-10074333102']
# 자산총계: ['507791952398'] 부채총계: ['193319735379'] 자본총계: ['314472217019'] 단기차입금: ['2327000000'] 유동성장기부채: ['21650074895'] 장기차입금: ['13333320000'] 비유동자산: ['114680680754'] 비유동부채: ['40396006201'] 전기말 자산총계: ['487229930026'] 전기말 부채총계: ['186906371349'] 전기말 자본총계: ['300323558677'] 매출채권: ['37924017581'] 매입채무: ['43872670067'] 재고자산: ['93172768613'] 당기순이익: ['10105980846'] 영업이익: ['12356004767'] 수익(매출액): ['108193698204'] 법인세비용차감전순이익(손실): ['13040175080'] 금융비용: ['551961711'] 전기 수익(매출액): ['106509199499'] 전기 영업이익: ['-11345539842'] 영업활동으로 인한 현금흐름: ['86796784252']
# 자산총계: ['543226809462'] 부채총계: ['225469895312'] 자본총계: ['317756914150'] 단기차입금: ['0'] 유동성장기부채: ['14992992036'] 장기차입금: ['69458479535'] 비유동자산: ['108644805066'] 비유동부채: ['104391183936'] 전기말 자산총계: ['469386259226'] 전기말 부채총계: ['167286404113'] 전기말 자본총계: ['302099855113'] 매출채권: ['43011018016'] 매입채무: ['54928732790'] 재고자산: ['86636677867'] 당기순이익: ['18171839463'] 영업이익: ['28486910867'] 수익(매출액): ['485236330934'] 법인세비용차감전순이익(손실): ['23269351421'] 금융비용: ['1299513870'] 전기 수익(매출액): ['548055256061'] 전기 영업이익: ['24032013331'] 영업활동으로 인한 현금흐름: ['31253809023']
# 자산총계: ['557818138546'] 부채총계: ['240565655471'] 자본총계: ['317252483075'] 단기차입금: ['0'] 유동성장기부채: ['14998467468'] 장기차입금: ['69458479535'] 비유동자산: ['114477491166'] 비유동부채: ['106073842868'] 전기말 자산총계: ['468591603341'] 전기말 부채총계: ['165217063744'] 전기말 자본총계: ['303374539597'] 매출채권: ['46754021684'] 매입채무: ['57816913162'] 재고자산: ['87184473438'] 당기순이익: ['2952821888'] 영업이익: ['4207384053'] 수익(매출액): ['104441396101'] 법인세비용차감전순이익(손실): ['4483986437'] 금융비용: ['235575264'] 전기 수익(매출액): ['95434499036'] 전기 영업이익: ['7302211753'] 영업활동으로 인한 현금흐름: ['16204943960']
# 자산총계: ['623901410668'] 부채총계: ['283284229867'] 자본총계: ['340617180801'] 단기차입금: ['0'] 유동성장기부채: ['90200000000'] 장기차입금: ['38474521567'] 비유동자산: ['115306202495'] 비유동부채: ['79373078702'] 전기말 자산총계: ['486038729182'] 전기말 부채총계: ['182103073372'] 전기말 자본총계: ['303935655810'] 매출채권: ['34568214302'] 매입채무: ['63305017302'] 재고자산: ['86279887204'] 당기순이익: ['22049807032'] 영업이익: ['26395925583'] 수익(매출액): ['156165945233'] 법인세비용차감전순이익(손실): ['28928249342'] 금융비용: ['153408212'] 전기 수익(매출액): ['131120884631'] 전기 영업이익: ['1336317035'] 영업활동으로 인한 현금흐름: ['-17834487778']
# 자산총계: ['662478013540'] 부채총계: ['314146802086'] 자본총계: ['348331211454'] 단기차입금: ['10000000000'] 유동성장기부채: ['90200000000'] 장기차입금: ['38474521567'] 비유동자산: ['117796366054'] 비유동부채: ['95311695058'] 전기말 자산총계: ['507791952398'] 전기말 부채총계: ['193319735379'] 전기말 자본총계: ['314472217019'] 매출채권: ['72311278015'] 매입채무: ['67771439763'] 재고자산: ['87281634223'] 당기순이익: ['7663878126'] 영업이익: ['8419572736'] 수익(매출액): ['152120191901'] 법인세비용차감전순이익(손실): ['10051946189'] 금융비용: ['-9753870'] 전기 수익(매출액): ['108193698204'] 전기 영업이익: ['12356004767'] 영업활동으로 인한 현금흐름: ['-55818799334']
# 자산총계: ['754513209734'] 부채총계: ['393018265246'] 자본총계: ['361494944488'] 단기차입금: ['0'] 유동성장기부채: ['145300000000'] 장기차입금: ['42369949193'] 비유동자산: ['117946106274'] 비유동부채: ['108202047801'] 전기말 자산총계: ['543226809462'] 전기말 부채총계: ['225469895312'] 전기말 자본총계: ['317756914150'] 매출채권: ['96729185628'] 매입채무: ['84936476694'] 재고자산: ['87183578787'] 당기순이익: ['46416953200'] 영업이익: ['55816077094'] 수익(매출액): ['608817281256'] 법인세비용차감전순이익(손실): ['63731810048'] 금융비용: ['824509716'] 전기 수익(매출액): ['485236330934'] 전기 영업이익: ['28486910867'] 영업활동으로 인한 현금흐름: ['-89829933823']
# 자산총계: ['779887942357'] 부채총계: ['410746632152'] 자본총계: ['369141310205'] 단기차입금: ['17000000000'] 유동성장기부채: ['145300000000'] 장기차입금: ['42369949193'] 비유동자산: ['146297050309'] 비유동부채: ['113222495243'] 전기말 자산총계: ['557818138546'] 전기말 부채총계: ['240565655471'] 전기말 자본총계: ['317252483075'] 매출채권: ['80065602164'] 매입채무: ['82113004084'] 재고자산: ['115133623020'] 당기순이익: ['11839970132'] 영업이익: ['16772154156'] 수익(매출액): ['160144310627'] 법인세비용차감전순이익(손실): ['15444566701'] 금융비용: ['2637153130'] 전기 수익(매출액): ['104441396101'] 전기 영업이익: ['4207384053'] 영업활동으로 인한 현금흐름: ['-11652298528']
# 자산총계: ['930568225103'] 부채총계: ['545388722770'] 자본총계: ['385179502333'] 단기차입금: ['69800000000'] 유동성장기부채: ['145300000000'] 장기차입금: ['95467000000'] 비유동자산: ['131006946747'] 비유동부채: ['159649438469'] 전기말 자산총계: ['623901410668'] 전기말 부채총계: ['283284229867'] 전기말 자본총계: ['340617180801'] 매출채권: ['107425971517'] 매입채무: ['98876825996'] 재고자산: ['431143191575'] 당기순이익: ['16411034804'] 영업이익: ['20160216303'] 수익(매출액): ['197411856474'] 법인세비용차감전순이익(손실): ['21153290609'] 금융비용: ['1506151701'] 전기 수익(매출액): ['156165945233'] 전기 영업이익: ['26395925583'] 영업활동으로 인한 현금흐름: ['-178613066495']
# 자산총계: ['1008840230181'] 부채총계: ['629830518121'] 자본총계: ['379009712060'] 단기차입금: ['89800000000'] 유동성장기부채: ['135300000000'] 장기차입금: ['108922000000'] 비유동자산: ['137010826403'] 비유동부채: ['172765566194'] 전기말 자산총계: ['662478013540'] 전기말 부채총계: ['314146802086'] 전기말 자본총계: ['348331211454'] 매출채권: ['111870374182'] 매입채무: ['112626762208'] 재고자산: ['432863146961'] 당기순이익: ['-5891364944'] 영업이익: ['-24557364591'] 수익(매출액): ['167923913203'] 법인세비용차감전순이익(손실): ['-6828717970'] 금융비용: ['5420904790'] 전기 수익(매출액): ['152120191901'] 전기 영업이익: ['8419572736'] 영업활동으로 인한 현금흐름: ['-168021358770']
# 자산총계: ['1037164604745'] 부채총계: ['640625387374'] 자본총계: ['396539217371'] 단기차입금: ['65100000000'] 유동성장기부채: ['135300000000'] 장기차입금: ['122522000000'] 비유동자산: ['139906474073'] 비유동부채: ['198048157216'] 전기말 자산총계: ['754513209734'] 전기말 부채총계: ['393018265246'] 전기말 자본총계: ['361494944488'] 매출채권: ['148750355830'] 매입채무: ['102759644600'] 재고자산: ['465233826648'] 당기순이익: ['39572591210'] 영업이익: ['59930960643'] 수익(매출액): ['735785544385'] 법인세비용차감전순이익(손실): ['57172021396'] 금융비용: ['10959537446'] 전기 수익(매출액): ['608817281256'] 전기 영업이익: ['55816077094'] 영업활동으로 인한 현금흐름: ['-158966626125']
#              기업명    연도  보고서 코드        부채비율     차입금의존도    고정장기적합률  자기자본순이익률  \
# 아이디
# 011370202001  서한  2020  1분기보고서   54.459766   8.314356  25.157714  0.016821
# 011370202002  서한  2020   반기보고서   59.915008  10.013116  25.869245  0.001201
# 011370202003  서한  2020  3분기보고서   61.474345   7.347575  32.316413  0.032876
# 011370202004  서한  2020   사업보고서   70.956724  15.546264  25.736183  0.058632
# 011370202101  서한  2021  1분기보고서   75.827824  15.140588  27.042375  0.009516
# 011370202102  서한  2021   반기보고서   83.167922  20.624175  27.454494  0.068419
# 011370202103  서한  2021  3분기보고서   90.186234  20.932698  26.552068  0.023126
# 011370202104  서한  2021   사업보고서  108.720266  24.872984  25.111105  0.136671
# 011370202201  서한  2022  1분기보고서  111.270839  26.243507  30.329193  0.034499
# 011370202202  서한  2022   반기보고서  141.593392  33.373910  24.045519  0.045222
# 011370202203  서한  2022  3분기보고서  166.177936  33.109504  24.830911 -0.016200
# 011370202204  서한  2022   사업보고서  161.554106  31.135077  23.530011  0.104408
#
#               매출액영업이익률  매출액경상이익률   이자보상배율(배)   매출액 증가율   총자산 증가율   영업이익 증가율  \
# 아이디
# 011370202001  0.076515  0.063096    9.716138 -0.282367 -0.067624   0.689921
# 011370202002  0.010191  0.004286    3.979556 -0.175379 -0.097151  -0.913353
# 011370202003  0.114203  0.120526   22.385619  0.015816  0.042202  -2.089063
# 011370202004  0.058707  0.047955   21.921206 -0.114622  0.157313   0.185373
# 011370202101  0.040285  0.042933   17.860042  0.094378  0.190414  -0.423821
# 011370202102  0.169025  0.185240  172.063316  0.191007  0.283645  18.752742
# 011370202103  0.055348  0.066079 -863.203296  0.405999  0.304625  -0.318585
# 011370202104  0.091680  0.104681   67.696082  0.254682  0.388947   0.959359
# 011370202201  0.104732  0.096442    6.359947  0.533341  0.398104   2.986362
# 011370202202  0.102123  0.107153   13.385250  0.264116  0.491531  -0.236238
# 011370202203 -0.146241 -0.040666   -4.530123  0.103890  0.522828  -3.916700
# 011370202204  0.081452  0.077702    5.468384  0.208549  0.374614   0.073722
#
#               자기자본 증가율  매출채권 회전기일(일)  재고자산 회전기일(일)  매입채무 회전기일(일)   총자산 회전율  \
# 아이디
# 011370202001  0.015226      0.015226     41.544274     55.738789  0.203662
# 011370202002 -0.011635     -0.011635     70.695045     66.776933  0.269775
# 011370202003  0.047111      0.047111     96.042385    111.107318  0.213067
# 011370202004  0.051827      0.051827     32.441991     41.431185  0.893248
# 011370202101  0.045745      0.045745     40.289216     49.822411  0.187232
# 011370202102  0.120688      0.120688     40.065373     73.372003  0.250305
# 011370202103  0.107669      0.107669    129.772246    121.624900  0.229623
# 011370202104  0.137646      0.137646     57.991377     50.921376  0.806901
# 011370202201  0.163557      0.163557     44.996317     46.146943  0.205343
# 011370202202  0.130828      0.130828     98.495102     90.656690  0.212141
# 011370202203  0.088073      0.088073    181.871727    183.101415  0.166452
# 011370202204  0.096943      0.096943     73.790360     50.975818  0.709420
#
#               부채상환계수(배)  총차입금상환능력비율
# 아이디
# 011370202001   0.072721   -0.007322
# 011370202002  -0.286399   -0.207003
# 011370202003   3.561035    2.326343
# 011370202004   1.998055    0.370080
# 011370202101   1.079196    0.191872
# 011370202102  -0.195688   -0.138602
# 011370202103  -0.557225   -0.402517
# 011370202104  -0.609107   -0.478659
# 011370202201  -0.054658   -0.056932
# 011370202202  -0.817645   -0.575119
# 011370202203  -0.705361   -0.503025
# 011370202204  -0.700262   -0.492276

# %%
df.to_csv(f'/content/drive/MyDrive/ICR/재무비율/{corp_name_p}_재무비율.csv')

# %% [markdown]
# ### 태영건설

# %%
corp_name = ['DL이앤씨', 'HDC현대산업개발', '한전KPS', 'HJ중공업', '신세계건설', 'KCC건설', '대우건설', '서희건설', '특수건설', '계룡건설산업', '신원종합개발', '서한', '태영건설', '현대건설', 'GS건설', '동부건설', '코오롱글로벌', 'DL건설', '진흥기업', '남광토건', '한신공영', '금호건설', '삼부토건']
corp_code = ['375500', '294870', '051600', '097230', '034300', '021320', '047040', '035890', '026150', '013580', '017000', '011370', '009410', '000720', '006360', '005960', '003070', '001880', '002780', '001260', '004960', '002990', '001470']
report_code = ["11013", "11012", "11014", "11011"] # '11013'=1분기보고서, '11012'=반기보고서, '11014'=3분기보고서, '11011'=사업보고서

corp_name_p = corp_name[12]
corp_code_p = corp_code[12]

all = pd.DataFrame()

for year in range(2019, 2023):
  for code in report_code:
    corp = dart.finstate_all(corp_code_p, year, code, fs_div="OFS")
    # corp = corp.drop('account_id', axis=1)
    all = pd.concat([all, corp], ignore_index=True) # 2019년~2022년 별도 재무제표 전문(분기보고서+반기보고서+사업보고서)

all
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# 주석에 있는 단기차입금, 유동성장기부채, 회사채, 장기차입금은 수기로 가져와야 함
short_term_loan = ['343094681000', '243082512000', '334313720000', '131074044000', '171324832000', '171395185000', '171696598000', '171787401000', '171914859000', '182398624000', '242398624000', '412486320000']
liquidity_enhancing_long_term_debt = ['45927138000', '40700000000', '0', '0', '0', '0', '0', '0', '38362451000', '0', '0', '17664953000']
corporate_bond = ['478746683000', '478893875000', '479042685000', '479191494000', '399329487000', '379446445000', '479257023000', '479402935000', '379535682000', '379643705000', '259724298000', '259795352000']
long_term_loan = ['0', '0', '0', '0', '0', '19181299000', '19181299000', '38362450000', '0', '89100000000', '89100000000', '89719161000']
year_i = ['2020','2020','2020','2020','2021','2021','2021','2021','2022','2022','2022','2022']
report_code_i = ["11013", "11012", "11014", "11011","11013", "11012", "11014", "11011","11013", "11012", "11014", "11011"]

debt = {
    'year':year_i,
    'report_code':report_code_i,
    '단기차입금': short_term_loan,
    '유동성장기부채': liquidity_enhancing_long_term_debt,
    '사채': corporate_bond,
    '장기차입금': long_term_loan}

debt_df = pd.DataFrame(debt)
debt_df
# Out:
#     year report_code         단기차입금      유동성장기부채            사채        장기차입금
# 0   2020       11013  343094681000  45927138000  478746683000            0
# 1   2020       11012  243082512000  40700000000  478893875000            0
# 2   2020       11014  334313720000            0  479042685000            0
# 3   2020       11011  131074044000            0  479191494000            0
# 4   2021       11013  171324832000            0  399329487000            0
# 5   2021       11012  171395185000            0  379446445000  19181299000
# 6   2021       11014  171696598000            0  479257023000  19181299000
# 7   2021       11011  171787401000            0  479402935000  38362450000
# 8   2022       11013  171914859000  38362451000  379535682000            0
# 9   2022       11012  182398624000            0  379643705000  89100000000
# 10  2022       11014  242398624000            0  259724298000  89100000000
# 11  2022       11011  412486320000  17664953000  259795352000  89719161000

# %%
Quarter = []
cor_year = []
ID_list = []
corp_name_list = []
year_list = []
report_code_list = []
Debt_Ratio = []
Debt_to_Asset_Ratio = []
Fixed_Asset_Turnover_Ratio = []
Return_on_Equity = []
Operating_Profit_Margin = []
Gross_Profit_Margin = []
Interest_Coverage_Ratio =[]
Sales_Growth_Rate = []
Total_Asset_Growth_Rate = []
Operating_Profit_Growth_Rate = []
Equity_Growth_Rate= []
Accounts_Receivable_Turnover = []
Inventory_Turnover = []
Accounts_Payable_Turnover = []
Total_Asset_Turnover_Ratio = []
Debt_Service_Coverage_Ratio = []
Debt_to_Equity_Ratio = []


for year in range(2020, 2023):
  str_year = str(year)
  report_code_list.extend(['1분기보고서' if code == '11013' else '반기보고서' if code == '11012' else '3분기보고서' if code == '11014' else '사업보고서' for code in report_code])
  Quarter.extend(['01' if code == '11013' else '02' if code == '11012' else '03' if code == '11014' else '04' for code in report_code])
  for code in report_code:
    BS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '자산총계' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자산총계
    BS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 부채총계
    BS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자본총계
    BS4 = [(row['단기차입금']) for index, row in debt_df.iterrows() if row['year'] == str(year) and row['report_code'] == str(code)]
    BS5 = [(row['유동성장기부채']) for index, row in debt_df.iterrows() if row['year'] == str(year) and row['report_code'] == str(code)]
    BS6 = [(row['사채']) for index, row in debt_df.iterrows() if row['year'] == str(year) and row['report_code'] == str(code)]
    BS7 = [(row['장기차입금']) for index, row in debt_df.iterrows() if row['year'] == str(year) and row['report_code'] == str(code)]
    # BS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '단기차입금' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 단기차입금
    # BS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and ('유동성장기부채' in row['account_nm'] or '유동성장기채무' in row['account_nm']) and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 유동성장기부채
    # BS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '사채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 사채
    # BS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '장기차입금' in row['account_nm'] and '유동성' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 장기차입금
    BS8 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동자산' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동자산
    BS9 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동부채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동부채
    BS10 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자산총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자산총계
    BS11 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 부채총계
    BS12 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자본총계
    BS13 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매출채권' in row['account_nm'] and '비유동' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매출채권
    BS14 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매입채무' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매입채무
    BS15 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '재고자산' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 재고자산

    IS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '포괄손익계산서' and '기순이익' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 당기순이익
    IS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and '법인세' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업이익
    IS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '매출액' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 수익(매출액)
    IS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '법인세' in row['account_nm'] and '차감전' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 법인세비용차감전순이익(손실)
    IS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and (row['account_nm'] == '금융비용' or row['account_nm'] == '금융원가') and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 금융비용
    IS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '매출액' in row['account_nm'] and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 수익(매출액) # 분기 보고서만 해당
    IS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '영업이익(손실)' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 영업이익 # 분기 보고서만 해당

    CF1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '현금흐름표' and row['account_nm'] == '영업활동현금흐름' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업활동으로 인한 현금흐름

    # if BS6 == BS7: # '사채 및 장기차입금'으로 계정과목 하나만 쓰는 회사는 합침(어차피 사채는 차입금 의존도에서만 사용해서 하나 0으로 만들어도 상관없음)
    #   BS6 = ['0']
    # if BS4 == BS5:
    #   BS4 = ['0'] # '단기차입금 및 유동성장기부채' 로 병합해서 쓰는 회사는 ㅎ나로 합침(어차피 둘이 항상 붙어서 계산해서 상관없음)
    # if BS4 == []:
    #   BS4 = ['0']
    # if BS5 == [''] or BS5 == []:
    #   BS5 = ['0']
    # if BS6 == []:
    #   BS6 = ['0']
    # if BS16 == []:
    #   BS16 = ['0']
    # if BS7 == []:
    #   BS7 = ['0']
    if len(BS14) >= 2:
      BS14 = [str(BS14[0])]

    print("자산총계:", BS1, "부채총계:", BS2, "자본총계:", BS3, "단기차입금:", BS4, "유동성장기부채:", BS5, "사채:", BS6, "장기차입금:", BS7, "비유동자산:", BS8, "비유동부채:", BS9, "전기말 자산총계:", BS10, "전기말 부채총계:", BS11,
          "전기말 자본총계:", BS12, "매출채권:", BS13, "매입채무:", BS14, "재고자산:", BS15, "당기순이익:", IS1, "영업이익:", IS2, "수익(매출액):", IS3, "법인세비용차감전순이익(손실):", IS4,
          "금융비용:", IS5, "전기 수익(매출액):", IS6, "전기 영업이익:", IS7, "영업활동으로 인한 현금흐름:", CF1)

    if year != 2020:
      if code == "11013":
        accounting_period = 90
      elif code == "11012":
        accounting_period = 181
      elif code == "11014":
        accounting_period = 273
      elif code == "11011":
        accounting_period = 365
    else: # 2020년은 윤년
      if code == "11013":
        accounting_period = 91
      elif code == "11012":
        accounting_period = 182
      elif code == "11014":
        accounting_period = 274
      elif code == "11011":
        accounting_period = 366


    cor_year.extend([f"{corp_code_p}{str_year}"])
    corp_name_list.append(str(corp_name_p))
    year_list.append(str_year)
    Debt_Ratio.extend([int(BS2)/int(BS3)*100 for BS2, BS3 in zip(BS2, BS3)])
    Debt_to_Asset_Ratio.extend([((int(BS4) + int(BS5) + int(BS6) + int(BS7) ) / int(BS1) * 100) for BS4, BS5, BS6, BS7, BS1 in zip(BS4, BS5, BS6, BS7, BS1)])
    Fixed_Asset_Turnover_Ratio.extend([int(BS8)/(int(BS9)+int(BS3))*100 for BS8, BS9, BS3 in zip(BS8, BS9, BS3)]),
    Return_on_Equity.extend([int(IS1)/((int(BS12)+int(BS3))/2) for IS1, BS12, BS3 in zip(IS1, BS12, BS3)])
    Operating_Profit_Margin.extend([int(IS2)/int(IS3) for IS2, IS3 in zip(IS2, IS3)])
    Gross_Profit_Margin.extend([int(IS4)/int(IS3) for IS4, IS3 in zip(IS4, IS3)])
    Interest_Coverage_Ratio.extend([int(IS2)/int(IS5) for IS2, IS5 in zip(IS2, IS5)])
    Sales_Growth_Rate.extend([(int(IS3)-int(IS6))/int(IS6) for IS3, IS6 in zip(IS3, IS6)])
    Total_Asset_Growth_Rate.extend([(int(BS1)-int(BS10))/int(BS10) for BS1, BS10 in zip(BS1, BS10)])
    Operating_Profit_Growth_Rate.extend([(int(IS2)-int(IS7))/int(IS7) for IS2, IS7 in zip(IS2, IS7)])
    Equity_Growth_Rate.extend([(int(BS3)-int(BS12))/int(BS12) for BS3, BS12 in zip(BS3, BS12)])
    Accounts_Receivable_Turnover.extend([int(BS13)/int(IS3)*accounting_period for BS13, IS3 in zip(BS13, IS3)])
    Inventory_Turnover.extend([int(BS15)/int(IS3)*accounting_period for BS15, IS3 in zip(BS15, IS3)])
    Accounts_Payable_Turnover.extend([int(BS14)/int(IS3)*accounting_period for BS14, IS3 in zip(BS14, IS3)])
    Total_Asset_Turnover_Ratio.extend([int(IS3)/int(BS1) for IS3, BS1 in zip(IS3, BS1)])
    Debt_Service_Coverage_Ratio.extend([(int(CF1)+int(IS5))/(int(BS4)+int(BS5)+int(IS5)) for CF1, IS5, BS4, BS5 in zip(CF1, IS5, BS4, BS5)])
    Debt_to_Equity_Ratio.extend([int(CF1)/(int(BS4)+int(BS7)+int(BS5)) for CF1, BS4, BS7, BS5 in zip(CF1, BS4, BS7, BS5)])

ID_list.extend([x+y for x,y in zip(cor_year,Quarter)])

financial_ratio = {
      '아이디':ID_list,
      '기업명':corp_name_list,
      '연도':year_list,
      '보고서 코드':report_code_list,
      '부채비율' : Debt_Ratio,
      '차입금의존도' : Debt_to_Asset_Ratio,
      '고정장기적합률':Fixed_Asset_Turnover_Ratio,
      '자기자본순이익률':Return_on_Equity,
      '매출액영업이익률':Operating_Profit_Margin,
      '매출액경상이익률':Gross_Profit_Margin,
      '이자보상배율(배)':Interest_Coverage_Ratio,
      '매출액 증가율':Sales_Growth_Rate,
      '총자산 증가율':Total_Asset_Growth_Rate,
      '영업이익 증가율':Operating_Profit_Growth_Rate,
      '자기자본 증가율':Equity_Growth_Rate,
      '매출채권 회전기일(일)':Equity_Growth_Rate,
      '재고자산 회전기일(일)':Accounts_Receivable_Turnover,
      '매입채무 회전기일(일)':Accounts_Payable_Turnover,
      '총자산 회전율':Total_Asset_Turnover_Ratio,
      '부채상환계수(배)':Debt_Service_Coverage_Ratio,
      '총차입금상환능력비율':Debt_to_Equity_Ratio
                    }

df = pd.DataFrame(financial_ratio)
df.set_index('아이디', inplace=True)

df
# Out:
# 자산총계: ['3041419713160'] 부채총계: ['2007550415086'] 자본총계: ['1033869298074'] 단기차입금: ['343094681000'] 유동성장기부채: ['45927138000'] 사채: ['478746683000'] 장기차입금: ['0'] 비유동자산: ['1324240968747'] 비유동부채: ['617209977871'] 전기말 자산총계: ['2354124094115'] 전기말 부채총계: ['1402929880654'] 전기말 자본총계: ['951194213461'] 매출채권: ['322836681010'] 매입채무: ['330659799876'] 재고자산: ['503702368759'] 당기순이익: ['31544210184'] 영업이익: ['42405354840'] 수익(매출액): ['445046741805'] 법인세비용차감전순이익(손실): ['40839503925'] 금융비용: ['5199497084'] 전기 수익(매출액): ['453563791439'] 전기 영업이익: ['66548823623'] 영업활동으로 인한 현금흐름: ['33148652072']
# 자산총계: ['2920468442963'] 부채총계: ['1835408254739'] 자본총계: ['1085060188224'] 단기차입금: ['243082512000'] 유동성장기부채: ['40700000000'] 사채: ['478893875000'] 장기차입금: ['0'] 비유동자산: ['1349867758207'] 비유동부채: ['580115587476'] 전기말 자산총계: ['2569800422258'] 전기말 부채총계: ['1561404278235'] 전기말 자본총계: ['1008396144023'] 매출채권: ['259217845975'] 매입채무: ['359324945682'] 재고자산: ['495216799382'] 당기순이익: ['47700247471'] 영업이익: ['58967775647'] 수익(매출액): ['592190070743'] 법인세비용차감전순이익(손실): ['64818683227'] 금융비용: ['5493532874'] 전기 수익(매출액): ['563609214653'] 전기 영업이익: ['82815636774'] 영업활동으로 인한 현금흐름: ['14848529822']
# 자산총계: ['2638467141509'] 부채총계: ['1949380268161'] 자본총계: ['689086873348'] 단기차입금: ['334313720000'] 유동성장기부채: ['0'] 사채: ['479042685000'] 장기차입금: ['0'] 비유동자산: ['990039431548'] 비유동부채: ['619574662397'] 전기말 자산총계: ['2771035428758'] 전기말 부채총계: ['1735816223790'] 전기말 자본총계: ['1035219204968'] 매출채권: ['393918245543'] 매입채무: ['384662343619'] 재고자산: ['490369433066'] 당기순이익: ['698704341264'] 영업이익: ['78188191309'] 수익(매출액): ['591699482947'] 법인세비용차감전순이익(손실): ['722295523661'] 금융비용: ['5871053881'] 전기 수익(매출액): ['534775530335'] 전기 영업이익: ['64318032972'] 영업활동으로 인한 현금흐름: ['-132728325410']
# 자산총계: ['2682875572935'] 부채총계: ['1974850386006'] 자본총계: ['708025186929'] 단기차입금: ['131074044000'] 유동성장기부채: ['0'] 사채: ['479191494000'] 장기차입금: ['0'] 비유동자산: ['972781826513'] 비유동부채: ['557616540215'] 전기말 자산총계: ['2849668896003'] 전기말 부채총계: ['1828794197868'] 전기말 자본총계: ['1020874698135'] 매출채권: ['283204096624'] 매입채무: ['462301409915'] 재고자산: ['815895834439'] 당기순이익: ['784633282222'] 영업이익: ['208404205188'] 수익(매출액): ['2148138415287'] 법인세비용차감전순이익(손실): ['837833559383'] 금융비용: ['21849211134'] 전기 수익(매출액): ['2175685520993'] 전기 영업이익: ['271073133618'] 영업활동으로 인한 현금흐름: ['340217885768']
# 자산총계: ['2586455538115'] 부채총계: ['1846759287861'] 자본총계: ['739696250254'] 단기차입금: ['171324832000'] 유동성장기부채: ['0'] 사채: ['399329487000'] 장기차입금: ['0'] 비유동자산: ['989954490048'] 비유동부채: ['439678178058'] 전기말 자산총계: ['3041419713160'] 전기말 부채총계: ['2007550415086'] 전기말 자본총계: ['1033869298074'] 매출채권: ['242042231643'] 매입채무: ['385437618143'] 재고자산: ['697009375095'] 당기순이익: ['39070104396'] 영업이익: ['42522227283'] 수익(매출액): ['492815504500'] 법인세비용차감전순이익(손실): ['52625327236'] 금융비용: ['4721158173'] 전기 수익(매출액): ['445046741805'] 전기 영업이익: ['42405354840'] 영업활동으로 인한 현금흐름: ['106289211925']
# 자산총계: ['2709064409695'] 부채총계: ['1945824306199'] 자본총계: ['763240103496'] 단기차입금: ['171395185000'] 유동성장기부채: ['0'] 사채: ['379446445000'] 장기차입금: ['19181299000'] 비유동자산: ['1001251136147'] 비유동부채: ['491920503745'] 전기말 자산총계: ['2920468442963'] 전기말 부채총계: ['1835408254739'] 전기말 자본총계: ['1085060188224'] 매출채권: ['292181474131'] 매입채무: ['431733520221'] 재고자산: ['707669325639'] 당기순이익: ['18983314185'] 영업이익: ['48592532876'] 수익(매출액): ['565162756314'] 법인세비용차감전순이익(손실): ['38042653535'] 금융비용: ['4112181380'] 전기 수익(매출액): ['592190070743'] 전기 영업이익: ['58967775647'] 영업활동으로 인한 현금흐름: ['68012556084']
# 자산총계: ['2793332103004'] 부채총계: ['1986555890175'] 자본총계: ['806776212829'] 단기차입금: ['171696598000'] 유동성장기부채: ['0'] 사채: ['479257023000'] 장기차입금: ['19181299000'] 비유동자산: ['1060849263569'] 비유동부채: ['528336502688'] 전기말 자산총계: ['2638467141509'] 전기말 부채총계: ['1949380268161'] 전기말 자본총계: ['689086873348'] 매출채권: ['310541635888'] 매입채무: ['358856215020'] 재고자산: ['777200320781'] 당기순이익: ['43519485297'] 영업이익: ['42947535039'] 수익(매출액): ['511818531917'] 법인세비용차감전순이익(손실): ['55516098094'] 금융비용: ['4132477112'] 전기 수익(매출액): ['591699482947'] 전기 영업이익: ['78188191309'] 영업활동으로 인한 현금흐름: ['-79503749313']
# 자산총계: ['2745084306524'] 부채총계: ['1913313234959'] 자본총계: ['831771071565'] 단기차입금: ['171787401000'] 유동성장기부채: ['0'] 사채: ['479402935000'] 장기차입금: ['38362450000'] 비유동자산: ['1042513368894'] 비유동부채: ['592495284279'] 전기말 자산총계: ['2682875572935'] 전기말 부채총계: ['1974850386006'] 전기말 자본총계: ['708025186929'] 매출채권: ['330206235907'] 매입채무: ['359400168372'] 재고자산: ['519103647086'] 당기순이익: ['123163459449'] 영업이익: ['191847570401'] 수익(매출액): ['2437679944254'] 법인세비용차감전순이익(손실): ['175861289515'] 금융비용: ['19718367664'] 전기 수익(매출액): ['2148138415287'] 전기 영업이익: ['208404205188'] 영업활동으로 인한 현금흐름: ['212352558503']
# 자산총계: ['2548168891192'] 부채총계: ['1694319898498'] 자본총계: ['853848992694'] 단기차입금: ['171914859000'] 유동성장기부채: ['38362451000'] 사채: ['379535682000'] 장기차입금: ['0'] 비유동자산: ['1062820021295'] 비유동부채: ['352379386278'] 전기말 자산총계: ['2586455538115'] 전기말 부채총계: ['1846759287861'] 전기말 자본총계: ['739696250254'] 매출채권: ['382027911854'] 매입채무: ['313502277667'] 재고자산: ['421573863322'] 당기순이익: ['32928838866'] 영업이익: ['43419329534'] 수익(매출액): ['579688235915'] 법인세비용차감전순이익(손실): ['40467190052'] 금융비용: ['4707078336'] 전기 수익(매출액): ['492815504500'] 전기 영업이익: ['42522227283'] 영업활동으로 인한 현금흐름: ['236390728']
# 자산총계: ['2645431561979'] 부채총계: ['1797290133382'] 자본총계: ['848141428597'] 단기차입금: ['182398624000'] 유동성장기부채: ['0'] 사채: ['379643705000'] 장기차입금: ['89100000000'] 비유동자산: ['1073943741962'] 비유동부채: ['386558849234'] 전기말 자산총계: ['2709064409695'] 전기말 부채총계: ['1945824306199'] 전기말 자본총계: ['763240103496'] 매출채권: ['359854608415'] 매입채무: ['327918791516'] 재고자산: ['467614584054'] 당기순이익: ['8013003969'] 영업이익: ['5595039726'] 수익(매출액): ['600837485440'] 법인세비용차감전순이익(손실): ['10621591810'] 금융비용: ['4370532676'] 전기 수익(매출액): ['565162756314'] 전기 영업이익: ['48592532876'] 영업활동으로 인한 현금흐름: ['47842898296']
# 자산총계: ['2524684280124'] 부채총계: ['1659125924392'] 자본총계: ['865558355732'] 단기차입금: ['242398624000'] 유동성장기부채: ['0'] 사채: ['259724298000'] 장기차입금: ['89100000000'] 비유동자산: ['1052773327126'] 비유동부채: ['420685670588'] 전기말 자산총계: ['2793332103004'] 전기말 부채총계: ['1986555890175'] 전기말 자본총계: ['806776212829'] 매출채권: ['425032917213'] 매입채무: ['299426197767'] 재고자산: ['449636238311'] 당기순이익: ['21131144551'] 영업이익: ['12817208893'] 수익(매출액): ['569527005303'] 법인세비용차감전순이익(손실): ['20853819294'] 금융비용: ['4863807677'] 전기 수익(매출액): ['511818531917'] 전기 영업이익: ['42947535039'] 영업활동으로 인한 현금흐름: ['-60738495912']
# 자산총계: ['2966326502125'] 부채총계: ['2073747454718'] 자본총계: ['892579047407'] 단기차입금: ['412486320000'] 유동성장기부채: ['17664953000'] 사채: ['259795352000'] 장기차입금: ['89719161000'] 비유동자산: ['1210447073438'] 비유동부채: ['421270087655'] 전기말 자산총계: ['2745084306524'] 전기말 부채총계: ['1913313234959'] 전기말 자본총계: ['831771071565'] 매출채권: ['546851741472'] 매입채무: ['503030543874'] 재고자산: ['426136783996'] 당기순이익: ['79048061000'] 영업이익: ['126264508055'] 수익(매출액): ['2518358923626'] 법인세비용차감전순이익(손실): ['98571424308'] 금융비용: ['22872751691'] 전기 수익(매출액): ['2437679944254'] 전기 영업이익: ['191847570401'] 영업활동으로 인한 현금흐름: ['69197877910']
#                기업명    연도  보고서 코드        부채비율     차입금의존도    고정장기적합률  자기자본순이익률  \
# 아이디
# 009410202001  태영건설  2020  1분기보고서  194.178357  28.531692  80.204566  0.031782
# 009410202002  태영건설  2020   반기보고서  169.152668  26.114865  81.064581  0.045571
# 009410202003  태영건설  2020  3분기보고서  282.893252  30.826854  75.652826  0.810418
# 009410202004  태영건설  2020   사업보고서  278.923748  22.746696  76.860758  0.907668
# 009410202101  태영건설  2021  1분기보고서  249.664546  22.063179  83.938948  0.044058
# 009410202102  태영건설  2021   반기보고서  254.942619  21.041321  79.770758  0.020541
# 009410202103  태영건설  2021  3분기보고서  246.233820  23.990521  79.457656  0.058186
# 009410202104  태영건설  2021   사업보고서  230.028826  25.119549  73.196517  0.159974
# 009410202201  태영건설  2022  1분기보고서  198.433202  23.146542  88.111011  0.041328
# 009410202202  태영건설  2022   반기보고서  211.909249  24.613841  86.980117  0.009946
# 009410202203  태영건설  2022  3분기보고서  191.682734  23.417697  81.848647  0.025271
# 009410202204  태영건설  2022   사업보고서  232.332079  26.283883  92.129838  0.091684
#
#               매출액영업이익률  매출액경상이익률  이자보상배율(배)   매출액 증가율   총자산 증가율  영업이익 증가율  \
# 아이디
# 009410202001  0.095283  0.091765   8.155665 -0.018778  0.291954 -0.362793
# 009410202002  0.099576  0.109456  10.734035  0.050710  0.136457 -0.287963
# 009410202003  0.132142  1.220713  13.317573  0.106445 -0.047841  0.215650
# 009410202004  0.097016  0.390028   9.538294 -0.012661 -0.058531 -0.231188
# 009410202101  0.086284  0.106785   9.006736  0.107334 -0.149589  0.002756
# 009410202102  0.085980  0.067313  11.816729 -0.045640 -0.072387 -0.175948
# 009410202103  0.083912  0.108468  10.392686 -0.135003  0.058695 -0.450716
# 009410202104  0.078701  0.072143   9.729384  0.134787  0.023187 -0.079445
# 009410202201  0.074901  0.069809   9.224263  0.176278 -0.014803  0.021097
# 009410202202  0.009312  0.017678   1.280173  0.063123 -0.023489 -0.884858
# 009410202203  0.022505  0.036616   2.635221  0.112752 -0.096175 -0.701561
# 009410202204  0.050138  0.039141   5.520302  0.033097  0.080596 -0.341850
#
#               자기자본 증가율  매출채권 회전기일(일)  재고자산 회전기일(일)  매입채무 회전기일(일)   총자산 회전율  \
# 아이디
# 009410202001  0.086917      0.086917     66.011354     67.610970  0.146329
# 009410202002  0.076026      0.076026     79.666395    110.432686  0.202772
# 009410202003 -0.334357     -0.334357    182.412867    178.126710  0.224259
# 009410202004 -0.306452     -0.306452     48.252337     78.766952  0.800685
# 009410202101 -0.284536     -0.284536     44.202751     70.390208  0.190537
# 009410202102 -0.296592     -0.296592     93.574543    138.267723  0.208619
# 009410202103  0.170790      0.170790    165.640479    191.411097  0.183229
# 009410202104  0.174776      0.174776     49.442617     53.813899  0.888016
# 009410202201  0.154324      0.154324     59.312075     48.673068  0.227492
# 009410202202  0.111238      0.111238    108.404828     98.784285  0.227123
# 009410202203  0.072861      0.072861    203.737462    143.528492  0.225583
# 009410202204  0.073107      0.073107     79.258315     72.907061  0.848982
#
#               부채상환계수(배)  총차입금상환능력비율
# 아이디
# 009410202001   0.097276    0.085210
# 009410202002   0.070321    0.052324
# 009410202003  -0.372907   -0.397017
# 009410202004   2.367639    2.595616
# 009410202101   0.630576    0.620396
# 009410202102   0.410950    0.356878
# 009410202103  -0.428662   -0.416516
# 009410202104   1.211822    1.010482
# 009410202201   0.022995    0.001124
# 009410202202   0.279561    0.176218
# 009410202203  -0.225973   -0.183224
# 009410202204   0.203236    0.133106

# %%
df.to_csv(f'/content/drive/MyDrive/ICR/재무비율/{corp_name_p}_재무비율.csv')

# %% [markdown]
# ### 현대건설

# %%
corp_name = ['DL이앤씨', 'HDC현대산업개발', '한전KPS', 'HJ중공업', '신세계건설', 'KCC건설', '대우건설', '서희건설', '특수건설', '계룡건설산업', '신원종합개발', '서한', '태영건설', '현대건설', 'GS건설', '동부건설', '코오롱글로벌', 'DL건설', '진흥기업', '남광토건', '한신공영', '금호건설', '삼부토건']
corp_code = ['375500', '294870', '051600', '097230', '034300', '021320', '047040', '035890', '026150', '013580', '017000', '011370', '009410', '000720', '006360', '005960', '003070', '001880', '002780', '001260', '004960', '002990', '001470']
report_code = ["11013", "11012", "11014", "11011"] # '11013'=1분기보고서, '11012'=반기보고서, '11014'=3분기보고서, '11011'=사업보고서

corp_name_p = corp_name[13]
corp_code_p = corp_code[13]

all = pd.DataFrame()

for year in range(2019, 2023):
  for code in report_code:
    corp = dart.finstate_all(corp_code_p, year, code, fs_div="OFS")
    # corp = corp.drop('account_id', axis=1)
    all = pd.concat([all, corp], ignore_index=True) # 2019년~2022년 별도 재무제표 전문(분기보고서+반기보고서+사업보고서)

all
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
Quarter = []
cor_year = []
ID_list = []
corp_name_list = []
year_list = []
report_code_list = []
Debt_Ratio = []
Debt_to_Asset_Ratio = []
Fixed_Asset_Turnover_Ratio = []
Return_on_Equity = []
Operating_Profit_Margin = []
Gross_Profit_Margin = []
Interest_Coverage_Ratio =[]
Sales_Growth_Rate = []
Total_Asset_Growth_Rate = []
Operating_Profit_Growth_Rate = []
Equity_Growth_Rate= []
Accounts_Receivable_Turnover = []
Inventory_Turnover = []
Accounts_Payable_Turnover = []
Total_Asset_Turnover_Ratio = []
Debt_Service_Coverage_Ratio = []
Debt_to_Equity_Ratio = []


for year in range(2020, 2023):
  str_year = str(year)
  report_code_list.extend(['1분기보고서' if code == '11013' else '반기보고서' if code == '11012' else '3분기보고서' if code == '11014' else '사업보고서' for code in report_code])
  Quarter.extend(['01' if code == '11013' else '02' if code == '11012' else '03' if code == '11014' else '04' for code in report_code])
  for code in report_code:
    BS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '자산총계' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자산총계
    BS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 부채총계
    BS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자본총계
    BS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '단기차입금' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 단기차입금
    BS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and ('유동성장기부채' in row['account_nm'] or '유동성장기채무' in row['account_nm']) and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 유동성장기부채
    BS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '사채' in row['account_nm'] and row['account_id'] == 'dart_BondsIssued' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 사채
    BS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '차입금' in row['account_nm'] and '단기차입금' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 장기차입금
    BS8 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동자산' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동자산
    BS9 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동부채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동부채
    BS10 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자산총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자산총계
    BS11 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 부채총계
    BS12 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자본총계
    BS13 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '매출채권' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매출채권
    BS14 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '매입채무'  and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매입채무
    BS15 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '재고자산' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 재고자산

    IS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '포괄손익계산서' and '기순' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 당기순이익
    IS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업이익
    IS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '매출액' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 수익(매출액)
    IS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '법인세' in row['account_nm'] and '차감전' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 법인세비용차감전순이익(손실)
    IS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and (row['account_nm'] == '금융비용' or row['account_nm'] == '금융원가') and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 금융비용
    IS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '매출액' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 수익(매출액) # 분기 보고서만 해당
    IS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '영업이익' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 영업이익 # 분기 보고서만 해당

    CF1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '현금흐름표' and row['account_nm'] == '영업활동현금흐름' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업활동으로 인한 현금흐름

    # if BS6 == BS7: # '사채 및 장기차입금'으로 계정과목 하나만 쓰는 회사는 합침(어차피 사채는 차입금 의존도에서만 사용해서 하나 0으로 만들어도 상관없음)
    #   BS6 = ['0']
    # if BS4 == BS5:
    #   BS4 = ['0'] # '단기차입금 및 유동성장기부채' 로 병합해서 쓰는 회사는 ㅎ나로 합침(어차피 둘이 항상 붙어서 계산해서 상관없음)
    if BS4 == [''] or BS4 == []:
      BS4 = ['0']
    # if BS5 == [''] or BS5 == []:
    #   BS5 = ['0']
    # if BS6 == []:
    #   BS6 = ['0']
    # if BS7 == []:
    #   BS7 = ['0']

    print("자산총계:", BS1, "부채총계:", BS2, "자본총계:", BS3, "단기차입금:", BS4, "유동성장기부채:", BS5, "사채:", BS6, "장기차입금:", BS7, "비유동자산:", BS8, "비유동부채:", BS9, "전기말 자산총계:", BS10, "전기말 부채총계:", BS11,
          "전기말 자본총계:", BS12, "매출채권:", BS13, "매입채무:", BS14, "재고자산:", BS15, "당기순이익:", IS1, "영업이익:", IS2, "수익(매출액):", IS3, "법인세비용차감전순이익(손실):", IS4,
          "금융비용:", IS5, "전기 수익(매출액):", IS6, "전기 영업이익:", IS7, "영업활동으로 인한 현금흐름:", CF1)

    if year != 2020:
      if code == "11013":
        accounting_period = 90
      elif code == "11012":
        accounting_period = 181
      elif code == "11014":
        accounting_period = 273
      elif code == "11011":
        accounting_period = 365
    else: # 2020년은 윤년
      if code == "11013":
        accounting_period = 91
      elif code == "11012":
        accounting_period = 182
      elif code == "11014":
        accounting_period = 274
      elif code == "11011":
        accounting_period = 366


    cor_year.extend([f"{corp_code_p}{str_year}"])
    corp_name_list.append(str(corp_name_p))
    year_list.append(str_year)
    Debt_Ratio.extend([int(BS2)/int(BS3)*100 for BS2, BS3 in zip(BS2, BS3)])
    Debt_to_Asset_Ratio.extend([((int(BS4) + int(BS5) + int(BS6) + int(BS7)) / int(BS1) * 100) for BS4, BS5, BS6, BS7, BS1 in zip(BS4, BS5, BS6, BS7, BS1)])
    Fixed_Asset_Turnover_Ratio.extend([int(BS8)/(int(BS9)+int(BS3))*100 for BS8, BS9, BS3 in zip(BS8, BS9, BS3)]),
    Return_on_Equity.extend([int(IS1)/((int(BS12)+int(BS3))/2) for IS1, BS12, BS3 in zip(IS1, BS12, BS3)])
    Operating_Profit_Margin.extend([int(IS2)/int(IS3) for IS2, IS3 in zip(IS2, IS3)])
    Gross_Profit_Margin.extend([int(IS4)/int(IS3) for IS4, IS3 in zip(IS4, IS3)])
    Interest_Coverage_Ratio.extend([int(IS2)/int(IS5) for IS2, IS5 in zip(IS2, IS5)])
    Sales_Growth_Rate.extend([(int(IS3)-int(IS6))/int(IS6) for IS3, IS6 in zip(IS3, IS6)])
    Total_Asset_Growth_Rate.extend([(int(BS1)-int(BS10))/int(BS10) for BS1, BS10 in zip(BS1, BS10)])
    Operating_Profit_Growth_Rate.extend([(int(IS2)-int(IS7))/int(IS7) for IS2, IS7 in zip(IS2, IS7)])
    Equity_Growth_Rate.extend([(int(BS3)-int(BS12))/int(BS12) for BS3, BS12 in zip(BS3, BS12)])
    Accounts_Receivable_Turnover.extend([int(BS13)/int(IS3)*accounting_period for BS13, IS3 in zip(BS13, IS3)])
    Inventory_Turnover.extend([int(BS15)/int(IS3)*accounting_period for BS15, IS3 in zip(BS15, IS3)])
    Accounts_Payable_Turnover.extend([int(BS14)/int(IS3)*accounting_period for BS14, IS3 in zip(BS14, IS3)])
    Total_Asset_Turnover_Ratio.extend([int(IS3)/int(BS1) for IS3, BS1 in zip(IS3, BS1)])
    Debt_Service_Coverage_Ratio.extend([(int(CF1)+int(IS5))/(int(BS4)+int(BS5)+int(IS5)) for CF1, IS5, BS4, BS5 in zip(CF1, IS5, BS4, BS5)])
    Debt_to_Equity_Ratio.extend([int(CF1)/(int(BS4)+int(BS7)+int(BS5)) for CF1, BS4, BS7, BS5 in zip(CF1, BS4, BS7, BS5)])

ID_list.extend([x+y for x,y in zip(cor_year,Quarter)])

financial_ratio = {
      '아이디':ID_list,
      '기업명':corp_name_list,
      '연도':year_list,
      '보고서 코드':report_code_list,
      '부채비율' : Debt_Ratio,
      '차입금의존도' : Debt_to_Asset_Ratio,
      '고정장기적합률':Fixed_Asset_Turnover_Ratio,
      '자기자본순이익률':Return_on_Equity,
      '매출액영업이익률':Operating_Profit_Margin,
      '매출액경상이익률':Gross_Profit_Margin,
      '이자보상배율(배)':Interest_Coverage_Ratio,
      '매출액 증가율':Sales_Growth_Rate,
      '총자산 증가율':Total_Asset_Growth_Rate,
      '영업이익 증가율':Operating_Profit_Growth_Rate,
      '자기자본 증가율':Equity_Growth_Rate,
      '매출채권 회전기일(일)':Equity_Growth_Rate,
      '재고자산 회전기일(일)':Accounts_Receivable_Turnover,
      '매입채무 회전기일(일)':Accounts_Payable_Turnover,
      '총자산 회전율':Total_Asset_Turnover_Ratio,
      '부채상환계수(배)':Debt_Service_Coverage_Ratio,
      '총차입금상환능력비율':Debt_to_Equity_Ratio
                    }

df = pd.DataFrame(financial_ratio)
df.set_index('아이디', inplace=True)

df
# Out:
# 자산총계: ['12207290000000'] 부채총계: ['6564120000000'] 자본총계: ['5643170000000'] 단기차입금: ['208699000000'] 유동성장기부채: ['220279000000'] 사채: ['1326723000000'] 장기차입금: ['7020000000'] 비유동자산: ['3591656000000'] 비유동부채: ['2032824000000'] 전기말 자산총계: ['11721929000000'] 전기말 부채총계: ['6277717000000'] 전기말 자본총계: ['5444212000000'] 매출채권: ['860307000000'] 매입채무: ['1136445000000'] 재고자산: ['894845000000'] 당기순이익: ['100821000000'] 영업이익: ['56627000000'] 수익(매출액): ['2273488000000'] 법인세비용차감전순이익(손실): ['140545000000'] 금융비용: ['58374000000'] 전기 수익(매출액): ['2244821000000'] 전기 영업이익: ['95058000000'] 영업활동으로 인한 현금흐름: ['693661000000']
# 자산총계: ['11978664000000'] 부채총계: ['6341206000000'] 자본총계: ['5637458000000'] 단기차입금: ['286435000000'] 유동성장기부채: ['120328000000'] 사채: ['1326997000000'] 장기차입금: ['112186000000'] 비유동자산: ['3492256000000'] 비유동부채: ['2149105000000'] 전기말 자산총계: ['11640905000000'] 전기말 부채총계: ['6100053000000'] 전기말 자본총계: ['5540852000000'] 매출채권: ['838550000000'] 매입채무: ['1138767000000'] 재고자산: ['751760000000'] 당기순이익: ['28867000000'] 영업이익: ['86804000000'] 수익(매출액): ['2512212000000'] 법인세비용차감전순이익(손실): ['40369000000'] 금융비용: ['26419000000'] 전기 수익(매출액): ['2674000000000'] 전기 영업이익: ['100533000000'] 영업활동으로 인한 현금흐름: ['643851000000']
# 자산총계: ['12006593000000'] 부채총계: ['6368807000000'] 자본총계: ['5637786000000'] 단기차입금: ['80000000000'] 유동성장기부채: ['420193000000'] 사채: ['1435789000000'] 장기차입금: ['111800000000'] 비유동자산: ['3456408000000'] 비유동부채: ['2190384000000'] 전기말 자산총계: ['11563842000000'] 전기말 부채총계: ['5909413000000'] 전기말 자본총계: ['5654429000000'] 매출채권: ['884030000000'] 매입채무: ['966055000000'] 재고자산: ['618984000000'] 당기순이익: ['48592000000'] 영업이익: ['71560000000'] 수익(매출액): ['2248031000000'] 법인세비용차감전순이익(손실): ['57697000000'] 금융비용: ['21995000000'] 전기 수익(매출액): ['2382323000000'] 전기 영업이익: ['102304000000'] 영업활동으로 인한 현금흐름: ['779902000000']
# 자산총계: ['11905200000000'] 부채총계: ['6360125000000'] 자본총계: ['5545075000000'] 단기차입금: ['144620000000'] 유동성장기부채: ['420291000000'] 사채: ['1436091000000'] 장기차입금: ['6764000000'] 비유동자산: ['3780210000000'] 비유동부채: ['2082152000000'] 전기말 자산총계: ['11302918000000'] 전기말 부채총계: ['5717111000000'] 전기말 자본총계: ['5585807000000'] 매출채권: ['757052000000'] 매입채무: ['1055386000000'] 재고자산: ['483334000000'] 당기순이익: ['102477000000'] 영업이익: ['236363000000'] 수익(매출액): ['9320113000000'] 법인세비용차감전순이익(손실): ['143999000000'] 금융비용: ['141676000000'] 전기 수익(매출액): ['10014658000000'] 전기 영업이익: ['370564000000'] 영업활동으로 인한 현금흐름: ['1334157000000']
# 자산총계: ['12130906000000'] 부채총계: ['6476342000000'] 자본총계: ['5654564000000'] 단기차입금: ['0'] 유동성장기부채: ['590144000000'] 사채: ['1146611000000'] 장기차입금: ['6828000000'] 비유동자산: ['3855471000000'] 비유동부채: ['1800788000000'] 전기말 자산총계: ['12207290000000'] 전기말 부채총계: ['6564120000000'] 전기말 자본총계: ['5643170000000'] 매출채권: ['708578000000'] 매입채무: ['1057022000000'] 재고자산: ['388243000000'] 당기순이익: ['122305000000'] 영업이익: ['80169000000'] 수익(매출액): ['2285655000000'] 법인세비용차감전순이익(손실): ['167641000000'] 금융비용: ['28551000000'] 전기 수익(매출액): ['2273488000000'] 전기 영업이익: ['56627000000'] 영업활동으로 인한 현금흐름: ['493878000000']
# 자산총계: ['12522444000000'] 부채총계: ['6855455000000'] 자본총계: ['5666989000000'] 단기차입금: ['0'] 유동성장기부채: ['590261000000'] 사채: ['1445552000000'] 장기차입금: ['6893000000'] 비유동자산: ['3912099000000'] 비유동부채: ['2083847000000'] 전기말 자산총계: ['11978664000000'] 전기말 부채총계: ['6341206000000'] 전기말 자본총계: ['5637458000000'] 매출채권: ['914228000000'] 매입채무: ['1174852000000'] 재고자산: ['305551000000'] 당기순이익: ['15992000000'] 영업이익: ['19099000000'] 수익(매출액): ['2417413000000'] 법인세비용차감전순이익(손실): ['22479000000'] 금융비용: ['22986000000'] 전기 수익(매출액): ['2512212000000'] 전기 영업이익: ['86804000000'] 영업활동으로 인한 현금흐름: ['490107000000']
# 자산총계: ['12559588000000'] 부채총계: ['6749395000000'] 자본총계: ['5810193000000'] 단기차입금: ['0'] 유동성장기부채: ['290340000000'] 사채: ['1445865000000'] 장기차입금: ['6505000000'] 비유동자산: ['3910392000000'] 비유동부채: ['2087549000000'] 전기말 자산총계: ['12006593000000'] 전기말 부채총계: ['6368807000000'] 전기말 자본총계: ['5637786000000'] 매출채권: ['619960000000'] 매입채무: ['1066864000000'] 재고자산: ['277327000000'] 당기순이익: ['61326000000'] 영업이익: ['102974000000'] 수익(매출액): ['2448205000000'] 법인세비용차감전순이익(손실): ['83478000000'] 금융비용: ['16421000000'] 전기 수익(매출액): ['2248031000000'] 전기 영업이익: ['71560000000'] 영업활동으로 인한 현금흐름: ['837242000000']
# 자산총계: ['13291471000000'] 부채총계: ['7285634000000'] 자본총계: ['6005837000000'] 단기차입금: ['0'] 유동성장기부채: ['290401000000'] 사채: ['1446183000000'] 장기차입금: ['6568000000'] 비유동자산: ['4267328000000'] 비유동부채: ['2166698000000'] 전기말 자산총계: ['11905200000000'] 전기말 부채총계: ['6360125000000'] 전기말 자본총계: ['5545075000000'] 매출채권: ['803449000000'] 매입채무: ['1316358000000'] 재고자산: ['204580000000'] 당기순이익: ['285490000000'] 영업이익: ['305119000000'] 수익(매출액): ['10246315000000'] 법인세비용차감전순이익(손실): ['416041000000'] 금융비용: ['107128000000'] 전기 수익(매출액): ['9320113000000'] 전기 영업이익: ['236363000000'] 영업활동으로 인한 현금흐름: ['1120177000000']
# 자산총계: ['13343088000000'] 부채총계: ['7249891000000'] 자본총계: ['6093197000000'] 단기차입금: ['0'] 유동성장기부채: ['180299000000'] 사채: ['1266636000000'] 장기차입금: ['73632000000'] 비유동자산: ['4262500000000'] 비유동부채: ['1987872000000'] 전기말 자산총계: ['12130906000000'] 전기말 부채총계: ['6476342000000'] 전기말 자본총계: ['5654564000000'] 매출채권: ['647862000000'] 매입채무: ['1158276000000'] 재고자산: ['190061000000'] 당기순이익: ['135022000000'] 영업이익: ['87923000000'] 수익(매출액): ['2392866000000'] 법인세비용차감전순이익(손실): ['173429000000'] 금융비용: ['24219000000'] 전기 수익(매출액): ['2285655000000'] 전기 영업이익: ['80169000000'] 영업활동으로 인한 현금흐름: ['-89333000000']
# 자산총계: ['13705876000000'] 부채총계: ['7365538000000'] 자본총계: ['6340338000000'] 단기차입금: ['0'] 유동성장기부채: ['180338000000'] 사채: ['1266915000000'] 장기차입금: ['73696000000'] 비유동자산: ['4408972000000'] 비유동부채: ['2040496000000'] 전기말 자산총계: ['12522444000000'] 전기말 부채총계: ['6855455000000'] 전기말 자본총계: ['5666989000000'] 매출채권: ['925612000000'] 매입채무: ['1517243000000'] 재고자산: ['180534000000'] 당기순이익: ['143659000000'] 영업이익: ['101016000000'] 수익(매출액): ['2967544000000'] 법인세비용차감전순이익(손실): ['202498000000'] 금융비용: ['10399000000'] 전기 수익(매출액): ['2417413000000'] 전기 영업이익: ['19099000000'] 영업활동으로 인한 현금흐름: ['-268412000000']
# 자산총계: ['14059951000000'] 부채총계: ['7289004000000'] 자본총계: ['6770947000000'] 단기차입금: ['0'] 유동성장기부채: ['380124000000'] 사채: ['1067449000000'] 장기차입금: ['73303000000'] 비유동자산: ['4327298000000'] 비유동부채: ['1913139000000'] 전기말 자산총계: ['12559588000000'] 전기말 부채총계: ['6749395000000'] 전기말 자본총계: ['5810193000000'] 매출채권: ['1039492000000'] 매입채무: ['1489867000000'] 재고자산: ['302136000000'] 당기순이익: ['179372000000'] 영업이익: ['106667000000'] 수익(매출액): ['3130356000000'] 법인세비용차감전순이익(손실): ['244346000000'] 금융비용: ['21705000000'] 전기 수익(매출액): ['2448205000000'] 전기 영업이익: ['102974000000'] 영업활동으로 인한 현금흐름: ['-253140000000']
# 자산총계: ['13738416000000'] 부채총계: ['7344179000000'] 자본총계: ['6394237000000'] 단기차입금: ['0'] 유동성장기부채: ['430204000000'] 사채: ['1017693000000'] 장기차입금: ['73364000000'] 비유동자산: ['4255304000000'] 비유동부채: ['1775552000000'] 전기말 자산총계: ['13291471000000'] 전기말 부채총계: ['7285634000000'] 전기말 자본총계: ['6005837000000'] 매출채권: ['847098000000'] 매입채무: ['1651457000000'] 재고자산: ['288515000000'] 당기순이익: ['346572000000'] 영업이익: ['346342000000'] 수익(매출액): ['11978479000000'] 법인세비용차감전순이익(손실): ['503694000000'] 금융비용: ['142163000000'] 전기 수익(매출액): ['10246315000000'] 전기 영업이익: ['305119000000'] 영업활동으로 인한 현금흐름: ['-325273000000']
#                기업명    연도  보고서 코드        부채비율     차입금의존도    고정장기적합률  자기자본순이익률  \
# 아이디
# 000720202001  현대건설  2020  1분기보고서  116.319728  14.439904  46.790761  0.018187
# 000720202002  현대건설  2020   반기보고서  112.483428  15.410283  44.849775  0.005165
# 000720202003  현대건설  2020  3분기보고서  112.966455  17.055479  44.153461  0.008606
# 000720202004  현대건설  2020   사업보고서  114.698629  16.864614  49.562049  0.018413
# 000720202101  현대건설  2021  1분기보고서  114.533004  14.373065  51.714138  0.021651
# 000720202102  현대건설  2021   반기보고서  120.971736  16.312359  50.473252  0.002829
# 000720202103  현대건설  2021  3분기보고서  116.164730  13.875535  49.512785  0.010714
# 000720202104  현대건설  2021   사업보고서  121.309220  13.114816  52.215475  0.049432
# 000720202201  현대건설  2022  1분기보고서  118.983368  11.395915  52.746734  0.022987
# 000720202202  현대건설  2022   반기보고서  116.169485  11.097058  52.607795  0.023929
# 000720202203  현대건설  2022  3분기보고서  107.651175  10.817079  49.830207  0.028514
# 000720202204  현대건설  2022   사업보고서  114.856221  11.073045  52.085849  0.055898
#
#               매출액영업이익률  매출액경상이익률  이자보상배율(배)   매출액 증가율   총자산 증가율  영업이익 증가율  \
# 아이디
# 000720202001  0.024908  0.061819   0.970072  0.012770  0.041406 -0.404290
# 000720202002  0.034553  0.016069   3.285666 -0.060504  0.029015 -0.136562
# 000720202003  0.031832  0.025666   3.253467 -0.056370  0.038288 -0.300516
# 000720202004  0.025361  0.015450   1.668335 -0.069353  0.053286 -0.362153
# 000720202101  0.035075  0.073345   2.807923  0.005352 -0.006257  0.415738
# 000720202102  0.007901  0.009299   0.830897 -0.037735  0.045396 -0.779976
# 000720202103  0.042061  0.034098   6.270873  0.089044  0.046058  0.438988
# 000720202104  0.029778  0.040604   2.848172  0.099377  0.116442  0.290892
# 000720202201  0.036744  0.072478   3.630332  0.046906  0.099925  0.096721
# 000720202202  0.034040  0.068238   9.714011  0.227570  0.094505  4.289073
# 000720202203  0.034075  0.078057   4.914398  0.278633  0.119460  0.035863
# 000720202204  0.028914  0.042050   2.436232  0.169052  0.033626  0.135105
#
#               자기자본 증가율  매출채권 회전기일(일)  재고자산 회전기일(일)  매입채무 회전기일(일)   총자산 회전율  \
# 아이디
# 000720202001  0.036545      0.036545     34.435166     45.488032  0.186240
# 000720202002  0.017435      0.017435     60.749690     82.499245  0.209724
# 000720202003 -0.002943     -0.002943    107.749502    117.747073  0.187233
# 000720202004 -0.007292     -0.007292     29.729364     41.444913  0.782861
# 000720202101  0.002019      0.002019     27.900982     41.621321  0.188416
# 000720202102  0.005238      0.005238     68.451385     87.965198  0.193046
# 000720202103  0.030581      0.030581     69.131907    118.966292  0.194927
# 000720202104  0.083094      0.083094     28.620912     46.892046  0.770894
# 000720202201  0.077571      0.077571     24.367257     43.564847  0.179334
# 000720202202  0.118820      0.118820     56.456036     92.541503  0.216516
# 000720202203  0.165357      0.165357     90.654646    129.932088  0.222643
# 000720202204  0.064670      0.064670     25.812190     50.322066  0.871897
#
#               부채상환계수(배)  총차입금상환능력비율
# 아이디
# 000720202001   1.543104    1.590973
# 000720202002   1.547317    1.240683
# 000720202003   1.535648    1.274364
# 000720202004   2.088678    2.333768
# 000720202101   0.844405    0.827305
# 000720202102   0.836682    0.820738
# 000720202103   2.782828    2.820469
# 000720202104   3.087335    3.772033
# 000720202201  -0.318378   -0.351800
# 000720202202  -1.352716   -1.056599
# 000720202203  -0.575954   -0.558282
# 000720202204  -0.319917   -0.645937

# %%
df.to_csv(f'/content/drive/MyDrive/ICR/재무비율/{corp_name_p}_재무비율.csv')

# %% [markdown]
# ### GS 건설

# %%
corp_name = ['DL이앤씨', 'HDC현대산업개발', '한전KPS', 'HJ중공업', '신세계건설', 'KCC건설', '대우건설', '서희건설', '특수건설', '계룡건설산업', '신원종합개발', '서한', '태영건설', '현대건설', 'GS건설', '동부건설', '코오롱글로벌', 'DL건설', '진흥기업', '남광토건', '한신공영', '금호건설', '삼부토건']
corp_code = ['375500', '294870', '051600', '097230', '034300', '021320', '047040', '035890', '026150', '013580', '017000', '011370', '009410', '000720', '006360', '005960', '003070', '001880', '002780', '001260', '004960', '002990', '001470']
report_code = ["11013", "11012", "11014", "11011"] # '11013'=1분기보고서, '11012'=반기보고서, '11014'=3분기보고서, '11011'=사업보고서

corp_name_p = corp_name[14]
corp_code_p = corp_code[14]

all = pd.DataFrame()

for year in range(2019, 2023):
  for code in report_code:
    corp = dart.finstate_all(corp_code_p, year, code, fs_div="OFS")
    # corp = corp.drop('account_id', axis=1)
    all = pd.concat([all, corp], ignore_index=True) # 2019년~2022년 별도 재무제표 전문(분기보고서+반기보고서+사업보고서)

all
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# 주석에 있는 단기차입금, 유동성장기부채, 회사채, 장기차입금은 수기로 가져와야 함
short_term_loan = ['174729000000', '155038000000', '154811000000', '78619000000', '83990000000', '37776000000', '97401000000', '173607000000', '352499000000', '501993000000', '614461000000', '577061000000']
liquidity_enhancing_long_term_debt = ['405590000000', '499600000000', '514837000000', '360539000000', '414826000000', '337300000000', '548829000000', '560492000000', '369613000000', '603432000000', '621708000000', '790194000000']
corporate_bond = ['525144000000', '602670000000', '516172000000', '691140000000', '703615000000', '846159000000', '558585000000', '558969000000', '564760000000', '482723000000', '514064000000', '262743000000'] # 사채 계산할 때 사할차, 전환권 조정도 차감해줘야 함(내가)
long_term_loan = ['984959000000', '894501000000', '992068000000', '1025602000000', '857972000000', '892849000000', '965014000000', '939857000000', '1119800000000', '1044569000000', '999746000000', '1070586000000']
year_i = ['2020','2020','2020','2020','2021','2021','2021','2021','2022','2022','2022','2022']
report_code_i = ["11013", "11012", "11014", "11011","11013", "11012", "11014", "11011","11013", "11012", "11014", "11011"]

debt = {
    'year':year_i,
    'report_code':report_code_i,
    '단기차입금': short_term_loan,
    '유동성장기부채': liquidity_enhancing_long_term_debt,
    '사채': corporate_bond,
    '장기차입금': long_term_loan}

debt_df = pd.DataFrame(debt)
debt_df
# Out:
#     year report_code         단기차입금       유동성장기부채            사채          장기차입금
# 0   2020       11013  174729000000  405590000000  525144000000   984959000000
# 1   2020       11012  155038000000  499600000000  602670000000   894501000000
# 2   2020       11014  154811000000  514837000000  516172000000   992068000000
# 3   2020       11011   78619000000  360539000000  691140000000  1025602000000
# 4   2021       11013   83990000000  414826000000  703615000000   857972000000
# 5   2021       11012   37776000000  337300000000  846159000000   892849000000
# 6   2021       11014   97401000000  548829000000  558585000000   965014000000
# 7   2021       11011  173607000000  560492000000  558969000000   939857000000
# 8   2022       11013  352499000000  369613000000  564760000000  1119800000000
# 9   2022       11012  501993000000  603432000000  482723000000  1044569000000
# 10  2022       11014  614461000000  621708000000  514064000000   999746000000
# 11  2022       11011  577061000000  790194000000  262743000000  1070586000000

# %%
Quarter = []
cor_year = []
ID_list = []
corp_name_list = []
year_list = []
report_code_list = []
Debt_Ratio = []
Debt_to_Asset_Ratio = []
Fixed_Asset_Turnover_Ratio = []
Return_on_Equity = []
Operating_Profit_Margin = []
Gross_Profit_Margin = []
Interest_Coverage_Ratio =[]
Sales_Growth_Rate = []
Total_Asset_Growth_Rate = []
Operating_Profit_Growth_Rate = []
Equity_Growth_Rate= []
Accounts_Receivable_Turnover = []
Inventory_Turnover = []
Accounts_Payable_Turnover = []
Total_Asset_Turnover_Ratio = []
Debt_Service_Coverage_Ratio = []
Debt_to_Equity_Ratio = []


for year in range(2020, 2023):
  str_year = str(year)
  report_code_list.extend(['1분기보고서' if code == '11013' else '반기보고서' if code == '11012' else '3분기보고서' if code == '11014' else '사업보고서' for code in report_code])
  Quarter.extend(['01' if code == '11013' else '02' if code == '11012' else '03' if code == '11014' else '04' for code in report_code])
  for code in report_code:
    BS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '자산총계' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자산총계
    BS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 부채총계
    BS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자본총계
    BS4 = [(row['단기차입금']) for index, row in debt_df.iterrows() if row['year'] == str(year) and row['report_code'] == str(code)]
    BS5 = [(row['유동성장기부채']) for index, row in debt_df.iterrows() if row['year'] == str(year) and row['report_code'] == str(code)]
    BS6 = [(row['사채']) for index, row in debt_df.iterrows() if row['year'] == str(year) and row['report_code'] == str(code)]
    BS7 = [(row['장기차입금']) for index, row in debt_df.iterrows() if row['year'] == str(year) and row['report_code'] == str(code)]
    # BS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '단기차입금' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 단기차입금
    # BS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and ('유동성장기부채' in row['account_nm'] or '유동성장기채무' in row['account_nm']) and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 유동성장기부채
    # BS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '사채' in row['account_nm'] and row['account_id'] == 'dart_BondsIssued' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 사채
    # BS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '차입금' in row['account_nm'] and '단기차입금' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 장기차입금
    BS8 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동자산' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동자산
    BS9 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동부채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동부채
    BS10 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자산총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자산총계
    BS11 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 부채총계
    BS12 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자본총계
    BS13 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매출채권' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매출채권
    BS14 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매입채무' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매입채무
    BS15 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '재고자산' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 재고자산

    IS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '포괄손익계산서' and '기순' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 당기순이익
    IS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업이익
    IS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '매출액' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 수익(매출액)
    IS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '법인세' in row['account_nm'] and '차감전' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 법인세비용차감전순이익(손실)
    IS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and (row['account_nm'] == '금융비용' or row['account_nm'] == '금융원가') and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 금융비용
    IS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '매출액' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 수익(매출액) # 분기 보고서만 해당
    IS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '영업이익' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 영업이익 # 분기 보고서만 해당

    CF1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '현금흐름표' and row['account_nm'] == '영업활동으로 인한 현금흐름' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업활동으로 인한 현금흐름

    # if BS6 == BS7: # '사채 및 장기차입금'으로 계정과목 하나만 쓰는 회사는 합침(어차피 사채는 차입금 의존도에서만 사용해서 하나 0으로 만들어도 상관없음)
    #   BS6 = ['0']
    # if BS4 == BS5:
    #   BS4 = ['0'] # '단기차입금 및 유동성장기부채' 로 병합해서 쓰는 회사는 ㅎ나로 합침(어차피 둘이 항상 붙어서 계산해서 상관없음)
    # if BS4 == [''] or BS4 == []:
    #   BS4 = ['0']
    # if BS5 == [''] or BS5 == []:
    #   BS5 = ['0']
    # if BS6 == []:
    #   BS6 = ['0']
    # if BS7 == []:
    #   BS7 = ['0']

    print("자산총계:", BS1, "부채총계:", BS2, "자본총계:", BS3, "단기차입금:", BS4, "유동성장기부채:", BS5, "사채:", BS6, "장기차입금:", BS7, "비유동자산:", BS8, "비유동부채:", BS9, "전기말 자산총계:", BS10, "전기말 부채총계:", BS11,
          "전기말 자본총계:", BS12, "매출채권:", BS13, "매입채무:", BS14, "재고자산:", BS15, "당기순이익:", IS1, "영업이익:", IS2, "수익(매출액):", IS3, "법인세비용차감전순이익(손실):", IS4,
          "금융비용:", IS5, "전기 수익(매출액):", IS6, "전기 영업이익:", IS7, "영업활동으로 인한 현금흐름:", CF1)

    if year != 2020:
      if code == "11013":
        accounting_period = 90
      elif code == "11012":
        accounting_period = 181
      elif code == "11014":
        accounting_period = 273
      elif code == "11011":
        accounting_period = 365
    else: # 2020년은 윤년
      if code == "11013":
        accounting_period = 91
      elif code == "11012":
        accounting_period = 182
      elif code == "11014":
        accounting_period = 274
      elif code == "11011":
        accounting_period = 366


    cor_year.extend([f"{corp_code_p}{str_year}"])
    corp_name_list.append(str(corp_name_p))
    year_list.append(str_year)
    Debt_Ratio.extend([int(BS2)/int(BS3)*100 for BS2, BS3 in zip(BS2, BS3)])
    Debt_to_Asset_Ratio.extend([((int(BS4) + int(BS5) + int(BS6) + int(BS7)) / int(BS1) * 100) for BS4, BS5, BS6, BS7, BS1 in zip(BS4, BS5, BS6, BS7, BS1)])
    Fixed_Asset_Turnover_Ratio.extend([int(BS8)/(int(BS9)+int(BS3))*100 for BS8, BS9, BS3 in zip(BS8, BS9, BS3)]),
    Return_on_Equity.extend([int(IS1)/((int(BS12)+int(BS3))/2) for IS1, BS12, BS3 in zip(IS1, BS12, BS3)])
    Operating_Profit_Margin.extend([int(IS2)/int(IS3) for IS2, IS3 in zip(IS2, IS3)])
    Gross_Profit_Margin.extend([int(IS4)/int(IS3) for IS4, IS3 in zip(IS4, IS3)])
    Interest_Coverage_Ratio.extend([int(IS2)/int(IS5) for IS2, IS5 in zip(IS2, IS5)])
    Sales_Growth_Rate.extend([(int(IS3)-int(IS6))/int(IS6) for IS3, IS6 in zip(IS3, IS6)])
    Total_Asset_Growth_Rate.extend([(int(BS1)-int(BS10))/int(BS10) for BS1, BS10 in zip(BS1, BS10)])
    Operating_Profit_Growth_Rate.extend([(int(IS2)-int(IS7))/int(IS7) for IS2, IS7 in zip(IS2, IS7)])
    Equity_Growth_Rate.extend([(int(BS3)-int(BS12))/int(BS12) for BS3, BS12 in zip(BS3, BS12)])
    Accounts_Receivable_Turnover.extend([int(BS13)/int(IS3)*accounting_period for BS13, IS3 in zip(BS13, IS3)])
    Inventory_Turnover.extend([int(BS15)/int(IS3)*accounting_period for BS15, IS3 in zip(BS15, IS3)])
    Accounts_Payable_Turnover.extend([int(BS14)/int(IS3)*accounting_period for BS14, IS3 in zip(BS14, IS3)])
    Total_Asset_Turnover_Ratio.extend([int(IS3)/int(BS1) for IS3, BS1 in zip(IS3, BS1)])
    Debt_Service_Coverage_Ratio.extend([(int(CF1)+int(IS5))/(int(BS4)+int(BS5)+int(IS5)) for CF1, IS5, BS4, BS5 in zip(CF1, IS5, BS4, BS5)])
    Debt_to_Equity_Ratio.extend([int(CF1)/(int(BS4)+int(BS7)+int(BS5)) for CF1, BS4, BS7, BS5 in zip(CF1, BS4, BS7, BS5)])

ID_list.extend([x+y for x,y in zip(cor_year,Quarter)])

financial_ratio = {
      '아이디':ID_list,
      '기업명':corp_name_list,
      '연도':year_list,
      '보고서 코드':report_code_list,
      '부채비율' : Debt_Ratio,
      '차입금의존도' : Debt_to_Asset_Ratio,
      '고정장기적합률':Fixed_Asset_Turnover_Ratio,
      '자기자본순이익률':Return_on_Equity,
      '매출액영업이익률':Operating_Profit_Margin,
      '매출액경상이익률':Gross_Profit_Margin,
      '이자보상배율(배)':Interest_Coverage_Ratio,
      '매출액 증가율':Sales_Growth_Rate,
      '총자산 증가율':Total_Asset_Growth_Rate,
      '영업이익 증가율':Operating_Profit_Growth_Rate,
      '자기자본 증가율':Equity_Growth_Rate,
      '매출채권 회전기일(일)':Equity_Growth_Rate,
      '재고자산 회전기일(일)':Accounts_Receivable_Turnover,
      '매입채무 회전기일(일)':Accounts_Payable_Turnover,
      '총자산 회전율':Total_Asset_Turnover_Ratio,
      '부채상환계수(배)':Debt_Service_Coverage_Ratio,
      '총차입금상환능력비율':Debt_to_Equity_Ratio
                    }

df = pd.DataFrame(financial_ratio)
df.set_index('아이디', inplace=True)

df
# Out:
# 자산총계: ['12067437505413'] 부채총계: ['7841371569173'] 자본총계: ['4226065936240'] 단기차입금: ['174729000000'] 유동성장기부채: ['405590000000'] 사채: ['525144000000'] 장기차입금: ['984959000000'] 비유동자산: ['5789361036221'] 비유동부채: ['2715468485497'] 전기말 자산총계: ['11895911857885'] 전기말 부채총계: ['8073304899781'] 전기말 자본총계: ['3822606958104'] 매출채권: ['3202223013069'] 매입채무: ['1432120852441'] 재고자산: ['497803393056'] 당기순이익: ['136058944207'] 영업이익: ['173172894965'] 수익(매출액): ['2145582508245'] 법인세비용차감전순이익(손실): ['182508859645'] 금융비용: ['72301300267'] 전기 수익(매출액): ['2345652689267'] 전기 영업이익: ['171077705943'] 영업활동으로 인한 현금흐름: ['182442668721']
# 자산총계: ['11676108859847'] 부채총계: ['7381676622956'] 자본총계: ['4294432236891'] 단기차입금: ['155038000000'] 유동성장기부채: ['499600000000'] 사채: ['602670000000'] 장기차입금: ['894501000000'] 비유동자산: ['5647652686710'] 비유동부채: ['2671071486356'] 전기말 자산총계: ['11911969144230'] 전기말 부채총계: ['7902182312347'] 전기말 자본총계: ['4009786831883'] 매출채권: ['2195192897329'] 매입채무: ['1308782401756'] 재고자산: ['421857116312'] 당기순이익: ['98467354214'] 영업이익: ['149595505278'] 수익(매출액): ['2222841985569'] 법인세비용차감전순이익(손실): ['132549597849'] 금융비용: ['24193758647'] 전기 수익(매출액): ['2356402518596'] 전기 영업이익: ['192873201097'] 영업활동으로 인한 현금흐름: ['213798615942']
# 자산총계: ['11829196868666'] 부채총계: ['7414552120912'] 자본총계: ['4414644747754'] 단기차입금: ['154811000000'] 유동성장기부채: ['514837000000'] 사채: ['516172000000'] 장기차입금: ['992068000000'] 비유동자산: ['5798640234780'] 비유동부채: ['2689454592912'] 전기말 자산총계: ['12083708505198'] 전기말 부채총계: ['7912526301116'] 전기말 자본총계: ['4171182204082'] 매출채권: ['1987283706490'] 매입채무: ['1155035007712'] 재고자산: ['387115262988'] 당기순이익: ['119888182939'] 영업이익: ['175113165373'] 수익(매출액): ['2042135792885'] 법인세비용차감전순이익(손실): ['164440771325'] 금융비용: ['16177269635'] 전기 수익(매출액): ['2215128531715'] 전기 영업이익: ['165373619021'] 영업활동으로 인한 현금흐름: ['542098727158']
# 자산총계: ['11871047259267'] 부채총계: ['7450963186388'] 자본총계: ['4420084072879'] 단기차입금: ['78619000000'] 유동성장기부채: ['360539000000'] 사채: ['691140000000'] 장기차입금: ['1025602000000'] 비유동자산: ['5934858565562'] 비유동부채: ['2924332897078'] 전기말 자산총계: ['11474687207864'] 전기말 부채총계: ['7313280164074'] 전기말 자본총계: ['4161407043790'] 매출채권: ['1896612039008'] 매입채무: ['1141152974190'] 재고자산: ['907928210671'] 당기순이익: ['326944366118'] 영업이익: ['683181225296'] 수익(매출액): ['8890992062853'] 법인세비용차감전순이익(손실): ['476497878454'] 금융비용: ['277493979642'] 전기 수익(매출액): ['9485125995369'] 전기 영업이익: ['680931074214'] 영업활동으로 인한 현금흐름: ['647870870417']
# 자산총계: ['12515436087560'] 부채총계: ['7899671972676'] 자본총계: ['4615764114884'] 단기차입금: ['83990000000'] 유동성장기부채: ['414826000000'] 사채: ['703615000000'] 장기차입금: ['857972000000'] 비유동자산: ['6062590100567'] 비유동부채: ['2765406004452'] 전기말 자산총계: ['12067437505413'] 전기말 부채총계: ['7841371569173'] 전기말 자본총계: ['4226065936240'] 매출채권: ['1948673838776'] 매입채무: ['1105732073429'] 재고자산: ['860810042721'] 당기순이익: ['141053381978'] 영업이익: ['168700395760'] 수익(매출액): ['1753747644517'] 법인세비용차감전순이익(손실): ['193582649513'] 금융비용: ['58363290618'] 전기 수익(매출액): ['2145582508245'] 전기 영업이익: ['173172894965'] 영업활동으로 인한 현금흐름: ['444575769603']
# 자산총계: ['12522503114161'] 부채총계: ['7847158306267'] 자본총계: ['4675344807894'] 단기차입금: ['37776000000'] 유동성장기부채: ['337300000000'] 사채: ['846159000000'] 장기차입금: ['892849000000'] 비유동자산: ['6152260914694'] 비유동부채: ['2861538980509'] 전기말 자산총계: ['11676108859847'] 전기말 부채총계: ['7381676622956'] 전기말 자본총계: ['4294432236891'] 매출채권: ['1909143044190'] 매입채무: ['1173486316566'] 재고자산: ['787644131516'] 당기순이익: ['58105180231'] 영업이익: ['96201631196'] 수익(매출액): ['1953805767203'] 법인세비용차감전순이익(손실): ['87149915229'] 금융비용: ['19386020934'] 전기 수익(매출액): ['2222841985569'] 전기 영업이익: ['149595505278'] 영업활동으로 인한 현금흐름: ['455071652384']
# 자산총계: ['12480962256596'] 부채총계: ['7677102806202'] 자본총계: ['4803859450394'] 단기차입금: ['97401000000'] 유동성장기부채: ['548829000000'] 사채: ['558585000000'] 장기차입금: ['965014000000'] 비유동자산: ['6389428556563'] 비유동부채: ['2642753614625'] 전기말 자산총계: ['11829196868666'] 전기말 부채총계: ['7414552120912'] 전기말 자본총계: ['4414644747754'] 매출채권: ['1727667500032'] 매입채무: ['1088161732997'] 재고자산: ['790220838924'] 당기순이익: ['116011284352'] 영업이익: ['136432336117'] 수익(매출액): ['1890773292521'] 법인세비용차감전순이익(손실): ['157480518747'] 금융비용: ['67845781506'] 전기 수익(매출액): ['2042135792885'] 전기 영업이익: ['175113165373'] 영업활동으로 인한 현금흐름: ['681991744560']
# 자산총계: ['12829912597014'] 부채총계: ['7994357649103'] 자본총계: ['4835554947911'] 단기차입금: ['173607000000'] 유동성장기부채: ['560492000000'] 사채: ['558969000000'] 장기차입금: ['939857000000'] 비유동자산: ['6744746270191'] 비유동부채: ['2399319807049'] 전기말 자산총계: ['11871047259267'] 전기말 부채총계: ['7450963186388'] 전기말 자본총계: ['4420084072879'] 매출채권: ['2075478718676'] 매입채무: ['1396703625369'] 재고자산: ['794632293247'] 당기순이익: ['317165450225'] 영업이익: ['514791410851'] 수익(매출액): ['7795915289675'] 법인세비용차감전순이익(손실): ['462589575299'] 금융비용: ['185934848254'] 전기 수익(매출액): ['8890992062853'] 전기 영업이익: ['683181225296'] 영업활동으로 인한 현금흐름: ['841666207731']
# 자산총계: ['12830347020536'] 부채총계: ['7999850480881'] 자본총계: ['4830496539655'] 단기차입금: ['352499000000'] 유동성장기부채: ['369613000000'] 사채: ['564760000000'] 장기차입금: ['1119800000000'] 비유동자산: ['6898961192307'] 비유동부채: ['2575223126122'] 전기말 자산총계: ['12515436087560'] 전기말 부채총계: ['7899671972676'] 전기말 자본총계: ['4615764114884'] 매출채권: ['1631313086972'] 매입채무: ['1341130283326'] 재고자산: ['717616266244'] 당기순이익: ['118912143351'] 영업이익: ['127002432522'] 수익(매출액): ['1924834002229'] 법인세비용차감전순이익(손실): ['153875214824'] 금융비용: ['45053475523'] 전기 수익(매출액): ['1753747644517'] 전기 영업이익: ['168700395760'] 영업활동으로 인한 현금흐름: ['363947993250']
# 자산총계: ['12719359411184'] 부채총계: ['7760714134170'] 자본총계: ['4958645277014'] 단기차입금: ['501993000000'] 유동성장기부채: ['603432000000'] 사채: ['482723000000'] 장기차입금: ['1044569000000'] 비유동자산: ['6869813224016'] 비유동부채: ['2412800820122'] 전기말 자산총계: ['12522503114161'] 전기말 부채총계: ['7847158306267'] 전기말 자본총계: ['4675344807894'] 매출채권: ['1822544116071'] 매입채무: ['1279914723986'] 재고자산: ['701147236043'] 당기순이익: ['101958589578'] 영업이익: ['68084315715'] 수익(매출액): ['2040783773781'] 법인세비용차감전순이익(손실): ['131410492869'] 금융비용: ['91942933774'] 전기 수익(매출액): ['1953805767203'] 전기 영업이익: ['96201631196'] 영업활동으로 인한 현금흐름: ['198222935526']
# 자산총계: ['13141112523487'] 부채총계: ['8082631883376'] 자본총계: ['5058480640111'] 단기차입금: ['614461000000'] 유동성장기부채: ['621708000000'] 사채: ['514064000000'] 장기차입금: ['999746000000'] 비유동자산: ['6964037413542'] 비유동부채: ['2388653913071'] 전기말 자산총계: ['12480962256596'] 전기말 부채총계: ['7677102806202'] 전기말 자본총계: ['4803859450394'] 매출채권: ['2309160927243'] 매입채무: ['1288843195932'] 재고자산: ['713248613991'] 당기순이익: ['80098836483'] 영업이익: ['66915298744'] 수익(매출액): ['2001462839691'] 법인세비용차감전순이익(손실): ['109429336442'] 금융비용: ['177856554268'] 전기 수익(매출액): ['1890773292521'] 전기 영업이익: ['136432336117'] 영업활동으로 인한 현금흐름: ['42148036753']
# 자산총계: ['12739404443091'] 부채총계: ['7806315499276'] 자본총계: ['4933088943815'] 단기차입금: ['577061000000'] 유동성장기부채: ['790194000000'] 사채: ['262743000000'] 장기차입금: ['1070586000000'] 비유동자산: ['6683744310312'] 비유동부채: ['2181670495183'] 전기말 자산총계: ['12829912597014'] 전기말 부채총계: ['7994357649103'] 전기말 자본총계: ['4835554947911'] 매출채권: ['2402572212052'] 매입채무: ['1112706796878'] 재고자산: ['655237080804'] 당기순이익: ['240672685916'] 영업이익: ['281011392569'] 수익(매출액): ['8613702892101'] 법인세비용차감전순이익(손실): ['360875360692'] 금융비용: ['234828609952'] 전기 수익(매출액): ['7795915289675'] 전기 영업이익: ['514791410851'] 영업활동으로 인한 현금흐름: ['-84754979247']
#                기업명    연도  보고서 코드        부채비율     차입금의존도    고정장기적합률  자기자본순이익률  \
# 아이디
# 006360202001  GS건설  2020  1분기보고서  185.547781  17.322833  83.401748  0.033809
# 006360202002  GS건설  2020   반기보고서  171.889466  18.429162  81.080320  0.023715
# 006360202003  GS건설  2020  3분기보고서  167.953540  18.411123  81.623862  0.027927
# 006360202004  GS건설  2020   사업보고서  168.570621  18.160992  80.807756  0.076198
# 006360202101  GS건설  2021  1분기보고서  171.145487  16.462894  82.135894  0.031906
# 006360202102  GS건설  2021   반기보고서  167.841274  16.882280  81.628709  0.012956
# 006360202103  GS건설  2021  3분기보고서  159.811145  17.385110  85.803150  0.025169
# 006360202104  GS건설  2021   사업보고서  165.324513  17.404055  93.225474  0.068535
# 006360202201  GS건설  2022  1분기보고서  165.611349  18.757653  93.157202  0.025177
# 006360202202  GS건설  2022   반기보고서  156.508758  20.698503  93.194919  0.021166
# 006360202203  GS건설  2022  3분기보고서  159.783786  20.926531  93.512980  0.016243
# 006360202204  GS건설  2022   사업보고서  158.243964  21.198668  93.941958  0.049275
#
#               매출액영업이익률  매출액경상이익률  이자보상배율(배)   매출액 증가율   총자산 증가율  영업이익 증가율  \
# 아이디
# 006360202001  0.080711  0.085063   2.395156 -0.085294  0.014419  0.012247
# 006360202002  0.067299  0.059631   6.183227 -0.056680 -0.019800 -0.224384
# 006360202003  0.085750  0.080524  10.824643 -0.078096 -0.021062  0.058894
# 006360202004  0.076840  0.053593   2.461968 -0.062638  0.034542  0.003305
# 006360202101  0.096194  0.110382   2.890522 -0.182624  0.037125 -0.025827
# 006360202102  0.049238  0.044605   4.962423 -0.121033  0.072489 -0.356922
# 006360202103  0.072157  0.083289   2.010918 -0.074120  0.055098 -0.220890
# 006360202104  0.066033  0.059337   2.768666 -0.123167  0.080773 -0.246479
# 006360202201  0.065981  0.079942   2.818926  0.097555  0.025162 -0.247172
# 006360202202  0.033362  0.064392   0.740506  0.044517  0.015720 -0.292275
# 006360202203  0.033433  0.054675   0.376232  0.058542  0.052893 -0.509535
# 006360202204  0.032624  0.041895   1.196666  0.104899 -0.007054 -0.454126
#
#               자기자본 증가율  매출채권 회전기일(일)  재고자산 회전기일(일)  매입채무 회전기일(일)   총자산 회전율  \
# 아이디
# 006360202001  0.105546      0.105546    135.815003     60.740147  0.177799
# 006360202002  0.070988      0.070988    179.736171    107.159393  0.190375
# 006360202003  0.058368      0.058368    266.640317    154.974803  0.172635
# 006360202004  0.062161      0.062161     78.074528     46.975859  0.748964
# 006360202101  0.092213      0.092213    100.003353     56.744702  0.140127
# 006360202102  0.088699      0.088699    176.862458    108.711432  0.156024
# 006360202103  0.088164      0.088164    249.449910    157.114634  0.151493
# 006360202104  0.093996      0.093996     97.172648     65.392812  0.607636
# 006360202201  0.046522      0.046522     76.275761     62.707603  0.150022
# 006360202202  0.060595      0.060595    161.644016    113.517448  0.160447
# 006360202203  0.053003      0.053003    314.970091    175.798514  0.152305
# 006360202204  0.020170      0.020170    101.807419     47.150219  0.676146
#
#               부채상환계수(배)  총차입금상환능력비율
# 아이디
# 006360202001   0.390340    0.116556
# 006360202002   0.350591    0.138011
# 006360202003   0.814021    0.326228
# 006360202004   1.291233    0.442305
# 006360202101   0.902652    0.327668
# 006360202102   1.202797    0.358911
# 006360202103   1.050081    0.423270
# 006360202104   1.116917    0.502801
# 006360202201   0.533133    0.197592
# 006360202202   0.242336    0.092197
# 006360202203   0.155587    0.018850
# 006360202204   0.093674   -0.034766

# %%
df.to_csv(f'/content/drive/MyDrive/ICR/재무비율/{corp_name_p}_재무비율.csv')

# %% [markdown]
# ### 동부건설

# %%
corp_name = ['DL이앤씨', 'HDC현대산업개발', '한전KPS', 'HJ중공업', '신세계건설', 'KCC건설', '대우건설', '서희건설', '특수건설', '계룡건설산업', '신원종합개발', '서한', '태영건설', '현대건설', 'GS건설', '동부건설', '코오롱글로벌', 'DL건설', '진흥기업', '남광토건', '한신공영', '금호건설', '삼부토건']
corp_code = ['375500', '294870', '051600', '097230', '034300', '021320', '047040', '035890', '026150', '013580', '017000', '011370', '009410', '000720', '006360', '005960', '003070', '001880', '002780', '001260', '004960', '002990', '001470']
report_code = ["11013", "11012", "11014", "11011"] # '11013'=1분기보고서, '11012'=반기보고서, '11014'=3분기보고서, '11011'=사업보고서

corp_name_p = corp_name[15]
corp_code_p = corp_code[15]

all = pd.DataFrame()

for year in range(2019, 2023):
  for code in report_code:
    corp = dart.finstate_all(corp_code_p, year, code, fs_div="OFS")
    # corp = corp.drop('account_id', axis=1)
    all = pd.concat([all, corp], ignore_index=True) # 2019년~2022년 별도 재무제표 전문(분기보고서+반기보고서+사업보고서)

all
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# 주석에 있는 유동성장기부채 직접 수기로 가져옴
liquidity_enhancing_long_term_debt = ['0', '0', '0', '0', '0', '0', '0', '0', '25000000000', '75000000000', '75000000000', '0']
year_i = ['2020','2020','2020','2020','2021','2021','2021','2021','2022','2022','2022','2022']
report_code_i = ["11013", "11012", "11014", "11011","11013", "11012", "11014", "11011","11013", "11012", "11014", "11011"]

debt = {
    'year':year_i,
    'report_code':report_code_i,
    '유동성장기부채': liquidity_enhancing_long_term_debt
    }

debt_df = pd.DataFrame(debt)
debt_df
# Out:
#     year report_code      유동성장기부채
# 0   2020       11013            0
# 1   2020       11012            0
# 2   2020       11014            0
# 3   2020       11011            0
# 4   2021       11013            0
# 5   2021       11012            0
# 6   2021       11014            0
# 7   2021       11011            0
# 8   2022       11013  25000000000
# 9   2022       11012  75000000000
# 10  2022       11014  75000000000
# 11  2022       11011            0

# %%
import math

Quarter = []
cor_year = []
ID_list = []
corp_name_list = []
year_list = []
report_code_list = []
Debt_Ratio = []
Debt_to_Asset_Ratio = []
Fixed_Asset_Turnover_Ratio = []
Return_on_Equity = []
Operating_Profit_Margin = []
Gross_Profit_Margin = []
Interest_Coverage_Ratio =[]
Sales_Growth_Rate = []
Total_Asset_Growth_Rate = []
Operating_Profit_Growth_Rate = []
Equity_Growth_Rate= []
Accounts_Receivable_Turnover = []
Inventory_Turnover = []
Accounts_Payable_Turnover = []
Total_Asset_Turnover_Ratio = []
Debt_Service_Coverage_Ratio = []
Debt_to_Equity_Ratio = []


for year in range(2020, 2023):
  str_year = str(year)
  report_code_list.extend(['1분기보고서' if code == '11013' else '반기보고서' if code == '11012' else '3분기보고서' if code == '11014' else '사업보고서' for code in report_code])
  Quarter.extend(['01' if code == '11013' else '02' if code == '11012' else '03' if code == '11014' else '04' for code in report_code])
  for code in report_code:
    BS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '자산총계' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자산총계
    BS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 부채총계
    BS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자본총계
    BS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '유동성 차입금' in row['account_nm'] and '비유동성' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 단기차입금
    BS5 = [(row['유동성장기부채']) for index, row in debt_df.iterrows() if row['year'] == str(year) and row['report_code'] == str(code)]
    # BS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and ('유동성장기부채' in row['account_nm'] or '유동성장기채무' in row['account_nm']) and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 유동성장기부채
    BS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '사채' in row['account_nm'] and row['account_id'] == 'dart_BondsIssued' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 사채
    BS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '비유동성 차입금' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 장기차입금
    BS8 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동자산' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동자산
    BS9 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동부채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동부채
    BS10 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자산총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자산총계
    BS11 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 부채총계
    BS12 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자본총계
    BS13 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '매출채권' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매출채권
    BS14 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매입채무' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매입채무
    BS15 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '재고자산' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 재고자산

    IS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '포괄손익계산서' and '기순' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 당기순이익
    IS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업이익
    IS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '수익(매출액)' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 수익(매출액)
    IS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '법인세' in row['account_nm'] and '차감전' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 법인세비용차감전순이익(손실)
    IS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and (row['account_nm'] == '금융비용' or row['account_nm'] == '금융원가') and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 금융비용
    IS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '수익(매출액)' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 수익(매출액) # 분기 보고서만 해당
    IS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '영업이익(손실)' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 영업이익 # 분기 보고서만 해당

    CF1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '현금흐름표' and row['account_nm'] == '영업활동현금흐름' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업활동으로 인한 현금흐름

    # if BS6 == BS7: # '사채 및 장기차입금'으로 계정과목 하나만 쓰는 회사는 합침(어차피 사채는 차입금 의존도에서만 사용해서 하나 0으로 만들어도 상관없음)
    #   BS6 = ['0']
    # if BS4 == BS5:
    #   BS4 = ['0'] # '단기차입금 및 유동성장기부채' 로 병합해서 쓰는 회사는 하나로 합침(어차피 둘이 항상 붙어서 계산해서 상관없음)
    if BS4 == [''] or BS4 == []:
      BS4 = ['0']
    # if BS5 == [''] or BS5 == []:
    #   BS5 = ['0']
    if BS6 == []: # 동부건설은 '비유동성 차입금 및 사채'로 장기차입금과 사채를 합쳐서 씀(어차피 사채는 차입금 의존도에서만 사용해서 하나 0으로 만들어도 상관없음)
      BS6 = ['0']
    if BS7 == []:
      BS7 = ['0']
    if BS15 == [''] or BS15 == []:
      BS15 = ['0']

    print("자산총계:", BS1, "부채총계:", BS2, "자본총계:", BS3, "단기차입금:", BS4, "유동성장기부채:", BS5, "사채:", BS6, "장기차입금:", BS7, "비유동자산:", BS8, "비유동부채:", BS9, "전기말 자산총계:", BS10, "전기말 부채총계:", BS11,
          "전기말 자본총계:", BS12, "매출채권:", BS13, "매입채무:", BS14, "재고자산:", BS15, "당기순이익:", IS1, "영업이익:", IS2, "수익(매출액):", IS3, "법인세비용차감전순이익(손실):", IS4,
          "금융비용:", IS5, "전기 수익(매출액):", IS6, "전기 영업이익:", IS7, "영업활동으로 인한 현금흐름:", CF1)

    if year != 2020:
      if code == "11013":
        accounting_period = 90
      elif code == "11012":
        accounting_period = 181
      elif code == "11014":
        accounting_period = 273
      elif code == "11011":
        accounting_period = 365
    else: # 2020년은 윤년
      if code == "11013":
        accounting_period = 91
      elif code == "11012":
        accounting_period = 182
      elif code == "11014":
        accounting_period = 274
      elif code == "11011":
        accounting_period = 366


    cor_year.extend([f"{corp_code_p}{str_year}"])
    corp_name_list.append(str(corp_name_p))
    year_list.append(str_year)
    Debt_Ratio.extend([int(BS2)/int(BS3)*100 for BS2, BS3 in zip(BS2, BS3)])
    Debt_to_Asset_Ratio.extend([((int(BS4) + int(BS5) + int(BS6) + int(BS7)) / int(BS1) * 100) for BS4, BS5, BS6, BS7, BS1 in zip(BS4, BS5, BS6, BS7, BS1)])
    Fixed_Asset_Turnover_Ratio.extend([int(BS8)/(int(BS9)+int(BS3))*100 for BS8, BS9, BS3 in zip(BS8, BS9, BS3)]),
    Return_on_Equity.extend([int(IS1)/((int(BS12)+int(BS3))/2) for IS1, BS12, BS3 in zip(IS1, BS12, BS3)])
    Operating_Profit_Margin.extend([int(IS2)/int(IS3) for IS2, IS3 in zip(IS2, IS3)])
    Gross_Profit_Margin.extend([int(IS4)/int(IS3) for IS4, IS3 in zip(IS4, IS3)])
    Interest_Coverage_Ratio.extend([int(IS2)/int(IS5) for IS2, IS5 in zip(IS2, IS5)])
    Sales_Growth_Rate.extend([(int(IS3)-int(IS6))/int(IS6) for IS3, IS6 in zip(IS3, IS6)])
    Total_Asset_Growth_Rate.extend([(int(BS1)-int(BS10))/int(BS10) for BS1, BS10 in zip(BS1, BS10)])
    Operating_Profit_Growth_Rate.extend([(int(IS2)-int(IS7))/int(IS7) for IS2, IS7 in zip(IS2, IS7)])
    Equity_Growth_Rate.extend([(int(BS3)-int(BS12))/int(BS12) for BS3, BS12 in zip(BS3, BS12)])
    Accounts_Receivable_Turnover.extend([int(BS13)/int(IS3)*accounting_period for BS13, IS3 in zip(BS13, IS3)])
    Inventory_Turnover.extend([int(BS15)/int(IS3)*accounting_period for BS15, IS3 in zip(BS15, IS3)])
    Accounts_Payable_Turnover.extend([int(BS14)/int(IS3)*accounting_period for BS14, IS3 in zip(BS14, IS3)])
    Total_Asset_Turnover_Ratio.extend([int(IS3)/int(BS1) for IS3, BS1 in zip(IS3, BS1)])
    Debt_Service_Coverage_Ratio.extend([(int(CF1)+int(IS5))/(int(BS4)+int(BS5)+int(IS5)) for CF1, IS5, BS4, BS5 in zip(CF1, IS5, BS4, BS5)])
    Debt_to_Equity_Ratio.extend([int(CF1)/(int(BS4)+int(BS7)+int(BS5)) if (int(BS4) + int(BS7) + int(BS5)) != 0 else float('inf') for CF1, BS4, BS7, BS5 in zip(CF1, BS4, BS7, BS5)])

ID_list.extend([x+y for x,y in zip(cor_year,Quarter)])

financial_ratio = {
      '아이디':ID_list,
      '기업명':corp_name_list,
      '연도':year_list,
      '보고서 코드':report_code_list,
      '부채비율' : Debt_Ratio,
      '차입금의존도' : Debt_to_Asset_Ratio,
      '고정장기적합률':Fixed_Asset_Turnover_Ratio,
      '자기자본순이익률':Return_on_Equity,
      '매출액영업이익률':Operating_Profit_Margin,
      '매출액경상이익률':Gross_Profit_Margin,
      '이자보상배율(배)':Interest_Coverage_Ratio,
      '매출액 증가율':Sales_Growth_Rate,
      '총자산 증가율':Total_Asset_Growth_Rate,
      '영업이익 증가율':Operating_Profit_Growth_Rate,
      '자기자본 증가율':Equity_Growth_Rate,
      '매출채권 회전기일(일)':Equity_Growth_Rate,
      '재고자산 회전기일(일)':Accounts_Receivable_Turnover,
      '매입채무 회전기일(일)':Accounts_Payable_Turnover,
      '총자산 회전율':Total_Asset_Turnover_Ratio,
      '부채상환계수(배)':Debt_Service_Coverage_Ratio,
      '총차입금상환능력비율':Debt_to_Equity_Ratio
                    }

df = pd.DataFrame(financial_ratio)
df.set_index('아이디', inplace=True)

df
# Out:
# 자산총계: ['780519732563'] 부채총계: ['355019057764'] 자본총계: ['425500674799'] 단기차입금: ['0'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['0'] 비유동자산: ['345192291894'] 비유동부채: ['77466594177'] 전기말 자산총계: ['704458627780'] 전기말 부채총계: ['342288910119'] 전기말 자본총계: ['362169717661'] 매출채권: ['30674373808'] 매입채무: ['104515787362'] 재고자산: ['2505858369'] 당기순이익: ['19158155998'] 영업이익: ['18040021757'] 수익(매출액): ['285424841078'] 법인세비용차감전순이익(손실): ['22905946490'] 금융비용: ['123909332'] 전기 수익(매출액): ['194893555718'] 전기 영업이익: ['3061443012'] 영업활동으로 인한 현금흐름: ['-24384994677']
# 자산총계: ['776916268549'] 부채총계: ['355735300198'] 자본총계: ['421180968351'] 단기차입금: ['0'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['0'] 비유동자산: ['361953579114'] 비유동부채: ['57247280561'] 전기말 자산총계: ['799577731647'] 전기말 부채총계: ['426018756919'] 전기말 자본총계: ['373558974728'] 매출채권: ['35788671394'] 매입채무: ['103323554862'] 재고자산: ['2574505649'] 당기순이익: ['-4805167156'] 영업이익: ['15606737827'] 수익(매출액): ['269184264132'] 법인세비용차감전순이익(손실): ['-7805176434'] 금융비용: ['182526876'] 전기 수익(매출액): ['256417019760'] 전기 영업이익: ['14036719897'] 영업활동으로 인한 현금흐름: ['40844436673']
# 자산총계: ['735048486743'] 부채총계: ['277894408189'] 자본총계: ['457154078554'] 단기차입금: ['0'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['0'] 비유동자산: ['384678971633'] 비유동부채: ['54173998208'] 전기말 자산총계: ['748572843417'] 전기말 부채총계: ['361113481982'] 전기말 자본총계: ['387459361435'] 매출채권: ['19377406043'] 매입채무: ['84882547186'] 재고자산: ['3297000'] 당기순이익: ['26256142453'] 영업이익: ['5223510500'] 수익(매출액): ['249565255505'] 법인세비용차감전순이익(손실): ['28934518689'] 금융비용: ['104121783'] 전기 수익(매출액): ['286645411780'] 전기 영업이익: ['14416173715'] 영업활동으로 인한 현금흐름: ['9525724563']
# 자산총계: ['777463209806'] 부채총계: ['306292164341'] 자본총계: ['471171045465'] 단기차입금: ['0'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['0'] 비유동자산: ['448519123043'] 비유동부채: ['90833460453'] 전기말 자산총계: ['796251190832'] 전기말 부채총계: ['369393519308'] 전기말 자본총계: ['426857671524'] 매출채권: ['21401062440'] 매입채무: ['106794950447'] 재고자산: ['425880'] 당기순이익: ['50381128571'] 영업이익: ['56857551796'] 수익(매출액): ['1090216496472'] 법인세비용차감전순이익(손실): ['56725397064'] 금융비용: ['595998692'] 전기 수익(매출액): ['1097927762848'] 전기 영업이익: ['56512439415'] 영업활동으로 인한 현금흐름: ['-7427104139']
# 자산총계: ['811360002937'] 부채총계: ['343130954285'] 자본총계: ['468229048652'] 단기차입금: ['0'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['0'] 비유동자산: ['463205819111'] 비유동부채: ['111682379559'] 전기말 자산총계: ['780519732563'] 전기말 부채총계: ['355019057764'] 전기말 자본총계: ['425500674799'] 매출채권: ['12779417202'] 매입채무: ['87989927964'] 재고자산: ['0'] 당기순이익: ['16230936757'] 영업이익: ['4927224591'] 수익(매출액): ['208848287172'] 법인세비용차감전순이익(손실): ['15111286030'] 금융비용: ['1084000548'] 전기 수익(매출액): ['285424841078'] 전기 영업이익: ['18040021757'] 영업활동으로 인한 현금흐름: ['4339772757']
# 자산총계: ['906996052778'] 부채총계: ['406767369307'] 자본총계: ['500228683471'] 단기차입금: ['34000000000'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['79725937254'] 비유동자산: ['458862953103'] 비유동부채: ['156566254020'] 전기말 자산총계: ['776916268549'] 전기말 부채총계: ['355735300198'] 전기말 자본총계: ['421180968351'] 매출채권: ['33150801837'] 매입채무: ['99632442845'] 재고자산: ['128078000'] 당기순이익: ['31518834116'] 영업이익: ['12325442203'] 수익(매출액): ['253072055002'] 법인세비용차감전순이익(손실): ['33135010298'] 금융비용: ['785129285'] 전기 수익(매출액): ['269184264132'] 전기 영업이익: ['15606737827'] 영업활동으로 인한 현금흐름: ['-17494056765']
# 자산총계: ['933678764764'] 부채총계: ['385180612938'] 자본총계: ['548498151826'] 단기차입금: ['34000000000'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['79762289996'] 비유동자산: ['516931334524'] 비유동부채: ['160749002140'] 전기말 자산총계: ['735048486743'] 전기말 부채총계: ['277894408189'] 전기말 자본총계: ['457154078554'] 매출채권: ['36544978070'] 매입채무: ['76442544642'] 재고자산: ['118237325'] 당기순이익: ['47252263501'] 영업이익: ['21131867453'] 수익(매출액): ['235306515355'] 법인세비용차감전순이익(손실): ['63665243638'] 금융비용: ['1154104207'] 전기 수익(매출액): ['249565255505'] 전기 영업이익: ['5223510500'] 영업활동으로 인한 현금흐름: ['-39245505154']
# 자산총계: ['1010132311381'] 부채총계: ['467125028094'] 자본총계: ['543007283287'] 단기차입금: ['34000000000'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['79799026048'] 비유동자산: ['494216350663'] 비유동부채: ['156593034508'] 전기말 자산총계: ['777463209806'] 전기말 부채총계: ['306292164341'] 전기말 자본총계: ['471171045465'] 매출채권: ['37950832434'] 매입채무: ['131755080773'] 재고자산: ['0'] 당기순이익: ['88829940327'] 영업이익: ['57703357127'] 수익(매출액): ['1015792261054'] 법인세비용차감전순이익(손실): ['105035006078'] 금융비용: ['4667792537'] 전기 수익(매출액): ['1090216496472'] 전기 영업이익: ['56857551796'] 영업활동으로 인한 현금흐름: ['937818723']
# 자산총계: ['1062027774328'] 부채총계: ['509335855342'] 자본총계: ['552691918986'] 단기차입금: ['58962932788'] 유동성장기부채: ['25000000000'] 사채: ['0'] 장기차입금: ['54872828990'] 비유동자산: ['489162142805'] 비유동부채: ['127791553990'] 전기말 자산총계: ['811360002937'] 전기말 부채총계: ['343130954285'] 전기말 자본총계: ['468229048652'] 매출채권: ['36214094536'] 매입채무: ['137587400340'] 재고자산: ['0'] 당기순이익: ['32418003258'] 영업이익: ['6533521756'] 수익(매출액): ['231705440740'] 법인세비용차감전순이익(손실): ['39173775234'] 금융비용: ['1645170233'] 전기 수익(매출액): ['208848287172'] 전기 영업이익: ['4927224591'] 영업활동으로 인한 현금흐름: ['-13961134104']
# 자산총계: ['1084376113904'] 부채총계: ['530569314550'] 자본총계: ['553806799354'] 단기차입금: ['96333445684'] 유동성장기부채: ['75000000000'] 사채: ['0'] 장기차입금: ['37520449571'] 비유동자산: ['486611853803'] 비유동부채: ['108144820064'] 전기말 자산총계: ['906996052778'] 전기말 부채총계: ['406767369307'] 전기말 자본총계: ['500228683471'] 매출채권: ['30046706496'] 매입채무: ['134435938897'] 재고자산: ['0'] 당기순이익: ['7126558106'] 영업이익: ['6625637152'] 수익(매출액): ['299740772349'] 법인세비용차감전순이익(손실): ['8431917205'] 금융비용: ['1224901385'] 전기 수익(매출액): ['253072055002'] 전기 영업이익: ['12325442203'] 영업활동으로 인한 현금흐름: ['-31967007620']
# 자산총계: ['1121706337221'] 부채총계: ['561090346883'] 자본총계: ['560615990338'] 단기차입금: ['155557410383'] 유동성장기부채: ['75000000000'] 사채: ['0'] 장기차입금: ['35414740323'] 비유동자산: ['484163189479'] 비유동부채: ['106996927011'] 전기말 자산총계: ['933678764764'] 전기말 부채총계: ['385180612938'] 전기말 자본총계: ['548498151826'] 매출채권: ['26547901387'] 매입채무: ['156487114947'] 재고자산: ['494097193'] 당기순이익: ['7107616166'] 영업이익: ['5801253583'] 수익(매출액): ['336569828952'] 법인세비용차감전순이익(손실): ['9233868054'] 금융비용: ['1374253161'] 전기 수익(매출액): ['235306515355'] 전기 영업이익: ['21131867453'] 영업활동으로 인한 현금흐름: ['-120207352472']
# 자산총계: ['1256174707103'] 부채총계: ['687867321485'] 자본총계: ['568307385618'] 단기차입금: ['128878693213'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['93374045252'] 비유동자산: ['487510003030'] 비유동부채: ['173999197966'] 전기말 자산총계: ['1010132311381'] 전기말 부채총계: ['467125028094'] 전기말 자본총계: ['543007283287'] 매출채권: ['77185258421'] 매입채무: ['224830414417'] 재고자산: ['90726996086'] 당기순이익: ['46104412270'] 영업이익: ['26971265157'] 수익(매출액): ['1300137418408'] 법인세비용차감전순이익(손실): ['57193340429'] 금융비용: ['19558637653'] 전기 수익(매출액): ['1015792261054'] 전기 영업이익: ['57703357127'] 영업활동으로 인한 현금흐름: ['-78362545563']
#                기업명    연도  보고서 코드        부채비율     차입금의존도    고정장기적합률  자기자본순이익률  \
# 아이디
# 005960202001  동부건설  2020  1분기보고서   83.435604   0.000000  68.631164  0.048645
# 005960202002  동부건설  2020   반기보고서   84.461390   0.000000  75.654726 -0.012092
# 005960202003  동부건설  2020  3분기보고서   60.787910   0.000000  75.231342  0.062173
# 005960202004  동부건설  2020   사업보고서   65.006576   0.000000  79.807033  0.112204
# 005960202101  동부건설  2021  1분기보고서   73.282714   0.000000  79.875270  0.036322
# 005960202102  동부건설  2021   반기보고서   81.316282  12.538747  69.863960  0.068414
# 005960202103  동부건설  2021  3분기보고서   70.224596  12.184307  72.884513  0.093973
# 005960202104  동부건설  2021   사업보고서   86.025555  11.265754  70.642671  0.175176
# 005960202201  동부건설  2022  1분기보고서   92.155474  13.072705  71.884500  0.063507
# 005960202202  동부건설  2022   반기보고서   95.804045  19.260282  73.511695  0.013522
# 005960202203  동부건설  2022  3분기보고서  100.084613  23.711389  72.521543  0.012817
# 005960202204  동부건설  2022   사업보고서  121.037899  17.692821  65.675021  0.082973
#
#               매출액영업이익률  매출액경상이익률   이자보상배율(배)   매출액 증가율   총자산 증가율  영업이익 증가율  \
# 아이디
# 005960202001  0.063204  0.080252  145.590501  0.464517  0.107971  4.892653
# 005960202002  0.057978 -0.028996   85.503780  0.049791 -0.028342  0.111851
# 005960202003  0.020930  0.115940   50.167317 -0.129359 -0.018067 -0.637663
# 005960202004  0.052153  0.052031   95.398786 -0.007023 -0.023596  0.006107
# 005960202101  0.023592  0.072355    4.545408 -0.268290  0.039512 -0.726873
# 005960202102  0.048703  0.130931   15.698615 -0.059856  0.167431 -0.210249
# 005960202103  0.089806  0.270563   18.310190 -0.057134  0.270227  3.045530
# 005960202104  0.056806  0.103402   12.362023 -0.068266  0.299267  0.014876
# 005960202201  0.028198  0.169067    3.971335  0.109444  0.308948  0.326004
# 005960202202  0.022105  0.028131    5.409119  0.184409  0.195569 -0.462442
# 005960202203  0.017236  0.027435    4.221386  0.430346  0.201384 -0.725474
# 005960202204  0.020745  0.043990    1.378995  0.279925  0.243574 -0.532588
#
#               자기자본 증가율  매출채권 회전기일(일)  재고자산 회전기일(일)  매입채무 회전기일(일)   총자산 회전율  \
# 아이디
# 005960202001  0.174865      0.174865      9.779695     33.322035  0.365686
# 005960202002  0.127482      0.127482     24.197322     69.858790  0.346478
# 005960202003  0.179876      0.179876     21.274633     93.193333  0.339522
# 005960202004  0.103813      0.103813      7.184618     35.852468  1.402274
# 005960202101  0.100419      0.100419      5.507096     37.917924  0.257405
# 005960202102  0.187681      0.187681     23.709829     71.258252  0.279022
# 005960202103  0.199810      0.199810     42.399077     88.687789  0.252021
# 005960202104  0.152463      0.152463     13.636700     47.342952  1.005603
# 005960202201  0.180388      0.180388     14.066431     53.442276  0.218173
# 005960202202  0.107107      0.107107     18.143858     81.179830  0.276418
# 005960202203  0.022093      0.022093     21.533651    126.930517  0.300052
# 005960202204  0.046593      0.046593     21.668955     63.118790  1.034997
#
#                부채상환계수(배)  총차입금상환능력비율
# 아이디
# 005960202001 -195.797080         inf
# 005960202002  224.772178         inf
# 005960202003   92.486376         inf
# 005960202004  -11.461611         inf
# 005960202101    5.003478         inf
# 005960202102   -0.480347   -0.153826
# 005960202103   -1.083555   -0.344978
# 005960202104    0.144968    0.008241
# 005960202201   -0.143864   -0.100559
# 005960202202   -0.178155   -0.153059
# 005960202203   -0.512363   -0.451955
# 005960202204   -0.396153   -0.352583

# %%
df.to_csv(f'/content/drive/MyDrive/ICR/재무비율/{corp_name_p}_재무비율.csv')

# %% [markdown]
# ### 코오롱글로벌

# %%
corp_name = ['DL이앤씨', 'HDC현대산업개발', '한전KPS', 'HJ중공업', '신세계건설', 'KCC건설', '대우건설', '서희건설', '특수건설', '계룡건설산업', '신원종합개발', '서한', '태영건설', '현대건설', 'GS건설', '동부건설', '코오롱글로벌', 'DL건설', '진흥기업', '남광토건', '한신공영', '금호건설', '삼부토건']
corp_code = ['375500', '294870', '051600', '097230', '034300', '021320', '047040', '035890', '026150', '013580', '017000', '011370', '009410', '000720', '006360', '005960', '003070', '001880', '002780', '001260', '004960', '002990', '001470']
report_code = ["11013", "11012", "11014", "11011"] # '11013'=1분기보고서, '11012'=반기보고서, '11014'=3분기보고서, '11011'=사업보고서

corp_name_p = corp_name[16]
corp_code_p = corp_code[16]

all = pd.DataFrame()

for year in range(2019, 2023):
  for code in report_code:
    corp = dart.finstate_all(corp_code_p, year, code, fs_div="OFS")
    # corp = corp.drop('account_id', axis=1)
    all = pd.concat([all, corp], ignore_index=True) # 2019년~2022년 별도 재무제표 전문(분기보고서+반기보고서+사업보고서)

all
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# 주석에 있는 유동성장기부채 직접 수기로 가져옴
liquidity_enhancing_long_term_debt = ['64060000000', '55060000000', '58060000000', '53060000000', '73060000000', '73060000000', '87060000000', '87060000000', '120560000000', '120560000000', '70060000000', '110060000000']
year_i = ['2020','2020','2020','2020','2021','2021','2021','2021','2022','2022','2022','2022']
report_code_i = ["11013", "11012", "11014", "11011","11013", "11012", "11014", "11011","11013", "11012", "11014", "11011"]

debt = {
    'year':year_i,
    'report_code':report_code_i,
    '유동성장기부채': liquidity_enhancing_long_term_debt
    }

debt_df = pd.DataFrame(debt)
debt_df
# Out:
#     year report_code       유동성장기부채
# 0   2020       11013   64060000000
# 1   2020       11012   55060000000
# 2   2020       11014   58060000000
# 3   2020       11011   53060000000
# 4   2021       11013   73060000000
# 5   2021       11012   73060000000
# 6   2021       11014   87060000000
# 7   2021       11011   87060000000
# 8   2022       11013  120560000000
# 9   2022       11012  120560000000
# 10  2022       11014   70060000000
# 11  2022       11011  110060000000

# %%
Quarter = []
cor_year = []
ID_list = []
corp_name_list = []
year_list = []
report_code_list = []
Debt_Ratio = []
Debt_to_Asset_Ratio = []
Fixed_Asset_Turnover_Ratio = []
Return_on_Equity = []
Operating_Profit_Margin = []
Gross_Profit_Margin = []
Interest_Coverage_Ratio =[]
Sales_Growth_Rate = []
Total_Asset_Growth_Rate = []
Operating_Profit_Growth_Rate = []
Equity_Growth_Rate= []
Accounts_Receivable_Turnover = []
Inventory_Turnover = []
Accounts_Payable_Turnover = []
Total_Asset_Turnover_Ratio = []
Debt_Service_Coverage_Ratio = []
Debt_to_Equity_Ratio = []


for year in range(2020, 2023):
  str_year = str(year)
  report_code_list.extend(['1분기보고서' if code == '11013' else '반기보고서' if code == '11012' else '3분기보고서' if code == '11014' else '사업보고서' for code in report_code])
  Quarter.extend(['01' if code == '11013' else '02' if code == '11012' else '03' if code == '11014' else '04' for code in report_code])
  for code in report_code:
    BS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '자산총계' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자산총계
    BS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 부채총계
    BS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자본총계
    BS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '차입금' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 단기차입금
    BS5 = [(row['유동성장기부채']) for index, row in debt_df.iterrows() if row['year'] == str(year) and row['report_code'] == str(code)]
    # BS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and ('유동성장기부채' in row['account_nm'] or '유동성장기채무' in row['account_nm']) and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 유동성장기부채
    BS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '사채' in row['account_nm'] and '장기' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 사채
    BS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '장기차입금' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 장기차입금
    BS8 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동자산' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동자산
    BS9 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동부채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동부채
    BS10 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자산총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자산총계
    BS11 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 부채총계
    BS12 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자본총계
    BS13 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매출채권' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매출채권
    BS14 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매입채무' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매입채무
    BS15 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '재고자산' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 재고자산

    IS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '포괄손익계산서' and '기순' in row['account_nm'] and '영업' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 당기순이익
    IS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업이익
    IS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '매출액' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 수익(매출액)
    IS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '법인세' in row['account_nm'] and '차감전' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 법인세비용차감전순이익(손실)
    IS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and (row['account_nm'] == '금융비용' or row['account_nm'] == '금융원가') and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 금융비용
    IS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '매출액' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 수익(매출액) # 분기 보고서만 해당
    IS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '영업이익(손실)' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 영업이익 # 분기 보고서만 해당

    CF1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '현금흐름표' and row['account_nm'] == '영업활동현금흐름' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업활동으로 인한 현금흐름

    if BS6 == BS7: # '사채 및 장기차입금'으로 계정과목 하나만 쓰는 회사는 합침(어차피 사채는 차입금 의존도에서만 사용해서 하나 0으로 만들어도 상관없음)
      BS6 = ['0']
    # if BS4 == BS5:
    #   BS4 = ['0'] # '단기차입금 및 유동성장기부채' 로 병합해서 쓰는 회사는 하나로 합침(어차피 둘이 항상 붙어서 계산해서 상관없음)
    # if BS4 == [''] or BS4 == []:
    #   BS4 = ['0']
    # if BS5 == [''] or BS5 == []:
    #   BS5 = ['0']
    # if BS6 == []:
    #   BS6 = ['0']
    # if BS7 == []:
    #   BS7 = ['0']

    # 2021년 반기보고서 기재정정으로 값이 다 날라가서 재무제표 안 불러와짐.... 하나하나 수기로 채움
    if BS1 == []:
      BS1 = ['2240770250107']
    if BS2 == []:
      BS2 = ['1625117268143']
    if BS3 == []:
      BS3 = ['615652981964']
    if BS4 == []:
      BS4 = ['230543921999']
    if BS7 == []:
      BS7 = ['286768152688']
    if BS8 == []:
      BS8 = ['1290606318596']
    if BS9 == []:
      BS9 = ['518792850508']
    if BS13 == []:
      BS13 = ['335771447819']
    if BS14 == []:
      BS14 = ['482667309010']
    if BS15 == []:
      BS15 = ['127703285783']
    if IS1 == []:
      IS1 = ['49470381630']
    if IS2 == []:
      IS2 = ['74830972690']
    if IS3 == []:
      IS3 = ['1124704548937']
    if IS4 == []:
      IS4 = ['65277511880']
    if IS5 == []:
      IS5 = ['5257966084']
    if CF1 == []:
      CF1 = ['38254133704']

    if BS10 == []:
      BS10 = ['2240770250107']
    if BS11 == []:
      BS11 = ['1625117268143']
    if BS12 == []:
      BS12 = ['615652981964']
    if IS6 == []:
      IS6 = ['1124704548937']
    if IS7 == []:
      IS7 = ['74830972690']


    print("자산총계:", BS1, "부채총계:", BS2, "자본총계:", BS3, "단기차입금:", BS4, "유동성장기부채:", BS5, "사채:", BS6, "장기차입금:", BS7, "비유동자산:", BS8, "비유동부채:", BS9, "전기말 자산총계:", BS10, "전기말 부채총계:", BS11,
          "전기말 자본총계:", BS12, "매출채권:", BS13, "매입채무:", BS14, "재고자산:", BS15, "당기순이익:", IS1, "영업이익:", IS2, "수익(매출액):", IS3, "법인세비용차감전순이익(손실):", IS4,
          "금융비용:", IS5, "전기 수익(매출액):", IS6, "전기 영업이익:", IS7, "영업활동으로 인한 현금흐름:", CF1)

    if year != 2020:
      if code == "11013":
        accounting_period = 90
      elif code == "11012":
        accounting_period = 181
      elif code == "11014":
        accounting_period = 273
      elif code == "11011":
        accounting_period = 365
    else: # 2020년은 윤년
      if code == "11013":
        accounting_period = 91
      elif code == "11012":
        accounting_period = 182
      elif code == "11014":
        accounting_period = 274
      elif code == "11011":
        accounting_period = 366


    cor_year.extend([f"{corp_code_p}{str_year}"])
    corp_name_list.append(str(corp_name_p))
    year_list.append(str_year)
    Debt_Ratio.extend([int(BS2)/int(BS3)*100 for BS2, BS3 in zip(BS2, BS3)])
    Debt_to_Asset_Ratio.extend([((int(BS4) + int(BS5) + int(BS6) + int(BS7)) / int(BS1) * 100) for BS4, BS5, BS6, BS7, BS1 in zip(BS4, BS5, BS6, BS7, BS1)])
    Fixed_Asset_Turnover_Ratio.extend([int(BS8)/(int(BS9)+int(BS3))*100 for BS8, BS9, BS3 in zip(BS8, BS9, BS3)]),
    Return_on_Equity.extend([int(IS1)/((int(BS12)+int(BS3))/2) for IS1, BS12, BS3 in zip(IS1, BS12, BS3)])
    Operating_Profit_Margin.extend([int(IS2)/int(IS3) for IS2, IS3 in zip(IS2, IS3)])
    Gross_Profit_Margin.extend([int(IS4)/int(IS3) for IS4, IS3 in zip(IS4, IS3)])
    Interest_Coverage_Ratio.extend([int(IS2)/int(IS5) for IS2, IS5 in zip(IS2, IS5)])
    Sales_Growth_Rate.extend([(int(IS3)-int(IS6))/int(IS6) for IS3, IS6 in zip(IS3, IS6)])
    Total_Asset_Growth_Rate.extend([(int(BS1)-int(BS10))/int(BS10) for BS1, BS10 in zip(BS1, BS10)])
    Operating_Profit_Growth_Rate.extend([(int(IS2)-int(IS7))/int(IS7) for IS2, IS7 in zip(IS2, IS7)])
    Equity_Growth_Rate.extend([(int(BS3)-int(BS12))/int(BS12) for BS3, BS12 in zip(BS3, BS12)])
    Accounts_Receivable_Turnover.extend([int(BS13)/int(IS3)*accounting_period for BS13, IS3 in zip(BS13, IS3)])
    Inventory_Turnover.extend([int(BS15)/int(IS3)*accounting_period for BS15, IS3 in zip(BS15, IS3)])
    Accounts_Payable_Turnover.extend([int(BS14)/int(IS3)*accounting_period for BS14, IS3 in zip(BS14, IS3)])
    Total_Asset_Turnover_Ratio.extend([int(IS3)/int(BS1) for IS3, BS1 in zip(IS3, BS1)])
    Debt_Service_Coverage_Ratio.extend([(int(CF1)+int(IS5))/(int(BS4)+int(BS5)+int(IS5)) for CF1, IS5, BS4, BS5 in zip(CF1, IS5, BS4, BS5)])
    Debt_to_Equity_Ratio.extend([int(CF1)/(int(BS4)+int(BS7)+int(BS5)) for CF1, BS4, BS7, BS5 in zip(CF1, BS4, BS7, BS5)])

ID_list.extend([x+y for x,y in zip(cor_year,Quarter)])

financial_ratio = {
      '아이디':ID_list,
      '기업명':corp_name_list,
      '연도':year_list,
      '보고서 코드':report_code_list,
      '부채비율' : Debt_Ratio,
      '차입금의존도' : Debt_to_Asset_Ratio,
      '고정장기적합률':Fixed_Asset_Turnover_Ratio,
      '자기자본순이익률':Return_on_Equity,
      '매출액영업이익률':Operating_Profit_Margin,
      '매출액경상이익률':Gross_Profit_Margin,
      '이자보상배율(배)':Interest_Coverage_Ratio,
      '매출액 증가율':Sales_Growth_Rate,
      '총자산 증가율':Total_Asset_Growth_Rate,
      '영업이익 증가율':Operating_Profit_Growth_Rate,
      '자기자본 증가율':Equity_Growth_Rate,
      '매출채권 회전기일(일)':Equity_Growth_Rate,
      '재고자산 회전기일(일)':Accounts_Receivable_Turnover,
      '매입채무 회전기일(일)':Accounts_Payable_Turnover,
      '총자산 회전율':Total_Asset_Turnover_Ratio,
      '부채상환계수(배)':Debt_Service_Coverage_Ratio,
      '총차입금상환능력비율':Debt_to_Equity_Ratio
                    }

df = pd.DataFrame(financial_ratio)
df.set_index('아이디', inplace=True)

df
# Out:
# 자산총계: ['2059642967843'] 부채총계: ['1566754146237'] 자본총계: ['492888821606'] 단기차입금: ['350303715560'] 유동성장기부채: ['64060000000'] 사채: ['0'] 장기차입금: ['151468990585'] 비유동자산: ['1113462540949'] 비유동부채: ['360510136098'] 전기말 자산총계: ['2220452718977'] 전기말 부채총계: ['1763148596793'] 전기말 자본총계: ['457304122184'] 매출채권: ['294318521234'] 매입채무: ['497772470270'] 재고자산: ['161258814250'] 당기순이익: ['19639115223'] 영업이익: ['34419501236'] 수익(매출액): ['774877777823'] 법인세비용차감전순이익(손실): ['26293650292'] 금융비용: ['8400461406'] 전기 수익(매출액): ['773033219326'] 전기 영업이익: ['33086084325'] 영업활동으로 인한 현금흐름: ['145225400149']
# 자산총계: ['2129894244887'] 부채총계: ['1608452584379'] 자본총계: ['521441660508'] 단기차입금: ['428674035140'] 유동성장기부채: ['55060000000'] 사채: ['0'] 장기차입금: ['31430915082'] 비유동자산: ['1109016466826'] 비유동부채: ['235408356437'] 전기말 자산총계: ['2226647736472'] 전기말 부채총계: ['1762870546907'] 전기말 자본총계: ['463777189565'] 매출채권: ['332312836622'] 매입채무: ['555443505723'] 재고자산: ['124920479004'] 당기순이익: ['29030333738'] 영업이익: ['50634555255'] 수익(매출액): ['922531412175'] 법인세비용차감전순이익(손실): ['38092012854'] 금융비용: ['4044935804'] 전기 수익(매출액): ['869489821932'] 전기 영업이익: ['30900809335'] 영업활동으로 인한 현금흐름: ['268515548904']
# 자산총계: ['2135879905713'] 부채총계: ['1586097142281'] 자본총계: ['549782763432'] 단기차입금: ['430868400639'] 유동성장기부채: ['58060000000'] 사채: ['0'] 장기차입금: ['43430915082'] 비유동자산: ['1108915518230'] 비유동부채: ['257730091028'] 전기말 자산총계: ['2158201841332'] 전기말 부채총계: ['1677989084107'] 전기말 자본총계: ['480212757225'] 매출채권: ['342913718177'] 매입채무: ['554040531274'] 재고자산: ['107379831527'] 당기순이익: ['29970693965'] 영업이익: ['49079508994'] 수익(매출액): ['968200944879'] 법인세비용차감전순이익(손실): ['41051919749'] 금융비용: ['4038434180'] 전기 수익(매출액): ['860086638663'] 전기 영업이익: ['30662983996'] 영업활동으로 인한 현금흐름: ['204075424913']
# 자산총계: ['2289478877181'] 부채총계: ['1745980259463'] 자본총계: ['543498617718'] 단기차입금: ['437572369206'] 유동성장기부채: ['53060000000'] 사채: ['0'] 장기차입금: ['83357945418'] 비유동자산: ['1256251600704'] 비유동부채: ['306999889215'] 전기말 자산총계: ['2094859314526'] 전기말 부채총계: ['1619772904842'] 전기말 자본총계: ['475086409684'] 매출채권: ['360056505897'] 매입채무: ['645264668096'] 재고자산: ['153484822140'] 당기순이익: ['88093788689'] 영업이익: ['181983963265'] 수익(매출액): ['3802884624868'] 법인세비용차감전순이익(손실): ['122223055838'] 금융비용: ['25830444637'] 전기 수익(매출액): ['3433751395233'] 전기 영업이익: ['137151373699'] 영업활동으로 인한 현금흐름: ['302564115898']
# 자산총계: ['2292508742912'] 부채총계: ['1723803389959'] 자본총계: ['568705352953'] 단기차입금: ['415915778004'] 유동성장기부채: ['73060000000'] 사채: ['0'] 장기차입금: ['206809972124'] 비유동자산: ['1268528596377'] 비유동부채: ['447773887302'] 전기말 자산총계: ['2059642967843'] 전기말 부채총계: ['1566754146237'] 전기말 자본총계: ['492888821606'] 매출채권: ['418255926154'] 매입채무: ['468779359202'] 재고자산: ['121297411563'] 당기순이익: ['33276035188'] 영업이익: ['47036161309'] 수익(매출액): ['970630223818'] 법인세비용차감전순이익(손실): ['41322025030'] 금융비용: ['5146172876'] 전기 수익(매출액): ['774877777823'] 전기 영업이익: ['34419501236'] 영업활동으로 인한 현금흐름: ['-60117204931']
# 자산총계: ['2240770250107'] 부채총계: ['1625117268143'] 자본총계: ['615652981964'] 단기차입금: ['230543921999'] 유동성장기부채: ['73060000000'] 사채: ['0'] 장기차입금: ['286768152688'] 비유동자산: ['1290606318596'] 비유동부채: ['518792850508'] 전기말 자산총계: ['2129894244887'] 전기말 부채총계: ['1608452584379'] 전기말 자본총계: ['521441660508'] 매출채권: ['335771447819'] 매입채무: ['482667309010'] 재고자산: ['127703285783'] 당기순이익: ['49470381630'] 영업이익: ['74830972690'] 수익(매출액): ['1124704548937'] 법인세비용차감전순이익(손실): ['65277511880'] 금융비용: ['5257966084'] 전기 수익(매출액): ['922531412175'] 전기 영업이익: ['50634555255'] 영업활동으로 인한 현금흐름: ['38254133704']
# 자산총계: ['2322202267865'] 부채총계: ['1651630013248'] 자본총계: ['670572254617'] 단기차입금: ['244469822099'] 유동성장기부채: ['87060000000'] 사채: ['0'] 장기차입금: ['271286146680'] 비유동자산: ['1295145404253'] 비유동부채: ['496735232311'] 전기말 자산총계: ['2135879905713'] 전기말 부채총계: ['1586097142281'] 전기말 자본총계: ['549782763432'] 매출채권: ['361169207564'] 매입채무: ['474392328183'] 재고자산: ['126912703833'] 당기순이익: ['49689789927'] 영업이익: ['69217893472'] 수익(매출액): ['1047706479741'] 법인세비용차감전순이익(손실): ['66137315012'] 금융비용: ['4886209103'] 전기 수익(매출액): ['968200944879'] 전기 영업이익: ['49079508994'] 영업활동으로 인한 현금흐름: ['48615025919']
# 자산총계: ['2388512680806'] 부채총계: ['1717862286360'] 자본총계: ['670650394446'] 단기차입금: ['306891831750'] 유동성장기부채: ['87060000000'] 사채: ['0'] 장기차입금: ['206371293632'] 비유동자산: ['1334787385174'] 비유동부채: ['422799236356'] 전기말 자산총계: ['2289478877181'] 전기말 부채총계: ['1745980259463'] 전기말 자본총계: ['543498617718'] 매출채권: ['513694429676'] 매입채무: ['527670431909'] 재고자산: ['109640808811'] 당기순이익: ['136289029278'] 영업이익: ['238447374407'] 수익(매출액): ['4228724135333'] 법인세비용차감전순이익(손실): ['193397057928'] 금융비용: ['18842572568'] 전기 수익(매출액): ['3802884624868'] 전기 영업이익: ['181983963265'] 영업활동으로 인한 현금흐름: ['172392656100']
# 자산총계: ['2445003758336'] 부채총계: ['1770511251484'] 자본총계: ['674492506852'] 단기차입금: ['352688695563'] 유동성장기부채: ['120560000000'] 사채: ['0'] 장기차입금: ['171371293632'] 비유동자산: ['1365265841251'] 비유동부채: ['400878345870'] 전기말 자산총계: ['2292508742912'] 전기말 부채총계: ['1723803389959'] 전기말 자본총계: ['568705352953'] 매출채권: ['471466480505'] 매입채무: ['519943217610'] 재고자산: ['127753196348'] 당기순이익: ['39260680462'] 영업이익: ['57247727225'] 수익(매출액): ['1013197701984'] 법인세비용차감전순이익(손실): ['52335756212'] 금융비용: ['4900347405'] 전기 수익(매출액): ['970630223818'] 전기 영업이익: ['47036161309'] 영업활동으로 인한 현금흐름: ['26978443848']
# 자산총계: ['2517315016176'] 부채총계: ['1800073242834'] 자본총계: ['717241773342'] 단기차입금: ['451091720594'] 유동성장기부채: ['120560000000'] 사채: ['0'] 장기차입금: ['91311672182'] 비유동자산: ['1366594627330'] 비유동부채: ['305205373462'] 전기말 자산총계: ['2240770250107'] 전기말 부채총계: ['1625117268143'] 전기말 자본총계: ['615652981964'] 매출채권: ['503208330984'] 매입채무: ['526463090096'] 재고자산: ['171693606747'] 당기순이익: ['43844884682'] 영업이익: ['61678423111'] 수익(매출액): ['1115208434091'] 법인세비용차감전순이익(손실): ['54534671505'] 금융비용: ['5574842627'] 전기 수익(매출액): ['1124704548937'] 전기 영업이익: ['74830972690'] 영업활동으로 인한 현금흐름: ['143540754235']
# 자산총계: ['2593530054319'] 부채총계: ['1825121015607'] 자본총계: ['768409038712'] 단기차입금: ['418411743660'] 유동성장기부채: ['70060000000'] 사채: ['0'] 장기차입금: ['156311672182'] 비유동자산: ['1423486248337'] 비유동부채: ['386042924164'] 전기말 자산총계: ['2322202267865'] 전기말 부채총계: ['1651630013248'] 전기말 자본총계: ['670572254617'] 매출채권: ['455245356923'] 매입채무: ['497442196807'] 재고자산: ['155865558561'] 당기순이익: ['49836119183'] 영업이익: ['70046679440'] 수익(매출액): ['1091460404116'] 법인세비용차감전순이익(손실): ['66128566367'] 금융비용: ['7318137360'] 전기 수익(매출액): ['1047706479741'] 전기 영업이익: ['69217893472'] 영업활동으로 인한 현금흐름: ['115417340581']
# 자산총계: ['2687225452205'] 부채총계: ['2102162607242'] 자본총계: ['585062844963'] 단기차입금: ['209152963152'] 유동성장기부채: ['110060000000'] 사채: ['0'] 장기차입금: ['196311672182'] 비유동자산: ['979536785118'] 비유동부채: ['338373960500'] 전기말 자산총계: ['2388512680806'] 전기말 부채총계: ['1717862286360'] 전기말 자본총계: ['670650394446'] 매출채권: ['396224654160'] 매입채무: ['712265088485'] 재고자산: ['63021049765'] 당기순이익: ['148835324568'] 영업이익: ['166628587129'] 수익(매출액): ['2541197415205'] 법인세비용차감전순이익(손실): ['156456653595'] 금융비용: ['13995977868'] 전기 수익(매출액): ['4228724135333'] 전기 영업이익: ['238447374407'] 영업활동으로 인한 현금흐름: ['219966311243']
#                  기업명    연도  보고서 코드        부채비율     차입금의존도     고정장기적합률  \
# 아이디
# 003070202001  코오롱글로벌  2020  1분기보고서  317.871714  27.472369  130.473858
# 003070202002  코오롱글로벌  2020   반기보고서  308.462616  24.187349  146.530547
# 003070202003  코오롱글로벌  2020  3분기보고서  288.495247  24.924590  137.324813
# 003070202004  코오롱글로벌  2020   사업보고서  321.248335  25.070784  147.707679
# 003070202101  코오롱글로벌  2021  1분기보고서  303.110105  30.350408  124.796311
# 003070202102  코오롱글로벌  2021   반기보고서  263.966441  26.346837  113.765354
# 003070202103  코오롱글로벌  2021  3분기보고서  246.301573  25.958805  110.951520
# 003070202104  코오롱글로벌  2021   사업보고서  256.148703  25.133763  122.071227
# 003070202201  코오롱글로벌  2022  1분기보고서  262.495318  26.364785  126.957676
# 003070202202  코오롱글로벌  2022   반기보고서  250.971612  26.336131  133.659195
# 003070202203  코오롱글로벌  2022  3분기보고서  237.519462  24.861228  123.304069
# 003070202204  코오롱글로벌  2022   사업보고서  359.305436  19.184272  106.075129
#
#               자기자본순이익률  매출액영업이익률  매출액경상이익률  이자보상배율(배)   매출액 증가율   총자산 증가율  \
# 아이디
# 003070202001  0.041337  0.044419  0.033933   4.097335  0.002386 -0.072422
# 003070202002  0.058932  0.054887  0.041291  12.518012  0.061003 -0.043453
# 003070202003  0.058196  0.050691  0.042400  12.153104  0.125702 -0.010343
# 003070202004  0.172973  0.047854  0.032140   7.045328  0.107501  0.092903
# 003070202101  0.062691  0.048459  0.042572   9.140027  0.252624  0.113061
# 003070202102  0.087012  0.066534  0.058040  14.231924  0.219150  0.052057
# 003070202103  0.081435  0.066066  0.063126  14.165970  0.082117  0.087234
# 003070202104  0.224501  0.056388  0.045734  12.654714  0.111978  0.043256
# 003070202201  0.063161  0.056502  0.051654  11.682381  0.043856  0.066519
# 003070202202  0.065789  0.055307  0.048901  11.063707 -0.008443  0.123415
# 003070202203  0.069266  0.064177  0.060587   9.571654  0.041762  0.116841
# 003070202204  0.237053  0.065571  0.061568  11.905462 -0.399063  0.125062
#
#               영업이익 증가율  자기자본 증가율  매출채권 회전기일(일)  재고자산 회전기일(일)  매입채무 회전기일(일)  \
# 아이디
# 003070202001  0.040301  0.077814      0.077814     34.564142     58.457341
# 003070202002  0.638616  0.124337      0.124337     65.559758    109.579703
# 003070202003  0.600611  0.144873      0.144873     97.044275    156.792974
# 003070202004  0.326884  0.144000      0.144000     34.652821     62.102034
# 003070202101  0.366556  0.153821      0.153821     38.782054     43.466751
# 003070202102  0.477864  0.180675      0.180675     54.036086     77.676207
# 003070202103  0.410322  0.219704      0.219704     94.109558    123.612012
# 003070202104  0.310266  0.233951      0.233951     44.339252     45.545583
# 003070202201  0.217100  0.186014      0.186014     41.879273     46.185349
# 003070202202 -0.175763  0.165010      0.165010     81.671466     85.445748
# 003070202203  0.011974  0.145900      0.145900    113.867605    124.422031
# 003070202204 -0.301193 -0.127619     -0.127619     56.910966    102.304825
#
#                총자산 회전율  부채상환계수(배)  총차입금상환능력비율
# 아이디
# 003070202001  0.376219   0.363384    0.256658
# 003070202002  0.433135   0.558779    0.521222
# 003070202003  0.453303   0.422166    0.383342
# 003070202004  1.661026   0.635853    0.527124
# 003070202101  0.423392  -0.111250   -0.086402
# 003070202102  0.501928   0.140879    0.064797
# 003070202103  0.451169   0.159033    0.080647
# 003070202104  1.770442   0.463270    0.287166
# 003070202201  0.414395   0.066671    0.041852
# 003070202202  0.443015   0.258331    0.216514
# 003070202203  0.420840   0.247555    0.179002
# 003070202204  0.945658   0.702149    0.426684

# %%
df.to_csv(f'/content/drive/MyDrive/ICR/재무비율/{corp_name_p}_재무비율.csv')

# %% [markdown]
# ### DL 건설

# %%
corp_name = ['DL이앤씨', 'HDC현대산업개발', '한전KPS', 'HJ중공업', '신세계건설', 'KCC건설', '대우건설', '서희건설', '특수건설', '계룡건설산업', '신원종합개발', '서한', '태영건설', '현대건설',
             'GS건설', '동부건설', '코오롱글로벌', 'DL건설', '진흥기업', '남광토건', '한신공영', '금호건설', '삼부토건']
corp_code = ['375500', '294870', '051600', '097230', '034300', '021320', '047040', '035890', '026150', '013580', '017000', '011370', '009410', '000720', '006360', '005960', '003070', '001880', '002780', '001260', '004960', '002990', '001470']
report_code = ["11013", "11012", "11014", "11011"] # '11013'=1분기보고서, '11012'=반기보고서, '11014'=3분기보고서, '11011'=사업보고서

corp_name_p = corp_name[17]
corp_code_p = corp_code[17]

all = pd.DataFrame()

for year in range(2019, 2023):
  for code in report_code:
    corp = dart.finstate_all(corp_code_p, year, code, fs_div="OFS")
    # corp = corp.drop('account_id', axis=1)
    all = pd.concat([all, corp], ignore_index=True) # 2019년~2022년 별도 재무제표 전문(분기보고서+반기보고서+사업보고서)

all
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
Quarter = []
cor_year = []
ID_list = []
corp_name_list = []
year_list = []
report_code_list = []
Debt_Ratio = []
Debt_to_Asset_Ratio = []
Fixed_Asset_Turnover_Ratio = []
Return_on_Equity = []
Operating_Profit_Margin = []
Gross_Profit_Margin = []
Interest_Coverage_Ratio =[]
Sales_Growth_Rate = []
Total_Asset_Growth_Rate = []
Operating_Profit_Growth_Rate = []
Equity_Growth_Rate= []
Accounts_Receivable_Turnover = []
Inventory_Turnover = []
Accounts_Payable_Turnover = []
Total_Asset_Turnover_Ratio = []
Debt_Service_Coverage_Ratio = []
Debt_to_Equity_Ratio = []


for year in range(2020, 2023):
  str_year = str(year)
  report_code_list.extend(['1분기보고서' if code == '11013' else '반기보고서' if code == '11012' else '3분기보고서' if code == '11014' else '사업보고서' for code in report_code])
  Quarter.extend(['01' if code == '11013' else '02' if code == '11012' else '03' if code == '11014' else '04' for code in report_code])
  for code in report_code:
    BS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '자산총계' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자산총계
    BS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 부채총계
    BS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자본총계
    BS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '단기차입금' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 단기차입금
    BS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and ('유동성장기부채' in row['account_nm'] or '유동성장기채무' in row['account_nm']) and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 유동성장기부채
    BS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '사채' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 사채
    BS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '차입금' in row['account_nm'] and '단기차입금' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 장기차입금
    BS8 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동자산' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동자산
    BS9 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동부채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동부채
    BS10 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자산총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자산총계
    BS11 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 부채총계
    BS12 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자본총계
    BS13 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매출채권' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매출채권
    BS14 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매입채무' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매입채무
    BS15 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '재고자산' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 재고자산

    IS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '포괄손익계산서' and '기순' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 당기순이익
    IS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업이익
    IS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '매출액' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 수익(매출액)
    IS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '법인세' in row['account_nm'] and '차감전' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 법인세비용차감전순이익(손실)
    IS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and (row['account_nm'] == '금융비용' or row['account_nm'] == '금융원가') and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 금융비용
    IS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '매출액' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 수익(매출액) # 분기 보고서만 해당
    IS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '영업이익' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 영업이익 # 분기 보고서만 해당

    CF1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '현금흐름표' and row['account_nm'] == '영업활동현금흐름' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업활동으로 인한 현금흐름

    if BS6 == BS7: # '사채 및 장기차입금'으로 계정과목 하나만 쓰는 회사는 합침(어차피 사채는 차입금 의존도에서만 사용해서 하나 0으로 만들어도 상관없음)
      BS6 = ['0']
    if BS4 == BS5:
      BS4 = ['0'] # '단기차입금 및 유동성장기부채' 로 병합해서 쓰는 회사는 하나로 합침(어차피 둘이 항상 붙어서 계산해서 상관없음)
    # if BS4 == [''] or BS4 == []:
    #   BS4 = ['0']
    # if BS5 == [''] or BS5 == []:
    #   BS5 = ['0']
    # if BS6 == []:
    #   BS6 = ['0']
    # if BS7 == []:
    #   BS7 = ['0']

    print("자산총계:", BS1, "부채총계:", BS2, "자본총계:", BS3, "단기차입금:", BS4, "유동성장기부채:", BS5, "사채:", BS6, "장기차입금:", BS7, "비유동자산:", BS8, "비유동부채:", BS9, "전기말 자산총계:", BS10, "전기말 부채총계:", BS11,
          "전기말 자본총계:", BS12, "매출채권:", BS13, "매입채무:", BS14, "재고자산:", BS15, "당기순이익:", IS1, "영업이익:", IS2, "수익(매출액):", IS3, "법인세비용차감전순이익(손실):", IS4,
          "금융비용:", IS5, "전기 수익(매출액):", IS6, "전기 영업이익:", IS7, "영업활동으로 인한 현금흐름:", CF1)

    if year != 2020:
      if code == "11013":
        accounting_period = 90
      elif code == "11012":
        accounting_period = 181
      elif code == "11014":
        accounting_period = 273
      elif code == "11011":
        accounting_period = 365
    else: # 2020년은 윤년
      if code == "11013":
        accounting_period = 91
      elif code == "11012":
        accounting_period = 182
      elif code == "11014":
        accounting_period = 274
      elif code == "11011":
        accounting_period = 366


    cor_year.extend([f"{corp_code_p}{str_year}"])
    corp_name_list.append(str(corp_name_p))
    year_list.append(str_year)
    Debt_Ratio.extend([int(BS2)/int(BS3)*100 for BS2, BS3 in zip(BS2, BS3)])
    Debt_to_Asset_Ratio.extend([((int(BS4) + int(BS5) + int(BS6) + int(BS7)) / int(BS1) * 100) for BS4, BS5, BS6, BS7, BS1 in zip(BS4, BS5, BS6, BS7, BS1)])
    Fixed_Asset_Turnover_Ratio.extend([int(BS8)/(int(BS9)+int(BS3))*100 for BS8, BS9, BS3 in zip(BS8, BS9, BS3)]),
    Return_on_Equity.extend([int(IS1)/((int(BS12)+int(BS3))/2) for IS1, BS12, BS3 in zip(IS1, BS12, BS3)])
    Operating_Profit_Margin.extend([int(IS2)/int(IS3) for IS2, IS3 in zip(IS2, IS3)])
    Gross_Profit_Margin.extend([int(IS4)/int(IS3) for IS4, IS3 in zip(IS4, IS3)])
    Interest_Coverage_Ratio.extend([int(IS2)/int(IS5) for IS2, IS5 in zip(IS2, IS5)])
    Sales_Growth_Rate.extend([(int(IS3)-int(IS6))/int(IS6) for IS3, IS6 in zip(IS3, IS6)])
    Total_Asset_Growth_Rate.extend([(int(BS1)-int(BS10))/int(BS10) for BS1, BS10 in zip(BS1, BS10)])
    Operating_Profit_Growth_Rate.extend([(int(IS2)-int(IS7))/int(IS7) for IS2, IS7 in zip(IS2, IS7)])
    Equity_Growth_Rate.extend([(int(BS3)-int(BS12))/int(BS12) for BS3, BS12 in zip(BS3, BS12)])
    Accounts_Receivable_Turnover.extend([int(BS13)/int(IS3)*accounting_period for BS13, IS3 in zip(BS13, IS3)])
    Inventory_Turnover.extend([int(BS15)/int(IS3)*accounting_period for BS15, IS3 in zip(BS15, IS3)])
    Accounts_Payable_Turnover.extend([int(BS14)/int(IS3)*accounting_period for BS14, IS3 in zip(BS14, IS3)])
    Total_Asset_Turnover_Ratio.extend([int(IS3)/int(BS1) for IS3, BS1 in zip(IS3, BS1)])
    Debt_Service_Coverage_Ratio.extend([(int(CF1)+int(IS5))/(int(BS4)+int(BS5)+int(IS5)) for CF1, IS5, BS4, BS5 in zip(CF1, IS5, BS4, BS5)])
    Debt_to_Equity_Ratio.extend([int(CF1)/(int(BS4)+int(BS7)+int(BS5)) for CF1, BS4, BS7, BS5 in zip(CF1, BS4, BS7, BS5)])

ID_list.extend([x+y for x,y in zip(cor_year,Quarter)])

financial_ratio = {
      '아이디':ID_list,
      '기업명':corp_name_list,
      '연도':year_list,
      '보고서 코드':report_code_list,
      '부채비율' : Debt_Ratio,
      '차입금의존도' : Debt_to_Asset_Ratio,
      '고정장기적합률':Fixed_Asset_Turnover_Ratio,
      '자기자본순이익률':Return_on_Equity,
      '매출액영업이익률':Operating_Profit_Margin,
      '매출액경상이익률':Gross_Profit_Margin,
      '이자보상배율(배)':Interest_Coverage_Ratio,
      '매출액 증가율':Sales_Growth_Rate,
      '총자산 증가율':Total_Asset_Growth_Rate,
      '영업이익 증가율':Operating_Profit_Growth_Rate,
      '자기자본 증가율':Equity_Growth_Rate,
      '매출채권 회전기일(일)':Equity_Growth_Rate,
      '재고자산 회전기일(일)':Accounts_Receivable_Turnover,
      '매입채무 회전기일(일)':Accounts_Payable_Turnover,
      '총자산 회전율':Total_Asset_Turnover_Ratio,
      '부채상환계수(배)':Debt_Service_Coverage_Ratio,
      '총차입금상환능력비율':Debt_to_Equity_Ratio
                    }

df = pd.DataFrame(financial_ratio)
df.set_index('아이디', inplace=True)

df
# Out:
# 자산총계: ['1000009595652'] 부채총계: ['494551588489'] 자본총계: ['505458007163'] 단기차입금: ['0'] 유동성장기부채: ['14091525310'] 사채: ['0'] 장기차입금: ['652168308'] 비유동자산: ['125031890415'] 비유동부채: ['44430248897'] 전기말 자산총계: ['877077934506'] 전기말 부채총계: ['483349683743'] 전기말 자본총계: ['393728250763'] 매출채권: ['199639071700', '47615580067'] 매입채무: ['248797738914', '0'] 재고자산: ['1029703100'] 당기순이익: ['53682216076'] 영업이익: ['69852035246'] 수익(매출액): ['424702163492'] 법인세비용차감전순이익(손실): ['70532844004'] 금융비용: ['144175854'] 전기 수익(매출액): ['304820704535'] 전기 영업이익: ['35771057795'] 영업활동으로 인한 현금흐름: ['61442410071']
# 자산총계: ['957664183878'] 부채총계: ['415746186683'] 자본총계: ['541917997195'] 단기차입금: ['0'] 유동성장기부채: ['14091525310'] 사채: ['0'] 장기차입금: ['623160519'] 비유동자산: ['130187766002'] 비유동부채: ['45429974956'] 전기말 자산총계: ['915263540756'] 전기말 부채총계: ['486669631554'] 전기말 자본총계: ['428593909202'] 매출채권: ['184185753170', '53250180039'] 매입채무: ['187551152073', '0'] 재고자산: ['776334896'] 당기순이익: ['36248937249'] 영업이익: ['46259689944'] 수익(매출액): ['340777960291'] 법인세비용차감전순이익(손실): ['49005645802'] 금융비용: ['142938449'] 전기 수익(매출액): ['357053034948'] 전기 영업이익: ['45743849037'] 영업활동으로 인한 현금흐름: ['90747097526']
# 자산총계: ['1552567019383'] 부채총계: ['762147442384'] 자본총계: ['790419576999'] 단기차입금: ['0'] 유동성장기부채: ['26035060270'] 사채: ['0'] 장기차입금: ['143855121682'] 비유동자산: ['413067206241'] 비유동부채: ['239997280194'] 전기말 자산총계: ['877701738364'] 전기말 부채총계: ['421385689298'] 전기말 자본총계: ['456316049066'] 매출채권: ['242109991781', '176105489382'] 매입채무: ['253583167871', '236500000'] 재고자산: ['41245893443'] 당기순이익: ['43635449456'] 영업이익: ['53099564207'] 수익(매출액): ['460162956615'] 법인세비용차감전순이익(손실): ['50190232877'] 금융비용: ['2275635454'] 전기 수익(매출액): ['315060376903'] 전기 영업이익: ['33350501050'] 영업활동으로 인한 현금흐름: ['78380549643']
# 자산총계: ['1498377650002'] 부채총계: ['696525414351'] 자본총계: ['801852235651'] 단기차입금: ['0'] 유동성장기부채: ['97060270'] 사채: ['0'] 장기차입금: ['99820412460'] 비유동자산: ['393777057782'] 비유동부채: ['151495814604'] 전기말 자산총계: ['851719906629'] 전기말 부채총계: ['393877294304'] 전기말 자본총계: ['457842612325'] 매출채권: ['205386631863', '172679715987'] 매입채무: ['326892838003', '245500000'] 재고자산: ['41401597358'] 당기순이익: ['149320163315'] 영업이익: ['203361674104'] 수익(매출액): ['1734637383766'] 법인세비용차감전순이익(손실): ['193199195091'] 금융비용: ['9923034566'] 전기 수익(매출액): ['1279913145407'] 전기 영업이익: ['142966582933'] 영업활동으로 인한 현금흐름: ['159132451621']
# 자산총계: ['1579407266079'] 부채총계: ['741496354658'] 자본총계: ['837910911421'] 단기차입금: ['0'] 유동성장기부채: ['26397060270'] 사채: ['0'] 장기차입금: ['99820412460'] 비유동자산: ['410478683805'] 비유동부채: ['160400711774'] 전기말 자산총계: ['1000009595652'] 전기말 부채총계: ['494551588489'] 전기말 자본총계: ['505458007163'] 매출채권: ['177417778679', '195423195010'] 매입채무: ['327790018570', '245500000'] 재고자산: ['42378069084'] 당기순이익: ['54216344885'] 영업이익: ['62992151049'] 수익(매출액): ['417488989253'] 법인세비용차감전순이익(손실): ['70245109359'] 금융비용: ['1038583373'] 전기 수익(매출액): ['424702163492'] 전기 영업이익: ['69852035246'] 영업활동으로 인한 현금흐름: ['34705649753']
# 자산총계: ['1539369190814'] 부채총계: ['665163491888'] 자본총계: ['874205698926'] 단기차입금: ['0'] 유동성장기부채: ['26397060270'] 사채: ['0'] 장기차입금: ['99788887150'] 비유동자산: ['381354195298'] 비유동부채: ['159297786960'] 전기말 자산총계: ['957664183878'] 전기말 부채총계: ['415746186683'] 전기말 자본총계: ['541917997195'] 매출채권: ['219480464006', '170561523515'] 매입채무: ['271863734079', '245500000'] 재고자산: ['40190958872'] 당기순이익: ['36310183035'] 영업이익: ['53906213214'] 수익(매출액): ['493861372604'] 법인세비용차감전순이익(손실): ['45764681599'] 금융비용: ['1042093128'] 전기 수익(매출액): ['340777960291'] 전기 영업이익: ['46259689944'] 영업활동으로 인한 현금흐름: ['-1611385129']
# 자산총계: ['1516733695698'] 부채총계: ['604535526716'] 자본총계: ['912198168982'] 단기차입금: ['0'] 유동성장기부채: ['26397060270'] 사채: ['0'] 장기차입금: ['113235999395'] 비유동자산: ['390550364445'] 비유동부채: ['165059566701'] 전기말 자산총계: ['1552567019383'] 전기말 부채총계: ['762147442384'] 전기말 자본총계: ['790419576999'] 매출채권: ['250503263853', '181017126268'] 매입채무: ['234744999297', '245500000'] 재고자산: ['38643700292'] 당기순이익: ['38012339219'] 영업이익: ['53101983737'] 수익(매출액): ['464777328419'] 법인세비용차감전순이익(손실): ['52015073078'] 금융비용: ['5671168158'] 전기 수익(매출액): ['460162956615'] 전기 영업이익: ['53099564207'] 영업활동으로 인한 현금흐름: ['-57210420019']
# 자산총계: ['1669601207042'] 부채총계: ['711709962529'] 자본총계: ['957891244513'] 단기차입금: ['0'] 유동성장기부채: ['26397060270'] 사채: ['0'] 장기차입금: ['113235999395'] 비유동자산: ['428642452464'] 비유동부채: ['162763605443'] 전기말 자산총계: ['1498377650002'] 전기말 부채총계: ['696525414351'] 전기말 자본총계: ['801852235651'] 매출채권: ['269474784295', '214118542621'] 매입채무: ['371642591838', '245500000'] 재고자산: ['38067887570'] 당기순이익: ['175561248492'] 영업이익: ['229634333122'] 수익(매출액): ['2010344322791'] 법인세비용차감전순이익(손실): ['225095942688'] 금융비용: ['8821913008'] 전기 수익(매출액): ['1734637383766'] 전기 영업이익: ['203361674104'] 영업활동으로 인한 현금흐름: ['80350190260']
# 자산총계: ['1573761691856'] 부채총계: ['628330759043'] 자본총계: ['945430932813'] 단기차입금: ['0'] 유동성장기부채: ['26397060270'] 사채: ['0'] 장기차입금: ['113511671459'] 비유동자산: ['417849304052'] 비유동부채: ['159957397006'] 전기말 자산총계: ['1579407266079'] 전기말 부채총계: ['741496354658'] 전기말 자본총계: ['837910911421'] 매출채권: ['232801119742', '206803919083'] 매입채무: ['279693036406', '245500000'] 재고자산: ['37812373946'] 당기순이익: ['5672691546'] 영업이익: ['3919721158'] 수익(매출액): ['333264733985'] 법인세비용차감전순이익(손실): ['9130783286'] 금융비용: ['1405348232'] 전기 수익(매출액): ['417488989253'] 전기 영업이익: ['62992151049'] 영업활동으로 인한 현금흐름: ['-79203037666']
# 자산총계: ['1615844461611'] 부채총계: ['652610899616'] 자본총계: ['963233561995'] 단기차입금: ['0'] 유동성장기부채: ['26397060270'] 사채: ['0'] 장기차입금: ['156118096449'] 비유동자산: ['406478091488'] 비유동부채: ['203117218927'] 전기말 자산총계: ['1539369190814'] 전기말 부채총계: ['665163491888'] 전기말 자본총계: ['874205698926'] 매출채권: ['374792163338', '197553456873'] 매입채무: ['247066202029', '235500000'] 재고자산: ['37662895143'] 당기순이익: ['17917705977'] 영업이익: ['27552754752'] 수익(매출액): ['465981429200'] 법인세비용차감전순이익(손실): ['24246459258'] 금융비용: ['1584712880'] 전기 수익(매출액): ['493861372604'] 전기 영업이익: ['53906213214'] 영업활동으로 인한 현금흐름: ['-155492126040']
# 자산총계: ['1632426292969'] 부채총계: ['655026292981'] 자본총계: ['977399999988'] 단기차입금: ['0'] 유동성장기부채: ['71552082858'] 사채: ['0'] 장기차입금: ['122092592759'] 비유동자산: ['407310009604'] 비유동부채: ['171318553794'] 전기말 자산총계: ['1516733695698'] 전기말 부채총계: ['604535526716'] 전기말 자본총계: ['912198168982'] 매출채권: ['278148037423', '193338382523'] 매입채무: ['233957739296', '235500000'] 재고자산: ['37415583687'] 당기순이익: ['14210691675'] 영업이익: ['19494610622'] 수익(매출액): ['467086055937'] 법인세비용차감전순이익(손실): ['18866983654'] 금융비용: ['1588062609'] 전기 수익(매출액): ['464777328419'] 전기 영업이익: ['53101983737'] 영업활동으로 인한 현금흐름: ['-79708885024']
# 자산총계: ['1746816807975'] 부채총계: ['748120988544'] 자본총계: ['998695819431'] 단기차입금: ['0'] 유동성장기부채: ['71599327211'] 사채: ['0'] 장기차입금: ['122680489825'] 비유동자산: ['394878261606'] 비유동부채: ['149211271804'] 전기말 자산총계: ['1669601207042'] 전기말 부채총계: ['711709962529'] 전기말 자본총계: ['957891244513'] 매출채권: ['271685608158', '189204860928'] 매입채무: ['371292107203', '245500000'] 재고자산: ['37135177957'] 당기순이익: ['55421181166'] 영업이익: ['81072831792'] 수익(매출액): ['1962419334798'] 법인세비용차감전순이익(손실): ['84339671528'] 금융비용: ['6173894598'] 전기 수익(매출액): ['2010344322791'] 전기 영업이익: ['229634333122'] 영업활동으로 인한 현금흐름: ['27723899537']
#                기업명    연도  보고서 코드       부채비율     차입금의존도    고정장기적합률  자기자본순이익률  \
# 아이디
# 001880202001  DL건설  2020  1분기보고서  97.842270   1.474355  22.737691  0.119402
# 001880202002  DL건설  2020   반기보고서  76.717546   1.536518  22.165355  0.074701
# 001880202003  DL건설  2020  3분기보고서  96.423148  10.942535  40.087388  0.070000
# 001880202004  DL건설  2020   사업보고서  86.864560   6.668377  41.304648  0.237074
# 001880202101  DL건설  2021  1분기보고서  88.493460   7.991446  41.117290  0.080717
# 001880202102  DL건설  2021   반기보고서  76.087755   8.197250  36.899169  0.051281
# 001880202103  DL건설  2021  3분기보고서  66.272390   9.206168  36.254125  0.044652
# 001880202104  DL건설  2021   사업보고서  74.299663   8.363258  38.249284  0.199531
# 001880202201  DL건설  2022  1분기보고서  66.459721   8.890084  37.801132  0.006362
# 001880202202  DL건설  2022   반기보고서  67.752093  11.295342  34.850415  0.019503
# 001880202203  DL건설  2022  3분기보고서  67.017218  11.862384  35.457772  0.015041
# 001880202204  DL건설  2022   사업보고서  74.909795  11.121934  34.399845  0.056651
#
#               매출액영업이익률  매출액경상이익률   이자보상배율(배)   매출액 증가율   총자산 증가율  영업이익 증가율  \
# 아이디
# 001880202001  0.164473  0.166076  484.491913  0.393285  0.140160  0.952753
# 001880202002  0.135747  0.143805  323.633636 -0.045582  0.046326  0.011277
# 001880202003  0.115393  0.109071   23.333950  0.460555  0.768900  0.592167
# 001880202004  0.117236  0.111377   20.493900  0.355277  0.759238  0.422442
# 001880202101  0.150883  0.168256   60.651993 -0.016984  0.579392 -0.098206
# 001880202102  0.109153  0.092667   51.728787  0.449217  0.607421  0.165296
# 001880202103  0.114253  0.111914    9.363500  0.010028 -0.023080  0.000046
# 001880202104  0.114226  0.111969   26.029993  0.158942  0.114273  0.129192
# 001880202201  0.011762  0.027398    2.789146 -0.201740 -0.003574 -0.937774
# 001880202202  0.059128  0.052033   17.386591 -0.056453  0.049680 -0.488876
# 001880202203  0.041737  0.040393   12.275719  0.004967  0.076277 -0.632884
# 001880202204  0.041313  0.042977   13.131554 -0.023839  0.046248 -0.646948
#
#               자기자본 증가율  매출채권 회전기일(일)  재고자산 회전기일(일)  매입채무 회전기일(일)   총자산 회전율  \
# 아이디
# 001880202001  0.283774      0.283774     42.776226     53.309345  0.424698
# 001880202002  0.264409      0.264409     98.368472    100.165837  0.355843
# 001880202003  0.732176      0.732176    144.162273    150.993875  0.296388
# 001880202004  0.751371      0.751371     43.335574     68.972789  1.157677
# 001880202101  0.657726      0.657726     38.246757     70.663185  0.264333
# 001880202102  0.613170      0.613170     80.439504     99.637952  0.320821
# 001880202103  0.154068      0.154068    147.140118    137.884060  0.306433
# 001880202104  0.194598      0.194598     48.926094     67.475777  1.204087
# 001880202201  0.128319      0.128319     62.869241     75.532664  0.211763
# 001880202202  0.101839      0.101839    145.579582     95.967306  0.288383
# 001880202203  0.071478      0.071478    162.570501    136.742388  0.286130
# 001880202204  0.042598      0.042598     50.532139     69.058441  1.123426
#
#               부채상환계수(배)  총차입금상환능력비율
# 아이디
# 001880202001   4.326207    4.167369
# 001880202002   6.385210    6.167111
# 001880202003   2.848965    0.461360
# 001880202004  16.871645    1.592639
# 001880202101   1.302839    0.274967
# 001880202102  -0.020747   -0.012770
# 001880202103  -1.607175   -0.409720
# 001880202104   2.531934    0.575438
# 001880202201  -2.798236   -0.566105
# 001880202202  -5.500274   -0.851941
# 001880202203  -1.068098   -0.411624
# 001880202204   0.435854    0.142701

# %%
df.to_csv(f'/content/drive/MyDrive/ICR/재무비율/{corp_name_p}_재무비율.csv')

# %% [markdown]
# ### 진흥기업

# %%
corp_name = ['DL이앤씨', 'HDC현대산업개발', '한전KPS', 'HJ중공업', '신세계건설', 'KCC건설', '대우건설', '서희건설', '특수건설', '계룡건설산업', '신원종합개발',
             '서한', '태영건설', '현대건설', 'GS건설', '동부건설', '코오롱글로벌', 'DL건설', '진흥기업', '남광토건', '한신공영', '금호건설', '삼부토건']
corp_code = ['375500', '294870', '051600', '097230', '034300', '021320', '047040', '035890', '026150', '013580', '017000',
             '011370', '009410', '000720', '006360', '005960', '003070', '001880', '002780', '001260', '004960', '002990', '001470']
report_code = ["11013", "11012", "11014", "11011"] # '11013'=1분기보고서, '11012'=반기보고서, '11014'=3분기보고서, '11011'=사업보고서

corp_name_p = corp_name[18]
corp_code_p = corp_code[18]

all = pd.DataFrame()

for year in range(2019, 2023):
  for code in report_code:
    corp = dart.finstate_all(corp_code_p, year, code, fs_div="OFS")
    # corp = corp.drop('account_id', axis=1)
    all = pd.concat([all, corp], ignore_index=True) # 2019년~2022년 별도 재무제표 전문(분기보고서+반기보고서+사업보고서)

all
# Out:
# reprt_code='11013', fs_div='OFS' (1분기보고서, 별도(개별)제무제표)'
# reprt_code='11012', fs_div='OFS' (반기보고서, 별도(개별)제무제표)'
# reprt_code='11014', fs_div='OFS' (3분기보고서, 별도(개별)제무제표)'
# reprt_code='11011', fs_div='OFS' (사업보고서, 별도(개별)제무제표)'
# reprt_code='11013', fs_div='OFS' (1분기보고서, 별도(개별)제무제표)'
# reprt_code='11012', fs_div='OFS' (반기보고서, 별도(개별)제무제표)'
# reprt_code='11014', fs_div='OFS' (3분기보고서, 별도(개별)제무제표)'
# reprt_code='11011', fs_div='OFS' (사업보고서, 별도(개별)제무제표)'
# reprt_code='11013', fs_div='OFS' (1분기보고서, 별도(개별)제무제표)'
# reprt_code='11012', fs_div='OFS' (반기보고서, 별도(개별)제무제표)'
# reprt_code='11014', fs_div='OFS' (3분기보고서, 별도(개별)제무제표)'
# reprt_code='11011', fs_div='OFS' (사업보고서, 별도(개별)제무제표)'
# reprt_code='11013', fs_div='OFS' (1분기보고서, 별도(개별)제무제표)'
# reprt_code='11012', fs_div='OFS' (반기보고서, 별도(개별)제무제표)'
# reprt_code='11014', fs_div='OFS' (3분기보고서, 별도(개별)제무제표)'
# reprt_code='11011', fs_div='OFS' (사업보고서, 별도(개별)제무제표)'
#             rcept_no reprt_code bsns_year corp_code sj_div    sj_nm  \
# 0     20190510000753      11013      2019  00150828     BS    재무상태표
# 1     20190510000753      11013      2019  00150828     BS    재무상태표
# 2     20190510000753      11013      2019  00150828     BS    재무상태표
# 3     20190510000753      11013      2019  00150828     BS    재무상태표
# 4     20190510000753      11013      2019  00150828     BS    재무상태표
# 5     20190510000753      11013      2019  00150828     BS    재무상태표
# 6     20190510000753      11013      2019  00150828     BS    재무상태표
# 7     20190510000753      11013      2019  00150828     BS    재무상태표
# 8     20190510000753      11013      2019  00150828     BS    재무상태표
# 9     20190510000753      11013      2019  00150828     BS    재무상태표
# 10    20190510000753      11013      2019  00150828     BS    재무상태표
# 11    20190510000753      11013      2019  00150828     BS    재무상태표
# 12    20190510000753      11013      2019  00150828     BS    재무상태표
# 13    20190510000753      11013      2019  00150828     BS    재무상태표
# 14    20190510000753      11013      2019  00150828     BS    재무상태표
# 15    20190510000753      11013      2019  00150828     BS    재무상태표
# 16    20190510000753      11013      2019  00150828     BS    재무상태표
# 17    20190510000753      11013      2019  00150828     BS    재무상태표
# 18    20190510000753      11013      2019  00150828     BS    재무상태표
# 19    20190510000753      11013      2019  00150828     BS    재무상태표
# 20    20190510000753      11013      2019  00150828     BS    재무상태표
# 21    20190510000753      11013      2019  00150828     BS    재무상태표
# 22    20190510000753      11013      2019  00150828     BS    재무상태표
# 23    20190510000753      11013      2019  00150828     BS    재무상태표
# 24    20190510000753      11013      2019  00150828     BS    재무상태표
# 25    20190510000753      11013      2019  00150828     BS    재무상태표
# 26    20190510000753      11013      2019  00150828     BS    재무상태표
# 27    20190510000753      11013      2019  00150828     BS    재무상태표
# 28    20190510000753      11013      2019  00150828     BS    재무상태표
# 29    20190510000753      11013      2019  00150828     BS    재무상태표
# 30    20190510000753      11013      2019  00150828     BS    재무상태표
# 31    20190510000753      11013      2019  00150828     BS    재무상태표
# 32    20190510000753      11013      2019  00150828     BS    재무상태표
# 33    20190510000753      11013      2019  00150828     BS    재무상태표
# 34    20190510000753      11013      2019  00150828     IS    손익계산서
# 35    20190510000753      11013      2019  00150828     IS    손익계산서
# 36    20190510000753      11013      2019  00150828     IS    손익계산서
# 37    20190510000753      11013      2019  00150828     IS    손익계산서
# 38    20190510000753      11013      2019  00150828     IS    손익계산서
# 39    20190510000753      11013      2019  00150828     IS    손익계산서
# 40    20190510000753      11013      2019  00150828     IS    손익계산서
# 41    20190510000753      11013      2019  00150828     IS    손익계산서
# 42    20190510000753      11013      2019  00150828     IS    손익계산서
# 43    20190510000753      11013      2019  00150828     IS    손익계산서
# 44    20190510000753      11013      2019  00150828     IS    손익계산서
# 45    20190510000753      11013      2019  00150828     IS    손익계산서
# 46    20190510000753      11013      2019  00150828     IS    손익계산서
# 47    20190510000753      11013      2019  00150828    CIS  포괄손익계산서
# 48    20190510000753      11013      2019  00150828    CIS  포괄손익계산서
# 49    20190510000753      11013      2019  00150828    CIS  포괄손익계산서
# 50    20190510000753      11013      2019  00150828    CIS  포괄손익계산서
# 51    20190510000753      11013      2019  00150828    CIS  포괄손익계산서
# 52    20190510000753      11013      2019  00150828    CIS  포괄손익계산서
# 53    20190510000753      11013      2019  00150828     CF    현금흐름표
# 54    20190510000753      11013      2019  00150828     CF    현금흐름표
# 55    20190510000753      11013      2019  00150828     CF    현금흐름표
# 56    20190510000753      11013      2019  00150828     CF    현금흐름표
# 57    20190510000753      11013      2019  00150828     CF    현금흐름표
# 58    20190510000753      11013      2019  00150828     CF    현금흐름표
# 59    20190510000753      11013      2019  00150828     CF    현금흐름표
# 60    20190510000753      11013      2019  00150828     CF    현금흐름표
# 61    20190510000753      11013      2019  00150828     CF    현금흐름표
# 62    20190510000753      11013      2019  00150828     CF    현금흐름표
# 63    20190510000753      11013      2019  00150828     CF    현금흐름표
# 64    20190510000753      11013      2019  00150828     CF    현금흐름표
# 65    20190510000753      11013      2019  00150828     CF    현금흐름표
# 66    20190510000753      11013      2019  00150828     CF    현금흐름표
# 67    20190510000753      11013      2019  00150828     CF    현금흐름표
# 68    20190510000753      11013      2019  00150828     CF    현금흐름표
# 69    20190510000753      11013      2019  00150828     CF    현금흐름표
# 70    20190510000753      11013      2019  00150828     CF    현금흐름표
# 71    20190510000753      11013      2019  00150828     CF    현금흐름표
# 72    20190510000753      11013      2019  00150828     CF    현금흐름표
# 73    20190510000753      11013      2019  00150828     CF    현금흐름표
# 74    20190510000753      11013      2019  00150828     CF    현금흐름표
# 75    20190510000753      11013      2019  00150828     CF    현금흐름표
# 76    20190510000753      11013      2019  00150828     CF    현금흐름표
# 77    20190510000753      11013      2019  00150828     CF    현금흐름표
# 78    20190510000753      11013      2019  00150828    SCE    자본변동표
# 79    20190510000753      11013      2019  00150828    SCE    자본변동표
# 80    20190510000753      11013      2019  00150828    SCE    자본변동표
# 81    20190510000753      11013      2019  00150828    SCE    자본변동표
# 82    20190510000753      11013      2019  00150828    SCE    자본변동표
# 83    20190510000753      11013      2019  00150828    SCE    자본변동표
# 84    20190510000753      11013      2019  00150828    SCE    자본변동표
# 85    20190510000753      11013      2019  00150828    SCE    자본변동표
# 86    20190510000753      11013      2019  00150828    SCE    자본변동표
# 87    20190510000753      11013      2019  00150828    SCE    자본변동표
# 88    20190510000753      11013      2019  00150828    SCE    자본변동표
# 89    20190510000753      11013      2019  00150828    SCE    자본변동표
# 90    20190510000753      11013      2019  00150828    SCE    자본변동표
# 91    20190510000753      11013      2019  00150828    SCE    자본변동표
# 92    20190510000753      11013      2019  00150828    SCE    자본변동표
# 93    20190510000753      11013      2019  00150828    SCE    자본변동표
# 94    20190510000753      11013      2019  00150828    SCE    자본변동표
# 95    20190510000753      11013      2019  00150828    SCE    자본변동표
# 96    20190510000753      11013      2019  00150828    SCE    자본변동표
# 97    20190510000753      11013      2019  00150828    SCE    자본변동표
# 98    20190510000753      11013      2019  00150828    SCE    자본변동표
# 99    20190510000753      11013      2019  00150828    SCE    자본변동표
# 100   20190813000444      11012      2019  00150828     BS    재무상태표
# 101   20190813000444      11012      2019  00150828     BS    재무상태표
# 102   20190813000444      11012      2019  00150828     BS    재무상태표
# 103   20190813000444      11012      2019  00150828     BS    재무상태표
# 104   20190813000444      11012      2019  00150828     BS    재무상태표
# 105   20190813000444      11012      2019  00150828     BS    재무상태표
# 106   20190813000444      11012      2019  00150828     BS    재무상태표
# 107   20190813000444      11012      2019  00150828     BS    재무상태표
# 108   20190813000444      11012      2019  00150828     BS    재무상태표
# 109   20190813000444      11012      2019  00150828     BS    재무상태표
# 110   20190813000444      11012      2019  00150828     BS    재무상태표
# 111   20190813000444      11012      2019  00150828     BS    재무상태표
# 112   20190813000444      11012      2019  00150828     BS    재무상태표
# 113   20190813000444      11012      2019  00150828     BS    재무상태표
# 114   20190813000444      11012      2019  00150828     BS    재무상태표
# 115   20190813000444      11012      2019  00150828     BS    재무상태표
# 116   20190813000444      11012      2019  00150828     BS    재무상태표
# 117   20190813000444      11012      2019  00150828     BS    재무상태표
# 118   20190813000444      11012      2019  00150828     BS    재무상태표
# 119   20190813000444      11012      2019  00150828     BS    재무상태표
# 120   20190813000444      11012      2019  00150828     BS    재무상태표
# 121   20190813000444      11012      2019  00150828     BS    재무상태표
# 122   20190813000444      11012      2019  00150828     BS    재무상태표
# 123   20190813000444      11012      2019  00150828     BS    재무상태표
# 124   20190813000444      11012      2019  00150828     BS    재무상태표
# 125   20190813000444      11012      2019  00150828     BS    재무상태표
# 126   20190813000444      11012      2019  00150828     BS    재무상태표
# 127   20190813000444      11012      2019  00150828     BS    재무상태표
# 128   20190813000444      11012      2019  00150828     BS    재무상태표
# 129   20190813000444      11012      2019  00150828     BS    재무상태표
# 130   20190813000444      11012      2019  00150828     BS    재무상태표
# 131   20190813000444      11012      2019  00150828     BS    재무상태표
# 132   20190813000444      11012      2019  00150828     BS    재무상태표
# 133   20190813000444      11012      2019  00150828     BS    재무상태표
# 134   20190813000444      11012      2019  00150828     BS    재무상태표
# 135   20190813000444      11012      2019  00150828     BS    재무상태표
# 136   20190813000444      11012      2019  00150828     IS    손익계산서
# 137   20190813000444      11012      2019  00150828     IS    손익계산서
# 138   20190813000444      11012      2019  00150828     IS    손익계산서
# 139   20190813000444      11012      2019  00150828     IS    손익계산서
# 140   20190813000444      11012      2019  00150828     IS    손익계산서
# 141   20190813000444      11012      2019  00150828     IS    손익계산서
# 142   20190813000444      11012      2019  00150828     IS    손익계산서
# 143   20190813000444      11012      2019  00150828     IS    손익계산서
# 144   20190813000444      11012      2019  00150828     IS    손익계산서
# 145   20190813000444      11012      2019  00150828     IS    손익계산서
# 146   20190813000444      11012      2019  00150828     IS    손익계산서
# 147   20190813000444      11012      2019  00150828     IS    손익계산서
# 148   20190813000444      11012      2019  00150828     IS    손익계산서
# 149   20190813000444      11012      2019  00150828     IS    손익계산서
# 150   20190813000444      11012      2019  00150828    CIS  포괄손익계산서
# 151   20190813000444      11012      2019  00150828    CIS  포괄손익계산서
# 152   20190813000444      11012      2019  00150828    CIS  포괄손익계산서
# 153   20190813000444      11012      2019  00150828    CIS  포괄손익계산서
# 154   20190813000444      11012      2019  00150828    CIS  포괄손익계산서
# 155   20190813000444      11012      2019  00150828     CF    현금흐름표
# 156   20190813000444      11012      2019  00150828     CF    현금흐름표
# 157   20190813000444      11012      2019  00150828     CF    현금흐름표
# 158   20190813000444      11012      2019  00150828     CF    현금흐름표
# 159   20190813000444      11012      2019  00150828     CF    현금흐름표
# 160   20190813000444      11012      2019  00150828     CF    현금흐름표
# 161   20190813000444      11012      2019  00150828     CF    현금흐름표
# 162   20190813000444      11012      2019  00150828     CF    현금흐름표
# 163   20190813000444      11012      2019  00150828     CF    현금흐름표
# 164   20190813000444      11012      2019  00150828     CF    현금흐름표
# 165   20190813000444      11012      2019  00150828     CF    현금흐름표
# 166   20190813000444      11012      2019  00150828     CF    현금흐름표
# 167   20190813000444      11012      2019  00150828     CF    현금흐름표
# 168   20190813000444      11012      2019  00150828     CF    현금흐름표
# 169   20190813000444      11012      2019  00150828     CF    현금흐름표
# 170   20190813000444      11012      2019  00150828     CF    현금흐름표
# 171   20190813000444      11012      2019  00150828     CF    현금흐름표
# 172   20190813000444      11012      2019  00150828     CF    현금흐름표
# 173   20190813000444      11012      2019  00150828     CF    현금흐름표
# 174   20190813000444      11012      2019  00150828     CF    현금흐름표
# 175   20190813000444      11012      2019  00150828     CF    현금흐름표
# 176   20190813000444      11012      2019  00150828     CF    현금흐름표
# 177   20190813000444      11012      2019  00150828     CF    현금흐름표
# 178   20190813000444      11012      2019  00150828     CF    현금흐름표
# 179   20190813000444      11012      2019  00150828     CF    현금흐름표
# 180   20190813000444      11012      2019  00150828     CF    현금흐름표
# 181   20190813000444      11012      2019  00150828    SCE    자본변동표
# 182   20190813000444      11012      2019  00150828    SCE    자본변동표
# 183   20190813000444      11012      2019  00150828    SCE    자본변동표
# 184   20190813000444      11012      2019  00150828    SCE    자본변동표
# 185   20190813000444      11012      2019  00150828    SCE    자본변동표
# 186   20190813000444      11012      2019  00150828    SCE    자본변동표
# 187   20190813000444      11012      2019  00150828    SCE    자본변동표
# 188   20190813000444      11012      2019  00150828    SCE    자본변동표
# 189   20190813000444      11012      2019  00150828    SCE    자본변동표
# 190   20190813000444      11012      2019  00150828    SCE    자본변동표
# 191   20190813000444      11012      2019  00150828    SCE    자본변동표
# 192   20190813000444      11012      2019  00150828    SCE    자본변동표
# 193   20190813000444      11012      2019  00150828    SCE    자본변동표
# 194   20190813000444      11012      2019  00150828    SCE    자본변동표
# 195   20190813000444      11012      2019  00150828    SCE    자본변동표
# 196   20190813000444      11012      2019  00150828    SCE    자본변동표
# 197   20190813000444      11012      2019  00150828    SCE    자본변동표
# 198   20190813000444      11012      2019  00150828    SCE    자본변동표
# 199   20190813000444      11012      2019  00150828    SCE    자본변동표
# 200   20190813000444      11012      2019  00150828    SCE    자본변동표
# 201   20190813000444      11012      2019  00150828    SCE    자본변동표
# 202   20190813000444      11012      2019  00150828    SCE    자본변동표
# 203   20190813000444      11012      2019  00150828    SCE    자본변동표
# 204   20190813000444      11012      2019  00150828    SCE    자본변동표
# 205   20191114002028      11014      2019  00150828     BS    재무상태표
# 206   20191114002028      11014      2019  00150828     BS    재무상태표
# 207   20191114002028      11014      2019  00150828     BS    재무상태표
# 208   20191114002028      11014      2019  00150828     BS    재무상태표
# 209   20191114002028      11014      2019  00150828     BS    재무상태표
# 210   20191114002028      11014      2019  00150828     BS    재무상태표
# 211   20191114002028      11014      2019  00150828     BS    재무상태표
# 212   20191114002028      11014      2019  00150828     BS    재무상태표
# 213   20191114002028      11014      2019  00150828     BS    재무상태표
# 214   20191114002028      11014      2019  00150828     BS    재무상태표
# 215   20191114002028      11014      2019  00150828     BS    재무상태표
# 216   20191114002028      11014      2019  00150828     BS    재무상태표
# 217   20191114002028      11014      2019  00150828     BS    재무상태표
# 218   20191114002028      11014      2019  00150828     BS    재무상태표
# 219   20191114002028      11014      2019  00150828     BS    재무상태표
# 220   20191114002028      11014      2019  00150828     BS    재무상태표
# 221   20191114002028      11014      2019  00150828     BS    재무상태표
# 222   20191114002028      11014      2019  00150828     BS    재무상태표
# 223   20191114002028      11014      2019  00150828     BS    재무상태표
# 224   20191114002028      11014      2019  00150828     BS    재무상태표
# 225   20191114002028      11014      2019  00150828     BS    재무상태표
# 226   20191114002028      11014      2019  00150828     BS    재무상태표
# 227   20191114002028      11014      2019  00150828     BS    재무상태표
# 228   20191114002028      11014      2019  00150828     BS    재무상태표
# 229   20191114002028      11014      2019  00150828     BS    재무상태표
# 230   20191114002028      11014      2019  00150828     BS    재무상태표
# 231   20191114002028      11014      2019  00150828     BS    재무상태표
# 232   20191114002028      11014      2019  00150828     BS    재무상태표
# 233   20191114002028      11014      2019  00150828     BS    재무상태표
# 234   20191114002028      11014      2019  00150828     BS    재무상태표
# 235   20191114002028      11014      2019  00150828     BS    재무상태표
# 236   20191114002028      11014      2019  00150828     BS    재무상태표
# 237   20191114002028      11014      2019  00150828     BS    재무상태표
# 238   20191114002028      11014      2019  00150828     BS    재무상태표
# 239   20191114002028      11014      2019  00150828     BS    재무상태표
# 240   20191114002028      11014      2019  00150828     BS    재무상태표
# 241   20191114002028      11014      2019  00150828     IS    손익계산서
# 242   20191114002028      11014      2019  00150828     IS    손익계산서
# 243   20191114002028      11014      2019  00150828     IS    손익계산서
# 244   20191114002028      11014      2019  00150828     IS    손익계산서
# 245   20191114002028      11014      2019  00150828     IS    손익계산서
# 246   20191114002028      11014      2019  00150828     IS    손익계산서
# 247   20191114002028      11014      2019  00150828     IS    손익계산서
# 248   20191114002028      11014      2019  00150828     IS    손익계산서
# 249   20191114002028      11014      2019  00150828     IS    손익계산서
# 250   20191114002028      11014      2019  00150828     IS    손익계산서
# 251   20191114002028      11014      2019  00150828     IS    손익계산서
# 252   20191114002028      11014      2019  00150828     IS    손익계산서
# 253   20191114002028      11014      2019  00150828     IS    손익계산서
# 254   20191114002028      11014      2019  00150828     IS    손익계산서
# 255   20191114002028      11014      2019  00150828    CIS  포괄손익계산서
# 256   20191114002028      11014      2019  00150828    CIS  포괄손익계산서
# 257   20191114002028      11014      2019  00150828    CIS  포괄손익계산서
# 258   20191114002028      11014      2019  00150828    CIS  포괄손익계산서
# 259   20191114002028      11014      2019  00150828    CIS  포괄손익계산서
# 260   20191114002028      11014      2019  00150828     CF    현금흐름표
# 261   20191114002028      11014      2019  00150828     CF    현금흐름표
# 262   20191114002028      11014      2019  00150828     CF    현금흐름표
# 263   20191114002028      11014      2019  00150828     CF    현금흐름표
# 264   20191114002028      11014      2019  00150828     CF    현금흐름표
# 265   20191114002028      11014      2019  00150828     CF    현금흐름표
# 266   20191114002028      11014      2019  00150828     CF    현금흐름표
# 267   20191114002028      11014      2019  00150828     CF    현금흐름표
# 268   20191114002028      11014      2019  00150828     CF    현금흐름표
# 269   20191114002028      11014      2019  00150828     CF    현금흐름표
# 270   20191114002028      11014      2019  00150828     CF    현금흐름표
# 271   20191114002028      11014      2019  00150828     CF    현금흐름표
# 272   20191114002028      11014      2019  00150828     CF    현금흐름표
# 273   20191114002028      11014      2019  00150828     CF    현금흐름표
# 274   20191114002028      11014      2019  00150828     CF    현금흐름표
# 275   20191114002028      11014      2019  00150828     CF    현금흐름표
# 276   20191114002028      11014      2019  00150828     CF    현금흐름표
# 277   20191114002028      11014      2019  00150828     CF    현금흐름표
# 278   20191114002028      11014      2019  00150828     CF    현금흐름표
# 279   20191114002028      11014      2019  00150828     CF    현금흐름표
# 280   20191114002028      11014      2019  00150828     CF    현금흐름표
# 281   20191114002028      11014      2019  00150828     CF    현금흐름표
# 282   20191114002028      11014      2019  00150828     CF    현금흐름표
# 283   20191114002028      11014      2019  00150828     CF    현금흐름표
# 284   20191114002028      11014      2019  00150828     CF    현금흐름표
# 285   20191114002028      11014      2019  00150828     CF    현금흐름표
# 286   20191114002028      11014      2019  00150828     CF    현금흐름표
# 287   20191114002028      11014      2019  00150828     CF    현금흐름표
# 288   20191114002028      11014      2019  00150828    SCE    자본변동표
# 289   20191114002028      11014      2019  00150828    SCE    자본변동표
# 290   20191114002028      11014      2019  00150828    SCE    자본변동표
# 291   20191114002028      11014      2019  00150828    SCE    자본변동표
# 292   20191114002028      11014      2019  00150828    SCE    자본변동표
# 293   20191114002028      11014      2019  00150828    SCE    자본변동표
# 294   20191114002028      11014      2019  00150828    SCE    자본변동표
# 295   20191114002028      11014      2019  00150828    SCE    자본변동표
# 296   20191114002028      11014      2019  00150828    SCE    자본변동표
# 297   20191114002028      11014      2019  00150828    SCE    자본변동표
# 298   20191114002028      11014      2019  00150828    SCE    자본변동표
# 299   20191114002028      11014      2019  00150828    SCE    자본변동표
# 300   20191114002028      11014      2019  00150828    SCE    자본변동표
# 301   20191114002028      11014      2019  00150828    SCE    자본변동표
# 302   20191114002028      11014      2019  00150828    SCE    자본변동표
# 303   20191114002028      11014      2019  00150828    SCE    자본변동표
# 304   20191114002028      11014      2019  00150828    SCE    자본변동표
# 305   20191114002028      11014      2019  00150828    SCE    자본변동표
# 306   20191114002028      11014      2019  00150828    SCE    자본변동표
# 307   20191114002028      11014      2019  00150828    SCE    자본변동표
# 308   20191114002028      11014      2019  00150828    SCE    자본변동표
# 309   20191114002028      11014      2019  00150828    SCE    자본변동표
# 310   20191114002028      11014      2019  00150828    SCE    자본변동표
# 311   20191114002028      11014      2019  00150828    SCE    자본변동표
# 312   20191114002028      11014      2019  00150828    SCE    자본변동표
# 313   20191114002028      11014      2019  00150828    SCE    자본변동표
# 314   20200330004077      11011      2019  00150828     BS    재무상태표
# 315   20200330004077      11011      2019  00150828     BS    재무상태표
# 316   20200330004077      11011      2019  00150828     BS    재무상태표
# 317   20200330004077      11011      2019  00150828     BS    재무상태표
# 318   20200330004077      11011      2019  00150828     BS    재무상태표
# 319   20200330004077      11011      2019  00150828     BS    재무상태표
# 320   20200330004077      11011      2019  00150828     BS    재무상태표
# 321   20200330004077      11011      2019  00150828     BS    재무상태표
# 322   20200330004077      11011      2019  00150828     BS    재무상태표
# 323   20200330004077      11011      2019  00150828     BS    재무상태표
# 324   20200330004077      11011      2019  00150828     BS    재무상태표
# 325   20200330004077      11011      2019  00150828     BS    재무상태표
# 326   20200330004077      11011      2019  00150828     BS    재무상태표
# 327   20200330004077      11011      2019  00150828     BS    재무상태표
# 328   20200330004077      11011      2019  00150828     BS    재무상태표
# 329   20200330004077      11011      2019  00150828     BS    재무상태표
# 330   20200330004077      11011      2019  00150828     BS    재무상태표
# 331   20200330004077      11011      2019  00150828     BS    재무상태표
# 332   20200330004077      11011      2019  00150828     BS    재무상태표
# 333   20200330004077      11011      2019  00150828     BS    재무상태표
# 334   20200330004077      11011      2019  00150828     BS    재무상태표
# 335   20200330004077      11011      2019  00150828     BS    재무상태표
# 336   20200330004077      11011      2019  00150828     BS    재무상태표
# 337   20200330004077      11011      2019  00150828     BS    재무상태표
# 338   20200330004077      11011      2019  00150828     BS    재무상태표
# 339   20200330004077      11011      2019  00150828     BS    재무상태표
# 340   20200330004077      11011      2019  00150828     BS    재무상태표
# 341   20200330004077      11011      2019  00150828     BS    재무상태표
# 342   20200330004077      11011      2019  00150828     BS    재무상태표
# 343   20200330004077      11011      2019  00150828     BS    재무상태표
# 344   20200330004077      11011      2019  00150828     BS    재무상태표
# 345   20200330004077      11011      2019  00150828     BS    재무상태표
# 346   20200330004077      11011      2019  00150828     BS    재무상태표
# 347   20200330004077      11011      2019  00150828     BS    재무상태표
# 348   20200330004077      11011      2019  00150828     BS    재무상태표
# 349   20200330004077      11011      2019  00150828     BS    재무상태표
# 350   20200330004077      11011      2019  00150828     BS    재무상태표
# 351   20200330004077      11011      2019  00150828     BS    재무상태표
# 352   20200330004077      11011      2019  00150828     IS    손익계산서
# 353   20200330004077      11011      2019  00150828     IS    손익계산서
# 354   20200330004077      11011      2019  00150828     IS    손익계산서
# 355   20200330004077      11011      2019  00150828     IS    손익계산서
# 356   20200330004077      11011      2019  00150828     IS    손익계산서
# 357   20200330004077      11011      2019  00150828     IS    손익계산서
# 358   20200330004077      11011      2019  00150828     IS    손익계산서
# 359   20200330004077      11011      2019  00150828     IS    손익계산서
# 360   20200330004077      11011      2019  00150828     IS    손익계산서
# 361   20200330004077      11011      2019  00150828     IS    손익계산서
# 362   20200330004077      11011      2019  00150828     IS    손익계산서
# 363   20200330004077      11011      2019  00150828     IS    손익계산서
# 364   20200330004077      11011      2019  00150828     IS    손익계산서
# 365   20200330004077      11011      2019  00150828     IS    손익계산서
# 366   20200330004077      11011      2019  00150828    CIS  포괄손익계산서
# 367   20200330004077      11011      2019  00150828    CIS  포괄손익계산서
# 368   20200330004077      11011      2019  00150828    CIS  포괄손익계산서
# 369   20200330004077      11011      2019  00150828    CIS  포괄손익계산서
# 370   20200330004077      11011      2019  00150828    CIS  포괄손익계산서
# 371   20200330004077      11011      2019  00150828    CIS  포괄손익계산서
# 372   20200330004077      11011      2019  00150828    CIS  포괄손익계산서
# 373   20200330004077      11011      2019  00150828     CF    현금흐름표
# 374   20200330004077      11011      2019  00150828     CF    현금흐름표
# 375   20200330004077      11011      2019  00150828     CF    현금흐름표
# 376   20200330004077      11011      2019  00150828     CF    현금흐름표
# 377   20200330004077      11011      2019  00150828     CF    현금흐름표
# 378   20200330004077      11011      2019  00150828     CF    현금흐름표
# 379   20200330004077      11011      2019  00150828     CF    현금흐름표
# 380   20200330004077      11011      2019  00150828     CF    현금흐름표
# 381   20200330004077      11011      2019  00150828     CF    현금흐름표
# 382   20200330004077      11011      2019  00150828     CF    현금흐름표
# 383   20200330004077      11011      2019  00150828     CF    현금흐름표
# 384   20200330004077      11011      2019  00150828     CF    현금흐름표
# 385   20200330004077      11011      2019  00150828     CF    현금흐름표
# 386   20200330004077      11011      2019  00150828     CF    현금흐름표
# 387   20200330004077      11011      2019  00150828     CF    현금흐름표
# 388   20200330004077      11011      2019  00150828     CF    현금흐름표
# 389   20200330004077      11011      2019  00150828     CF    현금흐름표
# 390   20200330004077      11011      2019  00150828     CF    현금흐름표
# 391   20200330004077      11011      2019  00150828     CF    현금흐름표
# 392   20200330004077      11011      2019  00150828     CF    현금흐름표
# 393   20200330004077      11011      2019  00150828     CF    현금흐름표
# 394   20200330004077      11011      2019  00150828     CF    현금흐름표
# 395   20200330004077      11011      2019  00150828     CF    현금흐름표
# 396   20200330004077      11011      2019  00150828     CF    현금흐름표
# 397   20200330004077      11011      2019  00150828     CF    현금흐름표
# 398   20200330004077      11011      2019  00150828     CF    현금흐름표
# 399   20200330004077      11011      2019  00150828     CF    현금흐름표
# 400   20200330004077      11011      2019  00150828     CF    현금흐름표
# 401   20200330004077      11011      2019  00150828     CF    현금흐름표
# 402   20200330004077      11011      2019  00150828     CF    현금흐름표
# 403   20200330004077      11011      2019  00150828     CF    현금흐름표
# 404   20200330004077      11011      2019  00150828     CF    현금흐름표
# 405   20200330004077      11011      2019  00150828     CF    현금흐름표
# 406   20200330004077      11011      2019  00150828     CF    현금흐름표
# 407   20200330004077      11011      2019  00150828     CF    현금흐름표
# 408   20200330004077      11011      2019  00150828    SCE    자본변동표
# 409   20200330004077      11011      2019  00150828    SCE    자본변동표
# 410   20200330004077      11011      2019  00150828    SCE    자본변동표
# 411   20200330004077      11011      2019  00150828    SCE    자본변동표
# 412   20200330004077      11011      2019  00150828    SCE    자본변동표
# 413   20200330004077      11011      2019  00150828    SCE    자본변동표
# 414   20200330004077      11011      2019  00150828    SCE    자본변동표
# 415   20200330004077      11011      2019  00150828    SCE    자본변동표
# 416   20200330004077      11011      2019  00150828    SCE    자본변동표
# 417   20200330004077      11011      2019  00150828    SCE    자본변동표
# 418   20200330004077      11011      2019  00150828    SCE    자본변동표
# 419   20200330004077      11011      2019  00150828    SCE    자본변동표
# 420   20200330004077      11011      2019  00150828    SCE    자본변동표
# 421   20200330004077      11011      2019  00150828    SCE    자본변동표
# 422   20200330004077      11011      2019  00150828    SCE    자본변동표
# 423   20200330004077      11011      2019  00150828    SCE    자본변동표
# 424   20200330004077      11011      2019  00150828    SCE    자본변동표
# 425   20200330004077      11011      2019  00150828    SCE    자본변동표
# 426   20200330004077      11011      2019  00150828    SCE    자본변동표
# 427   20200330004077      11011      2019  00150828    SCE    자본변동표
# 428   20200330004077      11011      2019  00150828    SCE    자본변동표
# 429   20200330004077      11011      2019  00150828    SCE    자본변동표
# 430   20200330004077      11011      2019  00150828    SCE    자본변동표
# 431   20200330004077      11011      2019  00150828    SCE    자본변동표
# 432   20200330004077      11011      2019  00150828    SCE    자본변동표
# 433   20200330004077      11011      2019  00150828    SCE    자본변동표
# 434   20200330004077      11011      2019  00150828    SCE    자본변동표
# 435   20200330004077      11011      2019  00150828    SCE    자본변동표
# 436   20200330004077      11011      2019  00150828    SCE    자본변동표
# 437   20200330004077      11011      2019  00150828    SCE    자본변동표
# 438   20200330004077      11011      2019  00150828    SCE    자본변동표
# 439   20200330004077      11011      2019  00150828    SCE    자본변동표
# 440   20200330004077      11011      2019  00150828    SCE    자본변동표
# 441   20200330004077      11011      2019  00150828    SCE    자본변동표
# 442   20200330004077      11011      2019  00150828    SCE    자본변동표
# 443   20200330004077      11011      2019  00150828    SCE    자본변동표
# 444   20200513000920      11013      2020  00150828     BS    재무상태표
# 445   20200513000920      11013      2020  00150828     BS    재무상태표
# 446   20200513000920      11013      2020  00150828     BS    재무상태표
# 447   20200513000920      11013      2020  00150828     BS    재무상태표
# 448   20200513000920      11013      2020  00150828     BS    재무상태표
# 449   20200513000920      11013      2020  00150828     BS    재무상태표
# 450   20200513000920      11013      2020  00150828     BS    재무상태표
# 451   20200513000920      11013      2020  00150828     BS    재무상태표
# 452   20200513000920      11013      2020  00150828     BS    재무상태표
# 453   20200513000920      11013      2020  00150828     BS    재무상태표
# 454   20200513000920      11013      2020  00150828     BS    재무상태표
# 455   20200513000920      11013      2020  00150828     BS    재무상태표
# 456   20200513000920      11013      2020  00150828     BS    재무상태표
# 457   20200513000920      11013      2020  00150828     BS    재무상태표
# 458   20200513000920      11013      2020  00150828     BS    재무상태표
# 459   20200513000920      11013      2020  00150828     BS    재무상태표
# 460   20200513000920      11013      2020  00150828     BS    재무상태표
# 461   20200513000920      11013      2020  00150828     BS    재무상태표
# 462   20200513000920      11013      2020  00150828     BS    재무상태표
# 463   20200513000920      11013      2020  00150828     BS    재무상태표
# 464   20200513000920      11013      2020  00150828     BS    재무상태표
# 465   20200513000920      11013      2020  00150828     BS    재무상태표
# 466   20200513000920      11013      2020  00150828     BS    재무상태표
# 467   20200513000920      11013      2020  00150828     BS    재무상태표
# 468   20200513000920      11013      2020  00150828     BS    재무상태표
# 469   20200513000920      11013      2020  00150828     BS    재무상태표
# 470   20200513000920      11013      2020  00150828     BS    재무상태표
# 471   20200513000920      11013      2020  00150828     BS    재무상태표
# 472   20200513000920      11013      2020  00150828     BS    재무상태표
# 473   20200513000920      11013      2020  00150828     BS    재무상태표
# 474   20200513000920      11013      2020  00150828     BS    재무상태표
# 475   20200513000920      11013      2020  00150828     BS    재무상태표
# 476   20200513000920      11013      2020  00150828     BS    재무상태표
# 477   20200513000920      11013      2020  00150828     BS    재무상태표
# 478   20200513000920      11013      2020  00150828     BS    재무상태표
# 479   20200513000920      11013      2020  00150828     BS    재무상태표
# 480   20200513000920      11013      2020  00150828     BS    재무상태표
# 481   20200513000920      11013      2020  00150828     IS    손익계산서
# 482   20200513000920      11013      2020  00150828     IS    손익계산서
# 483   20200513000920      11013      2020  00150828     IS    손익계산서
# 484   20200513000920      11013      2020  00150828     IS    손익계산서
# 485   20200513000920      11013      2020  00150828     IS    손익계산서
# 486   20200513000920      11013      2020  00150828     IS    손익계산서
# 487   20200513000920      11013      2020  00150828     IS    손익계산서
# 488   20200513000920      11013      2020  00150828     IS    손익계산서
# 489   20200513000920      11013      2020  00150828     IS    손익계산서
# 490   20200513000920      11013      2020  00150828     IS    손익계산서
# 491   20200513000920      11013      2020  00150828     IS    손익계산서
# 492   20200513000920      11013      2020  00150828     IS    손익계산서
# 493   20200513000920      11013      2020  00150828     IS    손익계산서
# 494   20200513000920      11013      2020  00150828    CIS  포괄손익계산서
# 495   20200513000920      11013      2020  00150828    CIS  포괄손익계산서
# 496   20200513000920      11013      2020  00150828    CIS  포괄손익계산서
# 497   20200513000920      11013      2020  00150828    CIS  포괄손익계산서
# 498   20200513000920      11013      2020  00150828    CIS  포괄손익계산서
# 499   20200513000920      11013      2020  00150828     CF    현금흐름표
# 500   20200513000920      11013      2020  00150828     CF    현금흐름표
# 501   20200513000920      11013      2020  00150828     CF    현금흐름표
# 502   20200513000920      11013      2020  00150828     CF    현금흐름표
# 503   20200513000920      11013      2020  00150828     CF    현금흐름표
# 504   20200513000920      11013      2020  00150828     CF    현금흐름표
# 505   20200513000920      11013      2020  00150828     CF    현금흐름표
# 506   20200513000920      11013      2020  00150828     CF    현금흐름표
# 507   20200513000920      11013      2020  00150828     CF    현금흐름표
# 508   20200513000920      11013      2020  00150828     CF    현금흐름표
# 509   20200513000920      11013      2020  00150828     CF    현금흐름표
# 510   20200513000920      11013      2020  00150828     CF    현금흐름표
# 511   20200513000920      11013      2020  00150828     CF    현금흐름표
# 512   20200513000920      11013      2020  00150828     CF    현금흐름표
# 513   20200513000920      11013      2020  00150828     CF    현금흐름표
# 514   20200513000920      11013      2020  00150828     CF    현금흐름표
# 515   20200513000920      11013      2020  00150828     CF    현금흐름표
# 516   20200513000920      11013      2020  00150828     CF    현금흐름표
# 517   20200513000920      11013      2020  00150828     CF    현금흐름표
# 518   20200513000920      11013      2020  00150828     CF    현금흐름표
# 519   20200513000920      11013      2020  00150828     CF    현금흐름표
# 520   20200513000920      11013      2020  00150828     CF    현금흐름표
# 521   20200513000920      11013      2020  00150828     CF    현금흐름표
# 522   20200513000920      11013      2020  00150828     CF    현금흐름표
# 523   20200513000920      11013      2020  00150828    SCE    자본변동표
# 524   20200513000920      11013      2020  00150828    SCE    자본변동표
# 525   20200513000920      11013      2020  00150828    SCE    자본변동표
# 526   20200513000920      11013      2020  00150828    SCE    자본변동표
# 527   20200513000920      11013      2020  00150828    SCE    자본변동표
# 528   20200513000920      11013      2020  00150828    SCE    자본변동표
# 529   20200513000920      11013      2020  00150828    SCE    자본변동표
# 530   20200513000920      11013      2020  00150828    SCE    자본변동표
# 531   20200513000920      11013      2020  00150828    SCE    자본변동표
# 532   20200513000920      11013      2020  00150828    SCE    자본변동표
# 533   20200513000920      11013      2020  00150828    SCE    자본변동표
# 534   20200513000920      11013      2020  00150828    SCE    자본변동표
# 535   20200513000920      11013      2020  00150828    SCE    자본변동표
# 536   20200513000920      11013      2020  00150828    SCE    자본변동표
# 537   20200513000920      11013      2020  00150828    SCE    자본변동표
# 538   20200513000920      11013      2020  00150828    SCE    자본변동표
# 539   20200513000920      11013      2020  00150828    SCE    자본변동표
# 540   20200513000920      11013      2020  00150828    SCE    자본변동표
# 541   20200513000920      11013      2020  00150828    SCE    자본변동표
# 542   20200814000972      11012      2020  00150828     BS    재무상태표
# 543   20200814000972      11012      2020  00150828     BS    재무상태표
# 544   20200814000972      11012      2020  00150828     BS    재무상태표
# 545   20200814000972      11012      2020  00150828     BS    재무상태표
# 546   20200814000972      11012      2020  00150828     BS    재무상태표
# 547   20200814000972      11012      2020  00150828     BS    재무상태표
# 548   20200814000972      11012      2020  00150828     BS    재무상태표
# 549   20200814000972      11012      2020  00150828     BS    재무상태표
# 550   20200814000972      11012      2020  00150828     BS    재무상태표
# 551   20200814000972      11012      2020  00150828     BS    재무상태표
# 552   20200814000972      11012      2020  00150828     BS    재무상태표
# 553   20200814000972      11012      2020  00150828     BS    재무상태표
# 554   20200814000972      11012      2020  00150828     BS    재무상태표
# 555   20200814000972      11012      2020  00150828     BS    재무상태표
# 556   20200814000972      11012      2020  00150828     BS    재무상태표
# 557   20200814000972      11012      2020  00150828     BS    재무상태표
# 558   20200814000972      11012      2020  00150828     BS    재무상태표
# 559   20200814000972      11012      2020  00150828     BS    재무상태표
# 560   20200814000972      11012      2020  00150828     BS    재무상태표
# 561   20200814000972      11012      2020  00150828     BS    재무상태표
# 562   20200814000972      11012      2020  00150828     BS    재무상태표
# 563   20200814000972      11012      2020  00150828     BS    재무상태표
# 564   20200814000972      11012      2020  00150828     BS    재무상태표
# 565   20200814000972      11012      2020  00150828     BS    재무상태표
# 566   20200814000972      11012      2020  00150828     BS    재무상태표
# 567   20200814000972      11012      2020  00150828     BS    재무상태표
# 568   20200814000972      11012      2020  00150828     BS    재무상태표
# 569   20200814000972      11012      2020  00150828     BS    재무상태표
# 570   20200814000972      11012      2020  00150828     BS    재무상태표
# 571   20200814000972      11012      2020  00150828     BS    재무상태표
# 572   20200814000972      11012      2020  00150828     BS    재무상태표
# 573   20200814000972      11012      2020  00150828     BS    재무상태표
# 574   20200814000972      11012      2020  00150828     BS    재무상태표
# 575   20200814000972      11012      2020  00150828     BS    재무상태표
# 576   20200814000972      11012      2020  00150828     BS    재무상태표
# 577   20200814000972      11012      2020  00150828     BS    재무상태표
# 578   20200814000972      11012      2020  00150828     BS    재무상태표
# 579   20200814000972      11012      2020  00150828     IS    손익계산서
# 580   20200814000972      11012      2020  00150828     IS    손익계산서
# 581   20200814000972      11012      2020  00150828     IS    손익계산서
# 582   20200814000972      11012      2020  00150828     IS    손익계산서
# 583   20200814000972      11012      2020  00150828     IS    손익계산서
# 584   20200814000972      11012      2020  00150828     IS    손익계산서
# 585   20200814000972      11012      2020  00150828     IS    손익계산서
# 586   20200814000972      11012      2020  00150828     IS    손익계산서
# 587   20200814000972      11012      2020  00150828     IS    손익계산서
# 588   20200814000972      11012      2020  00150828     IS    손익계산서
# 589   20200814000972      11012      2020  00150828     IS    손익계산서
# 590   20200814000972      11012      2020  00150828     IS    손익계산서
# 591   20200814000972      11012      2020  00150828     IS    손익계산서
# 592   20200814000972      11012      2020  00150828     IS    손익계산서
# 593   20200814000972      11012      2020  00150828    CIS  포괄손익계산서
# 594   20200814000972      11012      2020  00150828    CIS  포괄손익계산서
# 595   20200814000972      11012      2020  00150828    CIS  포괄손익계산서
# 596   20200814000972      11012      2020  00150828    CIS  포괄손익계산서
# 597   20200814000972      11012      2020  00150828    CIS  포괄손익계산서
# 598   20200814000972      11012      2020  00150828     CF    현금흐름표
# 599   20200814000972      11012      2020  00150828     CF    현금흐름표
# 600   20200814000972      11012      2020  00150828     CF    현금흐름표
# 601   20200814000972      11012      2020  00150828     CF    현금흐름표
# 602   20200814000972      11012      2020  00150828     CF    현금흐름표
# 603   20200814000972      11012      2020  00150828     CF    현금흐름표
# 604   20200814000972      11012      2020  00150828     CF    현금흐름표
# 605   20200814000972      11012      2020  00150828     CF    현금흐름표
# 606   20200814000972      11012      2020  00150828     CF    현금흐름표
# 607   20200814000972      11012      2020  00150828     CF    현금흐름표
# 608   20200814000972      11012      2020  00150828     CF    현금흐름표
# 609   20200814000972      11012      2020  00150828     CF    현금흐름표
# 610   20200814000972      11012      2020  00150828     CF    현금흐름표
# 611   20200814000972      11012      2020  00150828     CF    현금흐름표
# 612   20200814000972      11012      2020  00150828     CF    현금흐름표
# 613   20200814000972      11012      2020  00150828     CF    현금흐름표
# 614   20200814000972      11012      2020  00150828     CF    현금흐름표
# 615   20200814000972      11012      2020  00150828     CF    현금흐름표
# 616   20200814000972      11012      2020  00150828     CF    현금흐름표
# 617   20200814000972      11012      2020  00150828     CF    현금흐름표
# 618   20200814000972      11012      2020  00150828     CF    현금흐름표
# 619   20200814000972      11012      2020  00150828     CF    현금흐름표
# 620   20200814000972      11012      2020  00150828     CF    현금흐름표
# 621   20200814000972      11012      2020  00150828     CF    현금흐름표
# 622   20200814000972      11012      2020  00150828     CF    현금흐름표
# 623   20200814000972      11012      2020  00150828     CF    현금흐름표
# 624   20200814000972      11012      2020  00150828    SCE    자본변동표
# 625   20200814000972      11012      2020  00150828    SCE    자본변동표
# 626   20200814000972      11012      2020  00150828    SCE    자본변동표
# 627   20200814000972      11012      2020  00150828    SCE    자본변동표
# 628   20200814000972      11012      2020  00150828    SCE    자본변동표
# 629   20200814000972      11012      2020  00150828    SCE    자본변동표
# 630   20200814000972      11012      2020  00150828    SCE    자본변동표
# 631   20200814000972      11012      2020  00150828    SCE    자본변동표
# 632   20200814000972      11012      2020  00150828    SCE    자본변동표
# 633   20200814000972      11012      2020  00150828    SCE    자본변동표
# 634   20200814000972      11012      2020  00150828    SCE    자본변동표
# 635   20200814000972      11012      2020  00150828    SCE    자본변동표
# 636   20200814000972      11012      2020  00150828    SCE    자본변동표
# 637   20200814000972      11012      2020  00150828    SCE    자본변동표
# 638   20200814000972      11012      2020  00150828    SCE    자본변동표
# 639   20200814000972      11012      2020  00150828    SCE    자본변동표
# 640   20200814000972      11012      2020  00150828    SCE    자본변동표
# 641   20200814000972      11012      2020  00150828    SCE    자본변동표
# 642   20200814000972      11012      2020  00150828    SCE    자본변동표
# 643   20201116001244      11014      2020  00150828     BS    재무상태표
# 644   20201116001244      11014      2020  00150828     BS    재무상태표
# 645   20201116001244      11014      2020  00150828     BS    재무상태표
# 646   20201116001244      11014      2020  00150828     BS    재무상태표
# 647   20201116001244      11014      2020  00150828     BS    재무상태표
# 648   20201116001244      11014      2020  00150828     BS    재무상태표
# 649   20201116001244      11014      2020  00150828     BS    재무상태표
# 650   20201116001244      11014      2020  00150828     BS    재무상태표
# 651   20201116001244      11014      2020  00150828     BS    재무상태표
# 652   20201116001244      11014      2020  00150828     BS    재무상태표
# 653   20201116001244      11014      2020  00150828     BS    재무상태표
# 654   20201116001244      11014      2020  00150828     BS    재무상태표
# 655   20201116001244      11014      2020  00150828     BS    재무상태표
# 656   20201116001244      11014      2020  00150828     BS    재무상태표
# 657   20201116001244      11014      2020  00150828     BS    재무상태표
# 658   20201116001244      11014      2020  00150828     BS    재무상태표
# 659   20201116001244      11014      2020  00150828     BS    재무상태표
# 660   20201116001244      11014      2020  00150828     BS    재무상태표
# 661   20201116001244      11014      2020  00150828     BS    재무상태표
# ...
# 1229       제 61 기       4043342230
# 1230       제 61 기        400102200
# 1231       제 61 기     154916060652
# 1232       제 61 기        489620000
# 1233       제 61 기      12761972006
# 1234       제 61 기       4355564243
# 1235       제 61 기        227395000
# 1236       제 61 기         65435000
# 1237       제 61 기       9534698928
# 1238       제 61 기      -1797643578
# 1239       제 61 기        403990920
# 1240       제 61 기       1393652658
# 1241       제 61 기     -11964166482
# 1242       제 61 기      12555530444
# 1243       제 61 기        591363962
# 1244       제 61 기       6404024702
# 1245       제 61 기         94867140
# 1246       제 61 기      73311885500
# 1247       제 61 기       -944897318
# 1248       제 61 기      78804146252
# 1249       제 61 기        -61733772
# 1250       제 61 기      20338293556
# 1251       제 61 기      20338293556
# 1252       제 61 기
# 1253       제 61 기
# 1254       제 61 기        -56518180
# 1255       제 61 기        -56518180
# 1256       제 61 기      -1674631780
# 1257       제 61 기      -1674631780
# 1258       제 61 기         94867140
# 1259       제 61 기        -94867140
# 1260       제 61 기      73311885500
# 1261       제 61 기      17813631598
# 1262       제 61 기        -61733772
# 1263       제 61 기      97411289848
# 1264       제 61 기       6347506522
# 1265          NaN              NaN
# 1266          NaN              NaN
# 1267          NaN              NaN
# 1268          NaN              NaN
# 1269          NaN              NaN
# 1270          NaN              NaN
# 1271          NaN              NaN
# 1272          NaN              NaN
# 1273          NaN              NaN
# 1274          NaN              NaN
# 1275          NaN              NaN
# 1276          NaN              NaN
# 1277          NaN              NaN
# 1278          NaN              NaN
# 1279          NaN              NaN
# 1280          NaN              NaN
# 1281          NaN              NaN
# 1282          NaN              NaN
# 1283          NaN              NaN
# 1284          NaN              NaN
# 1285          NaN              NaN
# 1286          NaN              NaN
# 1287          NaN              NaN
# 1288          NaN              NaN
# 1289          NaN              NaN
# 1290          NaN              NaN
# 1291          NaN              NaN
# 1292          NaN              NaN
# 1293          NaN              NaN
# 1294          NaN              NaN
# 1295          NaN              NaN
# 1296          NaN              NaN
# 1297          NaN              NaN
# 1298          NaN              NaN
# 1299          NaN              NaN
# 1300          NaN              NaN
# 1301          NaN              NaN
# 1302          NaN              NaN
# 1303          NaN              NaN
# 1304          NaN              NaN
# 1305          NaN              NaN
# 1306          NaN              NaN
# 1307          NaN              NaN
# 1308          NaN              NaN
# 1309          NaN              NaN
# 1310          NaN              NaN
# 1311          NaN              NaN
# 1312          NaN              NaN
# 1313          NaN              NaN
# 1314          NaN              NaN
# 1315          NaN              NaN
# 1316          NaN              NaN
# 1317          NaN              NaN
# 1318          NaN              NaN
# 1319          NaN              NaN
# 1320          NaN              NaN
# 1321          NaN              NaN
# 1322          NaN              NaN
# 1323          NaN              NaN
# 1324          NaN              NaN
# 1325          NaN              NaN
# 1326          NaN              NaN
# 1327          NaN              NaN
# 1328          NaN              NaN
# 1329          NaN              NaN
# 1330          NaN              NaN
# 1331          NaN              NaN
# 1332          NaN              NaN
# 1333          NaN              NaN
# 1334          NaN              NaN
# 1335          NaN              NaN
# 1336          NaN              NaN
# 1337          NaN              NaN
# 1338          NaN              NaN
# 1339          NaN              NaN
# 1340          NaN              NaN
# 1341          NaN              NaN
# 1342          NaN              NaN
# 1343          NaN              NaN
# 1344          NaN              NaN
# 1345          NaN              NaN
# 1346          NaN              NaN
# 1347          NaN              NaN
# 1348          NaN              NaN
# 1349          NaN              NaN
# 1350          NaN              NaN
# 1351          NaN              NaN
# 1352          NaN              NaN
# 1353          NaN              NaN
# 1354          NaN              NaN
# 1355          NaN              NaN
# 1356          NaN              NaN
# 1357          NaN              NaN
# 1358          NaN              NaN
# 1359          NaN              NaN
# 1360          NaN              NaN
# 1361          NaN              NaN
# 1362          NaN              NaN
# 1363          NaN              NaN
# 1364          NaN              NaN
# 1365          NaN              NaN
# 1366          NaN              NaN
# 1367          NaN              NaN
# 1368          NaN              NaN
# 1369          NaN              NaN
# 1370          NaN              NaN
# 1371          NaN              NaN
# 1372          NaN              NaN
# 1373          NaN              NaN
# 1374          NaN              NaN
# 1375          NaN              NaN
# 1376          NaN              NaN
# 1377          NaN              NaN
# 1378          NaN              NaN
# 1379          NaN              NaN
# 1380          NaN              NaN
# 1381          NaN              NaN
# 1382          NaN              NaN
# 1383          NaN              NaN
# 1384          NaN              NaN
# 1385          NaN              NaN
# 1386          NaN              NaN
# 1387          NaN              NaN
# 1388          NaN              NaN
# 1389          NaN              NaN
# 1390          NaN              NaN
# 1391          NaN              NaN
# 1392          NaN              NaN
# 1393          NaN              NaN
# 1394          NaN              NaN
# 1395          NaN              NaN
# 1396          NaN              NaN
# 1397          NaN              NaN
# 1398          NaN              NaN
# 1399          NaN              NaN
# 1400          NaN              NaN
# 1401          NaN              NaN
# 1402          NaN              NaN
# 1403          NaN              NaN
# 1404          NaN              NaN
# 1405          NaN              NaN
# 1406          NaN              NaN
# 1407          NaN              NaN
# 1408          NaN              NaN
# 1409          NaN              NaN
# 1410          NaN              NaN
# 1411          NaN              NaN
# 1412          NaN              NaN
# 1413          NaN              NaN
# 1414          NaN              NaN
# 1415          NaN              NaN
# 1416          NaN              NaN
# 1417          NaN              NaN
# 1418          NaN              NaN
# 1419          NaN              NaN
# 1420          NaN              NaN
# 1421          NaN              NaN
# 1422          NaN              NaN
# 1423          NaN              NaN
# 1424          NaN              NaN
# 1425          NaN              NaN
# 1426          NaN              NaN
# 1427          NaN              NaN
# 1428          NaN              NaN
# 1429          NaN              NaN
# 1430          NaN              NaN
# 1431          NaN              NaN
# 1432          NaN              NaN
# 1433          NaN              NaN
# 1434          NaN              NaN
# 1435          NaN              NaN
# 1436          NaN              NaN
# 1437          NaN              NaN
# 1438          NaN              NaN
# 1439          NaN              NaN
# 1440          NaN              NaN
# 1441          NaN              NaN
# 1442          NaN              NaN
# 1443          NaN              NaN
# 1444          NaN              NaN
# 1445          NaN              NaN
# 1446          NaN              NaN
# 1447          NaN              NaN
# 1448          NaN              NaN
# 1449          NaN              NaN
# 1450          NaN              NaN
# 1451          NaN              NaN
# 1452          NaN              NaN
# 1453          NaN              NaN
# 1454          NaN              NaN
# 1455          NaN              NaN
# 1456          NaN              NaN
# 1457          NaN              NaN
# 1458          NaN              NaN
# 1459          NaN              NaN
# 1460          NaN              NaN
# 1461          NaN              NaN
# 1462          NaN              NaN
# 1463          NaN              NaN
# 1464          NaN              NaN
# 1465          NaN              NaN
# 1466          NaN              NaN
# 1467          NaN              NaN
# 1468          NaN              NaN
# 1469          NaN              NaN
# 1470          NaN              NaN
# 1471          NaN              NaN
# 1472          NaN              NaN
# 1473          NaN              NaN
# 1474          NaN              NaN
# 1475          NaN              NaN
# 1476          NaN              NaN
# 1477          NaN              NaN
# 1478          NaN              NaN
# 1479          NaN              NaN
# 1480          NaN              NaN
# 1481          NaN              NaN
# 1482          NaN              NaN
# 1483          NaN              NaN
# 1484          NaN              NaN
# 1485          NaN              NaN
# 1486          NaN              NaN
# 1487          NaN              NaN
# 1488          NaN              NaN
# 1489          NaN              NaN
# 1490          NaN              NaN
# 1491          NaN              NaN
# 1492          NaN              NaN
# 1493          NaN              NaN
# 1494          NaN              NaN
# 1495          NaN              NaN
# 1496          NaN              NaN
# 1497          NaN              NaN
# 1498          NaN              NaN
# 1499          NaN              NaN
# 1500          NaN              NaN
# 1501          NaN              NaN
# 1502          NaN              NaN
# 1503          NaN              NaN
# 1504          NaN              NaN
# 1505          NaN              NaN
# 1506          NaN              NaN
# 1507          NaN              NaN
# 1508          NaN              NaN
# 1509          NaN              NaN
# 1510          NaN              NaN
# 1511          NaN              NaN
# 1512          NaN              NaN
# 1513          NaN              NaN
# 1514          NaN              NaN
# 1515          NaN              NaN
# 1516          NaN              NaN
# 1517          NaN              NaN
# 1518          NaN              NaN
# 1519          NaN              NaN
# 1520          NaN              NaN
# 1521          NaN              NaN
# 1522          NaN              NaN
# 1523          NaN              NaN
# 1524          NaN              NaN
# 1525          NaN              NaN
# 1526          NaN              NaN
# 1527          NaN              NaN
# 1528          NaN              NaN
# 1529          NaN              NaN
# 1530          NaN              NaN
# 1531          NaN              NaN
# 1532          NaN              NaN
# 1533          NaN              NaN
# 1534          NaN              NaN
# 1535          NaN              NaN
# 1536          NaN              NaN
# 1537          NaN              NaN
# 1538          NaN              NaN
# 1539          NaN              NaN
# 1540          NaN              NaN
# 1541          NaN              NaN
# 1542          NaN              NaN
# 1543          NaN              NaN
# 1544          NaN              NaN
# 1545          NaN              NaN
# 1546          NaN              NaN
# 1547          NaN              NaN
# 1548          NaN              NaN
# 1549          NaN              NaN
# 1550          NaN              NaN
# 1551          NaN              NaN
# 1552          NaN              NaN
# 1553          NaN              NaN
# 1554          NaN              NaN
# 1555          NaN              NaN
# 1556          NaN              NaN
# 1557          NaN              NaN
# 1558       제 62 기     163362307948
# 1559       제 62 기       2354008400
# 1560       제 62 기     150392685360
# 1561       제 62 기        635970137
# 1562       제 62 기       6530732109
# 1563       제 62 기       3448911942
# 1564       제 62 기     119555170112
# 1565       제 62 기      98172751028
# 1566       제 62 기       1948889822
# 1567       제 62 기       5007960386
# 1568       제 62 기      12956824083
# 1569       제 62 기       1053549808
# 1570       제 62 기        308570177
# 1571       제 62 기        106624808
# 1572       제 62 기     282917478060
# 1573       제 62 기     109353910281
# 1574       제 62 기      84214942558
# 1575       제 62 기        177113293
# 1576       제 62 기        802082463
# 1577       제 62 기       2879751553
# 1578       제 62 기        779297602
# 1579       제 62 기       7478183930
# 1580       제 62 기      12454800858
# 1581       제 62 기        567738024
# 1582       제 62 기      54715346516
# 1583       제 62 기        885566540
# 1584       제 62 기        240129128
# 1585       제 62 기      11491681767
# 1586       제 62 기      42030969081
# 1587       제 62 기         67000000
# 1588       제 62 기     164069256797
# 1589       제 62 기      73311885500
# 1590       제 62 기        -61733772
# 1591       제 62 기       6982194444
# 1592       제 62 기      38615875091
# 1593       제 62 기     118848221263
# 1594       제 62 기     282917478060
# 1595       제 62 기     377247251739
# 1596       제 62 기     336179194773
# 1597       제 62 기      41068056966
# 1598       제 62 기      26387340689
# 1599       제 62 기      14680716277
# 1600       제 62 기       5626922026
# 1601       제 62 기       6322226693
# 1602       제 62 기       1019982241
# 1603       제 62 기        807678662
# 1604       제 62 기      14197715189
# 1605       제 62 기      -6199111838
# 1606       제 62 기      20396827027
# 1607       제 62 기              140
# 1608       제 62 기              140
# 1609       제 62 기      20396827027
# 1610       제 62 기       1040104388
# 1611       제 62 기        405416466
# 1612       제 62 기        583206890
# 1613       제 62 기         51481032
# 1614       제 62 기      21436931415
# 1615       제 62 기      41218248368
# 1616       제 62 기      43690989374
# 1617       제 62 기       1023517502
# 1618       제 62 기        720939030
# 1619       제 62 기       3085688442
# 1620       제 62 기        310368964
# 1621       제 62 기     -15377869019
# 1622       제 62 기        430102200
# 1623       제 62 기        999644230
# 1624       제 62 기       1137920000
# 1625       제 62 기      12326157154
# 1626       제 62 기
# 1627       제 62 기       1710076960
# 1628       제 62 기         30000000
# 1629       제 62 기         50000000
# 1630       제 62 기        457190000
# 1631       제 62 기      21523861164
# 1632       제 62 기       2058914659
# 1633       제 62 기        142754740
# 1634       제 62 기         54190000
# 1635       제 62 기       7664859000
# 1636       제 62 기     -24077734911
# 1637       제 62 기
# 1638       제 62 기      22324938274
# 1639       제 62 기       1752796637
# 1640       제 62 기       1762644438
# 1641       제 62 기        591363962
# 1642       제 62 기       2354008400
# 1643       제 62 기       6347506522
# 1644       제 62 기      73311885500
# 1645       제 62 기      17813631598
# 1646       제 62 기      97411289848
# 1647       제 62 기        -61733772
# 1648       제 62 기      20396827027
# 1649       제 62 기      20396827027
# 1650       제 62 기        583206890
# 1651       제 62 기        583206890
# 1652       제 62 기         51481032
# 1653       제 62 기         51481032
# 1654       제 62 기        405416466
# 1655       제 62 기        405416466
# 1656       제 62 기      73311885500
# 1657       제 62 기      38615875091
# 1658       제 62 기       6982194444
# 1659       제 62 기     118848221263
# 1660       제 62 기        -61733772

# %%
Quarter = []
cor_year = []
ID_list = []
corp_name_list = []
year_list = []
report_code_list = []
Debt_Ratio = []
Debt_to_Asset_Ratio = []
Fixed_Asset_Turnover_Ratio = []
Return_on_Equity = []
Operating_Profit_Margin = []
Gross_Profit_Margin = []
Interest_Coverage_Ratio =[]
Sales_Growth_Rate = []
Total_Asset_Growth_Rate = []
Operating_Profit_Growth_Rate = []
Equity_Growth_Rate= []
Accounts_Receivable_Turnover = []
Inventory_Turnover = []
Accounts_Payable_Turnover = []
Total_Asset_Turnover_Ratio = []
Debt_Service_Coverage_Ratio = []
Debt_to_Equity_Ratio = []


for year in range(2020, 2023):
  str_year = str(year)
  report_code_list.extend(['1분기보고서' if code == '11013' else '반기보고서' if code == '11012' else '3분기보고서' if code == '11014' else '사업보고서' for code in report_code])
  Quarter.extend(['01' if code == '11013' else '02' if code == '11012' else '03' if code == '11014' else '04' for code in report_code])
  for code in report_code:
    BS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '자산총계' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자산총계
    BS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 부채총계
    BS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자본총계
    BS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '단기차입금' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 단기차입금
    BS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and ('유동성장기부채' in row['account_nm'] or '유동성장기채무' in row['account_nm']) and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 유동성장기부채
    BS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '사채' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 사채
    BS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '차입금' in row['account_nm'] and '단기차입금' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 장기차입금
    BS8 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동자산' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동자산
    BS9 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동부채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동부채
    BS10 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자산총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자산총계
    BS11 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 부채총계
    BS12 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자본총계
    BS13 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매출채권' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매출채권
    BS14 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매입채무' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매입채무
    BS15 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '재고자산' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 재고자산

    IS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '포괄손익계산서' and '기순' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 당기순이익
    IS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업이익
    IS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '매출액' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 수익(매출액)
    IS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '법인세' in row['account_nm'] and '차감전' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 법인세비용차감전순이익(손실)
    IS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and (row['account_nm'] == '금융비용' or row['account_nm'] == '금융원가') and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 금융비용
    IS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '매출액' in row['account_nm'] and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 수익(매출액) # 분기 보고서만 해당
    IS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 영업이익 # 분기 보고서만 해당

    CF1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '현금흐름표' and row['account_nm'] == '영업활동현금흐름' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업활동으로 인한 현금흐름

    # if BS6 == BS7: # '사채 및 장기차입금'으로 계정과목 하나만 쓰는 회사는 합침(어차피 사채는 차입금 의존도에서만 사용해서 하나 0으로 만들어도 상관없음)
    #   BS6 = ['0']
    # if BS4 == BS5:
    #   BS4 = ['0'] # '단기차입금 및 유동성장기부채' 로 병합해서 쓰는 회사는 하나로 합침(어차피 둘이 항상 붙어서 계산해서 상관없음)
    # if BS4 == [''] or BS4 == []:
    #   BS4 = ['0']
    if BS5 == [''] or BS5 == []:
      BS5 = ['0'] # 진흥기업은 단기차입금 안에 유동성장기부채 포함해서 공시해놓음(어차피 단기차입금과 유동성 장기부채는 항상 붙어다녀서 0으로 만들어도 됨)
    if BS6 == []:
      BS6 = ['0'] # 진흥기업은 회사채 발행 안 함
    # if BS7 == []:
    #   BS7 = ['0']

    print("자산총계:", BS1, "부채총계:", BS2, "자본총계:", BS3, "단기차입금:", BS4, "유동성장기부채:", BS5, "사채:", BS6, "장기차입금:", BS7, "비유동자산:", BS8, "비유동부채:", BS9, "전기말 자산총계:", BS10, "전기말 부채총계:", BS11,
          "전기말 자본총계:", BS12, "매출채권:", BS13, "매입채무:", BS14, "재고자산:", BS15, "당기순이익:", IS1, "영업이익:", IS2, "수익(매출액):", IS3, "법인세비용차감전순이익(손실):", IS4,
          "금융비용:", IS5, "전기 수익(매출액):", IS6, "전기 영업이익:", IS7, "영업활동으로 인한 현금흐름:", CF1)

    if year != 2020:
      if code == "11013":
        accounting_period = 90
      elif code == "11012":
        accounting_period = 181
      elif code == "11014":
        accounting_period = 273
      elif code == "11011":
        accounting_period = 365
    else: # 2020년은 윤년
      if code == "11013":
        accounting_period = 91
      elif code == "11012":
        accounting_period = 182
      elif code == "11014":
        accounting_period = 274
      elif code == "11011":
        accounting_period = 366


    cor_year.extend([f"{corp_code_p}{str_year}"])
    corp_name_list.append(str(corp_name_p))
    year_list.append(str_year)
    Debt_Ratio.extend([int(BS2)/int(BS3)*100 for BS2, BS3 in zip(BS2, BS3)])
    Debt_to_Asset_Ratio.extend([((int(BS4) + int(BS5) + int(BS6) + int(BS7)) / int(BS1) * 100) for BS4, BS5, BS6, BS7, BS1 in zip(BS4, BS5, BS6, BS7, BS1)])
    Fixed_Asset_Turnover_Ratio.extend([int(BS8)/(int(BS9)+int(BS3))*100 for BS8, BS9, BS3 in zip(BS8, BS9, BS3)]),
    Return_on_Equity.extend([int(IS1)/((int(BS12)+int(BS3))/2) for IS1, BS12, BS3 in zip(IS1, BS12, BS3)])
    Operating_Profit_Margin.extend([int(IS2)/int(IS3) for IS2, IS3 in zip(IS2, IS3)])
    Gross_Profit_Margin.extend([int(IS4)/int(IS3) for IS4, IS3 in zip(IS4, IS3)])
    Interest_Coverage_Ratio.extend([int(IS2)/int(IS5) for IS2, IS5 in zip(IS2, IS5)])
    Sales_Growth_Rate.extend([(int(IS3)-int(IS6))/int(IS6) for IS3, IS6 in zip(IS3, IS6)])
    Total_Asset_Growth_Rate.extend([(int(BS1)-int(BS10))/int(BS10) for BS1, BS10 in zip(BS1, BS10)])
    Operating_Profit_Growth_Rate.extend([(int(IS2)-int(IS7))/int(IS7) for IS2, IS7 in zip(IS2, IS7)])
    Equity_Growth_Rate.extend([(int(BS3)-int(BS12))/int(BS12) for BS3, BS12 in zip(BS3, BS12)])
    Accounts_Receivable_Turnover.extend([int(BS13)/int(IS3)*accounting_period for BS13, IS3 in zip(BS13, IS3)])
    Inventory_Turnover.extend([int(BS15)/int(IS3)*accounting_period for BS15, IS3 in zip(BS15, IS3)])
    Accounts_Payable_Turnover.extend([int(BS14)/int(IS3)*accounting_period for BS14, IS3 in zip(BS14, IS3)])
    Total_Asset_Turnover_Ratio.extend([int(IS3)/int(BS1) for IS3, BS1 in zip(IS3, BS1)])
    Debt_Service_Coverage_Ratio.extend([(int(CF1)+int(IS5))/(int(BS4)+int(BS5)+int(IS5)) for CF1, IS5, BS4, BS5 in zip(CF1, IS5, BS4, BS5)])
    Debt_to_Equity_Ratio.extend([int(CF1)/(int(BS4)+int(BS7)+int(BS5)) for CF1, BS4, BS7, BS5 in zip(CF1, BS4, BS7, BS5)])

ID_list.extend([x+y for x,y in zip(cor_year,Quarter)])

financial_ratio = {
      '아이디':ID_list,
      '기업명':corp_name_list,
      '연도':year_list,
      '보고서 코드':report_code_list,
      '부채비율' : Debt_Ratio,
      '차입금의존도' : Debt_to_Asset_Ratio,
      '고정장기적합률':Fixed_Asset_Turnover_Ratio,
      '자기자본순이익률':Return_on_Equity,
      '매출액영업이익률':Operating_Profit_Margin,
      '매출액경상이익률':Gross_Profit_Margin,
      '이자보상배율(배)':Interest_Coverage_Ratio,
      '매출액 증가율':Sales_Growth_Rate,
      '총자산 증가율':Total_Asset_Growth_Rate,
      '영업이익 증가율':Operating_Profit_Growth_Rate,
      '자기자본 증가율':Equity_Growth_Rate,
      '매출채권 회전기일(일)':Equity_Growth_Rate,
      '재고자산 회전기일(일)':Accounts_Receivable_Turnover,
      '매입채무 회전기일(일)':Accounts_Payable_Turnover,
      '총자산 회전율':Total_Asset_Turnover_Ratio,
      '부채상환계수(배)':Debt_Service_Coverage_Ratio,
      '총차입금상환능력비율':Debt_to_Equity_Ratio
                    }

df = pd.DataFrame(financial_ratio)
df.set_index('아이디', inplace=True)

df
# Out:
# 자산총계: ['323957232270'] 부채총계: ['224654546744'] 자본총계: ['99302685526'] 단기차입금: ['17388427830'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['5957920337'] 비유동자산: ['110924381754'] 비유동부채: ['76113777262'] 전기말 자산총계: ['387591002141'] 전기말 부채총계: ['301304712224'] 전기말 자본총계: ['86286289917'] 매출채권: ['188017854730'] 매입채무: ['108507892575'] 재고자산: ['3484128308'] 당기순이익: ['1944551994'] 영업이익: ['2106456891'] 수익(매출액): ['85767219880'] 법인세비용차감전순이익(손실): ['1944551994'] 금융비용: ['156892400'] 전기 수익(매출액): ['148861007759'] 전기 영업이익: ['6818783132'] 영업활동으로 인한 현금흐름: ['3191271378']
# 자산총계: ['317885480339'] 부채총계: ['214988876527'] 자본총계: ['102896603812'] 단기차입금: ['17387149123'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['5777515877'] 비유동자산: ['118005585567'] 비유동부채: ['76904872744'] 전기말 자산총계: ['368861793285'] 전기말 부채총계: ['272362316675'] 전기말 자본총계: ['96499476610'] 매출채권: ['179548812059'] 매입채무: ['98554009035'] 재고자산: ['3454847785'] 당기순이익: ['3593752446'] 영업이익: ['4808747949'] 수익(매출액): ['90676490576'] 법인세비용차감전순이익(손실): ['3705923550'] 금융비용: ['384728872'] 전기 수익(매출액): ['148001398739'] 전기 영업이익: ['7928699123'] 영업활동으로 인한 현금흐름: ['6459664799']
# 자산총계: ['307916639651'] 부채총계: ['202215980205'] 자본총계: ['105700659446'] 단기차입금: ['6269858312'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['5777515877'] 비유동자산: ['129791102415'] 비유동부채: ['75221445321'] 전기말 자산총계: ['351350815864'] 전기말 부채총계: ['248460483540'] 전기말 자본총계: ['102890332324'] 매출채권: ['159852436473'] 매입채무: ['96707056767'] 재고자산: ['3447018181'] 당기순이익: ['2804154411'] 영업이익: ['2906385510'] 수익(매출액): ['91352174026'] 법인세비용차감전순이익(손실): ['3131177236'] 금융비용: ['153576983'] 전기 수익(매출액): ['123308960670'] 전기 영업이익: ['7985123706'] 영업활동으로 인한 현금흐름: ['30743583542']
# 자산총계: ['282917478060'] 부채총계: ['164069256797'] 자본총계: ['118848221263'] 단기차입금: ['177113293'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['885566540'] 비유동자산: ['119555170112'] 비유동부채: ['54715346516'] 전기말 자산총계: ['325811159734'] 전기말 부채총계: ['228399869886'] 전기말 자본총계: ['97411289848'] 매출채권: ['150392685360'] 매입채무: ['84214942558'] 재고자산: ['3448911942'] 당기순이익: ['20396827027'] 영업이익: ['14680716277'] 수익(매출액): ['377247251739'] 법인세비용차감전순이익(손실): ['14197715189'] 금융비용: ['807678662'] 전기 수익(매출액): ['546534147300'] 전기 영업이익: ['28039803736'] 영업활동으로 인한 현금흐름: ['41218248368']
# 자산총계: ['288983500395'] 부채총계: ['160918755466'] 자본총계: ['128064744929'] 단기차입금: ['177113293'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['885566540'] 비유동자산: ['120076050411'] 비유동부채: ['54269443904'] 전기말 자산총계: ['323957232270'] 전기말 부채총계: ['224654546744'] 전기말 자본총계: ['99302685526'] 매출채권: ['143610326310'] 매입채무: ['79798175780'] 재고자산: ['3447316307'] 당기순이익: ['9263491656'] 영업이익: ['8942001221'] 수익(매출액): ['79607104967'] 법인세비용차감전순이익(손실): ['9318372511'] 금융비용: ['9869204'] 전기 수익(매출액): ['85767219880'] 전기 영업이익: ['2106456891'] 영업활동으로 인한 현금흐름: ['9381870187']
# 자산총계: ['314984492649'] 부채총계: ['164311801373'] 자본총계: ['150672691276'] 단기차입금: ['175831265'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['703325130'] 비유동자산: ['118138120341'] 비유동부채: ['54953368615'] 전기말 자산총계: ['317885480339'] 전기말 부채총계: ['214988876527'] 전기말 자본총계: ['102896603812'] 매출채권: ['142393561210'] 매입채무: ['92991451377'] 재고자산: ['3462692595'] 당기순이익: ['22610955672'] 영업이익: ['16716470943'] 수익(매출액): ['106317781750'] 법인세비용차감전순이익(손실): ['22995812833'] 금융비용: ['13821120'] 전기 수익(매출액): ['90676490576'] 전기 영업이익: ['4808747949'] 영업활동으로 인한 현금흐름: ['34473750853']
# 자산총계: ['309547445181'] 부채총계: ['150565009272'] 자본총계: ['158982435909'] 단기차입금: ['175831265'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['703325130'] 비유동자산: ['122427244552'] 비유동부채: ['54176644121'] 전기말 자산총계: ['307916639651'] 전기말 부채총계: ['202215980205'] 전기말 자본총계: ['105700659446'] 매출채권: ['142888897673'] 매입채무: ['79451778402'] 재고자산: ['3463572220'] 당기순이익: ['8318030197'] 영업이익: ['8702010605'] 수익(매출액): ['104160038719'] 법인세비용차감전순이익(손실): ['9296688434'] 금융비용: ['9776660'] 전기 수익(매출액): ['91352174026'] 전기 영업이익: ['2906385510'] 영업활동으로 인한 현금흐름: ['28759155825']
# 자산총계: ['334617161562'] 부채총계: ['163663632831'] 자본총계: ['170953528731'] 단기차입금: ['167091634'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['734486641'] 비유동자산: ['135085060991'] 비유동부채: ['59538136521'] 전기말 자산총계: ['282917478060'] 전기말 부채총계: ['164069256797'] 전기말 자본총계: ['118848221263'] 매출채권: ['142285434869'] 매입채무: ['84651511428'] 재고자산: ['3469877557'] 당기순이익: ['53413211910'] 영업이익: ['43348738057'] 수익(매출액): ['444244783883'] 법인세비용차감전순이익(손실): ['49456184782'] 금융비용: ['72529794'] 전기 수익(매출액): ['377247251739'] 전기 영업이익: ['14680716277'] 영업활동으로 인한 현금흐름: ['51376717919']
# 자산총계: ['356830821832'] 부채총계: ['175479593484'] 자본총계: ['181351228348'] 단기차입금: ['167091634'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['734486641'] 비유동자산: ['133035423874'] 비유동부채: ['58299559311'] 전기말 자산총계: ['288983500395'] 전기말 부채총계: ['160918755466'] 전기말 자본총계: ['128064744929'] 매출채권: ['153465408791'] 매입채무: ['97827924150'] 재고자산: ['3471063744'] 당기순이익: ['10490169013'] 영업이익: ['12937951125'] 수익(매출액): ['120424090790'] 법인세비용차감전순이익(손실): ['13465241923'] 금융비용: ['10174808'] 전기 수익(매출액): ['79607104967'] 전기 영업이익: ['8942001221'] 영업활동으로 인한 현금흐름: ['7677852985']
# 자산총계: ['378736185314'] 부채총계: ['188378981821'] 자본총계: ['190357203493'] 단기차입금: ['172481213'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['543641342'] 비유동자산: ['137061553225'] 비유동부채: ['59534896416'] 전기말 자산총계: ['314984492649'] 전기말 부채총계: ['164311801373'] 전기말 자본총계: ['150672691276'] 매출채권: ['191231527085'] 매입채무: ['104049222897'] 재고자산: ['3467584871'] 당기순이익: ['9057691166'] 영업이익: ['12201841367'] 수익(매출액): ['161938972516'] 법인세비용차감전순이익(손실): ['11813144754'] 금융비용: ['13736376'] 전기 수익(매출액): ['106317781750'] 전기 영업이익: ['16716470943'] 영업활동으로 인한 현금흐름: ['-8217651452']
# 자산총계: ['405554331266'] 부채총계: ['196304717422'] 자본총계: ['209249613844'] 단기차입금: ['172481213'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['543641342'] 비유동자산: ['145081910764'] 비유동부채: ['61513059265'] 전기말 자산총계: ['309547445181'] 전기말 부채총계: ['150565009272'] 전기말 자본총계: ['158982435909'] 매출채권: ['216076241127'] 매입채무: ['110212466745'] 재고자산: ['3461706869'] 당기순이익: ['18928052042'] 영업이익: ['11371338396'] 수익(매출액): ['149524599153'] 법인세비용차감전순이익(손실): ['13197658478'] 금융비용: ['13125232'] 전기 수익(매출액): ['104160038719'] 전기 영업이익: ['8702010605'] 영업활동으로 인한 현금흐름: ['-8318801485']
# 자산총계: ['451746878881'] 부채총계: ['227013990002'] 자본총계: ['224732888879'] 단기차입금: ['173381218'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['16561105422'] 비유동자산: ['119152137674'] 비유동부채: ['76545605162'] 전기말 자산총계: ['334617161562'] 전기말 부채총계: ['163663632831'] 전기말 자본총계: ['170953528731'] 매출채권: ['209572187199'] 매입채무: ['124674696857'] 재고자산: ['3462159360'] 당기순이익: ['49560577253'] 영업이익: ['50682532747'] 수익(매출액): ['628936048866'] 법인세비용차감전순이익(손실): ['53220598562'] 금융비용: ['1790947972'] 전기 수익(매출액): ['444244783883'] 전기 영업이익: ['43348738057'] 영업활동으로 인한 현금흐름: ['32953309590']
#                기업명    연도  보고서 코드        부채비율    차입금의존도    고정장기적합률  자기자본순이익률  \
# 아이디
# 002780202001  진흥기업  2020  1분기보고서  226.232096  7.206614  63.234875  0.020955
# 002780202002  진흥기업  2020   반기보고서  208.936805  7.287110  65.631044  0.036046
# 002780202003  진흥기업  2020  3분기보고서  191.310046  3.912544  71.738665  0.026887
# 002780202004  진흥기업  2020   사업보고서  138.049400  0.375615  68.882641  0.188633
# 002780202101  진흥기업  2021  1분기보고서  125.654219  0.367730  65.854929  0.081485
# 002780202102  진흥기업  2021   반기보고서  109.052145  0.279111  57.452893  0.178341
# 002780202103  진흥기업  2021  3분기보고서   94.705436  0.284013  57.434684  0.062853
# 002780202104  진흥기업  2021   사업보고서   95.735744  0.269436  58.607352  0.368619
# 002780202201  진흥기업  2022  1분기보고서   96.762286  0.252663  55.512200  0.067806
# 002780202202  진흥기업  2022   반기보고서   98.960784  0.189082  54.848294  0.053120
# 002780202203  진흥기업  2022  3분기보고서   93.813658  0.176579  53.582685  0.102805
# 002780202204  진흥기업  2022   사업보고서  101.015028  3.704395  39.548836  0.250504
#
#               매출액영업이익률  매출액경상이익률    이자보상배율(배)   매출액 증가율   총자산 증가율  영업이익 증가율  \
# 아이디
# 002780202001  0.024560  0.022672    13.426124 -0.423844 -0.164178 -0.691080
# 002780202002  0.053032  0.040870    12.499057 -0.387327 -0.138199 -0.393501
# 002780202003  0.031815  0.034276    18.924617 -0.259160 -0.123621 -0.636025
# 002780202004  0.038915  0.037635    18.176432 -0.309746 -0.131652 -0.476433
# 002780202101  0.112327  0.117055   906.050906 -0.071824 -0.107958  3.245044
# 002780202102  0.157231  0.216293  1209.487432  0.172496 -0.009126  2.476263
# 002780202103  0.083545  0.089254   890.080110  0.140203  0.005296  1.994101
# 002780202104  0.097578  0.111326   597.668016  0.177596  0.182738  1.952767
# 002780202201  0.107437  0.111815  1271.567102  0.512730  0.234779  0.446874
# 002780202202  0.075348  0.072948   888.286792  0.523160  0.202396 -0.270071
# 002780202203  0.076050  0.088264   866.372373  0.435527  0.310152  0.306748
# 002780202204  0.080585  0.084620    28.299277  0.415742  0.350041  0.169181
#
#               자기자본 증가율  매출채권 회전기일(일)  재고자산 회전기일(일)  매입채무 회전기일(일)   총자산 회전율  \
# 아이디
# 002780202001  0.150851      0.150851    199.489092    115.128113  0.264749
# 002780202002  0.066292      0.066292    360.378788    197.811247  0.285249
# 002780202003  0.027314      0.027314    479.458404    290.061335  0.296678
# 002780202004  0.220066      0.220066    145.908877     81.704158  1.333418
# 002780202101  0.289640      0.289640    162.358993     90.216016  0.275473
# 002780202102  0.464312      0.464312    242.416971    158.312678  0.337533
# 002780202103  0.504082      0.504082    374.507052    208.240471  0.336491
# 002780202104  0.438419      0.438419    116.904431     69.551299  1.327621
# 002780202201  0.416090      0.416090    114.693719     73.112557  0.337482
# 002780202202  0.263382      0.263382    213.740435    116.296337  0.427577
# 002780202203  0.316181      0.316181    394.509092    201.224438  0.368692
# 002780202204  0.314585      0.314585    121.624207     72.354358  1.392231
#
#                부채상환계수(배)  총차입금상환능력비율
# 아이디
# 002780202001    0.190829    0.136693
# 002780202002    0.385125    0.278859
# 002780202003    4.810068    2.551891
# 002780202004   42.674929   38.787081
# 002780202101   50.227907    8.828501
# 002780202102  181.846234   39.212307
# 002780202103  154.998406   32.712218
# 002780202104  214.710546   56.985310
# 002780202201   43.369900    8.516014
# 002780202202  -44.055533  -11.475203
# 002780202203  -44.748857  -11.616449
# 002780202204   17.687594    1.969186

# %%
df.to_csv(f'/content/drive/MyDrive/ICR/재무비율/{corp_name_p}_재무비율.csv')

# %% [markdown]
# ### 남광토건

# %%
corp_name = ['DL이앤씨', 'HDC현대산업개발', '한전KPS', 'HJ중공업', '신세계건설', 'KCC건설', '대우건설', '서희건설', '특수건설', '계룡건설산업', '신원종합개발',
             '서한', '태영건설', '현대건설', 'GS건설', '동부건설', '코오롱글로벌', 'DL건설', '진흥기업', '남광토건', '한신공영', '금호건설', '삼부토건']
corp_code = ['375500', '294870', '051600', '097230', '034300', '021320', '047040', '035890', '026150', '013580', '017000',
             '011370', '009410', '000720', '006360', '005960', '003070', '001880', '002780', '001260', '004960', '002990', '001470']
report_code = ["11013", "11012", "11014", "11011"] # '11013'=1분기보고서, '11012'=반기보고서, '11014'=3분기보고서, '11011'=사업보고서

corp_name_p = corp_name[19]
corp_code_p = corp_code[19]

all = pd.DataFrame()

for year in range(2019, 2023):
  for code in report_code:
    corp = dart.finstate_all(corp_code_p, year, code, fs_div="OFS")
    # corp = corp.drop('account_id', axis=1)
    all = pd.concat([all, corp], ignore_index=True) # 2019년~2022년 별도 재무제표 전문(분기보고서+반기보고서+사업보고서)

all
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
Quarter = []
cor_year = []
ID_list = []
corp_name_list = []
year_list = []
report_code_list = []
Debt_Ratio = []
Debt_to_Asset_Ratio = []
Fixed_Asset_Turnover_Ratio = []
Return_on_Equity = []
Operating_Profit_Margin = []
Gross_Profit_Margin = []
Interest_Coverage_Ratio =[]
Sales_Growth_Rate = []
Total_Asset_Growth_Rate = []
Operating_Profit_Growth_Rate = []
Equity_Growth_Rate= []
Accounts_Receivable_Turnover = []
Inventory_Turnover = []
Accounts_Payable_Turnover = []
Total_Asset_Turnover_Ratio = []
Debt_Service_Coverage_Ratio = []
Debt_to_Equity_Ratio = []


for year in range(2020, 2023):
  str_year = str(year)
  report_code_list.extend(['1분기보고서' if code == '11013' else '반기보고서' if code == '11012' else '3분기보고서' if code == '11014' else '사업보고서' for code in report_code])
  Quarter.extend(['01' if code == '11013' else '02' if code == '11012' else '03' if code == '11014' else '04' for code in report_code])
  for code in report_code:
    BS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '자산총계' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자산총계
    BS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 부채총계
    BS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자본총계
    BS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '단기차입금' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 단기차입금
    BS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and ('유동성장기차입금' in row['account_nm'] or '유동성장기채무' in row['account_nm']) and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 유동성장기부채
    BS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '사채' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 사채
    BS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '장기차입금' in row['account_nm'] and '유동성' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 장기차입금
    BS8 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동자산' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동자산
    BS9 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동부채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동부채
    BS10 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자산총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자산총계
    BS11 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 부채총계
    BS12 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자본총계
    BS13 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매출채권' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매출채권
    BS14 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매입채무' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매입채무
    BS15 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '재고자산' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 재고자산

    IS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '포괄손익계산서' and '기순' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 당기순이익
    IS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업이익
    IS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '매출액' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 수익(매출액)
    IS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '법인세' in row['account_nm'] and '차감전' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 법인세비용차감전순이익(손실)
    IS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and (row['account_nm'] == '금융비용' or row['account_nm'] == '금융원가') and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 금융비용
    IS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '매출액' in row['account_nm'] and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 수익(매출액) # 분기 보고서만 해당
    IS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 영업이익 # 분기 보고서만 해당

    CF1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '현금흐름표' and row['account_nm'] == '영업활동현금흐름' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업활동으로 인한 현금흐름

    # if BS6 == BS7: # '사채 및 장기차입금'으로 계정과목 하나만 쓰는 회사는 합침(어차피 사채는 차입금 의존도에서만 사용해서 하나 0으로 만들어도 상관없음)
    #   BS6 = ['0']
    # if BS4 == BS5:
    #   BS4 = ['0'] # '단기차입금 및 유동성장기부채' 로 병합해서 쓰는 회사는 하나로 합침(어차피 둘이 항상 붙어서 계산해서 상관없음)
    # if BS4 == [''] or BS4 == []:
    #   BS4 = ['0']
    if BS5 == [''] or BS5 == []:
      BS5 = ['0']
    # if BS6 == []:
    #   BS6 = ['0']
    if BS7 == [] or BS7 == ['']:
      BS7 = ['0']
    if BS15 == [] or BS15 == ['']:
      BS15 = ['0']


    print("자산총계:", BS1, "부채총계:", BS2, "자본총계:", BS3, "단기차입금:", BS4, "유동성장기부채:", BS5, "사채:", BS6, "장기차입금:", BS7, "비유동자산:", BS8, "비유동부채:", BS9, "전기말 자산총계:", BS10, "전기말 부채총계:", BS11,
          "전기말 자본총계:", BS12, "매출채권:", BS13, "매입채무:", BS14, "재고자산:", BS15, "당기순이익:", IS1, "영업이익:", IS2, "수익(매출액):", IS3, "법인세비용차감전순이익(손실):", IS4,
          "금융비용:", IS5, "전기 수익(매출액):", IS6, "전기 영업이익:", IS7, "영업활동으로 인한 현금흐름:", CF1)

    if year != 2020:
      if code == "11013":
        accounting_period = 90
      elif code == "11012":
        accounting_period = 181
      elif code == "11014":
        accounting_period = 273
      elif code == "11011":
        accounting_period = 365
    else: # 2020년은 윤년
      if code == "11013":
        accounting_period = 91
      elif code == "11012":
        accounting_period = 182
      elif code == "11014":
        accounting_period = 274
      elif code == "11011":
        accounting_period = 366


    cor_year.extend([f"{corp_code_p}{str_year}"])
    corp_name_list.append(str(corp_name_p))
    year_list.append(str_year)
    Debt_Ratio.extend([int(BS2)/int(BS3)*100 for BS2, BS3 in zip(BS2, BS3)])
    Debt_to_Asset_Ratio.extend([((int(BS4) + int(BS5) + int(BS6) + int(BS7)) / int(BS1) * 100) for BS4, BS5, BS6, BS7, BS1 in zip(BS4, BS5, BS6, BS7, BS1)])
    Fixed_Asset_Turnover_Ratio.extend([int(BS8)/(int(BS9)+int(BS3))*100 for BS8, BS9, BS3 in zip(BS8, BS9, BS3)]),
    Return_on_Equity.extend([int(IS1)/((int(BS12)+int(BS3))/2) for IS1, BS12, BS3 in zip(IS1, BS12, BS3)])
    Operating_Profit_Margin.extend([int(IS2)/int(IS3) for IS2, IS3 in zip(IS2, IS3)])
    Gross_Profit_Margin.extend([int(IS4)/int(IS3) for IS4, IS3 in zip(IS4, IS3)])
    Interest_Coverage_Ratio.extend([int(IS2)/int(IS5) for IS2, IS5 in zip(IS2, IS5)])
    Sales_Growth_Rate.extend([(int(IS3)-int(IS6))/int(IS6) for IS3, IS6 in zip(IS3, IS6)])
    Total_Asset_Growth_Rate.extend([(int(BS1)-int(BS10))/int(BS10) for BS1, BS10 in zip(BS1, BS10)])
    Operating_Profit_Growth_Rate.extend([(int(IS2)-int(IS7))/int(IS7) for IS2, IS7 in zip(IS2, IS7)])
    Equity_Growth_Rate.extend([(int(BS3)-int(BS12))/int(BS12) for BS3, BS12 in zip(BS3, BS12)])
    Accounts_Receivable_Turnover.extend([int(BS13)/int(IS3)*accounting_period for BS13, IS3 in zip(BS13, IS3)])
    Inventory_Turnover.extend([int(BS15)/int(IS3)*accounting_period for BS15, IS3 in zip(BS15, IS3)])
    Accounts_Payable_Turnover.extend([int(BS14)/int(IS3)*accounting_period for BS14, IS3 in zip(BS14, IS3)])
    Total_Asset_Turnover_Ratio.extend([int(IS3)/int(BS1) for IS3, BS1 in zip(IS3, BS1)])
    Debt_Service_Coverage_Ratio.extend([(int(CF1)+int(IS5))/(int(BS4)+int(BS5)+int(IS5)) for CF1, IS5, BS4, BS5 in zip(CF1, IS5, BS4, BS5)])
    Debt_to_Equity_Ratio.extend([int(CF1)/(int(BS4)+int(BS7)+int(BS5)) for CF1, BS4, BS7, BS5 in zip(CF1, BS4, BS7, BS5)])

ID_list.extend([x+y for x,y in zip(cor_year,Quarter)])

financial_ratio = {
      '아이디':ID_list,
      '기업명':corp_name_list,
      '연도':year_list,
      '보고서 코드':report_code_list,
      '부채비율' : Debt_Ratio,
      '차입금의존도' : Debt_to_Asset_Ratio,
      '고정장기적합률':Fixed_Asset_Turnover_Ratio,
      '자기자본순이익률':Return_on_Equity,
      '매출액영업이익률':Operating_Profit_Margin,
      '매출액경상이익률':Gross_Profit_Margin,
      '이자보상배율(배)':Interest_Coverage_Ratio,
      '매출액 증가율':Sales_Growth_Rate,
      '총자산 증가율':Total_Asset_Growth_Rate,
      '영업이익 증가율':Operating_Profit_Growth_Rate,
      '자기자본 증가율':Equity_Growth_Rate,
      '매출채권 회전기일(일)':Equity_Growth_Rate,
      '재고자산 회전기일(일)':Accounts_Receivable_Turnover,
      '매입채무 회전기일(일)':Accounts_Payable_Turnover,
      '총자산 회전율':Total_Asset_Turnover_Ratio,
      '부채상환계수(배)':Debt_Service_Coverage_Ratio,
      '총차입금상환능력비율':Debt_to_Equity_Ratio
                    }

df = pd.DataFrame(financial_ratio)
df.set_index('아이디', inplace=True)

df
# Out:
# 자산총계: ['199910287018'] 부채총계: ['144006297114'] 자본총계: ['55903989904'] 단기차입금: ['10203329352'] 유동성장기부채: ['0'] 사채: ['25006916721'] 장기차입금: ['0'] 비유동자산: ['62775336720'] 비유동부채: ['9226537245'] 전기말 자산총계: ['152062028267'] 전기말 부채총계: ['100226123788'] 전기말 자본총계: ['51835904479'] 매출채권: ['31057464151'] 매입채무: ['22139479419'] 재고자산: ['127224000'] 당기순이익: ['3031064056'] 영업이익: ['1668909183'] 수익(매출액): ['50568975029'] 법인세비용차감전순이익(손실): ['3031064056'] 금융비용: ['90143714'] 전기 수익(매출액): ['43931389906'] 전기 영업이익: ['1463584188'] 영업활동으로 인한 현금흐름: ['30679371014']
# 자산총계: ['246920578707'] 부채총계: ['190550013949'] 자본총계: ['56370564758'] 단기차입금: ['9245011352'] 유동성장기부채: ['499992000'] 사채: ['30387893138'] 장기차입금: ['333328000'] 비유동자산: ['66609297404'] 비유동부채: ['9422218790'] 전기말 자산총계: ['165680385451'] 전기말 부채총계: ['114192200781'] 전기말 자본총계: ['51488184670'] 매출채권: ['76248707664'] 매입채무: ['20023909013'] 재고자산: ['127224000'] 당기순이익: ['1021572457'] 영업이익: ['2486464495'] 수익(매출액): ['57597021165'] 법인세비용차감전순이익(손실): ['1008956227'] 금융비용: ['67687466'] 전기 수익(매출액): ['58056303965'] 전기 영업이익: ['239910994'] 영업활동으로 인한 현금흐름: ['25544184810']
# 자산총계: ['250527699030'] 부채총계: ['191669139369'] 자본총계: ['58858559661'] 단기차입금: ['9245011352'] 유동성장기부채: ['499992000'] 사채: ['25144826536'] 장기차입금: ['208330000'] 비유동자산: ['68219520607'] 비유동부채: ['8671468307'] 전기말 자산총계: ['175886803444'] 전기말 부채총계: ['123604150217'] 전기말 자본총계: ['52282653227'] 매출채권: ['13285580880'] 매입채무: ['15569187431'] 재고자산: ['127224000'] 당기순이익: ['2487994903'] 영업이익: ['5220407895'] 수익(매출액): ['45906324316'] 법인세비용차감전순이익(손실): ['2487994903'] 금융비용: ['34505519'] 전기 수익(매출액): ['63094484035'] 전기 영업이익: ['2643367375'] 영업활동으로 인한 현금흐름: ['92503562772']
# 자산총계: ['203882590806'] 부채총계: ['137580634869'] 자본총계: ['66301955937'] 단기차입금: ['9245011352'] 유동성장기부채: ['499992000'] 사채: ['32265921910'] 장기차입금: ['83332000'] 비유동자산: ['76412946853'] 비유동부채: ['6820887289'] 전기말 자산총계: ['202430435444'] 전기말 부채총계: ['149557509596'] 전기말 자본총계: ['52872925848'] 매출채권: ['9658582996'] 매입채무: ['25899918944'] 재고자산: ['127224000'] 당기순이익: ['13761610897'] 영업이익: ['15215334844'] 수익(매출액): ['237961500135'] 법인세비용차감전순이익(손실): ['13748994667'] 금융비용: ['390618978'] 전기 수익(매출액): ['236179654398'] 전기 영업이익: ['4821012248'] 영업활동으로 인한 현금흐름: ['38154031806']
# 자산총계: ['248940863717'] 부채총계: ['179220190548'] 자본총계: ['69720673169'] 단기차입금: ['9245011352'] 유동성장기부채: ['374994000'] 사채: ['55999430063'] 장기차입금: ['83332000'] 비유동자산: ['76226542622'] 비유동부채: ['7413748678'] 전기말 자산총계: ['199910287018'] 전기말 부채총계: ['144006297114'] 전기말 자본총계: ['55903989904'] 매출채권: ['5312851173'] 매입채무: ['21307154481'] 재고자산: ['127224000'] 당기순이익: ['3418717232'] 영업이익: ['2996472855'] 수익(매출액): ['60534088645'] 법인세비용차감전순이익(손실): ['3418717232'] 금융비용: ['33985732'] 전기 수익(매출액): ['50568975029'] 전기 영업이익: ['1668909183'] 영업활동으로 인한 현금흐름: ['20936622898']
# 자산총계: ['246347122788'] 부채총계: ['173609970084'] 자본총계: ['72737152704'] 단기차입금: ['9245011352'] 유동성장기부채: ['333328000'] 사채: ['71180743352'] 장기차입금: ['0'] 비유동자산: ['61924311018'] 비유동부채: ['8121985815'] 전기말 자산총계: ['246920578707'] 전기말 부채총계: ['190550013949'] 전기말 자본총계: ['56370564758'] 매출채권: ['9165956479'] 매입채무: ['22298621535'] 재고자산: ['127224000'] 당기순이익: ['3106388027'] 영업이익: ['2778146089'] 수익(매출액): ['85922077922'] 법인세비용차감전순이익(손실): ['3500930289'] 금융비용: ['208211718'] 전기 수익(매출액): ['57597021165'] 전기 영업이익: ['2486464495'] 영업활동으로 인한 현금흐름: ['-2607870521']
# 자산총계: ['249774915281'] 부채총계: ['173331586391'] 자본총계: ['76443328890'] 단기차입금: ['9245011352'] 유동성장기부채: ['208330000'] 사채: ['104185828561'] 장기차입금: ['0'] 비유동자산: ['56329865640'] 비유동부채: ['8779540184'] 전기말 자산총계: ['250527699030'] 전기말 부채총계: ['191669139369'] 전기말 자본총계: ['58858559661'] 매출채권: ['456650566'] 매입채무: ['22506025838'] 재고자산: ['0'] 당기순이익: ['3705646186'] 영업이익: ['2860102236'] 수익(매출액): ['82559653455'] 법인세비용차감전순이익(손실): ['3705646186'] 금융비용: ['30908805'] 전기 수익(매출액): ['45906324316'] 전기 영업이익: ['5220407895'] 영업활동으로 인한 현금흐름: ['-33408598626']
# 자산총계: ['273842119656'] 부채총계: ['186096875465'] 자본총계: ['87745244191'] 단기차입금: ['34245011352'] 유동성장기부채: ['83332000'] 사채: ['70003158414'] 장기차입금: ['5000000000'] 비유동자산: ['68057750883'] 비유동부채: ['15053136431'] 전기말 자산총계: ['203882590806'] 전기말 부채총계: ['137580634869'] 전기말 자본총계: ['66301955937'] 매출채권: ['11503424784'] 매입채무: ['34401739110'] 재고자산: ['0'] 당기순이익: ['21679416652'] 영업이익: ['20804647592'] 수익(매출액): ['356740019691'] 법인세비용차감전순이익(손실): ['23894663066'] 금융비용: ['837527020'] 전기 수익(매출액): ['237961500135'] 전기 영업이익: ['15215334844'] 영업활동으로 인한 현금흐름: ['-10811766294']
# 자산총계: ['310157189797'] 부채총계: ['220775887398'] 자본총계: ['89381302399'] 단기차입금: ['25000000000'] 유동성장기부채: ['0'] 사채: ['76662849445'] 장기차입금: ['14245011352'] 비유동자산: ['72769770199'] 비유동부채: ['24923092872'] 전기말 자산총계: ['248940863717'] 전기말 부채총계: ['179220190548'] 전기말 자본총계: ['69720673169'] 매출채권: ['5962883676'] 매입채무: ['25331873604'] 재고자산: ['0'] 당기순이익: ['1636058208'] 영업이익: ['1682054315'] 수익(매출액): ['82691006077'] 법인세비용차감전순이익(손실): ['1636058208'] 금융비용: ['282731451'] 전기 수익(매출액): ['60534088645'] 전기 영업이익: ['2996472855'] 영업활동으로 인한 현금흐름: ['15653067924']
# 자산총계: ['344593761359'] 부채총계: ['252863436546'] 자본총계: ['91730324813'] 단기차입금: ['25000000000'] 유동성장기부채: ['0'] 사채: ['115817182325'] 장기차입금: ['14245011352'] 비유동자산: ['74765720098'] 비유동부채: ['24929147965'] 전기말 자산총계: ['246347122788'] 전기말 부채총계: ['173609970084'] 전기말 자본총계: ['72737152704'] 매출채권: ['7282450706'] 매입채무: ['26210046276'] 재고자산: ['0'] 당기순이익: ['2514707792'] 영업이익: ['2344193981'] 수익(매출액): ['106815968204'] 법인세비용차감전순이익(손실): ['2707997194'] 금융비용: ['395932378'] 전기 수익(매출액): ['85922077922'] 전기 영업이익: ['2778146089'] 영업활동으로 인한 현금흐름: ['11632464672']
# 자산총계: ['305108158656'] 부채총계: ['212919192597'] 자본총계: ['92188966059'] 단기차입금: ['25000000000'] 유동성장기부채: ['0'] 사채: ['110641328696'] 장기차입금: ['14245011352'] 비유동자산: ['75594447322'] 비유동부채: ['25853652334'] 전기말 자산총계: ['249774915281'] 전기말 부채총계: ['173331586391'] 전기말 자본총계: ['76443328890'] 매출채권: ['1910317876'] 매입채무: ['41146918127'] 재고자산: ['0'] 당기순이익: ['458641246'] 영업이익: ['190339586'] 수익(매출액): ['116882893067'] 법인세비용차감전순이익(손실): ['458641246'] 금융비용: ['338805491'] 전기 수익(매출액): ['82559653455'] 전기 영업이익: ['2860102236'] 영업활동으로 인한 현금흐름: ['-25349146729']
# 자산총계: ['345786655082'] 부채총계: ['238784577050'] 자본총계: ['107002078032'] 단기차입금: ['25000000000'] 유동성장기부채: ['0'] 사채: ['100413897330'] 장기차입금: ['14245011352'] 비유동자산: ['82705820847'] 비유동부채: ['22838185000'] 전기말 자산총계: ['273842119656'] 전기말 부채총계: ['186096875465'] 전기말 자본총계: ['87745244191'] 매출채권: ['4826759168'] 매입채무: ['74052570739'] 재고자산: ['0'] 당기순이익: ['19332575729'] 영업이익: ['11115819532'] 수익(매출액): ['450379452331'] 법인세비용차감전순이익(손실): ['15758164576'] 금융비용: ['1553948349'] 전기 수익(매출액): ['356740019691'] 전기 영업이익: ['20804647592'] 영업활동으로 인한 현금흐름: ['26902362520']
#                기업명    연도  보고서 코드        부채비율     차입금의존도     고정장기적합률  자기자본순이익률  \
# 아이디
# 001260202001  남광토건  2020  1분기보고서  257.595741  17.613024   96.383892  0.056266
# 001260202002  남광토건  2020   반기보고서  338.031054  16.388356  101.241039  0.018943
# 001260202003  남광토건  2020  3분기보고서  325.643612  14.009692  101.021016  0.044772
# 001260202004  남광토건  2020   사업보고서  207.506148  20.646323  104.499420  0.230948
# 001260202101  남광토건  2021  1분기보고서  257.054590  26.392922   98.822991  0.054427
# 001260202102  남광토건  2021   반기보고서  238.681284  32.782637   76.582947  0.048121
# 001260202103  남광토건  2021  3분기보고서  226.745210  45.496630   66.097124  0.054776
# 001260202104  남광토건  2021   사업보고서  212.087706  39.925013   66.205081  0.281465
# 001260202201  남광토건  2022  1분기보고서  247.004554  37.370683   63.663143  0.020566
# 001260202202  남광토건  2022   반기보고서  275.659589  44.998549   64.088855  0.030580
# 001260202203  남광토건  2022  3분기보고서  230.959519  49.125641   64.039961  0.005440
# 001260202204  남광토건  2022   사업보고서  223.158822  40.388750   63.698131  0.198540
#
#               매출액영업이익률  매출액경상이익률   이자보상배율(배)   매출액 증가율   총자산 증가율  영업이익 증가율  \
# 아이디
# 001260202001  0.033003  0.059939   18.513872  0.151090  0.314663  0.140289
# 001260202002  0.043170  0.017518   36.734489 -0.007911  0.490343  9.364112
# 001260202003  0.113719  0.054197  151.291969 -0.272419  0.424369  0.974908
# 001260202004  0.063940  0.057778   38.951858  0.007544  0.007174  2.156046
# 001260202101  0.049501  0.056476   88.168554  0.197060  0.245263  0.795468
# 001260202102  0.032333  0.040745   13.342890  0.491780 -0.002322  0.117308
# 001260202103  0.034643  0.044884   92.533575  0.798437 -0.003005 -0.452131
# 001260202104  0.058319  0.066981   24.840569  0.499150  0.343136  0.367347
# 001260202201  0.020341  0.019785    5.949300  0.366024  0.245907 -0.438655
# 001260202202  0.021946  0.025352    5.920693  0.243173  0.398814 -0.156202
# 001260202203  0.001628  0.003924    0.561796  0.415739  0.221532 -0.933450
# 001260202204  0.024681  0.034989    7.153275  0.262486  0.262723 -0.465705
#
#               자기자본 증가율  매출채권 회전기일(일)  재고자산 회전기일(일)  매입채무 회전기일(일)   총자산 회전율  \
# 아이디
# 001260202001  0.078480      0.078480     55.888600     39.840488  0.252958
# 001260202002  0.094825      0.094825    240.937196     63.273263  0.233261
# 001260202003  0.125776      0.125776     79.297335     92.927443  0.183239
# 001260202004  0.253987      0.253987     14.855518     39.835731  1.167150
# 001260202101  0.247150      0.247150      7.898964     31.678744  0.243167
# 001260202102  0.290339      0.290339     19.308636     46.973381  0.348785
# 001260202103  0.298763      0.298763      1.510006     74.420674  0.330536
# 001260202104  0.323419      0.323419     11.769776     35.198279  1.302722
# 001260202201  0.281991      0.281991      6.489938     27.570938  0.266610
# 001260202202  0.261121      0.261121     12.340136     44.413007  0.309977
# 001260202203  0.205978      0.205978      4.461874     96.105669  0.383087
# 001260202204  0.219463      0.219463      3.911740     60.014257  1.302478
#
#               부채상환계수(배)  총차입금상환능력비율
# 아이디
# 001260202001   2.989226    3.006800
# 001260202002   2.610076    2.534565
# 001260202003   9.462445    9.293727
# 001260202004   3.802889    3.882044
# 001260202101   2.172222    2.157672
# 001260202102  -0.245200   -0.272268
# 001260202103  -3.519276   -3.534052
# 001260202104  -0.283634   -0.274910
# 001260202201   0.630304    0.398855
# 001260202202   0.473635    0.296406
# 001260202203  -0.987037   -0.645920
# 001260202204   1.071641    0.685498

# %%
df.to_csv(f'/content/drive/MyDrive/ICR/재무비율/{corp_name_p}_재무비율.csv')

# %% [markdown]
# ### 한신공영

# %%
corp_name = ['DL이앤씨', 'HDC현대산업개발', '한전KPS', 'HJ중공업', '신세계건설', 'KCC건설', '대우건설', '서희건설', '특수건설', '계룡건설산업', '신원종합개발',
             '서한', '태영건설', '현대건설', 'GS건설', '동부건설', '코오롱글로벌', 'DL건설', '진흥기업', '남광토건', '한신공영', '금호건설', '삼부토건']
corp_code = ['375500', '294870', '051600', '097230', '034300', '021320', '047040', '035890', '026150', '013580', '017000',
             '011370', '009410', '000720', '006360', '005960', '003070', '001880', '002780', '001260', '004960', '002990', '001470']
report_code = ["11013", "11012", "11014", "11011"] # '11013'=1분기보고서, '11012'=반기보고서, '11014'=3분기보고서, '11011'=사업보고서

corp_name_p = corp_name[20]
corp_code_p = corp_code[20]

all = pd.DataFrame()

for year in range(2019, 2023):
  for code in report_code:
    corp = dart.finstate_all(corp_code_p, year, code, fs_div="OFS")
    # corp = corp.drop('account_id', axis=1)
    all = pd.concat([all, corp], ignore_index=True) # 2019년~2022년 별도 재무제표 전문(분기보고서+반기보고서+사업보고서)

all
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# 주석에 있는 단기차입금, 유동성장기부채, 회사채, 장기차입금은 수기로 가져와야 함
short_term_loan = ['112500000000', '115500000000', '115500000000', '115500000000', '179500000000', '223500000000', '142500000000', '132500000000', '137500000000', '137500000000', '142000000000', '182000000000']
liquidity_enhancing_long_term_debt = ['64477000000', '120478000000', '62078000000', '60078000000', '58078000000', '40078000000', '40078000000', '73478000000', '73478000000', '48154000000', '77755000000', '63078000000']
corporate_bond = ['143279000000', '143350000000', '127390000000', '127445000000', '118795000000', '118854000000', '120873000000', '140924000000', '146774000000', '146843000000', '119900000000', '99958000000']
# long_term_loan = ['0', '0', '0', '0', '0', '19181299000', '19181299000', '38362450000', '0', '89100000000', '89100000000', '89719161000']
year_i = ['2020','2020','2020','2020','2021','2021','2021','2021','2022','2022','2022','2022']
report_code_i = ["11013", "11012", "11014", "11011","11013", "11012", "11014", "11011","11013", "11012", "11014", "11011"]

debt = {
    'year':year_i,
    'report_code':report_code_i,
    '단기차입금': short_term_loan,
    '유동성장기부채': liquidity_enhancing_long_term_debt,
    '사채': corporate_bond,
    # '장기차입금': long_term_loan
    }

debt_df = pd.DataFrame(debt)
debt_df
# Out:
#     year report_code         단기차입금       유동성장기부채            사채
# 0   2020       11013  112500000000   64477000000  143279000000
# 1   2020       11012  115500000000  120478000000  143350000000
# 2   2020       11014  115500000000   62078000000  127390000000
# 3   2020       11011  115500000000   60078000000  127445000000
# 4   2021       11013  179500000000   58078000000  118795000000
# 5   2021       11012  223500000000   40078000000  118854000000
# 6   2021       11014  142500000000   40078000000  120873000000
# 7   2021       11011  132500000000   73478000000  140924000000
# 8   2022       11013  137500000000   73478000000  146774000000
# 9   2022       11012  137500000000   48154000000  146843000000
# 10  2022       11014  142000000000   77755000000  119900000000
# 11  2022       11011  182000000000   63078000000   99958000000

# %%
Quarter = []
cor_year = []
ID_list = []
corp_name_list = []
year_list = []
report_code_list = []
Debt_Ratio = []
Debt_to_Asset_Ratio = []
Fixed_Asset_Turnover_Ratio = []
Return_on_Equity = []
Operating_Profit_Margin = []
Gross_Profit_Margin = []
Interest_Coverage_Ratio =[]
Sales_Growth_Rate = []
Total_Asset_Growth_Rate = []
Operating_Profit_Growth_Rate = []
Equity_Growth_Rate= []
Accounts_Receivable_Turnover = []
Inventory_Turnover = []
Accounts_Payable_Turnover = []
Total_Asset_Turnover_Ratio = []
Debt_Service_Coverage_Ratio = []
Debt_to_Equity_Ratio = []


for year in range(2020, 2023):
  str_year = str(year)
  report_code_list.extend(['1분기보고서' if code == '11013' else '반기보고서' if code == '11012' else '3분기보고서' if code == '11014' else '사업보고서' for code in report_code])
  Quarter.extend(['01' if code == '11013' else '02' if code == '11012' else '03' if code == '11014' else '04' for code in report_code])
  for code in report_code:
    BS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '자산총계' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자산총계
    BS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 부채총계
    BS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자본총계
    BS4 = [(row['단기차입금']) for index, row in debt_df.iterrows() if row['year'] == str(year) and row['report_code'] == str(code)]
    BS5 = [(row['유동성장기부채']) for index, row in debt_df.iterrows() if row['year'] == str(year) and row['report_code'] == str(code)]
    BS6 = [(row['사채']) for index, row in debt_df.iterrows() if row['year'] == str(year) and row['report_code'] == str(code)]
    # BS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '단기차입금' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 단기차입금
    # BS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and ('유동성장기차입금' in row['account_nm'] or '유동성장기채무' in row['account_nm']) and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 유동성장기부채
    # BS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '사채' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 사채
    BS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '장기차입금' in row['account_nm'] and '유동성' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 장기차입금
    BS8 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동자산' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동자산
    BS9 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동부채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동부채
    BS10 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자산총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자산총계
    BS11 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 부채총계
    BS12 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자본총계
    BS13 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매출채권' in row['account_nm'] and row['account_id'] == 'ifrs-full_TradeAndOtherCurrentReceivables' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매출채권
    BS14 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매입채무' in row['account_nm'] and row['account_id'] == 'ifrs-full_TradeAndOtherCurrentPayables' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매입채무
    BS15 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '재고자산' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 재고자산

    IS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '포괄손익계산서' and '기순' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 당기순이익
    IS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업이익
    IS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '매출액' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 수익(매출액)
    IS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '법인세' in row['account_nm'] and '차감전' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 법인세비용차감전순이익(손실)
    IS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and (row['account_nm'] == '금융비용' or row['account_nm'] == '금융원가') and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 금융비용
    IS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '매출액' in row['account_nm'] and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 수익(매출액) # 분기 보고서만 해당
    IS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 영업이익 # 분기 보고서만 해당

    CF1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '현금흐름표' and row['account_nm'] == '영업활동현금흐름' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업활동으로 인한 현금흐름

    # if BS6 == BS7: # '사채 및 장기차입금'으로 계정과목 하나만 쓰는 회사는 합침(어차피 사채는 차입금 의존도에서만 사용해서 하나 0으로 만들어도 상관없음)
    #   BS6 = ['0']
    # if BS4 == BS5:
    #   BS4 = ['0'] # '단기차입금 및 유동성장기부채' 로 병합해서 쓰는 회사는 하나로 합침(어차피 둘이 항상 붙어서 계산해서 상관없음)
    # if BS4 == [''] or BS4 == []:
    #   BS4 = ['0']
    # if BS5 == [''] or BS5 == []:
    #   BS5 = ['0']
    # if BS6 == []:
    #   BS6 = ['0']
    # if BS7 == [] or BS7 == ['']:
    #   BS7 = ['0']
    # if BS15 == [] or BS15 == ['']:
    #   BS15 = ['0']


    print("자산총계:", BS1, "부채총계:", BS2, "자본총계:", BS3, "단기차입금:", BS4, "유동성장기부채:", BS5, "사채:", BS6, "장기차입금:", BS7, "비유동자산:", BS8, "비유동부채:", BS9, "전기말 자산총계:", BS10, "전기말 부채총계:", BS11,
          "전기말 자본총계:", BS12, "매출채권:", BS13, "매입채무:", BS14, "재고자산:", BS15, "당기순이익:", IS1, "영업이익:", IS2, "수익(매출액):", IS3, "법인세비용차감전순이익(손실):", IS4,
          "금융비용:", IS5, "전기 수익(매출액):", IS6, "전기 영업이익:", IS7, "영업활동으로 인한 현금흐름:", CF1)

    if year != 2020:
      if code == "11013":
        accounting_period = 90
      elif code == "11012":
        accounting_period = 181
      elif code == "11014":
        accounting_period = 273
      elif code == "11011":
        accounting_period = 365
    else: # 2020년은 윤년
      if code == "11013":
        accounting_period = 91
      elif code == "11012":
        accounting_period = 182
      elif code == "11014":
        accounting_period = 274
      elif code == "11011":
        accounting_period = 366


    cor_year.extend([f"{corp_code_p}{str_year}"])
    corp_name_list.append(str(corp_name_p))
    year_list.append(str_year)
    Debt_Ratio.extend([int(BS2)/int(BS3)*100 for BS2, BS3 in zip(BS2, BS3)])
    Debt_to_Asset_Ratio.extend([((int(BS4) + int(BS5) + int(BS6) + int(BS7)) / int(BS1) * 100) for BS4, BS5, BS6, BS7, BS1 in zip(BS4, BS5, BS6, BS7, BS1)])
    Fixed_Asset_Turnover_Ratio.extend([int(BS8)/(int(BS9)+int(BS3))*100 for BS8, BS9, BS3 in zip(BS8, BS9, BS3)]),
    Return_on_Equity.extend([int(IS1)/((int(BS12)+int(BS3))/2) for IS1, BS12, BS3 in zip(IS1, BS12, BS3)])
    Operating_Profit_Margin.extend([int(IS2)/int(IS3) for IS2, IS3 in zip(IS2, IS3)])
    Gross_Profit_Margin.extend([int(IS4)/int(IS3) for IS4, IS3 in zip(IS4, IS3)])
    Interest_Coverage_Ratio.extend([int(IS2)/int(IS5) for IS2, IS5 in zip(IS2, IS5)])
    Sales_Growth_Rate.extend([(int(IS3)-int(IS6))/int(IS6) for IS3, IS6 in zip(IS3, IS6)])
    Total_Asset_Growth_Rate.extend([(int(BS1)-int(BS10))/int(BS10) for BS1, BS10 in zip(BS1, BS10)])
    Operating_Profit_Growth_Rate.extend([(int(IS2)-int(IS7))/int(IS7) for IS2, IS7 in zip(IS2, IS7)])
    Equity_Growth_Rate.extend([(int(BS3)-int(BS12))/int(BS12) for BS3, BS12 in zip(BS3, BS12)])
    Accounts_Receivable_Turnover.extend([int(BS13)/int(IS3)*accounting_period for BS13, IS3 in zip(BS13, IS3)])
    Inventory_Turnover.extend([int(BS15)/int(IS3)*accounting_period for BS15, IS3 in zip(BS15, IS3)])
    Accounts_Payable_Turnover.extend([int(BS14)/int(IS3)*accounting_period for BS14, IS3 in zip(BS14, IS3)])
    Total_Asset_Turnover_Ratio.extend([int(IS3)/int(BS1) for IS3, BS1 in zip(IS3, BS1)])
    Debt_Service_Coverage_Ratio.extend([(int(CF1)+int(IS5))/(int(BS4)+int(BS5)+int(IS5)) for CF1, IS5, BS4, BS5 in zip(CF1, IS5, BS4, BS5)])
    Debt_to_Equity_Ratio.extend([int(CF1)/(int(BS4)+int(BS7)+int(BS5)) for CF1, BS4, BS7, BS5 in zip(CF1, BS4, BS7, BS5)])

ID_list.extend([x+y for x,y in zip(cor_year,Quarter)])

financial_ratio = {
      '아이디':ID_list,
      '기업명':corp_name_list,
      '연도':year_list,
      '보고서 코드':report_code_list,
      '부채비율' : Debt_Ratio,
      '차입금의존도' : Debt_to_Asset_Ratio,
      '고정장기적합률':Fixed_Asset_Turnover_Ratio,
      '자기자본순이익률':Return_on_Equity,
      '매출액영업이익률':Operating_Profit_Margin,
      '매출액경상이익률':Gross_Profit_Margin,
      '이자보상배율(배)':Interest_Coverage_Ratio,
      '매출액 증가율':Sales_Growth_Rate,
      '총자산 증가율':Total_Asset_Growth_Rate,
      '영업이익 증가율':Operating_Profit_Growth_Rate,
      '자기자본 증가율':Equity_Growth_Rate,
      '매출채권 회전기일(일)':Equity_Growth_Rate,
      '재고자산 회전기일(일)':Accounts_Receivable_Turnover,
      '매입채무 회전기일(일)':Accounts_Payable_Turnover,
      '총자산 회전율':Total_Asset_Turnover_Ratio,
      '부채상환계수(배)':Debt_Service_Coverage_Ratio,
      '총차입금상환능력비율':Debt_to_Equity_Ratio
                    }

df = pd.DataFrame(financial_ratio)
df.set_index('아이디', inplace=True)

df
# Out:
# 자산총계: ['1639473378867'] 부채총계: ['1138558187403'] 자본총계: ['500915191464'] 단기차입금: ['112500000000'] 유동성장기부채: ['64477000000'] 사채: ['143279000000'] 장기차입금: ['236138953680'] 비유동자산: ['650647314132'] 비유동부채: ['367414494373'] 전기말 자산총계: ['1710798830583'] 전기말 부채총계: ['1272881954244'] 전기말 자본총계: ['437916876339'] 매출채권: ['239592544451'] 매입채무: ['319227626002'] 재고자산: ['211340204415'] 당기순이익: ['17585700343'] 영업이익: ['22650286142'] 수익(매출액): ['344185391324'] 법인세비용차감전순이익(손실): ['21394993613'] 금융비용: ['10107883544'] 전기 수익(매출액): ['359748762863'] 전기 영업이익: ['20257663759'] 영업활동으로 인한 현금흐름: ['68378964479']
# 자산총계: ['1652672342064'] 부채총계: ['1132446382897'] 자본총계: ['520225959167'] 단기차입금: ['115500000000'] 유동성장기부채: ['120478000000'] 사채: ['143350000000'] 장기차입금: ['178198366568'] 비유동자산: ['673212576497'] 비유동부채: ['311466904637'] 전기말 자산총계: ['1563204443077'] 전기말 부채총계: ['1098008360151'] 전기말 자본총계: ['465196082926'] 매출채권: ['301938586943'] 매입채무: ['304770005334'] 재고자산: ['173306926810'] 당기순이익: ['19203838719'] 영업이익: ['22030605361'] 수익(매출액): ['404532396140'] 법인세비용차감전순이익(손실): ['25176714906'] 금융비용: ['6777185682'] 전기 수익(매출액): ['393548385318'] 전기 영업이익: ['15836363797'] 영업활동으로 인한 현금흐름: ['59485199487']
# 자산총계: ['1560684847977'] 부채총계: ['1018818371195'] 자본총계: ['541866476782'] 단기차입금: ['115500000000'] 유동성장기부채: ['62078000000'] 사채: ['127390000000'] 장기차입금: ['168210123735'] 비유동자산: ['690882580850'] 비유동부채: ['300830410210'] 전기말 자산총계: ['1584672751647'] 전기말 부채총계: ['1106800909240'] 전기말 자본총계: ['477871842407'] 매출채권: ['197235573237'] 매입채무: ['265196597220'] 재고자산: ['111286461447'] 당기순이익: ['21451464388'] 영업이익: ['32384215633'] 수익(매출액): ['338172998120'] 법인세비용차감전순이익(손실): ['28009199942'] 금융비용: ['9204305123'] 전기 수익(매출액): ['351637307634'] 전기 영업이익: ['19113027557'] 영업활동으로 인한 현금흐름: ['225476895281']
# 자산총계: ['1595186693728'] 부채총계: ['1001404768405'] 자본총계: ['593781925323'] 단기차입금: ['115500000000'] 유동성장기부채: ['60078000000'] 사채: ['127445000000'] 장기차입금: ['168264123312'] 비유동자산: ['668288849722'] 비유동부채: ['286738078813'] 전기말 자산총계: ['1505748879941'] 전기말 부채총계: ['1018149146419'] 전기말 자본총계: ['487599733522'] 매출채권: ['240737035751'] 매입채무: ['238984234462'] 재고자산: ['92166434473'] 당기순이익: ['105685467087'] 영업이익: ['90914126329'] 수익(매출액): ['1500329130295'] 법인세비용차감전순이익(손실): ['137517470797'] 금융비용: ['28292345418'] 전기 수익(매출액): ['1541115912799'] 전기 영업이익: ['104276713486'] 영업활동으로 인한 현금흐름: ['131977837755']
# 자산총계: ['1708256242843'] 부채총계: ['1106392036430'] 자본총계: ['601864206413'] 단기차입금: ['179500000000'] 유동성장기부채: ['58078000000'] 사채: ['118795000000'] 장기차입금: ['216007973515'] 비유동자산: ['732852154721'] 비유동부채: ['329392397980'] 전기말 자산총계: ['1639473378867'] 전기말 부채총계: ['1138558187403'] 전기말 자본총계: ['500915191464'] 매출채권: ['226074873795'] 매입채무: ['248104069304'] 재고자산: ['80406485419'] 당기순이익: ['12483520446'] 영업이익: ['11507905681'] 수익(매출액): ['265126692327'] 법인세비용차감전순이익(손실): ['15913090737'] 금융비용: ['6431564751'] 전기 수익(매출액): ['344185391324'] 전기 영업이익: ['22650286142'] 영업활동으로 인한 현금흐름: ['54159129295']
# 자산총계: ['1711142743517'] 부채총계: ['1103637881037'] 자본총계: ['607504862480'] 단기차입금: ['223500000000'] 유동성장기부채: ['40078000000'] 사채: ['118854000000'] 장기차입금: ['235939988459'] 비유동자산: ['721535963855'] 비유동부채: ['344459235632'] 전기말 자산총계: ['1652672342064'] 전기말 부채총계: ['1132446382897'] 전기말 자본총계: ['520225959167'] 매출채권: ['282059696737'] 매입채무: ['221766957052'] 재고자산: ['65046308674'] 당기순이익: ['5966195717'] 영업이익: ['9756999533'] 수익(매출액): ['320409721448'] 법인세비용차감전순이익(손실): ['8973845355'] 금융비용: ['7407279646'] 전기 수익(매출액): ['404532396140'] 전기 영업이익: ['22030605361'] 영업활동으로 인한 현금흐름: ['-30982663225']
# 자산총계: ['1786082570344'] 부채총계: ['1170303854732'] 자본총계: ['615778715612'] 단기차입금: ['142500000000'] 유동성장기부채: ['40078000000'] 사채: ['120873000000'] 장기차입금: ['382718437612'] 비유동자산: ['719481397010'] 비유동부채: ['493229284348'] 전기말 자산총계: ['1560684847977'] 전기말 부채총계: ['1018818371195'] 전기말 자본총계: ['541866476782'] 매출채권: ['252834474607'] 매입채무: ['242424993282'] 재고자산: ['287476312390'] 당기순이익: ['9073770343'] 영업이익: ['6909365018'] 수익(매출액): ['318028028270'] 법인세비용차감전순이익(손실): ['11822646938'] 금융비용: ['4639941115'] 전기 수익(매출액): ['338172998120'] 전기 영업이익: ['32384215633'] 영업활동으로 인한 현금흐름: ['-71280504966']
# 자산총계: ['1854652674126'] 부채총계: ['1194434503804'] 자본총계: ['660218170322'] 단기차입금: ['132500000000'] 유동성장기부채: ['73478000000'] 사채: ['140924000000'] 장기차입금: ['354246218973'] 비유동자산: ['759562296723'] 비유동부채: ['456383766730'] 전기말 자산총계: ['1595186693728'] 전기말 부채총계: ['1001404768405'] 전기말 자본총계: ['593781925323'] 매출채권: ['310410153439'] 매입채무: ['245867753702'] 재고자산: ['279098138189'] 당기순이익: ['55718841122'] 영업이익: ['47144324306'] 수익(매출액): ['1291893468893'] 법인세비용차감전순이익(손실): ['81227457358'] 금융비용: ['25760832893'] 전기 수익(매출액): ['1500329130295'] 전기 영업이익: ['90914126329'] 영업활동으로 인한 현금흐름: ['-77796944186']
# 자산총계: ['1917707892519'] 부채총계: ['1248578591543'] 자본총계: ['669129300976'] 단기차입금: ['137500000000'] 유동성장기부채: ['73478000000'] 사채: ['146774000000'] 장기차입금: ['346454994455'] 비유동자산: ['756472563271'] 비유동부채: ['446533744736'] 전기말 자산총계: ['1708256242843'] 전기말 부채총계: ['1106392036430'] 전기말 자본총계: ['601864206413'] 매출채권: ['304640875912'] 매입채무: ['275653572239'] 재고자산: ['289773676551'] 당기순이익: ['13813396210'] 영업이익: ['17981817361'] 수익(매출액): ['273030062943'] 법인세비용차감전순이익(손실): ['17921033912'] 금융비용: ['8100490422'] 전기 수익(매출액): ['265126692327'] 전기 영업이익: ['11507905681'] 영업활동으로 인한 현금흐름: ['10434958528']
# 자산총계: ['1908809375132'] 부채총계: ['1235593458493'] 자본총계: ['673215916639'] 단기차입금: ['137500000000'] 유동성장기부채: ['48154000000'] 사채: ['146843000000'] 장기차입금: ['320023109071'] 비유동자산: ['766903890008'] 비유동부채: ['417323286517'] 전기말 자산총계: ['1711142743517'] 전기말 부채총계: ['1103637881037'] 전기말 자본총계: ['607504862480'] 매출채권: ['311173494423'] 매입채무: ['304830610064'] 재고자산: ['267594452874'] 당기순이익: ['4556549489'] 영업이익: ['3058730748'] 수익(매출액): ['342025054691'] 법인세비용차감전순이익(손실): ['5893425861'] 금융비용: ['8890746860'] 전기 수익(매출액): ['320409721448'] 전기 영업이익: ['9756999533'] 영업활동으로 인한 현금흐름: ['56343178662']
# 자산총계: ['1846173572905'] 부채총계: ['1162406326156'] 자본총계: ['683767246749'] 단기차입금: ['142000000000'] 유동성장기부채: ['77755000000'] 사채: ['119900000000'] 장기차입금: ['297699008513'] 비유동자산: ['768068434138'] 비유동부채: ['395218534430'] 전기말 자산총계: ['1786082570344'] 전기말 부채총계: ['1170303854732'] 전기말 자본총계: ['615778715612'] 매출채권: ['271603305677'] 매입채무: ['256581565208'] 재고자산: ['265909609427'] 당기순이익: ['8964694808'] 영업이익: ['1877691511'] 수익(매출액): ['241902216673'] 법인세비용차감전순이익(손실): ['12071197265'] 금융비용: ['7821255455'] 전기 수익(매출액): ['318028028270'] 전기 영업이익: ['6909365018'] 영업활동으로 인한 현금흐름: ['45843277602']
# 자산총계: ['1997213423657'] 부채총계: ['1274120643917'] 자본총계: ['723092779740'] 단기차입금: ['182000000000'] 유동성장기부채: ['63078000000'] 사채: ['99958000000'] 장기차입금: ['338955376465'] 비유동자산: ['851286305194'] 비유동부채: ['427870770233'] 전기말 자산총계: ['1854652674126'] 전기말 부채총계: ['1194434503804'] 전기말 자본총계: ['660218170322'] 매출채권: ['255565331714'] 매입채무: ['290022627446'] 재고자산: ['264146190779'] 당기순이익: ['50369227832'] 영업이익: ['36051365411'] 수익(매출액): ['1190595680782'] 법인세비용차감전순이익(손실): ['66290683468'] 금융비용: ['42525163319'] 전기 수익(매출액): ['1291893468893'] 전기 영업이익: ['47144324306'] 영업활동으로 인한 현금흐름: ['113222152665']
#                기업명    연도  보고서 코드        부채비율     차입금의존도    고정장기적합률  자기자본순이익률  \
# 아이디
# 004960202001  한신공영  2020  1분기보고서  227.295599  33.937419  74.930908  0.037463
# 004960202002  한신공영  2020   반기보고서  217.683559  33.734840  80.944854  0.038976
# 004960202003  한신공영  2020  3분기보고서  188.020189  30.318621  81.984708  0.042072
# 004960202004  한신공영  2020   사업보고서  168.648577  29.544324  75.897066  0.195464
# 004960202101  한신공영  2021  1분기보고서  183.827519  33.506740  78.694975  0.022640
# 004960202102  한신공영  2021   반기보고서  181.667333  36.137955  75.794451  0.010581
# 004960202103  한신공영  2021  3분기보고서  190.052664  38.417565  64.876123  0.015676
# 004960202104  한신공영  2021   사업보고서  180.915121  37.804826  68.024447  0.088866
# 004960202201  한신공영  2022  1분기보고서  186.597507  36.721286  67.804752  0.021736
# 004960202202  한신공영  2022   반기보고서  183.535984  34.184666  70.323367  0.007116
# 004960202203  한신공영  2022  3분기보고서  170.000293  34.522973  71.184296  0.013797
# 004960202204  한신공영  2022   사업보고서  176.204310  34.247285  73.962925  0.072824
#
#               매출액영업이익률  매출액경상이익률  이자보상배율(배)   매출액 증가율   총자산 증가율  영업이익 증가율  \
# 아이디
# 004960202001  0.065808  0.062161   2.240853 -0.043262 -0.041691  0.118109
# 004960202002  0.054459  0.062237   3.250701  0.027910  0.057234  0.391140
# 004960202003  0.095762  0.082825   3.518377 -0.038290 -0.015137  0.694353
# 004960202004  0.060596  0.091658   3.213382 -0.026466  0.059398 -0.128145
# 004960202101  0.043405  0.060021   1.789286 -0.229698  0.041954 -0.491931
# 004960202102  0.030452  0.028007   1.317218 -0.207950  0.035379 -0.557116
# 004960202103  0.021726  0.037175   1.489106 -0.059570  0.144422 -0.786644
# 004960202104  0.036492  0.062875   1.830078 -0.138927  0.162656 -0.481441
# 004960202201  0.065860  0.065638   2.219843  0.029810  0.122611  0.562562
# 004960202202  0.008943  0.017231   0.344035  0.067462  0.115517 -0.686509
# 004960202203  0.007762  0.049901   0.240075 -0.239368  0.033644 -0.728240
# 004960202204  0.030280  0.055679   0.847765 -0.078410  0.076867 -0.235298
#
#               자기자본 증가율  매출채권 회전기일(일)  재고자산 회전기일(일)  매입채무 회전기일(일)   총자산 회전율  \
# 아이디
# 004960202001  0.143859      0.143859     63.346447     84.401357  0.209937
# 004960202002  0.118294      0.118294    135.842823    137.116685  0.244775
# 004960202003  0.133916      0.133916    159.807398    214.871879  0.216682
# 004960202004  0.217765      0.217765     58.726951     58.299361  0.940535
# 004960202101  0.201529      0.201529     76.743456     84.221494  0.155203
# 004960202102  0.167771      0.167771    159.336005    125.276534  0.187249
# 004960202103  0.136403      0.136403    217.036882    208.101228  0.178059
# 004960202104  0.111887      0.111887     87.700502     69.465271  0.696569
# 004960202201  0.111761      0.111761    100.420000     90.864798  0.142373
# 004960202202  0.108165      0.108165    164.673324    161.316663  0.179182
# 004960202203  0.110411      0.110411    306.519318    289.566455  0.131029
# 004960202204  0.095233      0.095233     78.348467     88.912013  0.596128
#
#               부채상환계수(배)  총차입금상환능력비율
# 아이디
# 004960202001   0.419525    0.165520
# 004960202002   0.272960    0.143623
# 004960202003   1.256442    0.652067
# 004960202004   0.786138    0.383833
# 004960202101   0.248313    0.119402
# 004960202102  -0.086999   -0.062025
# 004960202103  -0.355952   -0.126094
# 004960202104  -0.224546   -0.138868
# 004960202201   0.084606    0.018720
# 004960202202   0.335316    0.111421
# 004960202203   0.235809    0.088594
# 004960202204   0.541535    0.193862

# %%
df.to_csv(f'/content/drive/MyDrive/ICR/재무비율/{corp_name_p}_재무비율.csv')

# %% [markdown]
# ### 금호건설

# %%
corp_name = ['DL이앤씨', 'HDC현대산업개발', '한전KPS', 'HJ중공업', '신세계건설', 'KCC건설', '대우건설', '서희건설', '특수건설', '계룡건설산업', '신원종합개발',
             '서한', '태영건설', '현대건설', 'GS건설', '동부건설', '코오롱글로벌', 'DL건설', '진흥기업', '남광토건', '한신공영', '금호건설', '삼부토건']
corp_code = ['375500', '294870', '051600', '097230', '034300', '021320', '047040', '035890', '026150', '013580', '017000',
             '011370', '009410', '000720', '006360', '005960', '003070', '001880', '002780', '001260', '004960', '002990', '001470']
report_code = ["11013", "11012", "11014", "11011"] # '11013'=1분기보고서, '11012'=반기보고서, '11014'=3분기보고서, '11011'=사업보고서

corp_name_p = corp_name[21]
corp_code_p = corp_code[21]

all = pd.DataFrame()

for year in range(2019, 2023):
  for code in report_code:
    corp = dart.finstate_all(corp_code_p, year, code, fs_div="OFS")
    # corp = corp.drop('account_id', axis=1)
    all = pd.concat([all, corp], ignore_index=True) # 2019년~2022년 별도 재무제표 전문(분기보고서+반기보고서+사업보고서)

all
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
Quarter = []
cor_year = []
ID_list = []
corp_name_list = []
year_list = []
report_code_list = []
Debt_Ratio = []
Debt_to_Asset_Ratio = []
Fixed_Asset_Turnover_Ratio = []
Return_on_Equity = []
Operating_Profit_Margin = []
Gross_Profit_Margin = []
Interest_Coverage_Ratio =[]
Sales_Growth_Rate = []
Total_Asset_Growth_Rate = []
Operating_Profit_Growth_Rate = []
Equity_Growth_Rate= []
Accounts_Receivable_Turnover = []
Inventory_Turnover = []
Accounts_Payable_Turnover = []
Total_Asset_Turnover_Ratio = []
Debt_Service_Coverage_Ratio = []
Debt_to_Equity_Ratio = []


for year in range(2020, 2023):
  str_year = str(year)
  report_code_list.extend(['1분기보고서' if code == '11013' else '반기보고서' if code == '11012' else '3분기보고서' if code == '11014' else '사업보고서' for code in report_code])
  Quarter.extend(['01' if code == '11013' else '02' if code == '11012' else '03' if code == '11014' else '04' for code in report_code])
  for code in report_code:
    BS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '자산총계' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자산총계
    BS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 부채총계
    BS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '기말 자본' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자본총계
    BS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '단기차입금' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 단기차입금
    BS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and ('유동성장기차입금' in row['account_nm'] or '유동성장기채무' in row['account_nm']) and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 유동성장기부채
    BS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '사채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 사채
    BS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '장기차입금' in row['account_nm'] and '유동성' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 장기차입금
    BS8 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동자산' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동자산
    BS9 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동부채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동부채
    BS10 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자산총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자산총계
    BS11 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 부채총계
    BS12 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '기말 자본' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자본총계
    BS13 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매출채권' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매출채권
    BS14 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매입채무' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매입채무
    BS15 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '재고자산' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 재고자산
    BS16 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '유동성사채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 유동성사채

    IS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '포괄손익계산서' and '기순' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 당기순이익
    IS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업이익
    IS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '매출액' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 수익(매출액)
    IS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '법인세' in row['account_nm'] and '차감전' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 법인세비용차감전순이익(손실)
    IS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and (row['account_nm'] == '금융비용' or row['account_nm'] == '금융원가') and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 금융비용
    IS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '매출액' in row['account_nm'] and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 수익(매출액) # 분기 보고서만 해당
    IS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '영업이익' in row['account_nm'] and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 영업이익 # 분기 보고서만 해당

    CF1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '현금흐름표' and row['account_nm'] == '영업활동현금흐름' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업활동으로 인한 현금흐름

    # if BS6 == BS7: # '사채 및 장기차입금'으로 계정과목 하나만 쓰는 회사는 합침(어차피 사채는 차입금 의존도에서만 사용해서 하나 0으로 만들어도 상관없음)
    #   BS6 = ['0']
    # if BS4 == BS5:
    #   BS4 = ['0'] # '단기차입금 및 유동성장기부채' 로 병합해서 쓰는 회사는 하나로 합침(어차피 둘이 항상 붙어서 계산해서 상관없음)
    # if BS4 == [''] or BS4 == []:
    #   BS4 = ['0']
    # if BS5 == [''] or BS5 == []:
    #   BS5 = ['0']
    if BS6 == ['']:
      BS6 = ['0']
    # if BS7 == [] or BS7 == ['']:
    #   BS7 = ['0']
    # if BS15 == [] or BS15 == ['']:
    #   BS15 = ['0']


    print("자산총계:", BS1, "부채총계:", BS2, "자본총계:", BS3, "단기차입금:", BS4, "유동성장기부채:", BS5, "사채:", BS6, "장기차입금:", BS7, "비유동자산:", BS8, "비유동부채:", BS9, "전기말 자산총계:", BS10, "전기말 부채총계:", BS11,
          "전기말 자본총계:", BS12, "매출채권:", BS13, "매입채무:", BS14, "재고자산:", BS15, "당기순이익:", IS1, "영업이익:", IS2, "수익(매출액):", IS3, "법인세비용차감전순이익(손실):", IS4,
          "금융비용:", IS5, "전기 수익(매출액):", IS6, "전기 영업이익:", IS7, "영업활동으로 인한 현금흐름:", CF1)

    if year != 2020:
      if code == "11013":
        accounting_period = 90
      elif code == "11012":
        accounting_period = 181
      elif code == "11014":
        accounting_period = 273
      elif code == "11011":
        accounting_period = 365
    else: # 2020년은 윤년
      if code == "11013":
        accounting_period = 91
      elif code == "11012":
        accounting_period = 182
      elif code == "11014":
        accounting_period = 274
      elif code == "11011":
        accounting_period = 366


    cor_year.extend([f"{corp_code_p}{str_year}"])
    corp_name_list.append(str(corp_name_p))
    year_list.append(str_year)
    Debt_Ratio.extend([int(BS2)/int(BS3)*100 for BS2, BS3 in zip(BS2, BS3)])
    Debt_to_Asset_Ratio.extend([((int(BS4) + int(BS5) + int(BS6) + int(BS7) + int(BS16)) / int(BS1) * 100) for BS4, BS5, BS6, BS7, BS1, BS16 in zip(BS4, BS5, BS6, BS7, BS1, BS16)])
    Fixed_Asset_Turnover_Ratio.extend([int(BS8)/(int(BS9)+int(BS3))*100 for BS8, BS9, BS3 in zip(BS8, BS9, BS3)]),
    Return_on_Equity.extend([int(IS1)/((int(BS12)+int(BS3))/2) for IS1, BS12, BS3 in zip(IS1, BS12, BS3)])
    Operating_Profit_Margin.extend([int(IS2)/int(IS3) for IS2, IS3 in zip(IS2, IS3)])
    Gross_Profit_Margin.extend([int(IS4)/int(IS3) for IS4, IS3 in zip(IS4, IS3)])
    Interest_Coverage_Ratio.extend([int(IS2)/int(IS5) for IS2, IS5 in zip(IS2, IS5)])
    Sales_Growth_Rate.extend([(int(IS3)-int(IS6))/int(IS6) for IS3, IS6 in zip(IS3, IS6)])
    Total_Asset_Growth_Rate.extend([(int(BS1)-int(BS10))/int(BS10) for BS1, BS10 in zip(BS1, BS10)])
    Operating_Profit_Growth_Rate.extend([(int(IS2)-int(IS7))/int(IS7) for IS2, IS7 in zip(IS2, IS7)])
    Equity_Growth_Rate.extend([(int(BS3)-int(BS12))/int(BS12) for BS3, BS12 in zip(BS3, BS12)])
    Accounts_Receivable_Turnover.extend([int(BS13)/int(IS3)*accounting_period for BS13, IS3 in zip(BS13, IS3)])
    Inventory_Turnover.extend([int(BS15)/int(IS3)*accounting_period for BS15, IS3 in zip(BS15, IS3)])
    Accounts_Payable_Turnover.extend([int(BS14)/int(IS3)*accounting_period for BS14, IS3 in zip(BS14, IS3)])
    Total_Asset_Turnover_Ratio.extend([int(IS3)/int(BS1) for IS3, BS1 in zip(IS3, BS1)])
    Debt_Service_Coverage_Ratio.extend([(int(CF1)+int(IS5))/(int(BS4)+int(BS5)+int(IS5)) for CF1, IS5, BS4, BS5 in zip(CF1, IS5, BS4, BS5)])
    Debt_to_Equity_Ratio.extend([int(CF1)/(int(BS4)+int(BS7)+int(BS5)) for CF1, BS4, BS7, BS5 in zip(CF1, BS4, BS7, BS5)])

ID_list.extend([x+y for x,y in zip(cor_year,Quarter)])

financial_ratio = {
      '아이디':ID_list,
      '기업명':corp_name_list,
      '연도':year_list,
      '보고서 코드':report_code_list,
      '부채비율' : Debt_Ratio,
      '차입금의존도' : Debt_to_Asset_Ratio,
      '고정장기적합률':Fixed_Asset_Turnover_Ratio,
      '자기자본순이익률':Return_on_Equity,
      '매출액영업이익률':Operating_Profit_Margin,
      '매출액경상이익률':Gross_Profit_Margin,
      '이자보상배율(배)':Interest_Coverage_Ratio,
      '매출액 증가율':Sales_Growth_Rate,
      '총자산 증가율':Total_Asset_Growth_Rate,
      '영업이익 증가율':Operating_Profit_Growth_Rate,
      '자기자본 증가율':Equity_Growth_Rate,
      '매출채권 회전기일(일)':Equity_Growth_Rate,
      '재고자산 회전기일(일)':Accounts_Receivable_Turnover,
      '매입채무 회전기일(일)':Accounts_Payable_Turnover,
      '총자산 회전율':Total_Asset_Turnover_Ratio,
      '부채상환계수(배)':Debt_Service_Coverage_Ratio,
      '총차입금상환능력비율':Debt_to_Equity_Ratio
                    }

df = pd.DataFrame(financial_ratio)
df.set_index('아이디', inplace=True)

df
# Out:
# 자산총계: ['1352471973714'] 부채총계: ['977229734773'] 자본총계: ['375242238941'] 단기차입금: ['71655450000'] 유동성장기부채: ['39338890059'] 사채: ['24600000000'] 장기차입금: ['29988793898'] 비유동자산: ['331731243607'] 비유동부채: ['184221556479'] 전기말 자산총계: ['1215982936853'] 전기말 부채총계: ['883246106921'] 전기말 자본총계: ['332736829932'] 매출채권: ['239533337075'] 매입채무: ['194522576764'] 재고자산: ['130901027875'] 당기순이익: ['13055693303'] 영업이익: ['16587813411'] 수익(매출액): ['356890228107'] 법인세비용차감전순이익(손실): ['16504567411'] 금융비용: ['3266720835'] 전기 수익(매출액): ['311389893261'] 전기 영업이익: ['6761112009'] 영업활동으로 인한 현금흐름: ['74787394728']
# 자산총계: ['1352807890981'] 부채총계: ['965611521087'] 자본총계: ['387196369894'] 단기차입금: ['69455450000'] 유동성장기부채: ['39338890059'] 사채: ['21900000000'] 장기차입금: ['28525359393'] 비유동자산: ['311812554700'] 비유동부채: ['171117697310'] 전기말 자산총계: ['1304005482877'] 전기말 부채총계: ['953267273114'] 전기말 자본총계: ['350738209763'] 매출채권: ['257329396997'] 매입채무: ['217992312962'] 재고자산: ['135141897170'] 당기순이익: ['12115090530'] 영업이익: ['18232660803'] 수익(매출액): ['433909362539'] 법인세비용차감전순이익(손실): ['15188945361'] 금융비용: ['2281544047'] 전기 수익(매출액): ['450661055639'] 전기 영업이익: ['14564986331'] 영업활동으로 인한 현금흐름: ['94124798904']
# 자산총계: ['1324290142390'] 부채총계: ['931589590817'] 자본총계: ['392700551573'] 단기차입금: ['69455450000'] 유동성장기부채: ['34829058330'] 사채: ['19200000000'] 장기차입금: ['26919066659'] 비유동자산: ['328391134604'] 비유동부채: ['162458161048'] 전기말 자산총계: ['1255457057313'] 전기말 부채총계: ['888423768180'] 전기말 자본총계: ['367033289133'] 매출채권: ['283640574584'] 매입채무: ['236301360206'] 재고자산: ['147733047175'] 당기순이익: ['5657097743'] 영업이익: ['23734632096'] 수익(매출액): ['489884474922'] 법인세비용차감전순이익(손실): ['3396725653'] 금융비용: ['3290764825'] 전기 수익(매출액): ['426013831475'] 전기 영업이익: ['16681901598'] 영업활동으로 인한 현금흐름: ['40619910036']
# 자산총계: ['1380157441704'] 부채총계: ['980065075097'] 자본총계: ['400092366607'] 단기차입금: ['68455450000'] 유동성장기부채: ['34338890059'] 사채: ['16500000000'] 장기차입금: ['25461725555'] 비유동자산: ['601343835620'] 비유동부채: ['149734528172'] 전기말 자산총계: ['1328869610754'] 전기말 부채총계: ['953105020789'] 전기말 자본총계: ['375764589965'] 매출채권: ['321782843767'] 매입채무: ['241005454437'] 재고자산: ['165385493204'] 당기순이익: ['44152345665'] 영업이익: ['81019900079'] 수익(매출액): ['1829136280851'] 법인세비용차감전순이익(손실): ['46787202097'] 금융비용: ['19174629522'] 전기 수익(매출액): ['1597271635672'] 전기 영업이익: ['55241336936'] 영업활동으로 인한 현금흐름: ['104069566121']
# 자산총계: ['1518166909694'] 부채총계: ['1072441284735'] 자본총계: ['445725624959'] 단기차입금: ['58455450000'] 유동성장기부채: ['27338890059'] 사채: ['13800000000'] 장기차입금: ['34003013390'] 비유동자산: ['639561812867'] 비유동부채: ['156052140038'] 전기말 자산총계: ['1352471973714'] 전기말 부채총계: ['977229734773'] 전기말 자본총계: ['375242238941'] 매출채권: ['318706680183'] 매입채무: ['222727130503'] 재고자산: ['221201970741'] 당기순이익: ['18422384655'] 영업이익: ['22280260136'] 수익(매출액): ['412520089455'] 법인세비용차감전순이익(손실): ['20722538976'] 금융비용: ['2160264279'] 전기 수익(매출액): ['356890228107'] 전기 영업이익: ['16587813411'] 영업활동으로 인한 현금흐름: ['34817466720']
# 자산총계: ['1578353457305'] 부채총계: ['1083263708203'] 자본총계: ['495089749102'] 단기차입금: ['58455450000'] 유동성장기부채: ['21338890059'] 사채: ['11100000000'] 장기차입금: ['49404593462'] 비유동자산: ['645483862621'] 비유동부채: ['169621782184'] 전기말 자산총계: ['1352807890981'] 전기말 부채총계: ['965611521087'] 전기말 자본총계: ['387196369894'] 매출채권: ['342568983437'] 매입채무: ['232060918400'] 재고자산: ['242954808270'] 당기순이익: ['49432637246'] 영업이익: ['35070636356'] 수익(매출액): ['530887333992'] 법인세비용차감전순이익(손실): ['35623568050'] 금융비용: ['1804037915'] 전기 수익(매출액): ['433909362539'] 전기 영업이익: ['18232660803'] 영업활동으로 인한 현금흐름: ['80285302363']
# 자산총계: ['1793278638405'] 부채총계: ['1052229013868'] 자본총계: ['741049624537'] 단기차입금: ['31355450000'] 유동성장기부채: ['15338890059'] 사채: ['8400000000'] 장기차입금: ['74907238271'] 비유동자산: ['847804706430'] 비유동부채: ['196717115625'] 전기말 자산총계: ['1324290142390'] 전기말 부채총계: ['931589590817'] 전기말 자본총계: ['392700551573'] 매출채권: ['340213732092'] 매입채무: ['211413924732'] 재고자산: ['240528333627'] 당기순이익: ['40777301590'] 영업이익: ['34234568403'] 수익(매출액): ['528187103680'] 법인세비용차감전순이익(손실): ['40308262975'] 금융비용: ['1429062105'] 전기 수익(매출액): ['489884474922'] 전기 영업이익: ['23734632096'] 영업활동으로 인한 현금흐름: ['112155237084']
# 자산총계: ['1740624183320'] 부채총계: ['1076530912577'] 자본총계: ['664093270743'] 단기차입금: ['31355450000'] 유동성장기부채: ['9338890059'] 사채: ['5700000000'] 장기차입금: ['90315120661'] 비유동자산: ['756024848045'] 비유동부채: ['208493624759'] 전기말 자산총계: ['1380157441704'] 전기말 부채총계: ['980065075097'] 전기말 자본총계: ['400092366607'] 매출채권: ['285325688633'] 매입채무: ['237017185698'] 재고자산: ['275881865512'] 당기순이익: ['149481858788'] 영업이익: ['111269186900'] 수익(매출액): ['2064503271482'] 법인세비용차감전순이익(손실): ['109825022984'] 금융비용: ['13065614293'] 전기 수익(매출액): ['1829136280851'] 전기 영업이익: ['81019900079'] 영업활동으로 인한 현금흐름: ['179188030244']
# 자산총계: ['1819451821183'] 부채총계: ['1145871533344'] 자본총계: ['673580287839'] 단기차입금: ['31355450000'] 유동성장기부채: ['53051346559'] 사채: ['3000000000'] 장기차입금: ['45152936119'] 비유동자산: ['790858137841'] 비유동부채: ['163631768054'] 전기말 자산총계: ['1518166909694'] 전기말 부채총계: ['1072441284735'] 전기말 자본총계: ['445725624959'] 매출채권: ['292679070177'] 매입채무: ['220114379293'] 재고자산: ['281180857528'] 당기순이익: ['6228389870'] 영업이익: ['14861899055'] 수익(매출액): ['411872032258'] 법인세비용차감전순이익(손실): ['14692339871'] 금융비용: ['1984721705'] 전기 수익(매출액): ['412520089455'] 전기 영업이익: ['22280260136'] 영업활동으로 인한 현금흐름: ['19374638210']
# 자산총계: ['1731967891317'] 부채총계: ['1153405669390'] 자본총계: ['578562221927'] 단기차입금: ['31355450000'] 유동성장기부채: ['19338890059'] 사채: ['300000000'] 장기차입금: ['134474289554'] 비유동자산: ['677459134395'] 비유동부채: ['252399962833'] 전기말 자산총계: ['1578353457305'] 전기말 부채총계: ['1083263708203'] 전기말 자본총계: ['495089749102'] 매출채권: ['261878941174'] 매입채무: ['212274993510'] 재고자산: ['289247600745'] 당기순이익: ['13615279077'] 영업이익: ['19950608973'] 수익(매출액): ['545130340190'] 법인세비용차감전순이익(손실): ['22079229078'] 금융비용: ['1786053917'] 전기 수익(매출액): ['530887333992'] 전기 영업이익: ['35070636356'] 영업활동으로 인한 현금흐름: ['19709625526']
# 자산총계: ['1616827589344'] 부채총계: ['1091347481367'] 자본총계: ['525480107977'] 단기차입금: ['31355450000'] 유동성장기부채: ['18098890059'] 사채: ['0'] 장기차입금: ['137698691175'] 비유동자산: ['636504343099'] 비유동부채: ['259512503897'] 전기말 자산총계: ['1793278638405'] 전기말 부채총계: ['1052229013868'] 전기말 자본총계: ['741049624537'] 매출채권: ['277428702060'] 매입채무: ['189690324776'] 재고자산: ['269743997586'] 당기순이익: ['8856346274'] 영업이익: ['15756813050'] 수익(매출액): ['520116184138'] 법인세비용차감전순이익(손실): ['17320296275'] 금융비용: ['2718023955'] 전기 수익(매출액): ['528187103680'] 전기 영업이익: ['34234568403'] 영업활동으로 인한 현금흐름: ['13919020542']
# 자산총계: ['1690618825276'] 부채총계: ['1132886299953'] 자본총계: ['557732525323'] 단기차입금: ['31355450000'] 유동성장기부채: ['16478890059'] 사채: ['0'] 장기차입금: ['165374914743'] 비유동자산: ['651261882522'] 비유동부채: ['282541808469'] 전기말 자산총계: ['1740624183320'] 전기말 부채총계: ['1076530912577'] 전기말 자본총계: ['664093270743'] 매출채권: ['253879336402'] 매입채무: ['232923878144'] 재고자산: ['284123241986'] 당기순이익: ['23918673608'] 영업이익: ['55276797761'] 수익(매출액): ['2041695477080'] 법인세비용차감전순이익(손실): ['60210595084'] 금융비용: ['9624155409'] 전기 수익(매출액): ['2064503271482'] 전기 영업이익: ['111269186900'] 영업활동으로 인한 현금흐름: ['46990443198']
#                기업명    연도  보고서 코드        부채비율     차입금의존도     고정장기적합률  자기자본순이익률  \
# 아이디
# 002990202001  금호건설  2020  1분기보고서  260.426368  14.520311   59.294497  0.036882
# 002990202002  금호건설  2020   반기보고서  249.385479  14.046318   55.848952  0.032835
# 002990202003  금호건설  2020  3분기보고서  237.226453  13.683072   59.152658  0.014892
# 002990202004  금호건설  2020   사업보고서  244.959704  11.270893  109.369665  0.113816
# 002990202101  금호건설  2021  1분기보고서  240.605706   9.511296  106.278738  0.044880
# 002990202102  금호건설  2021   반기보고서  218.801482   9.573200   97.107366  0.112056
# 002990202103  금호건설  2021  3분기보고서  141.991707   7.851629   90.406779  0.071933
# 002990202104  금호건설  2021   사업보고서  162.105379   8.474515   86.641783  0.280932
# 002990202201  금호건설  2022  1분기보고서  170.116548   7.879282   94.463300  0.011129
# 002990202202  금호건설  2022   반기보고서  199.357239  11.332117   81.527071  0.025363
# 002990202203  금호건설  2022  3분기보고서  207.685784  12.094860   81.084119  0.013985
# 002990202204  금호건설  2022   사업보고서  203.123585  12.948469   77.505864  0.039152
#
#               매출액영업이익률  매출액경상이익률  이자보상배율(배)   매출액 증가율   총자산 증가율  영업이익 증가율  \
# 아이디
# 002990202001  0.046479  0.046246   5.077818  0.146120  0.112246  1.453415
# 002990202002  0.042020  0.035005   7.991369 -0.037171  0.037425  0.251814
# 002990202003  0.048449  0.006934   7.212497  0.149926  0.054827  0.422777
# 002990202004  0.044294  0.025579   4.225370  0.145163  0.038595  0.466653
# 002990202101  0.054010  0.050234  10.313673  0.155874  0.122513  0.343170
# 002990202102  0.066060  0.067102  19.440077  0.223498  0.166724  0.923506
# 002990202103  0.064815  0.076314  23.955970  0.078187  0.354143  0.442389
# 002990202104  0.053896  0.053197   8.516185  0.128677  0.261178  0.373356
# 002990202201  0.036084  0.035672   7.488153 -0.001571  0.198453 -0.332957
# 002990202202  0.036598  0.040503  11.170217  0.026829  0.097326 -0.431131
# 002990202203  0.030295  0.033301   5.797158 -0.015280 -0.098396 -0.539740
# 002990202204  0.027074  0.029490   5.743548 -0.011048 -0.028728 -0.503216
#
#               자기자본 증가율  매출채권 회전기일(일)  재고자산 회전기일(일)  매입채무 회전기일(일)   총자산 회전율  \
# 아이디
# 002990202001  0.127745      0.127745     61.076297     49.599437  0.263880
# 002990202002  0.103947      0.103947    107.934869     91.435227  0.320747
# 002990202003  0.069932      0.069932    158.644581    132.167023  0.369922
# 002990202004  0.064742      0.064742     64.386958     48.223851  1.325310
# 002990202101  0.187834      0.187834     69.532617     48.592644  0.271722
# 002990202102  0.278653      0.278653    116.795000     79.118531  0.336355
# 002990202103  0.887060      0.887060    175.843651    109.271887  0.294537
# 002990202104  0.659850      0.659850     50.445004     41.904159  1.186071
# 002990202201  0.511199      0.511199     63.954613     48.098178  0.226371
# 002990202202  0.168601      0.168601     86.951844     70.481811  0.314746
# 002990202203 -0.290898     -0.290898    145.617533     99.565175  0.321689
# 002990202204 -0.160159     -0.160159     45.386767     41.640498  1.207662
#
#               부채상환계수(배)  총차입금상환능력비율
# 아이디
# 002990202001   0.683121    0.530471
# 002990202002   0.867932    0.685443
# 002990202003   0.408186    0.309595
# 002990202004   1.010455    0.811420
# 002990202101   0.420418    0.290636
# 002990202102   1.006017    0.621408
# 002990202103   2.360272    0.922317
# 002990202104   3.576150    1.367749
# 002990202201   0.247239    0.149542
# 002990202202   0.409594    0.106441
# 002990202203   0.318886    0.074372
# 002990202204   0.985313    0.220396

# %%
df.to_csv(f'/content/drive/MyDrive/ICR/재무비율/{corp_name_p}_재무비율.csv')

# %% [markdown]
# ### 삼부토건

# %%
corp_name = ['DL이앤씨', 'HDC현대산업개발', '한전KPS', 'HJ중공업', '신세계건설', 'KCC건설', '대우건설', '서희건설', '특수건설', '계룡건설산업', '신원종합개발',
             '서한', '태영건설', '현대건설', 'GS건설', '동부건설', '코오롱글로벌', 'DL건설', '진흥기업', '남광토건', '한신공영', '금호건설', '삼부토건']
corp_code = ['375500', '294870', '051600', '097230', '034300', '021320', '047040', '035890', '026150', '013580', '017000',
             '011370', '009410', '000720', '006360', '005960', '003070', '001880', '002780', '001260', '004960', '002990', '001470']
report_code = ["11013", "11012", "11014", "11011"] # '11013'=1분기보고서, '11012'=반기보고서, '11014'=3분기보고서, '11011'=사업보고서

corp_name_p = corp_name[22]
corp_code_p = corp_code[22]

all = pd.DataFrame()

for year in range(2019, 2023):
  for code in report_code:
    corp = dart.finstate_all(corp_code_p, year, code, fs_div="OFS")
    # corp = corp.drop('account_id', axis=1)
    all = pd.concat([all, corp], ignore_index=True) # 2019년~2022년 별도 재무제표 전문(분기보고서+반기보고서+사업보고서)

all
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
Quarter = []
cor_year = []
ID_list = []
corp_name_list = []
year_list = []
report_code_list = []
Debt_Ratio = []
Debt_to_Asset_Ratio = []
Fixed_Asset_Turnover_Ratio = []
Return_on_Equity = []
Operating_Profit_Margin = []
Gross_Profit_Margin = []
Interest_Coverage_Ratio =[]
Sales_Growth_Rate = []
Total_Asset_Growth_Rate = []
Operating_Profit_Growth_Rate = []
Equity_Growth_Rate= []
Accounts_Receivable_Turnover = []
Inventory_Turnover = []
Accounts_Payable_Turnover = []
Total_Asset_Turnover_Ratio = []
Debt_Service_Coverage_Ratio = []
Debt_to_Equity_Ratio = []


for year in range(2020, 2023):
  str_year = str(year)
  report_code_list.extend(['1분기보고서' if code == '11013' else '반기보고서' if code == '11012' else '3분기보고서' if code == '11014' else '사업보고서' for code in report_code])
  Quarter.extend(['01' if code == '11013' else '02' if code == '11012' else '03' if code == '11014' else '04' for code in report_code])
  for code in report_code:
    BS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '자산총계' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자산총계
    BS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 부채총계
    BS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 자본총계
    BS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '차입금' in row['account_nm'] and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 단기차입금
    BS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and ('유동성장기차입금' in row['account_nm'] or '유동성장기채무' in row['account_nm']) and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 유동성장기부채
    BS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '사채' in row['account_nm'] and '신주인수권' not in row['account_nm'] and '전환' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 사채
    BS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '장기차입금' in row['account_nm'] and '유동성' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 장기차입금
    BS8 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동자산' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동자산
    BS9 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '비유동부채' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 비유동부채
    BS10 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자산총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자산총계
    BS11 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '부채총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 부채총계
    BS12 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '자본총계' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기말 자본총계
    BS13 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매출채권' in row['account_nm'] and row['account_id'] == 'ifrs-full_TradeAndOtherCurrentReceivables' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매출채권
    BS14 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and '매입채무' in row['account_nm'] and row['account_id'] == 'ifrs-full_TradeAndOtherCurrentPayables' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 매입채무
    BS15 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '재무상태표' and row['account_nm'] == '재고자산' and '장기' not in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 재고자산

    IS1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '포괄손익계산서' and '기순' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 당기순이익
    IS2 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '영업이익(손실)' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업이익
    IS3 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '수익(매출액)' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 수익(매출액)
    IS4 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and '법인세' in row['account_nm'] and '차감전' in row['account_nm'] and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 법인세비용차감전순이익(손실)
    IS5 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and (row['account_nm'] == '금융비용' or row['account_nm'] == '금융원가') and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 금융비용
    IS6 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '수익(매출액)' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 수익(매출액) # 분기 보고서만 해당
    IS7 = [(row['thstrm_amount']) for index, row in all.iterrows() if (row['sj_nm'] == '포괄손익계산서' or row['sj_nm'] == '손익계산서') and row['account_nm'] == '영업이익(손실)' and row['bsns_year'] == str(year-1) and row['reprt_code'] == str(code)] # 전기 영업이익 # 분기 보고서만 해당

    CF1 = [(row['thstrm_amount']) for index, row in all.iterrows() if row['sj_nm'] == '현금흐름표' and row['account_nm'] == '영업활동현금흐름' and row['bsns_year'] == str(year) and row['reprt_code'] == str(code)] # 영업활동으로 인한 현금흐름

    # if BS6 == BS7: # '사채 및 장기차입금'으로 계정과목 하나만 쓰는 회사는 합침(어차피 사채는 차입금 의존도에서만 사용해서 하나 0으로 만들어도 상관없음)
    #   BS6 = ['0']
    # if BS4 == BS5:
    #   BS4 = ['0'] # '단기차입금 및 유동성장기부채' 로 병합해서 쓰는 회사는 하나로 합침(어차피 둘이 항상 붙어서 계산해서 상관없음)
    # if BS4 == [''] or BS4 == []:
    #   BS4 = ['0']
    if BS5 == [''] or BS5 == []:
      BS5 = ['0']
    if BS6 == []: # 삼부토건은 회사채 발행 안함
      BS6 = ['0']
    # if BS7 == [] or BS7 == ['']:
    #   BS7 = ['0']
    # if BS15 == [] or BS15 == ['']:
    #   BS15 = ['0']

    # 삼부토건도 기재정정으로 2020년 포괄손익계산서 값 다 날라감...... 수기로 하나하나 다 채웠음
    if IS2 == ['']:
      IS2 = ['6138413444']
    if IS3 == ['']:
      IS3 = ['376331921995']
    if IS4 == ['']:
      IS4 = ['8997259122']
    if IS5 == ['']:
      IS5 = ['15244567259']

    if IS6 == ['']:
      IS6 = ['376331921995']
    if IS7 == ['']:
      IS7 = ['6138413444']


    print("자산총계:", BS1, "부채총계:", BS2, "자본총계:", BS3, "단기차입금:", BS4, "유동성장기부채:", BS5, "사채:", BS6, "장기차입금:", BS7, "비유동자산:", BS8, "비유동부채:", BS9, "전기말 자산총계:", BS10, "전기말 부채총계:", BS11,
          "전기말 자본총계:", BS12, "매출채권:", BS13, "매입채무:", BS14, "재고자산:", BS15, "당기순이익:", IS1, "영업이익:", IS2, "수익(매출액):", IS3, "법인세비용차감전순이익(손실):", IS4,
          "금융비용:", IS5, "전기 수익(매출액):", IS6, "전기 영업이익:", IS7, "영업활동으로 인한 현금흐름:", CF1)

    if year != 2020:
      if code == "11013":
        accounting_period = 90
      elif code == "11012":
        accounting_period = 181
      elif code == "11014":
        accounting_period = 273
      elif code == "11011":
        accounting_period = 365
    else: # 2020년은 윤년
      if code == "11013":
        accounting_period = 91
      elif code == "11012":
        accounting_period = 182
      elif code == "11014":
        accounting_period = 274
      elif code == "11011":
        accounting_period = 366


    cor_year.extend([f"{corp_code_p}{str_year}"])
    corp_name_list.append(str(corp_name_p))
    year_list.append(str_year)
    Debt_Ratio.extend([int(BS2)/int(BS3)*100 for BS2, BS3 in zip(BS2, BS3)])
    Debt_to_Asset_Ratio.extend([((int(BS4) + int(BS5) + int(BS6) + int(BS7)) / int(BS1) * 100) for BS4, BS5, BS6, BS7, BS1 in zip(BS4, BS5, BS6, BS7, BS1)])
    Fixed_Asset_Turnover_Ratio.extend([int(BS8)/(int(BS9)+int(BS3))*100 for BS8, BS9, BS3 in zip(BS8, BS9, BS3)]),
    Return_on_Equity.extend([int(IS1)/((int(BS12)+int(BS3))/2) for IS1, BS12, BS3 in zip(IS1, BS12, BS3)])
    Operating_Profit_Margin.extend([int(IS2)/int(IS3) for IS2, IS3 in zip(IS2, IS3)])
    Gross_Profit_Margin.extend([int(IS4)/int(IS3) for IS4, IS3 in zip(IS4, IS3)])
    Interest_Coverage_Ratio.extend([int(IS2)/int(IS5) for IS2, IS5 in zip(IS2, IS5)])
    Sales_Growth_Rate.extend([(int(IS3)-int(IS6))/int(IS6) for IS3, IS6 in zip(IS3, IS6)])
    Total_Asset_Growth_Rate.extend([(int(BS1)-int(BS10))/int(BS10) for BS1, BS10 in zip(BS1, BS10)])
    Operating_Profit_Growth_Rate.extend([(int(IS2)-int(IS7))/int(IS7) for IS2, IS7 in zip(IS2, IS7)])
    Equity_Growth_Rate.extend([(int(BS3)-int(BS12))/int(BS12) for BS3, BS12 in zip(BS3, BS12)])
    Accounts_Receivable_Turnover.extend([int(BS13)/int(IS3)*accounting_period for BS13, IS3 in zip(BS13, IS3)])
    Inventory_Turnover.extend([int(BS15)/int(IS3)*accounting_period for BS15, IS3 in zip(BS15, IS3)])
    Accounts_Payable_Turnover.extend([int(BS14)/int(IS3)*accounting_period for BS14, IS3 in zip(BS14, IS3)])
    Total_Asset_Turnover_Ratio.extend([int(IS3)/int(BS1) for IS3, BS1 in zip(IS3, BS1)])
    Debt_Service_Coverage_Ratio.extend([(int(CF1)+int(IS5))/(int(BS4)+int(BS5)+int(IS5)) for CF1, IS5, BS4, BS5 in zip(CF1, IS5, BS4, BS5)])
    Debt_to_Equity_Ratio.extend([int(CF1)/(int(BS4)+int(BS7)+int(BS5)) for CF1, BS4, BS7, BS5 in zip(CF1, BS4, BS7, BS5)])

ID_list.extend([x+y for x,y in zip(cor_year,Quarter)])

financial_ratio = {
      '아이디':ID_list,
      '기업명':corp_name_list,
      '연도':year_list,
      '보고서 코드':report_code_list,
      '부채비율' : Debt_Ratio,
      '차입금의존도' : Debt_to_Asset_Ratio,
      '고정장기적합률':Fixed_Asset_Turnover_Ratio,
      '자기자본순이익률':Return_on_Equity,
      '매출액영업이익률':Operating_Profit_Margin,
      '매출액경상이익률':Gross_Profit_Margin,
      '이자보상배율(배)':Interest_Coverage_Ratio,
      '매출액 증가율':Sales_Growth_Rate,
      '총자산 증가율':Total_Asset_Growth_Rate,
      '영업이익 증가율':Operating_Profit_Growth_Rate,
      '자기자본 증가율':Equity_Growth_Rate,
      '매출채권 회전기일(일)':Equity_Growth_Rate,
      '재고자산 회전기일(일)':Accounts_Receivable_Turnover,
      '매입채무 회전기일(일)':Accounts_Payable_Turnover,
      '총자산 회전율':Total_Asset_Turnover_Ratio,
      '부채상환계수(배)':Debt_Service_Coverage_Ratio,
      '총차입금상환능력비율':Debt_to_Equity_Ratio
                    }

df = pd.DataFrame(financial_ratio)
df.set_index('아이디', inplace=True)

df
# Out:
# 자산총계: ['390247482817'] 부채총계: ['163861885541'] 자본총계: ['226385597276'] 단기차입금: ['9418460000'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['5000000000'] 비유동자산: ['150968919057'] 비유동부채: ['42459033673'] 전기말 자산총계: ['326562782560'] 전기말 부채총계: ['116677304628'] 전기말 자본총계: ['209885477932'] 매출채권: ['131857722742'] 매입채무: ['121402851868'] 재고자산: ['31797748187'] 당기순이익: ['893669173'] 영업이익: ['1000455008'] 수익(매출액): ['83688377898'] 법인세비용차감전순이익(손실): ['893669173'] 금융비용: ['452742200'] 전기 수익(매출액): ['38954330490'] 전기 영업이익: ['-1227642250'] 영업활동으로 인한 현금흐름: ['16769884640']
# 자산총계: ['383871309572'] 부채총계: ['156378898392'] 자본총계: ['227492411180'] 단기차입금: ['16000000000'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['5000000000'] 비유동자산: ['149980025347'] 비유동부채: ['28818989029'] 전기말 자산총계: ['334460425310'] 전기말 부채총계: ['125770901872'] 전기말 자본총계: ['208689523438'] 매출채권: ['145936981824'] 매입채무: ['127559909363'] 재고자산: ['31071335524'] 당기순이익: ['1900360716'] 영업이익: ['3458192355'] 수익(매출액): ['90022305429'] 법인세비용차감전순이익(손실): ['1900360716'] 금융비용: ['14406842989'] 전기 수익(매출액): ['46197967789'] 전기 영업이익: ['3647211823'] 영업활동으로 인한 현금흐름: ['-952531552']
# 자산총계: ['400751744029'] 부채총계: ['159774807959'] 자본총계: ['240976936070'] 단기차입금: ['16000000000'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['17000000000'] 비유동자산: ['117093863589'] 비유동부채: ['43019984889'] 전기말 자산총계: ['351422177020'] 전기말 부채총계: ['125040443697'] 전기말 자본총계: ['226381733323'] 매출채권: ['119530559428'] 매입채무: ['116754823070'] 재고자산: ['69025914566'] 당기순이익: ['13810411215'] 영업이익: ['4029936259'] 수익(매출액): ['116885562578'] 법인세비용차감전순이익(손실): ['13810411215'] 금융비용: ['493104544'] 전기 수익(매출액): ['55601106262'] 전기 영업이익: ['1381942892'] 영업활동으로 인한 현금흐름: ['-1008614286']
# 자산총계: ['440361271063'] 부채총계: ['207388187736'] 자본총계: ['232973083327'] 단기차입금: ['38000000000'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['4987000000'] 비유동자산: ['93780346774'] 비유동부채: ['28617302231'] 전기말 자산총계: ['376509620051'] 전기말 부채총계: ['151624407493'] 전기말 자본총계: ['224885212558'] 매출채권: ['159642919690'] 매입채무: ['140379160261'] 재고자산: ['68976782761'] 당기순이익: ['6418007702'] 영업이익: ['6138413444'] 수익(매출액): ['376331921995'] 법인세비용차감전순이익(손실): ['8997259122'] 금융비용: ['15244567259'] 전기 수익(매출액): ['226244600310'] 전기 영업이익: ['5935841784'] 영업활동으로 인한 현금흐름: ['28202671190']
# 자산총계: ['445397429134'] 부채총계: ['205441978936'] 자본총계: ['239955450198'] 단기차입금: ['38000000000'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['4948000000'] 비유동자산: ['94020584069'] 비유동부채: ['22930215521'] 전기말 자산총계: ['390247482817'] 전기말 부채총계: ['163861885541'] 전기말 자본총계: ['226385597276'] 매출채권: ['172606822693'] 매입채무: ['182511763415'] 재고자산: ['68385213730'] 당기순이익: ['4191499999'] 영업이익: ['2335742455'] 수익(매출액): ['74103791302'] 법인세비용차감전순이익(손실): ['4191499999'] 금융비용: ['1243675998'] 전기 수익(매출액): ['83688377898'] 전기 영업이익: ['1000455008'] 영업활동으로 인한 현금흐름: ['-8429702374']
# 자산총계: ['428064446794'] 부채총계: ['184516698795'] 자본총계: ['243547747999'] 단기차입금: ['28000000000'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['4909000000'] 비유동자산: ['87267646753'] 비유동부채: ['23530496115'] 전기말 자산총계: ['383871309572'] 전기말 부채총계: ['156378898392'] 전기말 자본총계: ['227492411180'] 매출채권: ['167800766271'] 매입채무: ['160986202680'] 재고자산: ['71699648012'] 당기순이익: ['3733227468'] 영업이익: ['3897572752'] 수익(매출액): ['79960324468'] 법인세비용차감전순이익(손실): ['3733227468'] 금융비용: ['1221585067'] 전기 수익(매출액): ['90022305429'] 전기 영업이익: ['3458192355'] 영업활동으로 인한 현금흐름: ['-13006936658']
# 자산총계: ['457661314143'] 부채총계: ['216374667287'] 자본총계: ['241286646856'] 단기차입금: ['51280000000'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['4870000000'] 비유동자산: ['94387926841'] 비유동부채: ['27849758174'] 전기말 자산총계: ['400751744029'] 전기말 부채총계: ['159774807959'] 전기말 자본총계: ['240976936070'] 매출채권: ['188578782502'] 매입채무: ['188524909113'] 재고자산: ['70821827265'] 당기순이익: ['-2038012599'] 영업이익: ['-864102122'] 수익(매출액): ['80634324266'] 법인세비용차감전순이익(손실): ['-2038012599'] 금융비용: ['952353016'] 전기 수익(매출액): ['116885562578'] 전기 영업이익: ['4029936259'] 영업활동으로 인한 현금흐름: ['-71991664865']
# 자산총계: ['480439559718'] 부채총계: ['231271329678'] 자본총계: ['249168230040'] 단기차입금: ['74560000000'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['2149000000'] 비유동자산: ['91176126238'] 비유동부채: ['25779394891'] 전기말 자산총계: ['440361271063'] 전기말 부채총계: ['207388187736'] 전기말 자본총계: ['232973083327'] 매출채권: ['178502811701'] 매입채무: ['129710709113'] 재고자산: ['71688986797'] 당기순이익: ['738188482'] 영업이익: ['-4112027218'] 수익(매출액): ['320576036148'] 법인세비용차감전순이익(손실): ['738188482'] 금융비용: ['7636039486'] 전기 수익(매출액): ['376331921995'] 전기 영업이익: ['6138413444'] 영업활동으로 인한 현금흐름: ['-86829857213']
# 자산총계: ['488123553970'] 부채총계: ['211961763367'] 자본총계: ['276161790603'] 단기차입금: ['79560000000'] 유동성장기부채: ['156000000'] 사채: ['0'] 장기차입금: ['1303000000'] 비유동자산: ['90079792294'] 비유동부채: ['24326158818'] 전기말 자산총계: ['445397429134'] 전기말 부채총계: ['205441978936'] 전기말 자본총계: ['239955450198'] 매출채권: ['188389517714'] 매입채무: ['187635604549'] 재고자산: ['70938703234'] 당기순이익: ['1718669236'] 영업이익: ['-1841824487'] 수익(매출액): ['72402984736'] 법인세비용차감전순이익(손실): ['1718669236'] 금융비용: ['927794113'] 전기 수익(매출액): ['74103791302'] 전기 영업이익: ['2335742455'] 영업활동으로 인한 현금흐름: ['-3382229740']
# 자산총계: ['533787229437'] 부채총계: ['248994252856'] 자본총계: ['284792976581'] 단기차입금: ['110653803896'] 유동성장기부채: ['156000000'] 사채: ['0'] 장기차입금: ['1264000000'] 비유동자산: ['100298397469'] 비유동부채: ['25942834970'] 전기말 자산총계: ['428064446794'] 전기말 부채총계: ['184516698795'] 전기말 자본총계: ['243547747999'] 매출채권: ['163851704743'] 매입채무: ['221849208675'] 재고자산: ['155347172291'] 당기순이익: ['-5199667110'] 영업이익: ['-4488867787'] 수익(매출액): ['94214990981'] 법인세비용차감전순이익(손실): ['-5199667110'] 금융비용: ['2521402545'] 전기 수익(매출액): ['79960324468'] 전기 영업이익: ['3897572752'] 영업활동으로 인한 현금흐름: ['-16931448443']
# 자산총계: ['524575018910'] 부채총계: ['250353572688'] 자본총계: ['274221446222'] 단기차입금: ['109342333831'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['13225000000'] 비유동자산: ['98280115922'] 비유동부채: ['38657309538'] 전기말 자산총계: ['457661314143'] 전기말 부채총계: ['216374667287'] 전기말 자본총계: ['241286646856'] 매출채권: ['158799441685'] 매입채무: ['67568310510'] 재고자산: ['155616897482'] 당기순이익: ['-12024035816'] 영업이익: ['-13261671259'] 수익(매출액): ['107894550390'] 법인세비용차감전순이익(손실): ['-11824139996'] 금융비용: ['202190696'] 전기 수익(매출액): ['80634324266'] 전기 영업이익: ['-864102122'] 영업활동으로 인한 현금흐름: ['-24079913300']
# 자산총계: ['505465736590'] 부채총계: ['286120904818'] 자본총계: ['219344831772'] 단기차입금: ['86478451710'] 유동성장기부채: ['0'] 사채: ['0'] 장기차입금: ['29186000000'] 비유동자산: ['91808896885'] 비유동부채: ['76899569891'] 전기말 자산총계: ['480439559718'] 전기말 부채총계: ['231271329678'] 전기말 자본총계: ['249168230040'] 매출채권: ['157821130016'] 매입채무: ['91455169166'] 재고자산: ['154578573623'] 당기순이익: ['-79098206682'] 영업이익: ['-76598992097'] 수익(매출액): ['400347801094'] 법인세비용차감전순이익(손실): ['-78877410862'] 금융비용: ['7941828511'] 전기 수익(매출액): ['320576036148'] 전기 영업이익: ['-4112027218'] 영업활동으로 인한 현금흐름: ['-30973630816']
#                기업명    연도  보고서 코드        부채비율     차입금의존도    고정장기적합률  자기자본순이익률  \
# 아이디
# 001470202001  삼부토건  2020  1분기보고서   72.381763   3.694696  56.154709  0.004097
# 001470202002  삼부토건  2020   반기보고서   68.740270   5.470583  58.514770  0.008714
# 001470202003  삼부토건  2020  3분기보고서   66.302946   8.234524  41.230681  0.059100
# 001470202004  삼부토건  2020   사업보고서   89.018089   9.761758  35.850074  0.028035
# 001470202101  삼부토건  2021  1분기보고서   85.616717   9.642624  35.764820  0.017976
# 001470202102  삼부토건  2021   반기보고서   75.762022   7.687861  32.674937  0.015851
# 001470202103  삼부토건  2021  3분기보고서   89.675359  12.268898  35.070665 -0.008452
# 001470202104  삼부토건  2021   사업보고서   92.817343  15.966420  33.161271  0.003062
# 001470202201  삼부토건  2022  1분기보고서   76.752748  16.598052  29.977839  0.006660
# 001470202202  삼부토건  2022   반기보고서   87.429913  20.995970  32.277708 -0.019683
# 001470202203  삼부토건  2022  3분기보고서   91.296132  23.365073  31.411566 -0.046649
# 001470202204  삼부토건  2022   사업보고서  130.443422  22.882748  30.990931 -0.337656
#
#               매출액영업이익률  매출액경상이익률  이자보상배율(배)   매출액 증가율   총자산 증가율   영업이익 증가율  \
# 아이디
# 001470202001  0.011955  0.010679   2.209768  1.148372  0.195015  -1.814940
# 001470202002  0.038415  0.021110   0.240038  0.948620  0.147733  -0.051826
# 001470202003  0.034478  0.118153   8.172580  1.102216  0.140371   1.916138
# 001470202004  0.016311  0.023908   0.402662  0.663385  0.169588   0.034127
# 001470202101  0.031520  0.056563   1.878096 -0.114527  0.141320   1.334680
# 001470202102  0.048744  0.046688   3.190586 -0.111772  0.115125   0.127055
# 001470202103 -0.010716 -0.025275  -0.907334 -0.310143  0.142007  -1.214421
# 001470202104 -0.012827  0.002303  -0.538503 -0.148156  0.091012  -1.669884
# 001470202201 -0.025439  0.023738  -1.985165 -0.022952  0.095928  -1.788539
# 001470202202 -0.047645 -0.055189  -1.780306  0.178272  0.246979  -2.151709
# 001470202203 -0.122913 -0.109590 -65.589918  0.338072  0.146208  14.347343
# 001470202204 -0.191331 -0.197022  -9.645007  0.248839  0.052090  17.628036
#
#               자기자본 증가율  매출채권 회전기일(일)  재고자산 회전기일(일)  매입채무 회전기일(일)   총자산 회전율  \
# 아이디
# 001470202001  0.078615      0.078615    143.377767    132.009483  0.214450
# 001470202002  0.090100      0.090100    295.043885    257.890568  0.234512
# 001470202003  0.064472      0.064472    280.200331    273.693524  0.291666
# 001470202004  0.035964      0.035964    155.260038    136.525151  0.854598
# 001470202101  0.059941      0.059941    209.633188    221.662865  0.166377
# 001470202102  0.070575      0.070575    379.837612    364.412012  0.186795
# 001470202103  0.001285      0.001285    638.462691    638.280294  0.176188
# 001470202104  0.069515      0.069515    203.238917    147.685427  0.667256
# 001470202201  0.150888      0.150888    234.176210    233.239064  0.148329
# 001470202202  0.169352      0.169352    314.781737    426.202947  0.176503
# 001470202203  0.136497      0.136497    401.802013    170.964601  0.205680
# 001470202204 -0.119692     -0.119692    143.886671     83.380342  0.792037
#
#               부채상환계수(배)  총차입금상환능력비율
# 아이디
# 001470202001   1.744734    1.163084
# 001470202002   0.442476   -0.045359
# 001470202003  -0.031256   -0.030564
# 001470202004   0.815994    0.656074
# 001470202101  -0.183113   -0.196277
# 001470202102  -0.403310   -0.395239
# 001470202103  -1.360063   -1.282131
# 001470202104  -0.963475   -1.131938
# 001470202201  -0.030436   -0.041746
# 001470202202  -0.127150   -0.151074
# 001470202203  -0.217973   -0.196463
# 001470202204  -0.243929   -0.267789

# %%
# 사업보고서 갈아엎으면서 값이 다 사라짐,,,,, 이건 뭐 어떻게 해야하는,,,,,, 일단 패스

# %%
df.to_csv(f'/content/drive/MyDrive/ICR/재무비율/{corp_name_p}_재무비율.csv')
