# %% [markdown]
# # 재무비율 데이터 합치기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import glob
import pandas as pd

def concat_all_csv_files(folder_path, output_path=None):

    file_paths = glob.glob(os.path.join(folder_path, '*.csv'))

    if not file_paths:
        raise ValueError("No CSV files found in the specified folder.")

    result_df = pd.concat(map(pd.read_csv, file_paths), ignore_index=True)

    if output_path:
        result_df.to_csv(output_path, index=False)

    return result_df

folder_path = "/content/drive/MyDrive/ICR/재무비율(건설업계)_백테스트"
output_path = "/content/drive/MyDrive/ICR/재무비율(건설업계)_백테스트/건설업계_재무비율_백테스트_임시.csv"
result_df = concat_all_csv_files(folder_path, output_path)

# %% [markdown]
# # 재무비율에 신용등급 merge

# %%
result_df = result_df.rename(columns={'아이디': 'ID'})
result_df.to_csv('/content/drive/MyDrive/ICR/재무비율(건설업계)_백테스트/건설업계_재무비율_백테스트.csv')

# %%
result_df.set_index('ID', inplace=True)

# %%
def merge_csv_files(file_a, file_b, common_column, output_path=None):

    df_FR = pd.read_csv(file_a)
    df_ICR = pd.read_csv(file_b)

    # 두 데이터프레임을 공통 열을 기준으로 병합
    merged_df = pd.merge(df_FR, df_ICR, how='left', on=common_column)

    if output_path:
        merged_df.to_csv(output_path, index=False)

    return merged_df

file_a = "/content/drive/MyDrive/ICR/재무비율(건설업계)_백테스트/건설업계_재무비율_백테스트.csv"
file_b = "/content/drive/MyDrive/ICR/기업 등급/df_rating.csv"
common_column = "ID"
output_path = "merged_result.csv"
result_df_merge = merge_csv_files(file_a, file_b, common_column, output_path)

# %%
result_df_merge.set_index('ID', inplace=True)
result_df_merge.to_csv('/content/drive/MyDrive/ICR/재무비율(건설업계)_백테스트/건설업계_재무비율_백테스트_신용등급_merge.csv')

# %% [markdown]
# # 정규화

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
result_df_merge
# Out:
#                 기업명    연도  보고서 코드        부채비율     차입금의존도    고정장기적합률  자기자본순이익률  \
# ID
# 13580202001  계룡건설산업  2020  1분기보고서  266.892067  32.960975  92.706229  0.041429
# 13580202002  계룡건설산업  2020   반기보고서  257.259451  31.849184  91.129678  0.058466
# 13580202003  계룡건설산업  2020  3분기보고서  220.309251  29.525137  73.210344  0.073404
# 13580202004  계룡건설산업  2020   사업보고서  198.536536  27.295838  71.526855  0.219440
# 13580202101  계룡건설산업  2021  1분기보고서  221.328586  22.241247  76.914569  0.046957
# ...             ...   ...     ...         ...        ...        ...       ...
# 1470202104     삼부토건  2021   사업보고서   92.817343  15.966420  33.161271  0.003062
# 1470202201     삼부토건  2022  1분기보고서   76.752748  16.598052  29.977839  0.006660
# 1470202202     삼부토건  2022   반기보고서   87.429913  20.995970  32.277708 -0.019683
# 1470202203     삼부토건  2022  3분기보고서   91.296132  23.365073  31.411566 -0.046649
# 1470202204     삼부토건  2022   사업보고서  130.443422  22.882748  30.990931 -0.337656
#
#              매출액영업이익률  매출액경상이익률  이자보상배율(배)  ...  재고자산 회전기일(일)  매입채무 회전기일(일)  \
# ID                                          ...
# 13580202001  0.070910  0.063869   8.116124  ...     33.417444    197.886370
# 13580202002  0.095524  0.077117  13.040949  ...     65.836938    357.900306
# 13580202003  0.111326  0.106282  15.724410  ...     65.476850    386.710747
# 13580202004  0.096729  0.082234  12.172203  ...     25.277922    119.313641
# 13580202101  0.081864  0.080984   8.307459  ...     33.601703    155.785560
# ...               ...       ...        ...  ...           ...           ...
# 1470202104  -0.012827  0.002303  -0.538503  ...    203.238917    147.685427
# 1470202201  -0.025439  0.023738  -1.985165  ...    234.176210    233.239064
# 1470202202  -0.047645 -0.055189  -1.780306  ...    314.781737    426.202947
# 1470202203  -0.122913 -0.109590 -65.589918  ...    401.802013    170.964601
# 1470202204  -0.191331 -0.197022  -9.645007  ...    143.886671     83.380342
#
#               총자산 회전율  부채상환계수(배)  총차입금상환능력비율   종목코드     종목명     회사명   등급  \
# ID
# 13580202001  0.220827   0.161104    0.124559  13580  계룡건설산업  계룡건설산업  BBB
# 13580202002  0.251659   0.291937    0.237367  13580  계룡건설산업  계룡건설산업  BBB
# 13580202003  0.258717   0.761413    0.388921  13580  계룡건설산업  계룡건설산업  BBB
# 13580202004  1.020474   1.064332    0.520951  13580  계룡건설산업  계룡건설산업  BBB
# 13580202101  0.216227   0.617660    0.370189  13580  계룡건설산업  계룡건설산업  BBB
# ...               ...        ...         ...    ...     ...     ...  ...
# 1470202104   0.667256  -0.963475   -1.131938   1470    삼부토건    삼부토건  BB+
# 1470202201   0.148329  -0.030436   -0.041746   1470    삼부토건    삼부토건  BB+
# 1470202202   0.176503  -0.127150   -0.151074   1470    삼부토건    삼부토건  BB+
# 1470202203   0.205680  -0.217973   -0.196463   1470    삼부토건    삼부토건  BB+
# 1470202204   0.792037  -0.243929   -0.267789   1470    삼부토건    삼부토건  BB+
#
#                 연분기
# ID
# 13580202001  202001
# 13580202002  202002
# 13580202003  202003
# 13580202004  202004
# 13580202101  202101
# ...             ...
# 1470202104   202104
# 1470202201   202201
# 1470202202   202202
# 1470202203   202203
# 1470202204   202204
#
# [268 rows x 25 columns]

# %%
result_df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 268 entries, 0 to 267
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            268 non-null    int64
#  1   기업명           268 non-null    object
#  2   연도            268 non-null    int64
#  3   보고서 코드        268 non-null    object
#  4   부채비율          268 non-null    float64
#  5   차입금의존도        268 non-null    float64
#  6   고정장기적합률       268 non-null    float64
#  7   자기자본순이익률      268 non-null    float64
#  8   매출액영업이익률      268 non-null    float64
#  9   매출액경상이익률      268 non-null    float64
#  10  이자보상배율(배)     268 non-null    float64
#  11  매출액 증가율       268 non-null    float64
#  12  총자산 증가율       268 non-null    float64
#  13  영업이익 증가율      268 non-null    float64
#  14  자기자본 증가율      268 non-null    float64
#  15  매출채권 회전기일(일)  268 non-null    float64
#  16  재고자산 회전기일(일)  268 non-null    float64
#  17  매입채무 회전기일(일)  268 non-null    float64
#  18  총자산 회전율       268 non-null    float64
#  19  부채상환계수(배)     268 non-null    float64
#  20  총차입금상환능력비율    268 non-null    float64
#  21  종목코드          268 non-null    int64
#  22  종목명           268 non-null    object
#  23  회사명           268 non-null    object
#  24  등급            268 non-null    object
#  25  연분기           268 non-null    int64
# dtypes: float64(17), int64(4), object(5)
# memory usage: 56.5+ KB

# %%
# 무한대 값을 NaN으로 대체
import math
result_df_merge.replace(float(math.inf), float(1.5), inplace=True)

# %%
result_df_merge.fillna(result_df_merge.median(numeric_only=True), inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler

minmax_scaler = MinMaxScaler()

# 정규화할 열 선택
columns_to_normalize = result_df_merge[['부채비율', '차입금의존도', '고정장기적합률', '자기자본순이익률', '매출액영업이익률', '매출액경상이익률', '이자보상배율(배)',
                                        '매출액 증가율', '총자산 증가율', '영업이익 증가율', '자기자본 증가율', '매출채권 회전기일(일)', '재고자산 회전기일(일)', '매입채무 회전기일(일)',
                                        '총자산 회전율', '부채상환계수(배)','총차입금상환능력비율']]

minmax_scaled = minmax_scaler.fit_transform(columns_to_normalize)

# 정규화된 값으로 열을 대체
result_df_merge[['부채비율', '차입금의존도', '고정장기적합률', '자기자본순이익률', '매출액영업이익률', '매출액경상이익률', '이자보상배율(배)',
                 '매출액 증가율', '총자산 증가율', '영업이익 증가율', '자기자본 증가율', '매출채권 회전기일(일)', '재고자산 회전기일(일)', '매입채무 회전기일(일)',
                 '총자산 회전율', '부채상환계수(배)','총차입금상환능력비율']] = minmax_scaled

pd.DataFrame(result_df_merge)
result_df_merge
# Out:
#                 기업명    연도  보고서 코드      부채비율    차입금의존도   고정장기적합률  자기자본순이익률  \
# ID
# 13580202001  계룡건설산업  2020  1분기보고서  0.283999  0.670953  0.426766  0.323087
# 13580202002  계룡건설산업  2020   반기보고서  0.272690  0.648321  0.417228  0.336401
# 13580202003  계룡건설산업  2020  3분기보고서  0.229311  0.601013  0.308818  0.348074
# 13580202004  계룡건설산업  2020   사업보고서  0.203749  0.555633  0.298633  0.462192
# 13580202101  계룡건설산업  2021  1분기보고서  0.230507  0.452742  0.331228  0.327407
# ...             ...   ...     ...       ...       ...       ...       ...
# 1470202104     삼부토건  2021   사업보고서  0.079635  0.325012  0.066524  0.293106
# 1470202201     삼부토건  2022  1분기보고서  0.060775  0.337869  0.047265  0.295917
# 1470202202     삼부토건  2022   반기보고서  0.073310  0.427393  0.061179  0.275332
# 1470202203     삼부토건  2022  3분기보고서  0.077849  0.475619  0.055939  0.254259
# 1470202204     삼부토건  2022   사업보고서  0.123808  0.465800  0.053394  0.026855
#
#              매출액영업이익률  매출액경상이익률  이자보상배율(배)  ...  재고자산 회전기일(일)  매입채무 회전기일(일)  \
# ID                                          ...
# 13580202001  0.688919  0.184020   0.215879  ...      0.044404      0.304569
# 13580202002  0.753580  0.193364   0.217100  ...      0.089100      0.557249
# 13580202003  0.795094  0.213936   0.217764  ...      0.088604      0.602744
# 13580202004  0.756748  0.196973   0.216884  ...      0.033182      0.180494
# 13580202101  0.717694  0.196092   0.215927  ...      0.044658      0.238087
# ...               ...       ...        ...  ...           ...           ...
# 1470202104   0.468938  0.140594   0.213735  ...      0.278533      0.225296
# 1470202201   0.435807  0.155713   0.213377  ...      0.321186      0.360395
# 1470202202   0.377470  0.100042   0.213427  ...      0.432315      0.665106
# 1470202203   0.179737  0.061670   0.197618  ...      0.552288      0.262057
# 1470202204   0.000000  0.000000   0.211479  ...      0.196706      0.123752
#
#               총자산 회전율  부채상환계수(배)  총차입금상환능력비율   종목코드     종목명     회사명   등급  \
# ID
# 13580202001  0.072850   0.435554    0.102075  13580  계룡건설산업  계룡건설산업  BBB
# 13580202002  0.091297   0.435845    0.103056  13580  계룡건설산업  계룡건설산업  BBB
# 13580202003  0.095520   0.436888    0.104373  13580  계룡건설산업  계룡건설산업  BBB
# 13580202004  0.551286   0.437562    0.105521  13580  계룡건설산업  계룡건설산업  BBB
# 13580202101  0.070098   0.436569    0.104211  13580  계룡건설산업  계룡건설산업  BBB
# ...               ...        ...         ...    ...     ...     ...  ...
# 1470202104   0.339953   0.433055    0.091151   1470    삼부토건    삼부토건  BB+
# 1470202201   0.029474   0.435128    0.100629   1470    삼부토건    삼부토건  BB+
# 1470202202   0.046331   0.434913    0.099679   1470    삼부토건    삼부토건  BB+
# 1470202203   0.063787   0.434712    0.099284   1470    삼부토건    삼부토건  BB+
# 1470202204   0.414611   0.434654    0.098664   1470    삼부토건    삼부토건  BB+
#
#                 연분기
# ID
# 13580202001  202001
# 13580202002  202002
# 13580202003  202003
# 13580202004  202004
# 13580202101  202101
# ...             ...
# 1470202104   202104
# 1470202201   202201
# 1470202202   202202
# 1470202203   202203
# 1470202204   202204
#
# [268 rows x 25 columns]

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## RFECV

# %%
from sklearn.model_selection import train_test_split

X = result_df_merge.iloc[:, -22:-6]
y = result_df_merge['등급']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %%
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE

estimator = LogisticRegression() # 학습시킬 모델 지정
selector = RFECV(estimator, step=1, cv = 3) # 한 step에 제거할 featrue 개수 및 cross validation fold 수 지정
selector = selector.fit(X_train, y_train) # feature selection 진행

# %%
from sklearn.metrics import f1_score

selected_columns = X_train.columns[selector.support_]
X_train_selected = X_train[selected_columns]

estimator.fit(X_train_selected, y_train)

X_test_selected = X_test[selected_columns]

y_pred = estimator.predict(X_test_selected)

f1 = f1_score(y_test, y_pred, average='weighted') # F1 Score 계산

print("Selected features:", selected_columns)
print("F1 Score (Weighted Average):", f1)
# Out:
# Selected features: Index(['부채비율', '차입금의존도', '고정장기적합률', '매출액영업이익률', '매출액경상이익률', '이자보상배율(배)',
#        '매출액 증가율', '총자산 증가율', '자기자본 증가율', '매출채권 회전기일(일)', '재고자산 회전기일(일)',
#        '매입채무 회전기일(일)', '총자산 회전율', '부채상환계수(배)'],
#       dtype='object')
# F1 Score (Weighted Average): 0.40804232804232804

# %% [markdown]
# ## SelectBest

# %%
from sklearn.feature_selection import f_classif, SelectKBest

selector = SelectKBest(score_func=f_classif, k=6)

X_train_selected = selector.fit_transform(X_train, y_train) ## 학습데이터에 fit_transform

X_test_selected = selector.transform(X_test) ## 테스트 데이터는 transform

X_train_selected.shape, X_test_selected.shape
# Out:
# ((214, 6), (54, 6))

# %%
all_names = X_train.columns

selected_mask = selector.get_support()
selected_names = all_names[selected_mask] ## 선택된 특성(변수)들
unselected_names = all_names[~selected_mask] ## 선택되지 않은 특성(변수)들

print('Selected names: ', selected_names)
print('Unselected names: ', unselected_names)
# Out:
# Selected names:  Index(['부채비율', '차입금의존도', '고정장기적합률', '매출액영업이익률', '매입채무 회전기일(일)', '부채상환계수(배)'], dtype='object')
# Unselected names:  Index(['자기자본순이익률', '매출액경상이익률', '이자보상배율(배)', '매출액 증가율', '총자산 증가율', '영업이익 증가율',
#        '자기자본 증가율', '매출채권 회전기일(일)', '재고자산 회전기일(일)', '총자산 회전율'],
#       dtype='object')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score

model = LogisticRegression()

model.fit(X_train_selected, y_train)

X_test_selected = selector.transform(X_test)

y_pred = model.predict(X_test_selected)

f1 = f1_score(y_test, y_pred, average='weighted') # F1 Score 계산

print("Selected features:", selected_names)
print("F1 Score (Weighted Average):", f1)
# Out:
# Selected features: Index(['부채비율', '차입금의존도', '고정장기적합률', '매출액영업이익률', '매입채무 회전기일(일)', '부채상환계수(배)'], dtype='object')
# F1 Score (Weighted Average): 0.38019079685746354
