# %% [markdown]
# <a href="https://colab.research.google.com/github/Sunnn-y/ICR_Project/blob/main/jobplanet_concat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
file_paths = ['/content/drive/MyDrive/ICR_project/잡플래닛/jobplanet_계룡건설산업.csv',
              '/content/drive/MyDrive/ICR_project/잡플래닛/jobplanet_금호건설.csv',
              '/content/drive/MyDrive/ICR_project/잡플래닛/jobplanet_남광토건.csv',
              '/content/drive/MyDrive/ICR_project/잡플래닛/jobplanet_대우건설.csv',
              '/content/drive/MyDrive/ICR_project/잡플래닛/jobplanet_동부건설.csv',
              '/content/drive/MyDrive/ICR_project/잡플래닛/jobplanet_삼부토건.csv',
              '/content/drive/MyDrive/ICR_project/잡플래닛/jobplanet_삼성물산.csv',
              '/content/drive/MyDrive/ICR_project/잡플래닛/jobplanet_서한.csv',
              '/content/drive/MyDrive/ICR_project/잡플래닛/jobplanet_서희건설.csv',
              '/content/drive/MyDrive/ICR_project/잡플래닛/jobplanet_신세계건설.csv',
              '/content/drive/MyDrive/ICR_project/잡플래닛/jobplanet_신원종합개발.csv',
              '/content/drive/MyDrive/ICR_project/잡플래닛/jobplanet_진흥기업.csv',
              '/content/drive/MyDrive/ICR_project/잡플래닛/jobplanet_코오롱글로벌.csv',
              '/content/drive/MyDrive/ICR_project/잡플래닛/jobplanet_태영건설.csv',
              '/content/drive/MyDrive/ICR_project/잡플래닛/jobplanet_특수건설.csv',
              '/content/drive/MyDrive/ICR_project/잡플래닛/jobplanet_한신공영.csv',
              '/content/drive/MyDrive/ICR_project/잡플래닛/jobplanet_한전KPS.csv',
              '/content/drive/MyDrive/ICR_project/잡플래닛/jobplanet_현대건설.csv',
              '/content/drive/MyDrive/ICR_project/잡플래닛/jobplanet_GS건설.csv',
              '/content/drive/MyDrive/ICR_project/잡플래닛/jobplanet_HDC현대산업개발.csv',
              '/content/drive/MyDrive/ICR_project/잡플래닛/jobplanet_HJ중공업.csv',
              '/content/drive/MyDrive/ICR_project/잡플래닛/jobplanet_KCC건설.csv']

len(file_paths)
# Out:
# 22

# %%
# CSV 파일을 담을 빈 리스트 생성
dataframes = []

# 각 파일 경로에 대해 파일을 읽어 데이터프레임으로 리스트에 추가
for file_path in file_paths:
    try:
        df = pd.read_csv(file_path, encoding='utf-8')
        dataframes.append(df)
    except UnicodeDecodeError:
        print(f"Unable to read file with detected encoding: {file_path}")

# 데이터프레임들을 행 방향으로 연결
df = pd.concat(dataframes, axis=0, ignore_index=True)

# 결과 확인
df.head()
# Out:
#         작성일         직무 재직 여부  지역  총점  승진 기회 및 가능성  복지 및 급여  업무와 삶의 균형  사내문화  \
# 0  2023. 11      엔지니어링   전직원  대전  80           80       80         60    80
# 1  2023. 10      인사/총무   전직원  대전  60           60       60         60    60
# 2  2023. 10  생산관리/품질관리   전직원  경기  20           20       20         20    20
# 3  2023. 09      인사/총무   전직원  경기  80           60      100         80    80
# 4  2023. 09      기획/경영   현직원  대전  60           80       60         60    60
#
#    경영진                          총평  \
# 0   80  업무환경은 힘들지만 만족도가 높으며 페이가 좋음
# 1   60  어떤 부사에 들어가느냐에 따라 회사생활이 달라짐
# 2   20      본사 위주의 안전관리 현장 신경 잘 안씀
# 3   80        아르바이트 환경으로는 나쁘지않은 기업
# 4   20      직원들 소리에 전혀 귀기울이지 않는 회사
#
#                                                   장점  \
# 0                     업무강도가 강하지만 그만큼 높은 급여를 기대할 수 있음
# 1                대전지역에 몇 없는  중견기업 중 하나 신입연봉치곤 괜찮은 연봉
# 2  연차 자유롭게 사용 가능 함 다만 현장이 바쁠때는 사용 불가 팀장이랑 조율 해야함 ...
# 3  제공되는 중식으로 식비를 절약할수있음 자유로운 휴식시간과 단순한 문서보조 작업만 해...
# ...

# %%
# 데이터프레임 칼럼 확인
df.columns
# Out:
# Index(['작성일', '직무', '재직 여부', '지역', '총점', '승진 기회 및 가능성', '복지 및 급여', '업무와 삶의 균형',
#        '사내문화', '경영진', '총평', '장점', '단점', '바라는점', 'Unnamed: 0'],
#       dtype='object')

# %%
# 필요 없는 칼럼(Unnamed: 0) 제거
df = df.drop(columns=['Unnamed: 0'])
df.head(1)
# Out:
#         작성일     직무 재직 여부  지역  총점  승진 기회 및 가능성  복지 및 급여  업무와 삶의 균형  사내문화  경영진  \
# 0  2023. 11  엔지니어링   전직원  대전  80           80       80         60    80   80
#
#                            총평                              장점  \
# 0  업무환경은 힘들지만 만족도가 높으며 페이가 좋음  업무강도가 강하지만 그만큼 높은 급여를 기대할 수 있음
#
#                                단점                  바라는점
# 0  현장에서 하는 일이다보니 몸이 힘들고 삶의 여유가 없음  더 좋은 회사로 성장하길 바라겠습니다

# %%
# csv 파일로 저장
df.to_csv('jobplanet_concat.csv', encoding = 'utf-8-sig', index=False)
